# %%
#import all the necessary packages

import pandas as pd
import random

import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk import stem
stemmer = stem.PorterStemmer()
from nltk import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))
import string
punct = list(string.punctuation)
from collections import Counter
import requests
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import numpy as np
import praw
import datetime
import json
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import PyPDF2

# %%
# open the PDF file
policy = open(r'C:\Users\aoife\Documents\Capstone\Capstone Quant Policies\Liverpool John Moores Disability.pdf', 'rb')

# create a PDF reader object
pdf_reader = PyPDF2.PdfReader(policy)

# %%
# read the text from each page
text = ''
for page_num in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[page_num]
    text += page.extract_text()

# close the PDF file
policy.close()

# %%
# split the text into sentences
sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)

# create a dataframe with the sentences as rows
df = pd.DataFrame({'Sentence': sentences})

# %%
df
# Out:
#                                               Sentence
# 0     \n \n \nDisability  Policy (Students) – \nPro...
# 1    \nDate introduced:  January 2012  \nDate(s) mo...
# 2     \nA wide range of provision is available to s...
# 3     \n \nThis policy sets out how LJMU meets its ...
# 4     \nIt identifies the University’s approach to ...
# ..                                                 ...
# 220   Students who fail to attend their \nassessmen...
# 221     \n \nA budget will be established to ensure...
# 222   \nIrlen Syndrome/Scotopic Sensitivity  \nFund...
# 223   Coloured overlays \ncan be purchased to assis...
# 224                                        \n   \n \n
#
# [225 rows x 1 columns]

# %%
#check to see if any rows are empty
rows_with_nan = df[df.isna().any(axis=1)]

len(rows_with_nan)
# Out:
# 0

# %%
#check the length of the dataframe
len(df)
# Out:
# 225

# %%
# convert each row in the dataframe to a string and then convert the datadrame to a list of strings
p1 = df.apply(lambda row: ' '.join(row.astype(str)), axis=1).tolist()

# %%
p1
# Out:
# [' \n \n \nDisability  Policy (Students) – \nProvision of support  \n \nResponsibility for Policy:  University Registrar and Chief Operating \nOfficer  \nRelevant to:  All LJMU Staff and Students  \nApproved by:  Academic Board, 11 March 2020  \nResponsibility for Document \nReview:  Director, Student Advice and Wellbeing \nServices .',
#  '\nDate introduced:  January 2012  \nDate(s) modified:  February 2016 , February 2020  \nNext Review Date:  February 2023  \n \nRELEVANT DOCUMENTS  \n\uf0b7 Equality Act 2010  \n\uf0b7 Special Educational Needs and Disability Act 2001  \n\uf0b7 Disability Discrimination Act 1995  \n\uf0b7 Public Sector Bodies (Website and Mobile Applications) Accessibility \nregulations 2018  \n \n \nRELATED POLICIES & DOCUMENTS  \n\uf0b7 LJMU Equality and Diversity policy  \n\uf0b7 SCP2 Evacuation Procedures  \n\uf0b7 SCP37 Personal Emergency Evacuation Plans  \n\uf0b7 Student Complaints Procedure  \n\uf0b7 Fitness to Study policy  \n\uf0b7 Fitness to Practice Policy  \n\uf0b7 Academic Framework  \n\uf0b7 Code of Practice for Placements  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nPolicy for the provision of reasonable adjustments and support for Disabled \nstudents  \n \n \n \n1 Introduction  \n \nLiverpool John Moores University (LJMU) is committed to providing an inclusive \nand accessible environment which enables all students to reach their potentia l.',
#  ' \nA wide range of provision is available to support students including specialist \nsupport, support through academic faculties , departments  and schools, and \nappropriate policies and procedures.',
#  ' \n \nThis policy sets out how LJMU meets its obligations under th e Equality Act 2010.',
#  ' \nIt identifies the University’s approach to supporting disabled students and \nformalises areas of responsibility.',
#  ' The policy is supported by the procedures \nwithin this document either appended or referenced.',
#  ' \n2 Duty to Make Reasonable A djustments  \n \n2.1 As provided for by the Equality Act 2010, LJMU has a duty to make reasonable \nadjustments for disabled students and this duty has been further highlighted by \nthe changes made to the Disabled Students Allowance (DSA ).',
#  '  \n2.2 The duty to make reasonable adjustments requires institutions to ensure that \nthey have anticipated and taken reasonable steps to address barriers which put \ndisabled students at a substantial disadvantage in relation to a relevant matter \nwhen compared to no n-disabled students.',
#  ' In particular there is a requirement on \ninstitutions, under new DSA regulations, to ensure that the provision of non -\nmedical help is available where appropriate.',
#  ' \n2.3 This provisions applies to delivery of LJMU business within the UK.',
#  ' \n2.4 The intention  is that the learning environment should be as inclusive as possible, \nso that individual interventions are the exception, not the rule.',
#  ' \n \n2.5 Institutional responsibility  \nLJMU wishes to maintain an environment in which disabled students are  able to \nfully participate in the student experience and will therefore take all reasonable \nsteps to ensure that disabled students  \n\uf0b7 Have access to appropriate learning and teaching support, for mandatory \nelements of academic programmes  (Mandatory refers t o elements of the \ncourse that are required in order to successfully achieve the target award \nand will include both core and optional modules) .',
#  '\n\uf0b7 Are able to access the estate and buildings utilised in the provision of \nteaching and learning and associated s ervices.',
#  ' \n\uf0b7 Have access to specialist staff who are able to advise on the range and \nextent of provision available throughout the institution.',
#  ' \n\uf0b7 Have documented support plans in place, including where appropriate for \na period of placement.',
#  '  \n\uf0b7 Can access IT facilities and services.',
#  ' \uf0b7 Are able to access learning materials in a timely manner, whether in \nhardcopy, electronic or other formats.',
#  ' \n\uf0b7 Are able to access additional support, which may or may not be \nrepresented in a formal needs assessment, in the form of  non-medical \nhelp*.',
#  ' \n\uf0b7 Have access to quiet or less formal environments to enable students to \nhave time away should they require it.',
#  ' \n \n(*Non -medical help is defined as the provision of support assistants, such as scribe, \nreader, lab assistant etc, and Enhanced Support Assistants, such as examination \nsupport workers, notetakers, study assistant.',
#  ' These were previously identified as \nBand 1 and Band 2 NMH Support) .',
#  '\n \n3 Scope  \n3.1 This policy addresses all aspects of support for disabled applicants and students at \nLJMU.',
#  ' \n3.2 This policy applies to all students studying with LJMU, within the UK, regardless of \nmode of study.',
#  '  However, students on s hort, professional CPD courses will be \nadvised and assessed based on the duration and intensity of their study.',
#  ' \n3.3 The principles of this policy apply to all cohorts.',
#  ' Students who disclosed or declared \na disability to the University prior to September 20 15 may have their needs met \nusing a slightly different process, due to changing external student finance \narrangements.',
#  ' \n \n4 Responsibilities  \nThis section outlines the roles an d responsibilities of key areas across the \ninstitution.',
#  ' It does not contain operational detail of these responsibilities.',
#  ' Further \ninformation about relevant procedures should be available from the relevant areas, \nand/or from the Disability team, within S tudent Advice and Wellbeing services.',
#  ' \n \n4.1  ELT are responsible for the University’s strategy with regards to disabled students, \nensuring compliance with the Equality Act 2010 and regulating the associated \nresource to fund support for disabled students.',
#  ' \n4.2 Equality,  Diversity  and Inclusivity  Committee  are responsible for reviewing \ncompli ance with this policy, requesting  appropriate changes and making \nrecommendations to EL T for amendments to policy and practice.',
#  ' \n4.3 Director of Student Advice and Wellbeing services  is responsible for advising \nthe University about strategy and policy in relation to disabled students and \nidentifying the impact of changes in the external environment on University \nprovision.',
#  ' S/he is also responsible  for ensuring that appropriate contracts are in \nplace for the provision of support workers, and holds the Disability budget to ensure \nadditional reasonable adjustments can be made, where other sources of funding are \nnot available.',
#  ' \n4.4 The Student Support M anager  is responsible for ensuring that students are aware \nof the support available to them through the Disability team.',
#  ' Once students have \ndeclared a disability, the Student Support Manager is responsible for ensuring that \nthey have an appropriate Indivi dual Student Learning Plan (ISLP), which identifies \nrelevant inclusive approaches to provision and, where appropriate, identifies anticipatory and individual reasonable adjustments to reduce barriers to the \nstudents’ participation in their academic program me.',
#  '\n4.5 The Disability team  are responsible for engaging with and receiving consent from \nstudents in order that they can create, store and/or communicate  the ISLP  (and \nassociated documents)  to all relevant parties and are responsible for providing \nadvice t o students and staff on disability related matters.',
#  '  The Disability team will \nstore the master copy of an individual student’s ISLP, and a copy will be sent to the \nstudent and the relevant Disability Coordinator.',
#  ' The Disability team also covers \nSpecialist Study Skills tutors who work directly with students.',
#  ' \n4.6 Directors of School/Heads of Department  are responsible for en suring that an \nISLP is effectively communicated  within the school or department and for the health \nand safety of disabled students includ ing ensuring that disabled students who \nrequire one, have a Personal Emergency Evacuation Plan  (PEEP) .',
#  ' They are also \nresponsible for ensuring that reasonable adjustments are in place for assessments \norganised within the department/school including in -class tests.',
#  ' Directors/Heads \nhave a responsibility to ensure that all teaching and learning materials and practices \nwithin  their areas meet the agreed  needs of disabled students.',
#  ' Directors/Heads are \nalso responsible for ensuring that their staff are aware of  this policy and the \navailability and remit of Student Advice and Wellbeing service s including the \nDisability team.',
#  ' \n4.7 Disability Coordinators (DisCo) are school and faculty based staff with \nresponsibility for ensuring relevant academic and admin istrative  staff are aware of \nstudent s support needs and for coordinating school based support.',
#  '(See appendix 1 \nfor the Disability Coordinator role descriptor)  \n4.8 Programme Leaders  are responsible for reviewing the curriculum of their \nprogrammes and identifying app ropriate inclusive approaches.',
#  '  \n4.9 Module Leaders  have a responsibility to be aware of which students on the module \nrequire reasonable adjustments and ensuring that programme colleagues are aware \nof the requirements.',
#  ' This information is available from t he DisCo and Programme \nLeaders in each school/department.',
#  ' \n4.10 Personal tutors  have a responsibility to be aware of which students within their \ntutee group require reasonable adjustments and to ensure that students are aware \nof the support available to the m.',
#  '\n4.11 All Programme staff  are responsible for implementing relevant reasonable \nadjustments as detailed within the student’s ISLP.',
#  '  The ISLP will be created as per \nSection 6 of this policy and in consultation between all relevant parties.',
#  ' \n4.12 The Directo r of Library services  is responsible for ensuring that disabled \nstudents are able to access all Library provision, and that they have the appropriate \nlevel of support and training.',
#  ' \n4.13 The Director of Student Advancement  is responsible for ensu ring that the \nservices delivered are appropriate to the needs of disabled students and graduates.',
#  ' \nS/he is also responsible for ensuring that the Code of Practice for Placements \naddresses the needs of disabled students.',
#  ' \n4.14 The Director of IT Services  is responsible for ensuring appropriate accessible \nsoftware and hardware is available for disabled students, including training on such \nequipment.',
#  ' S/he is also responsible for ensuring that all University corporate \nsystems , including the website, are inclusi ve and accessible.',
#  '  \n4.15 The Director s of Estates and Facilities Management  are responsible for \nensuring the University campus, including all University buildings, is physically accessible and that accessibility equipment and ergonomic furniture is manag ed \neffectively.',
#  ' S/he is also responsible for ensuring that campus services, such as \nparki ng and catering, are accessible and that timetabling i ssues are addressed \neffectively, including the availability of quiet spaces .',
#  ' \n4.16 The Accommodation Manager  is responsible for ensuring appropriate \naccessible accommodation is available through University partner Accommodation \nproviders to meet the needs of students.',
#  ' This is a sha red responsibility with the \nDirector  of Student Advice and Wellbeing services, and is  identified as a critical \nfactor in the contractual obligations outlined to providers.',
#  ' \n4.17 The Head of Operations  in each Faculty is responsible for ensuring that \nappropriate inclusive approaches and anticipatory and individual reasonable \nadjustments are available for formal examination and assessment periods, whilst \nworking within the University policy on Assessment and examination provisions \n(Appendix 2).',
#  ' The Head of Operations would also be responsible for resolving \nissues related to timetables and an individual ’s access needs.',
#  ' \n4.18 The Head of Academic Quality services  is responsible for ensuring that \naccessibility and inclusive practice are considered as part  of the module approval \nprocess, including appropriate consultation during course validation.',
#  ' \n4.19 The Dean  of the Learning and Teaching Academy  is responsible for updating \nappropriate information, including Regulations in Practise, and other publications on \ninclusive practices in higher education.',
#  '  There is al so a responsibility here  to ensure \nthat the institutional Virtual Learning Environment meets appropriate inclusivity \nrequirements.',
#  ' \n4.20 The Director of  Corporate Communications  and Stakeholder Engagement  \nis responsible for ensuring that all commun ications  produced by the Universi ty are \naccessible.',
#  ' \n4.21 The Director of Student Recruitment and Admissions  is responsible for \nensuring that University events such as open days are accessible to all participants \n(including visitors) , and that appropriate pre -entry disclos ure of disability is \nforwarded to the Disability team .',
#  ' Pre-entry disclosure processes will be applied to \nall levels and categories of students to ensure consistency.',
#  ' \n4.22 The Director of International Relations  is responsible  for ensuring that \nstudents who wish to participate in Study Abroad opportunities are able to declare a \ndisability, if not already known to the University.',
#  ' S/he is responsible for working with \nthe relevant teams within Student Advice and Wellbeing service s, the student and \nrelevant academic department to identify what adjustments are appropriate and \nreasonable within the context of a specific study abroad opportunity.',
#  ' \n4.23 The Academic Registrar  is responsible  for ensuring effective facilitation of \ndisclos ure of disability during the registration and enrolment processes.',
#  ' \n4.24 The Director of Human Resources , through th e Equality and Diversity \nManager , is responsible for ensuring relevant training and development \nopportunities related to issues of equality a nd diversity are available to staff.',
#  ' \n4.25 The Counselling Manager and Mental Wellbeing Advisor s are responsible \nfor ensuring appropriate provision of support to students with mental health \ndifficulties.',
#  ' \n4.26 The Occupational Health team  is responsible for assessing, at enrolment, \nwhether those students attending regulated, vocational programmes are suitable to \ncommence training and are likely to be fit to practice on completion of their studies, \nin accordance with guidance from relevant regulatory bodies.',
#  ' In addition, the Occupational Health team will advise programme leaders where students on \nregulated, vocational programmes have declared a disability, impairment or health \ncondition if they may need any adjustments to the training programme or \nprogramme of  study on medical grounds.',
#  ' The programme leader will liaise through \nthe DisCo with the Disability team if there is a need to clarify whether adjustments \nrecommended are considered to be reasonable in the circumstances of the \nindividual.',
#  ' \n4.27 Heads of all other departments  are responsible for ensuring that their \nprovisions are as accessible as possible, e.g. provision of alternative formats.',
#  ' \n4.28 The Manager of Health, Safety and Environment  Services  is responsible for \nensuring procedures for Person al Emergency Evacuation Plans are  available on the \nUniversity  intranet and for maintaining up -to-date evacuation  procedures covering \nall University buildings .',
#  ' S/he is responsible for training evacuation chair operators \nin the safe use of equipment to assi st persons with mobility impairments in an \nevacuation situation and for publishing up to date lists of such people, and first \naiders, on a building by building basis on the intranet.',
#  ' \n4.29 All students and applicants  have a responsibility to inform the Univ ersity, in a \ntimely manner, of their disability or medical condition in order that support can be \nprovided.',
#  ' \n \n5 Objectives  \n5.1 The University observes the social model of disability which views disability as    \nbeing  created by barriers within society rather than by the disability itself.',
#  ' Barriers \ncan be in the physical environment such as inaccessible buildings or services; \nattitudinal resulting in stereotypes; prejudices and assumptions about the \ncapabilities of di sabled people; or organisational such as having inflexible policies \nand procedures.',
#  '   The University aims to address all of these barriers to ensure that \ndisabled people can participate in all aspects of University life.',
#  ' \n \n5.2 The University recognises its  responsibilities to make provision as accessible as \npossible and will aim to do this using inclusive approaches to provision and services \nor  anticipatory reasonable adjustments wherever possible.',
#  ' The University aims to \nidentify the most common barriers experienced by disabled students and, wherever \npossible, to identify appropriate anticipatory adjustments to overcome these \nbarriers.',
#  ' Where this is not possible and/or additional needs are identified the \nUniversity will seek to implement appropriate indiv idual reasonable adjustments.',
#  ' \nReasonable adjustments (individual and anticipatory) can be made to provisions or \npractices but not to competence standards.',
#  ' Competence standards are academic, \nmedical or other standards which are required for the programme.',
#  '  Competence \nstandards must be directly related to the learning outcomes of the programme.',
#  ' \nThere is therefore no requirement to alter the academic standards of a programme \nfor a disabled student.',
#  ' However, it may be necessary to adjust the way in which a \ncompetence standard is assessed.',
#  ' \n \n5.3 The University has specialist, targeted provision to support this approach.',
#  ' The \nDisability team is the key specialist service provided by the University.',
#  ' Specialists \nwithin this team understand the barriers which can  impact on students’ ability to \nengage with their academic studies and identify inclusive approaches, anticipatory \nand individual reasonable adjustments to enable individuals to participate fully in university life.',
#  ' On some occasions, this provision will also be informed by an \nexternal third party with appropriate specialist knowledge.',
#  ' \n \n5.4 Disability Coordinators (DisCos) in faculties and schools provide targeted academic \nsupport for disabled students.',
#  ' DisCos have discipline specific knowledge which \nenab les them to apply the reasonable adjustments in a proportionate and \nappropriate manner , in consultation with Programme and Module leaders .',
#  ' DisCos \nare also a local point of contact for staff and disabled students and will coordinate \nsupport within the facu lty or school.',
#  ' \n \n5.5 All students have access to a Personal Tutor who will signpost to relevant specialist \nservices within the University.',
#  ' \n \n6 Disclosing a disability to the University  \n6.1 Students are able to disclose a disability at any point during their time at the \nUniversity.',
#  ' \n6.2 All applicants to the University will be given the opportunity to disclose their \ndisability to the University, prior to commencement of a programme.',
#  ' \n6.3 All students on regulated, vocational programmes will be required to complete a \nhealth declaration prior to commencing their programme.',
#  ' This will include a \nrequirement to notify any disability which may impact on their ability to complete the \nprogramme.',
#  ' This will result in an assessment by the Occupational Hea lth team.',
#  ' \n6.4 Students and applicants will need to provide relevant consent for process to be \nfollowed and must engage fully in this process.',
#  ' \n6.5 The Disability team will contact all students who disclose a disability through \nrecruitment processes, prior t o their arrival in order that the support process can be \nin place for the beginning of the programme.',
#  ' \n6.6 Students will be given a further opportunity to disclose a disability during the \nregistration and enrolment process.',
#  ' \n6.7 All students on regulated, vo cational programmes who disclose a significant \ndisability to the Disability team, Programme Leaders or others will be referred to the \nOccupational Health team for assessment of the potential impact on study and \npractice.',
#  ' This may result in confirmation th at the Occupational Health team have \nalready addressed the issue or may result in a new assessment.',
#  ' \n6.8 If, during their period of study, a student becomes aware of a previously \nundiagnosed disability, they should contact the Disability team as soon as pos sible.',
#  ' \n6.9 If at any time, any member of staff becomes aware of serious concerns regarding a \nstudent on a regulated, vocational programme which might impact on their ability to \nmeet competence standards, the student must be referred for an occupational \nhealth assessment through the Program leader  utilising the Fitness to \nStudy/Practice policies.',
#  ' \n6.10 Students who wish  to discuss access to reasonable adjustments are advised to \ncontact the Disability team as early as possible.',
#  ' \n6.11 Students who wish to access  reasonable adjustments will be required to provide \nevidence of their disability.',
#  ' Further guidance on evidence can be obtained from the \nDisability team.',
#  ' Students with specific learning difficulties and/or dyslexia should \nrefer to the Specific Learning Di fficulties and Dyslexia guidance contained within \nAppendix 3.',
#  '  \n7 Guidance on the identification and implementation of Reasonable \nAdjustments  \n \n7.1 The University has a range of established, inclusive practices in place across the \ninstitution to ensure that students can access programmes.',
#  ' Information on these \ninclusive practices can be obtained from the Disability team or DisCos within \nindividual schools and faculties, and will be highlighted to students who disclose a \ndisability to the university by the Dis ability team.',
#  ' Inclusive, anticipatory approaches \nwill be accessible to all students in order that students who do not wish to disclose \nto the University, can also access appropriate provision.',
#  '  \n7.2 Whilst inclusive approaches and anticipatory adjustments  will meet many disabled \nstudents’ needs, some students will still require additional individual adjustments.',
#  ' \n7.3 The Disability  team is responsible for identifying individual reasonable adjustments \n(to programmes of study) for individual students, in con sultation with Programme \nleaders where appropriate, and within the wider University provision.',
#  'Programme \nteams will be responsible for ensuring that anticipatory adjustments to programmes \nof study are in place.',
#  ' If a student has an independent Assessment o f Needs report \nfor Disabled Students Allowance (DSA) purposes or an Educational Psychologist’s \nreport, the recommendations from these reports will be considered when identifying \nreasonable adjustments.',
#  ' The Disability team will firstly consider whether \nanticipatory adjustments will meet the specific needs of the individual student and \nthen whether individual reasonable adjustments are required.',
#  ' \n7.4 The Disability team, in consultation with academic colleagues, will consider a \nnumber of factors when deciding  whether an individual adjustment is reasonable.',
#  ' \nFactors may include, but not be limited to, the perceived effectiveness of the \nadjustment, the time or resource required to implement the adjustment, the \nstudent’s previous experience of the adjustment and whether the need could be met \nthrough an existing inclusive approach or anticipatory adjustment.',
#  ' The University is \nnot obliged to offer the student their preferred adjustment particularly if an inclusive \napproach or alternative adjustment is available whi ch would provide appropriate \nsupport for the student.',
#  ' (For information regarding the complaints process to be \nused when a student disagrees with a proposed reasonable adjustment see section \n7) \n \n7.5 Where appropriate, the Disability team will liaise with the DisCo to discuss whether \nan individual adjustment may conflict with the competence standards for the \nprogramme, and how this might be addressed within the ISLP.',
#  ' \n7.6 For students who are able to ac cess external funding for a reasonable adjustment, \nfor example through DSA, the University requires the student to access such \nfunding.',
#  ' The Disability team will provide guidance and advice on this process \nwhere necessary.',
#  ' Where external financial sources  are not available and the \nDisability team identify the adjustment to be reasonable, the University will seek to \nfund this adjustment, where possible.',
#  ' \n7.7 Annually, the Director  of Student Advice and Wellbeing services will set, in \nconjunction with the Stu dent Support Manager and the Disability team, an upper \nfinancial limit for individual reasonable adjustments.',
#  ' In the majority of cases, this \nwill ensure that reasonable adjustments can be put in place without onwards referral, and therefore ease the speed  of the process.',
#  ' Where the upper limit is \nbreeched, the Disability team  will refer the case to the Director  of Student Advice \nand Wellbeing services for review and agreeme nt, if appropriate.',
#  ' If the Director  of \nStudent Advice and Wellbeing does not think that the proposed adjustment is \nreasonable, s/he will discuss alternative options with the Disability team who may \nthen discuss these with the student before any adjustments are agreed.',
#  ' \n7.8 With the student’s consent, the Disability team will produce an In dividual Student \nLearning Plan (ISLP) for each student which identifies the inclusive approaches and \nreasonable adjustments required.',
#  ' The Disability team will then forward this \ndocument to the DisCo in the relevant academic school or faculty.',
#  ' \n7.9 Without consent, the Disability team will be unable to progress support for an \nindividual student.',
#  ' \n7.10 A copy of the ISLP will be sent to the relevant DisCo for appropriate circulation \nwithin the school/faculty .',
#  ' Programme leaders will be responsible for ensuring that \nall relevant academic colleagues are aware of the reasonable adjustment required \nfor students within their cohorts.',
#  ' \n7.11 The Disability team are responsible, when requested to by a student, for ma king \nreferrals to external agencies for support workers and should be considered the \nnamed contact for this element of provision.',
#  ' \n7.12 If a student does not think that the recommended reasonable adjustments have \nbeen implemented, s/he should raise this wit h the relevant DisCo in the first \ninstance.',
#  ' If the situation is not resolved through this approach, then the student \nshould contact the Disability team who will endeavour to work with the appropriate \nacademic area and find an appropriate solution.',
#  ' If the  student remains dissatisfied, \nthen s/he should make a complaint using the student complaints procedure.',
#  ' \n7.13 The impact and/or nature of a  student’s disability may change over the course of \ntheir period of study.',
#  ' This may result in the anticipatory suppo rt or reasonable \nadjustments no longer being appropriate.',
#  ' In such cases, the student should contact \nthe Disability team at the earliest opportunity to discuss the changes.',
#  ' The Disability \nteam will identify whether there are additional or alternate inclus ive approaches or \nreasonable adjustments needed.',
#  ' The process will then proceed as from 6.4 above.',
#  ' \n7.14 Occupational health are responsible for ensuring that students on regulated, \nvocational programmes are suitable to commence study and likely to be fit t o \npractice on completion of their studies.',
#  ' This requires them to meet the relevant \ncompetence standards for the profession with reasonable adjustments if required.',
#  ' \nAdjustments which may be reasonable in the context of study may not be \nreasonable in the c ontext of professional practice.',
#  ' Wherever possible, the fitness to \npractice of applicants who have declared a disability will be assessed prior to the \napplicant entering the University.',
#  ' The Occupational Health team, in liaison with the \nProgramme leader m ay make recommendations for reasonable adjustments.',
#  ' \n7.15 Assistance Animal s – The University’s Health and Safety policies require that \nonly assistance animals be allowed onto campus.',
#  ' For this purpose, therefore, only \nassist ance animals registered with an  appropriate professio nal standards body  will \nbe allowed into University buildings.',
#  ' If a request is made through the Disability \nteam, this information will be passed to the relevant DisCo and to the Health and \nSafety team as early as possible to allow for  adjustments, such as spending pens, \nto be made.',
#  ' The owner of the assistance animal will be asked for their permission to communicate this fact to other students in order that any other issues can be \ncircumvented in a timely manner (e.g. allergies).',
#  ' \nThe s tudent owner of the animal will remain responsible for the animal at all times.',
#  ' \n \n \n \n8    Complaints  \nIn the first instance, concerns regarding the appropriate and/or timely nature of \nprovision of support, should b e directed to the Director  of Student Advice and Wellbeing \nservices, for informal resolution.',
#  ' \nIf a student, having first  referred the matter to the Director  of Student Advice and \nWellbeing services, believes that they have not received the appropriate reasonable \nadjustments to ensure that they can  study effectively,  the  matter should be referred to \nthe Student Governance team to be addressed through the University’s S tudent \nComplaints procedure.',
#  ' This can be accessed using the following link \nhttps://www.ljmu.ac.uk/about -us/public -information/student -regulations/appeals -and-\ncomplaints   \n \n9 Related Policies  \nThe University has a number of policies designed to support all students, some of \nwhich may have particular relevance to disabled students .',
#  ' Links are provided to these \npolicies below.',
#  ' Please note, policies are updated on a regular basis and the latest \nversion of the document should be accessed in each case.',
#  ' \n\uf0b7 Special Examination Provision – appendix 2 of this policy  \n\uf0b7 Academic Framework po licy, Extenuating Circumstances  \n\uf0b7 Fitness to Study policy  \n\uf0b7 Fitness to Practise policy  \n\uf0b7 SCP2 Evacuation Procedures  \n\uf0b7 SCP37 Personal Emergency Evacuation Plans  \n\uf0b7 Student Complaints procedure  \n\uf0b7 Equality and Diversity Policy  \n \nAppendix 1  \nDisability Coordinator - Role Descriptor  \n \n \nIn order that students across LJMU can have access to an equitable service, the  \nDisability Coordinator role needs to be applied consistently across the institution.',
#  '  \nThe role descriptor is intended to give that consistency.',
#  ' \n \nIt is expected that Faculties, Departments and Schools will allocate an appropriate level  \nof resource,  to ensure the demands of this role can be met.',
#  ' The average should be 50  \nhours per academic year, but t his will vary depending on the number of disclosed  \ndisabled students within the sch ool and the complexity of such cases.',
#  '  A Faculty,  \nDepartment or School should al low for multiple individuals to undertake the DisCo role  \nif appropriate to local circumstance s.',
#  ' \nThe Disability Coordinator will:  \n\uf0b7 Act as a point of contact for students with a disability support need.',
#  ' \n\uf0b7 Act as a liaison point between the school/department and the Disability team.',
#  ' \n\uf0b7 Ensure that the disclosure of disability is actively encouraged and communicated \neffectively within the school/department, including from academic colleagues to \nthe Disability team, and in reverse where appropriate.',
#  ' \n\uf0b7 Liaise with relevant colleagues within  the University regarding any issues \nrelating to the support of disabled students.',
#  ' \n\uf0b7 Raise awareness within the school/department of issues facing students with \ndisabilities and the academic implications this may have.',
#  ' \n\uf0b7 Work with standard procedures acros s the institution to ensure that all issues of \ndisclosure, distribution of ISLPs and related issues are dealt with in a consistent \nand systematic manner, including communication with relevant academic \ncolleagues.',
#  ' \n\uf0b7 Assist the Director/Head of School/Depart ment to ensure that a robust ISLP \nrecords system is in operation throughout the school.',
#  ' \n\uf0b7 Coordinate and support School/department based training, development and \nawareness raising activities for disability support, liaising with relevant \nProfessional serv ices staff (Disability Support/Equal Opportunities).',
#  ' \n\uf0b7 Contribute to and update Disability Support infor mation on the Faculty  \ncommunity sites.',
#  ' \n\uf0b7 Regularly attend meetings of the University DisCo Steering Group, and cascade \nrelevant information within the s chool or faculty.',
#  ' \n\uf0b7 Provide support and advice on disability matters to school colleagues, ensuring \nthat concerns are referred effectively.',
#  ' \n.',
#  '\n \nAppendix 2  \nAdditional Examination Provision  \nIn certain situations, it is appropriate for the University to suppor t students through \nformal examinations with reasonable adjustments.',
#  ' This policy document outlines the \nprovision, the criteria and the reasonable adjustments that may be put into place.',
#  ' \nProvision available  \nAll provision will be facilitated through the ISLP  \n\uf0b7 Extra time – this will be available for all students able to demonstrate need, \nwithin the main sitting of the exam (unless combined with additional reasonable \nadjustments)  \n\uf0b7 A Reader – this will provided using IT facilities within each faculty and will be \npre-recorded by a member of staff familiar with the terminology used.',
#  ' \n\uf0b7 Amanuensis – this facility will be offered in a separate space(*) from the main \nsitting  \n\uf0b7 Rest Breaks – this facility will be offered in a separate space (*) from the main \nsitting  \n(*) In all cases where a separate location may be needed, it would also be appropriate \nfor academic colleagues to consider alternative assessment.',
#  ' It may be that the \nlearning outcomes can be addressed via an alternative method of assessment and this \nshould  be discussed as early as possible in the academic year.',
#  ' Eligibility for Additional examination provision (AEP)  \nStudents must have disclosed a disability, medical condition or specific learning \ndifficulty to the University as soon as possible after diagno sis or enrolment at the \ninstitution (whichever occurs first) and in advance of the assessment period, as per the \nprocess below.',
#  ' \n\uf0b7 Eligibility for AEP will be documented in the form of a formal Individual Student \nLearning Plan or a Needs Assessment document .',
#  ' No other evidence will be \naccepted.',
#  ' \n\uf0b7 In the event of a temporary or newly disclosed disability, a doctor’s letter will be \nacceptable and provision will be put into place for the impending assessment \nperiod, but will not continue for the duration of the  course.',
#  ' \nPlease note, applications received after the 4 week (20 working days) deadline  \n(referred to in Process, below) will not be considered for the immediate assessment \nperiod, but will be actioned prior to subsequent periods.',
#  ' \nPlease note, at the end of  each assessment period, a review will be carried out by \nFaculty Examination officers and any students who do not take up the provision \nallocated to them, will be asked to review this position.',
#  ' This may result in the provision \nbeing withdrawn.',
#  ' \nProcess  \nThe AEP application form will be available at \nhttps://myservices.ljmu.ac.uk/Forms/AdditionalExamProvisions.aspx   .',
#  'The form  should be completed \nand submitted online.',
#  '  \nThe completed form will be sent to the appropriate Facu lty, where access will be \nrestricted to a small number of staff, working on a need to know basis.',
#  ' \nApplications for AEP should be made as early as possible and no later than 4 weeks  \n(20 working days)  prior to the start of the assessment period.',
#  ' \nAn applicat ion for AEP will remain in place for the entirety of the student’s course and \ntherefore there is no requirement for submission every year.',
#  '  However, should AEP be \nin place but not utilised, this  may result in withdrawal of this provision .',
#  ' N.B Flexibility \nwill be needed with extra time as this may not be used at every opportunity but the \nstudent may still wish to retain it.',
#  ' Faculty Examinations staff will review usage at the \nend of each assessment period and contact students accordingly.',
#  ' \n\uf0b7 If, at review, a student states that they no longer  need the provision, this \nshould  be reported in writing and appended to the ISLP.',
#  ' The provision \ncan be cancelled, and a copy of the correspondence sent to the Disability \nteam for completeness.',
#  ' \n\uf0b7 If, at r eview, a student states that they do still require  the provision, \nprovision will be kept in place for a subsequent assessment period.',
#  ' If at \nthe end of the second period , provision has not been utilised, the \nUniversity will withdraw the provision.',
#  ' Faculty  staff should send written \nconfirmation of this to the Disability team.',
#  ' \nFaculty administration staff will contact students ahead of the assessment period(s) \neach year to update module choice and ascertain if provision is still needed.',
#  ' \n  \nAppendix 3  \nLJMU Spe cific Learning Difficulties and Dyslexia Policy  \n \nBackground  \nInstitutions are expected to ensure that provision and support is available both within \nthe curriculum and generally through learning and teaching methods.',
#  ' \nLJMU will ensure that anticipatory adjustments and provision for students with mild \ndyslexia is incorporated into the learning environment and therefore should not need to \nbe individually addressed.',
#  ' Provision for those students with moderate to severe SpL d \nand Dyslexia will continue to be addressed individually.',
#  ' \nLJMU complies with the Equality Act (2010), the Disability Discrimination Act (1995) \nand Special Educational Needs & Disability Act (2001) in ensuring that all students are \nable to access the provi sion of education and associated services.',
#  ' The inclusion of the \nanticipatory duty ensures that the institution continues to review policy and procedure \nregularly and through student partnership.',
#  '  \nThis policy is part of the wider institutional policy on D isability provision for students  \n \nDiagnostic  Support  \nIt is anticipated that the majority of students coming into higher education will have \nreceived appropriate support and assessment whilst in primary or secondary education.',
#  ' \nIn the event of students not  having received such an assessment,  or not having the  \nappropriate level of assessment,  LJMU will m ake available a formal assessment .',
#  ' \nProvision of support  \nEligibility for formal Educational Psychologists assessment  \n\uf0b7 Undergraduate and post -graduate.',
#  ' \n\uf0b7 Studying on a programme with a duration of an academic year  or longer  \n\uf0b7 First language must be English  (defined as educated in the UK from the age of \n7).',
#  ' Translations of assessment reports will be accepted for the provision of \nsupport but due to the inab ility of the tests to assess dyslexia versus language \nissues, we are unable to assess those with another first language.',
#  ' \n\uf0b7 Student attending a course with a collaborative partner should access support \nthrough the provider college.',
#  ' \n\uf0b7 Internal Screening exer cise results in a possibility of moderate to severe dyslexia  \n \nFunding implications  \nThere is a cost associated with each Educational Psychologist’s report.',
#  ' Students are \nexpected to meet the eligibility criteria above, and to ensure that they inform LJMU, a t \nleast 24 hours in advance, if they unable to attend the assessment meeting.',
#  ' Students \nwill be responsible for 50% of the charge due for an assessment.',
#  ' LJMU will meet the  \nremaining  costs of each assessment up to an annual pre -determined maximum.',
#  ' Students will be reminded of appointments through a variety of timely media, such as \nemail, SMS text, outlook appointments and so on.',
#  ' Students who fail to attend their \nassessment appointment w ill be charged the full  fee incurred by the university , through  \nthe usual charging mechanisms within the University.',
#  '   \n \nA budget will be established to ensure that this is not a ‘first come, first served’ budget \nposition, but is based on need.',
#  ' \nIrlen Syndrome/Scotopic Sensitivity  \nFunding will be made available for stu dents to receive this test should it be deemed \nappropriate, through the Educational Psychologist’s ass essment.',
#  ' Coloured overlays \ncan be purchased to assist students, rather than the provision of pastel paper.',
#  ' \n   \n \n ']

# %%
# define a function to remove punctuation and numbers from a string
def remove_punctuation_and_numbers(text):
    # define a regular expression pattern to match punctuation characters and numbers
    pattern = r'[^A-Za-z\s]'
    # replace punctuation characters and numbers with an empty string
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

# apply the previously created function to each string in the list
cleaned_p1 = [remove_punctuation_and_numbers(string) for string in p1]

# display the cleaned list of strings
print(cleaned_p1)
# Out:
# [' \n \n \nDisability  Policy Students  \nProvision of support  \n \nResponsibility for Policy  University Registrar and Chief Operating \nOfficer  \nRelevant to  All LJMU Staff and Students  \nApproved by  Academic Board  March   \nResponsibility for Document \nReview  Director Student Advice and Wellbeing \nServices ', '\nDate introduced  January   \nDates modified  February   February   \nNext Review Date  February   \n \nRELEVANT DOCUMENTS  \n Equality Act   \n Special Educational Needs and Disability Act   \n Disability Discrimination Act   \n Public Sector Bodies Website and Mobile Applications Accessibility \nregulations   \n \n \nRELATED POLICIES  DOCUMENTS  \n LJMU Equality and Diversity policy  \n SCP Evacuation Procedures  \n SCP Personal Emergency Evacuation Plans  \n Student Complaints Procedure  \n Fitness to Study policy  \n Fitness to Practice Policy  \n Academic Framework  \n Code of Practice for Placements  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nPolicy for the provision of reasonable adjustments and support for Disabled \nstudents  \n \n \n \n Introduction  \n \nLiverpool John Moores University LJMU is committed to providing an inclusive \nand accessible environment which enables all students to reach their potentia l', ' \nA wide range of provision is available to support students including specialist \nsupport support through academic faculties  departments  and schools and \nappropriate policies and procedures', ' \n \nThis policy sets out how LJMU meets its obligations under th e Equality Act ', ' \nIt identifies the Universitys approach to supporting disabled students and \nformalises areas of responsibility', ' The policy is supported by the procedures \nwithin this document either appended or referenced', ' \n Duty to Make Reasonable A djustments  \n \n As provided for by the Equality Act  LJMU has a duty to make reasonable \nadjustments for disabled students and this duty has been further highlighted by \nthe changes made to the Disabled Students Allowance DSA ', '  \n The duty to make reasonable adjustments requires institutions to ensure that \nthey have anticipated and taken reasonable steps to address barriers which put \ndisabled students at a substantial disadvantage in relation to a relevant matter \nwhen compared to no ndisabled students', ' In particular there is a requirement on \ninstitutions under new DSA regulations to ensure that the provision of non \nmedical help is available where appropriate', ' \n This provisions applies to delivery of LJMU business within the UK', ' \n The intention  is that the learning environment should be as inclusive as possible \nso that individual interventions are the exception not the rule', ' \n \n Institutional responsibility  \nLJMU wishes to maintain an environment in which disabled students are  able to \nfully participate in the student experience and will therefore take all reasonable \nsteps to ensure that disabled students  \n Have access to appropriate learning and teaching support for mandatory \nelements of academic programmes  Mandatory refers t o elements of the \ncourse that are required in order to successfully achieve the target award \nand will include both core and optional modules ', '\n Are able to access the estate and buildings utilised in the provision of \nteaching and learning and associated s ervices', ' \n Have access to specialist staff who are able to advise on the range and \nextent of provision available throughout the institution', ' \n Have documented support plans in place including where appropriate for \na period of placement', '  \n Can access IT facilities and services', '  Are able to access learning materials in a timely manner whether in \nhardcopy electronic or other formats', ' \n Are able to access additional support which may or may not be \nrepresented in a formal needs assessment in the form of  nonmedical \nhelp', ' \n Have access to quiet or less formal environments to enable students to \nhav ...

# %%
# tokenize each string in the list of strings
tokenized_p1 = [word_tokenize(string) for string in cleaned_p1]

# display the tokenized list of strings
print(tokenized_p1)
# Out:
# [['Disability', 'Policy', 'Students', 'Provision', 'of', 'support', 'Responsibility', 'for', 'Policy', 'University', 'Registrar', 'and', 'Chief', 'Operating', 'Officer', 'Relevant', 'to', 'All', 'LJMU', 'Staff', 'and', 'Students', 'Approved', 'by', 'Academic', 'Board', 'March', 'Responsibility', 'for', 'Document', 'Review', 'Director', 'Student', 'Advice', 'and', 'Wellbeing', 'Services'], ['Date', 'introduced', 'January', 'Dates', 'modified', 'February', 'February', 'Next', 'Review', 'Date', 'February', 'RELEVANT', 'DOCUMENTS', 'Equality', 'Act', 'Special', 'Educational', 'Needs', 'and', 'Disability', 'Act', 'Disability', 'Discrimination', 'Act', 'Public', 'Sector', 'Bodies', 'Website', 'and', 'Mobile', 'Applications', 'Accessibility', 'regulations', 'RELATED', 'POLICIES', 'DOCUMENTS', 'LJMU', 'Equality', 'and', 'Diversity', 'policy', 'SCP', 'Evacuation', 'Procedures', 'SCP', 'Personal', 'Emergency', 'Evacuation', 'Plans', 'Student', 'Complaints', 'Procedure', 'Fitness', 'to', 'Study', 'policy', 'Fitness', 'to', 'Practice', 'Policy', 'Academic', 'Framework', 'Code', 'of', 'Practice', 'for', 'Placements', 'Policy', 'for', 'the', 'provision', 'of', 'reasonable', 'adjustments', 'and', 'support', 'for', 'Disabled', 'students', 'Introduction', 'Liverpool', 'John', 'Moores', 'University', 'LJMU', 'is', 'committed', 'to', 'providing', 'an', 'inclusive', 'and', 'accessible', 'environment', 'which', 'enables', 'all', 'students', 'to', 'reach', 'their', 'potentia', 'l'], ['A', 'wide', 'range', 'of', 'provision', 'is', 'available', 'to', 'support', 'students', 'including', 'specialist', 'support', 'support', 'through', 'academic', 'faculties', 'departments', 'and', 'schools', 'and', 'appropriate', 'policies', 'and', 'procedures'], ['This', 'policy', 'sets', 'out', 'how', 'LJMU', 'meets', 'its', 'obligations', 'under', 'th', 'e', 'Equality', 'Act'], ['It', 'identifies', 'the', 'Universitys', 'approach', 'to', 'supporting', 'disabled', 'students', 'and', 'formalises', 'areas', 'of', 'responsibility'], ['The', 'policy', 'is', 'supported', 'by', 'the', 'procedures', 'within', 'this', 'document', 'either', 'appended', 'or', 'referenced'], ['Duty', 'to', 'Make', 'Reasonable', 'A', 'djustments', 'As', 'provided', 'for', 'by', 'the', 'Equality', 'Act', 'LJMU', 'has', 'a', 'duty', 'to', 'make', 'reasonable', 'adjustments', 'for', 'disabled', 'students', 'and', 'this', 'duty', 'has', 'been', 'further', 'highlighted', 'by', 'the', 'changes', 'made', 'to', 'the', 'Disabled', 'Students', 'Allowance', 'DSA'], ['The', 'duty', 'to', 'make', 'reasonable', 'adjustments', 'requires', 'institutions', 'to', 'ensure', 'that', 'they', 'have', 'anticipated', 'and', 'taken', 'reasonable', 'steps', 'to', 'address', 'barriers', 'which', 'put', 'disabled', 'students', 'at', 'a', 'substantial', 'disadvantage', 'in', 'relation', 'to', 'a', 'relevant', 'matter', 'when', 'compared', 'to', 'no', 'ndisabled', 'students'], ['In', 'particular', 'there', 'is', 'a', 'requirement', 'on', 'institutions', 'under', 'new', 'DSA', 'regulations', 'to', 'ensure', 'that', 'the', 'provision', 'of', 'non', 'medical', 'help', 'is', 'available', 'where', 'appropriate'], ['This', 'provisions', 'applies', 'to', 'delivery', 'of', 'LJMU', 'business', 'within', 'the', 'UK'], ['The', 'intention', 'is', 'that', 'the', 'learning', 'environment', 'should', 'be', 'as', 'inclusive', 'as', 'possible', 'so', 'that', 'individual', 'interventions', 'are', 'the', 'exception', 'not', 'the', 'rule'], ['Institutional', 'responsibility', 'LJMU', 'wishes', 'to', 'maintain', 'an', 'environment', 'in', 'which', 'disabled', 'students', 'are', 'able', 'to', 'fully', 'participate', 'in', 'the', 'student', 'experience', 'and', 'will', 'therefore', 'take', 'all', 'reasonable', 'steps', 'to', 'ensure', 'that', 'disabled', 'students', 'Have', 'access', 'to', 'appropriate', 'learning', 'and', 'teaching', 'support', 'for', 'mandatory', 'elements', 'of', 'academic', 'programmes', 'Mandatory', 'refers', 't', 'o', 'elemen ...

# %%
# as some strings are now empty, remove empty strings from a list of strings
cleaned_list_of_strings = [string for string in tokenized_p1 if string]

# and just in case that doesn't work,, remove empty strings from a list of lists of strings
cleaned_tokenized_p1 = [[token for token in tokens if token] for tokens in tokenized_p1]

# %%
cleaned_tokenized_p1
# Out:
# [['Disability',
#   'Policy',
#   'Students',
#   'Provision',
#   'of',
#   'support',
#   'Responsibility',
#   'for',
#   'Policy',
#   'University',
#   'Registrar',
#   'and',
#   'Chief',
#   'Operating',
#   'Officer',
#   'Relevant',
#   'to',
#   'All',
#   'LJMU',
#   'Staff',
#   'and',
#   'Students',
#   'Approved',
#   'by',
#   'Academic',
#   'Board',
#   'March',
#   'Responsibility',
#   'for',
#   'Document',
#   'Review',
#   'Director',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'Services'],
#  ['Date',
#   'introduced',
#   'January',
#   'Dates',
#   'modified',
#   'February',
#   'February',
#   'Next',
#   'Review',
#   'Date',
#   'February',
#   'RELEVANT',
#   'DOCUMENTS',
#   'Equality',
#   'Act',
#   'Special',
#   'Educational',
#   'Needs',
#   'and',
#   'Disability',
#   'Act',
#   'Disability',
#   'Discrimination',
#   'Act',
#   'Public',
#   'Sector',
#   'Bodies',
#   'Website',
#   'and',
#   'Mobile',
#   'Applications',
#   'Accessibility',
#   'regulations',
#   'RELATED',
#   'POLICIES',
#   'DOCUMENTS',
#   'LJMU',
#   'Equality',
#   'and',
#   'Diversity',
#   'policy',
#   'SCP',
#   'Evacuation',
#   'Procedures',
#   'SCP',
#   'Personal',
#   'Emergency',
#   'Evacuation',
#   'Plans',
#   'Student',
#   'Complaints',
#   'Procedure',
#   'Fitness',
#   'to',
#   'Study',
#   'policy',
#   'Fitness',
#   'to',
#   'Practice',
#   'Policy',
#   'Academic',
#   'Framework',
#   'Code',
#   'of',
#   'Practice',
#   'for',
#   'Placements',
#   'Policy',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'reasonable',
#   'adjustments',
#   'and',
#   'support',
#   'for',
#   'Disabled',
#   'students',
#   'Introduction',
#   'Liverpool',
#   'John',
#   'Moores',
#   'University',
#   'LJMU',
#   'is',
#   'committed',
#   'to',
#   'providing',
#   'an',
#   'inclusive',
#   'and',
#   'accessible',
#   'environment',
#   'which',
#   'enables',
#   'all',
#   'students',
#   'to',
#   'reach',
#   'their',
#   'potentia',
#   'l'],
#  ['A',
#   'wide',
#   'range',
#   'of',
#   'provision',
#   'is',
#   'available',
#   'to',
#   'support',
#   'students',
#   'including',
#   'specialist',
#   'support',
#   'support',
#   'through',
#   'academic',
#   'faculties',
#   'departments',
#   'and',
#   'schools',
#   'and',
#   'appropriate',
#   'policies',
#   'and',
#   'procedures'],
#  ['This',
#   'policy',
#   'sets',
#   'out',
#   'how',
#   'LJMU',
#   'meets',
#   'its',
#   'obligations',
#   'under',
#   'th',
#   'e',
#   'Equality',
#   'Act'],
#  ['It',
#   'identifies',
#   'the',
#   'Universitys',
#   'approach',
#   'to',
#   'supporting',
#   'disabled',
#   'students',
#   'and',
#   'formalises',
#   'areas',
#   'of',
#   'responsibility'],
#  ['The',
#   'policy',
#   'is',
#   'supported',
#   'by',
#   'the',
#   'procedures',
#   'within',
#   'this',
#   'document',
#   'either',
#   'appended',
#   'or',
#   'referenced'],
#  ['Duty',
#   'to',
#   'Make',
#   'Reasonable',
#   'A',
#   'djustments',
#   'As',
#   'provided',
#   'for',
#   'by',
#   'the',
#   'Equality',
#   'Act',
#   'LJMU',
#   'has',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustments',
#   'for',
#   'disabled',
#   'students',
#   'and',
#   'this',
#   'duty',
#   'has',
#   'been',
#   'further',
#   'highlighted',
#   'by',
#   'the',
#   'changes',
#   'made',
#   'to',
#   'the',
#   'Disabled',
#   'Students',
#   'Allowance',
#   'DSA'],
#  ['The',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustments',
#   'requires',
#   'institutions',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'have',
#   'anticipated',
#   'and',
#   'taken',
#   'reasonable',
#   'steps',
#   'to',
#   'address',
#   'barriers',
#   'which',
#   'put',
#   'disabled',
#   'students',
#   'at',
#   'a',
#   'substantial',
#   'disadvantage',
#   'in',
#   'relation',
#   'to',
#   'a',
#   'relevant',
#   'matter',
#   'when',
#   'compared',
#   'to',
#   'no',
#   'ndisabled',
#   'students'],
#  ['In',
#   'particular',
#   'there',
#   'is',
#   'a',
#   'requirement',
#   'on',
#   'institutions',
#   'under',
#   'new',
#   'DSA',
#   'regulations',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'provision',
#   'of',
#   'non',
#   'medical',
#   'help',
#   'is',
#   'available',
#   'where',
#   'appropriate'],
#  ['This',
#   'provisions',
#   'applies',
#   'to',
#   'delivery',
#   'of',
#   'LJMU',
#   'business',
#   'within',
#   'the',
#   'UK'],
#  ['The',
#   'intention',
#   'is',
#   'that',
#   'the',
#   'learning',
#   'environment',
#   'should',
#   'be',
#   'as',
#   'inclusive',
#   'as',
#   'possible',
#   'so',
#   'that',
#   'individual',
#   'interventions',
#   'are',
#   'the',
#   'exception',
#   'not',
#   'the',
#   'rule'],
#  ['Institutional',
#   'responsibility',
#   'LJMU',
#   'wishes',
#   'to',
#   'maintain',
#   'an',
#   'environment',
#   'in',
#   'which',
#   'disabled',
#   'students',
#   'are',
#   'able',
#   'to',
#   'fully',
#   'participate',
#   'in',
#   'the',
#   'student',
#   'experience',
#   'and',
#   'will',
#   'therefore',
#   'take',
#   'all',
#   'reasonable',
#   'steps',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'students',
#   'Have',
#   'access',
#   'to',
#   'appropriate',
#   'learning',
#   'and',
#   'teaching',
#   'support',
#   'for',
#   'mandatory',
#   'elements',
#   'of',
#   'academic',
#   'programmes',
#   'Mandatory',
#   'refers',
#   't',
#   'o',
#   'elements',
#   'of',
#   'the',
#   'course',
#   'that',
#   'are',
#   'required',
#   'in',
#   'order',
#   'to',
#   'successfully',
#   'achieve',
#   'the',
#   'target',
#   'award',
#   'and',
#   'will',
#   'include',
#   'both',
#   'core',
#   'and',
#   'optional',
#   'modules'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'estate',
#   'and',
#   'buildings',
#   'utilised',
#   'in',
#   'the',
#   'provision',
#   'of',
#   'teaching',
#   'and',
#   'learning',
#   'and',
#   'associated',
#   's',
#   'ervices'],
#  ['Have',
#   'access',
#   'to',
#   'specialist',
#   'staff',
#   'who',
#   'are',
#   'able',
#   'to',
#   'advise',
#   'on',
#   'the',
#   'range',
#   'and',
#   'extent',
#   'of',
#   'provision',
#   'available',
#   'throughout',
#   'the',
#   'institution'],
#  ['Have',
#   'documented',
#   'support',
#   'plans',
#   'in',
#   'place',
#   'including',
#   'where',
#   'appropriate',
#   'for',
#   'a',
#   'period',
#   'of',
#   'placement'],
#  ['Can', 'access', 'IT', 'facilities', 'and', 'services'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'learning',
#   'materials',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'whether',
#   'in',
#   'hardcopy',
#   'electronic',
#   'or',
#   'other',
#   'formats'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'additional',
#   'support',
#   'which',
#   'may',
#   'or',
#   'may',
#   'not',
#   'be',
#   'represented',
#   'in',
#   'a',
#   'formal',
#   'needs',
#   'assessment',
#   'in',
#   'the',
#   'form',
#   'of',
#   'nonmedical',
#   'help'],
#  ['Have',
#   'access',
#   'to',
#   'quiet',
#   'or',
#   'less',
#   'formal',
#   'environments',
#   'to',
#   'enable',
#   'students',
#   'to',
#   'have',
#   'time',
#   'away',
#   'should',
#   'they',
#   'require',
#   'it'],
#  ['Non',
#   'medical',
#   'help',
#   'is',
#   'defined',
#   'as',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'assistants',
#   'such',
#   'as',
#   'scribe',
#   'reader',
#   'lab',
#   'assistant',
#   'etc',
#   'and',
#   'Enhanced',
#   'Support',
#   'Assistants',
#   'such',
#   'as',
#   'examination',
#   'support',
#   'workers',
#   'notetakers',
#   'study',
#   'assistant'],
#  ['These',
#   'were',
#   'previously',
#   'identified',
#   'as',
#   'Band',
#   'and',
#   'Band',
#   'NMH',
#   'Support'],
#  ['Scope',
#   'This',
#   'policy',
#   'addresses',
#   'all',
#   'aspects',
#   'of',
#   'support',
#   'for',
#   'disabled',
#   'applicants',
#   'and',
#   'students',
#   'at',
#   'LJMU'],
#  ['This',
#   'policy',
#   'applies',
#   'to',
#   'all',
#   'students',
#   'studying',
#   'with',
#   'LJMU',
#   'within',
#   'the',
#   'UK',
#   'regardless',
#   'of',
#   'mode',
#   'of',
#   'study'],
#  ['However',
#   'students',
#   'on',
#   's',
#   'hort',
#   'professional',
#   'CPD',
#   'courses',
#   'will',
#   'be',
#   'advised',
#   'and',
#   'assessed',
#   'based',
#   'on',
#   'the',
#   'duration',
#   'and',
#   'intensity',
#   'of',
#   'their',
#   'study'],
#  ['The',
#   'principles',
#   'of',
#   'this',
#   'policy',
#   'apply',
#   'to',
#   'all',
#   'cohorts'],
#  ['Students',
#   'who',
#   'disclosed',
#   'or',
#   'declared',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'prior',
#   'to',
#   'September',
#   'may',
#   'have',
#   'their',
#   'needs',
#   'met',
#   'using',
#   'a',
#   'slightly',
#   'different',
#   'process',
#   'due',
#   'to',
#   'changing',
#   'external',
#   'student',
#   'finance',
#   'arrangements'],
#  ['Responsibilities',
#   'This',
#   'section',
#   'outlines',
#   'the',
#   'roles',
#   'an',
#   'd',
#   'responsibilities',
#   'of',
#   'key',
#   'areas',
#   'across',
#   'the',
#   'institution'],
#  ['It',
#   'does',
#   'not',
#   'contain',
#   'operational',
#   'detail',
#   'of',
#   'these',
#   'responsibilities'],
#  ['Further',
#   'information',
#   'about',
#   'relevant',
#   'procedures',
#   'should',
#   'be',
#   'available',
#   'from',
#   'the',
#   'relevant',
#   'areas',
#   'andor',
#   'from',
#   'the',
#   'Disability',
#   'team',
#   'within',
#   'S',
#   'tudent',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services'],
#  ['ELT',
#   'are',
#   'responsible',
#   'for',
#   'the',
#   'Universitys',
#   'strategy',
#   'with',
#   'regards',
#   'to',
#   'disabled',
#   'students',
#   'ensuring',
#   'compliance',
#   'with',
#   'the',
#   'Equality',
#   'Act',
#   'and',
#   'regulating',
#   'the',
#   'associated',
#   'resource',
#   'to',
#   'fund',
#   'support',
#   'for',
#   'disabled',
#   'students'],
#  ['Equality',
#   'Diversity',
#   'and',
#   'Inclusivity',
#   'Committee',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'compli',
#   'ance',
#   'with',
#   'this',
#   'policy',
#   'requesting',
#   'appropriate',
#   'changes',
#   'and',
#   'making',
#   'recommendations',
#   'to',
#   'EL',
#   'T',
#   'for',
#   'amendments',
#   'to',
#   'policy',
#   'and',
#   'practice'],
#  ['Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'is',
#   'responsible',
#   'for',
#   'advising',
#   'the',
#   'University',
#   'about',
#   'strategy',
#   'and',
#   'policy',
#   'in',
#   'relation',
#   'to',
#   'disabled',
#   'students',
#   'and',
#   'identifying',
#   'the',
#   'impact',
#   'of',
#   'changes',
#   'in',
#   'the',
#   'external',
#   'environment',
#   'on',
#   'University',
#   'provision'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'contracts',
#   'are',
#   'in',
#   'place',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'workers',
#   'and',
#   'holds',
#   'the',
#   'Disability',
#   'budget',
#   'to',
#   'ensure',
#   'additional',
#   'reasonable',
#   'adjustments',
#   'can',
#   'be',
#   'made',
#   'where',
#   'other',
#   'sources',
#   'of',
#   'funding',
#   'are',
#   'not',
#   'available'],
#  ['The',
#   'Student',
#   'Support',
#   'M',
#   'anager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'students',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'them',
#   'through',
#   'the',
#   'Disability',
#   'team'],
#  ['Once',
#   'students',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'the',
#   'Student',
#   'Support',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'they',
#   'have',
#   'an',
#   'appropriate',
#   'Indivi',
#   'dual',
#   'Student',
#   'Learning',
#   'Plan',
#   'ISLP',
#   'which',
#   'identifies',
#   'relevant',
#   'inclusive',
#   'approaches',
#   'to',
#   'provision',
#   'and',
#   'where',
#   'appropriate',
#   'identifies',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustments',
#   'to',
#   'reduce',
#   'barriers',
#   'to',
#   'the',
#   'students',
#   'participation',
#   'in',
#   'their',
#   'academic',
#   'program',
#   'me'],
#  ['The',
#   'Disability',
#   'team',
#   'are',
#   'responsible',
#   'for',
#   'engaging',
#   'with',
#   'and',
#   'receiving',
#   'consent',
#   'from',
#   'students',
#   'in',
#   'order',
#   'that',
#   'they',
#   'can',
#   'create',
#   'store',
#   'andor',
#   'communicate',
#   'the',
#   'ISLP',
#   'and',
#   'associated',
#   'documents',
#   'to',
#   'all',
#   'relevant',
#   'parties',
#   'and',
#   'are',
#   'responsible',
#   'for',
#   'providing',
#   'advice',
#   't',
#   'o',
#   'students',
#   'and',
#   'staff',
#   'on',
#   'disability',
#   'related',
#   'matters'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'store',
#   'the',
#   'master',
#   'copy',
#   'of',
#   'an',
#   'individual',
#   'students',
#   'ISLP',
#   'and',
#   'a',
#   'copy',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'student',
#   'and',
#   'the',
#   'relevant',
#   'Disability',
#   'Coordinator'],
#  ['The',
#   'Disability',
#   'team',
#   'also',
#   'covers',
#   'Specialist',
#   'Study',
#   'Skills',
#   'tutors',
#   'who',
#   'work',
#   'directly',
#   'with',
#   'students'],
#  ['Directors',
#   'of',
#   'SchoolHeads',
#   'of',
#   'Department',
#   'are',
#   'responsible',
#   'for',
#   'en',
#   'suring',
#   'that',
#   'an',
#   'ISLP',
#   'is',
#   'effectively',
#   'communicated',
#   'within',
#   'the',
#   'school',
#   'or',
#   'department',
#   'and',
#   'for',
#   'the',
#   'health',
#   'and',
#   'safety',
#   'of',
#   'disabled',
#   'students',
#   'includ',
#   'ing',
#   'ensuring',
#   'that',
#   'disabled',
#   'students',
#   'who',
#   'require',
#   'one',
#   'have',
#   'a',
#   'Personal',
#   'Emergency',
#   'Evacuation',
#   'Plan',
#   'PEEP'],
#  ['They',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'reasonable',
#   'adjustments',
#   'are',
#   'in',
#   'place',
#   'for',
#   'assessments',
#   'organised',
#   'within',
#   'the',
#   'departmentschool',
#   'including',
#   'in',
#   'class',
#   'tests'],
#  ['DirectorsHeads',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'teaching',
#   'and',
#   'learning',
#   'materials',
#   'and',
#   'practices',
#   'within',
#   'their',
#   'areas',
#   'meet',
#   'the',
#   'agreed',
#   'needs',
#   'of',
#   'disabled',
#   'students'],
#  ['DirectorsHeads',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'the',
#   'availability',
#   'and',
#   'remit',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   's',
#   'including',
#   'the',
#   'Disability',
#   'team'],
#  ['Disability',
#   'Coordinators',
#   'DisCo',
#   'are',
#   'school',
#   'and',
#   'faculty',
#   'based',
#   'staff',
#   'with',
#   'responsibility',
#   'for',
#   'ensuring',
#   'relevant',
#   'academic',
#   'and',
#   'admin',
#   'istrative',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'student',
#   's',
#   'support',
#   'needs',
#   'and',
#   'for',
#   'coordinating',
#   'school',
#   'based',
#   'support'],
#  ['See',
#   'appendix',
#   'for',
#   'the',
#   'Disability',
#   'Coordinator',
#   'role',
#   'descriptor',
#   'Programme',
#   'Leaders',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'the',
#   'curriculum',
#   'of',
#   'their',
#   'programmes',
#   'and',
#   'identifying',
#   'app',
#   'ropriate',
#   'inclusive',
#   'approaches'],
#  ['Module',
#   'Leaders',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'students',
#   'on',
#   'the',
#   'module',
#   'require',
#   'reasonable',
#   'adjustments',
#   'and',
#   'ensuring',
#   'that',
#   'programme',
#   'colleagues',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'requirements'],
#  ['This',
#   'information',
#   'is',
#   'available',
#   'from',
#   't',
#   'he',
#   'DisCo',
#   'and',
#   'Programme',
#   'Leaders',
#   'in',
#   'each',
#   'schooldepartment'],
#  ['Personal',
#   'tutors',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'students',
#   'within',
#   'their',
#   'tutee',
#   'group',
#   'require',
#   'reasonable',
#   'adjustments',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'students',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'the',
#   'm'],
#  ['All',
#   'Programme',
#   'staff',
#   'are',
#   'responsible',
#   'for',
#   'implementing',
#   'relevant',
#   'reasonable',
#   'adjustments',
#   'as',
#   'detailed',
#   'within',
#   'the',
#   'students',
#   'ISLP'],
#  ['The',
#   'ISLP',
#   'will',
#   'be',
#   'created',
#   'as',
#   'per',
#   'Section',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'in',
#   'consultation',
#   'between',
#   'all',
#   'relevant',
#   'parties'],
#  ['The',
#   'Directo',
#   'r',
#   'of',
#   'Library',
#   'services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'disabled',
#   'students',
#   'are',
#   'able',
#   'to',
#   'access',
#   'all',
#   'Library',
#   'provision',
#   'and',
#   'that',
#   'they',
#   'have',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'support',
#   'and',
#   'training'],
#  ['The',
#   'Director',
#   'of',
#   'Student',
#   'Advancement',
#   'is',
#   'responsible',
#   'for',
#   'ensu',
#   'ring',
#   'that',
#   'the',
#   'services',
#   'delivered',
#   'are',
#   'appropriate',
#   'to',
#   'the',
#   'needs',
#   'of',
#   'disabled',
#   'students',
#   'and',
#   'graduates'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'Code',
#   'of',
#   'Practice',
#   'for',
#   'Placements',
#   'addresses',
#   'the',
#   'needs',
#   'of',
#   'disabled',
#   'students'],
#  ['The',
#   'Director',
#   'of',
#   'IT',
#   'Services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'software',
#   'and',
#   'hardware',
#   'is',
#   'available',
#   'for',
#   'disabled',
#   'students',
#   'including',
#   'training',
#   'on',
#   'such',
#   'equipment'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'University',
#   'corporate',
#   'systems',
#   'including',
#   'the',
#   'website',
#   'are',
#   'inclusi',
#   've',
#   'and',
#   'accessible'],
#  ['The',
#   'Director',
#   's',
#   'of',
#   'Estates',
#   'and',
#   'Facilities',
#   'Management',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'the',
#   'University',
#   'campus',
#   'including',
#   'all',
#   'University',
#   'buildings',
#   'is',
#   'physically',
#   'accessible',
#   'and',
#   'that',
#   'accessibility',
#   'equipment',
#   'and',
#   'ergonomic',
#   'furniture',
#   'is',
#   'manag',
#   'ed',
#   'effectively'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'campus',
#   'services',
#   'such',
#   'as',
#   'parki',
#   'ng',
#   'and',
#   'catering',
#   'are',
#   'accessible',
#   'and',
#   'that',
#   'timetabling',
#   'i',
#   'ssues',
#   'are',
#   'addressed',
#   'effectively',
#   'including',
#   'the',
#   'availability',
#   'of',
#   'quiet',
#   'spaces'],
#  ['The',
#   'Accommodation',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'accommodation',
#   'is',
#   'available',
#   'through',
#   'University',
#   'partner',
#   'Accommodation',
#   'providers',
#   'to',
#   'meet',
#   'the',
#   'needs',
#   'of',
#   'students'],
#  ['This',
#   'is',
#   'a',
#   'sha',
#   'red',
#   'responsibility',
#   'with',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'and',
#   'is',
#   'identified',
#   'as',
#   'a',
#   'critical',
#   'factor',
#   'in',
#   'the',
#   'contractual',
#   'obligations',
#   'outlined',
#   'to',
#   'providers'],
#  ['The',
#   'Head',
#   'of',
#   'Operations',
#   'in',
#   'each',
#   'Faculty',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'inclusive',
#   'approaches',
#   'and',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustments',
#   'are',
#   'available',
#   'for',
#   'formal',
#   'examination',
#   'and',
#   'assessment',
#   'periods',
#   'whilst',
#   'working',
#   'within',
#   'the',
#   'University',
#   'policy',
#   'on',
#   'Assessment',
#   'and',
#   'examination',
#   'provisions',
#   'Appendix'],
#  ['The',
#   'Head',
#   'of',
#   'Operations',
#   'would',
#   'also',
#   'be',
#   'responsible',
#   'for',
#   'resolving',
#   'issues',
#   'related',
#   'to',
#   'timetables',
#   'and',
#   'an',
#   'individual',
#   's',
#   'access',
#   'needs'],
#  ['The',
#   'Head',
#   'of',
#   'Academic',
#   'Quality',
#   'services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'accessibility',
#   'and',
#   'inclusive',
#   'practice',
#   'are',
#   'considered',
#   'as',
#   'part',
#   'of',
#   'the',
#   'module',
#   'approval',
#   'process',
#   'including',
#   'appropriate',
#   'consultation',
#   'during',
#   'course',
#   'validation'],
#  ['The',
#   'Dean',
#   'of',
#   'the',
#   'Learning',
#   'and',
#   'Teaching',
#   'Academy',
#   'is',
#   'responsible',
#   'for',
#   'updating',
#   'appropriate',
#   'information',
#   'including',
#   'Regulations',
#   'in',
#   'Practise',
#   'and',
#   'other',
#   'publications',
#   'on',
#   'inclusive',
#   'practices',
#   'in',
#   'higher',
#   'education'],
#  ['There',
#   'is',
#   'al',
#   'so',
#   'a',
#   'responsibility',
#   'here',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'institutional',
#   'Virtual',
#   'Learning',
#   'Environment',
#   'meets',
#   'appropriate',
#   'inclusivity',
#   'requirements'],
#  ['The',
#   'Director',
#   'of',
#   'Corporate',
#   'Communications',
#   'and',
#   'Stakeholder',
#   'Engagement',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'commun',
#   'ications',
#   'produced',
#   'by',
#   'the',
#   'Universi',
#   'ty',
#   'are',
#   'accessible'],
#  ['The',
#   'Director',
#   'of',
#   'Student',
#   'Recruitment',
#   'and',
#   'Admissions',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'University',
#   'events',
#   'such',
#   'as',
#   'open',
#   'days',
#   'are',
#   'accessible',
#   'to',
#   'all',
#   'participants',
#   'including',
#   'visitors',
#   'and',
#   'that',
#   'appropriate',
#   'pre',
#   'entry',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'is',
#   'forwarded',
#   'to',
#   'the',
#   'Disability',
#   'team'],
#  ['Preentry',
#   'disclosure',
#   'processes',
#   'will',
#   'be',
#   'applied',
#   'to',
#   'all',
#   'levels',
#   'and',
#   'categories',
#   'of',
#   'students',
#   'to',
#   'ensure',
#   'consistency'],
#  ['The',
#   'Director',
#   'of',
#   'International',
#   'Relations',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'students',
#   'who',
#   'wish',
#   'to',
#   'participate',
#   'in',
#   'Study',
#   'Abroad',
#   'opportunities',
#   'are',
#   'able',
#   'to',
#   'declare',
#   'a',
#   'disability',
#   'if',
#   'not',
#   'already',
#   'known',
#   'to',
#   'the',
#   'University'],
#  ['She',
#   'is',
#   'responsible',
#   'for',
#   'working',
#   'with',
#   'the',
#   'relevant',
#   'teams',
#   'within',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   's',
#   'the',
#   'student',
#   'and',
#   'relevant',
#   'academic',
#   'department',
#   'to',
#   'identify',
#   'what',
#   'adjustments',
#   'are',
#   'appropriate',
#   'and',
#   'reasonable',
#   'within',
#   'the',
#   'context',
#   'of',
#   'a',
#   'specific',
#   'study',
#   'abroad',
#   'opportunity'],
#  ['The',
#   'Academic',
#   'Registrar',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'effective',
#   'facilitation',
#   'of',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'processes'],
#  ['The',
#   'Director',
#   'of',
#   'Human',
#   'Resources',
#   'through',
#   'th',
#   'e',
#   'Equality',
#   'and',
#   'Diversity',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'relevant',
#   'training',
#   'and',
#   'development',
#   'opportunities',
#   'related',
#   'to',
#   'issues',
#   'of',
#   'equality',
#   'a',
#   'nd',
#   'diversity',
#   'are',
#   'available',
#   'to',
#   'staff'],
#  ['The',
#   'Counselling',
#   'Manager',
#   'and',
#   'Mental',
#   'Wellbeing',
#   'Advisor',
#   's',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'provision',
#   'of',
#   'support',
#   'to',
#   'students',
#   'with',
#   'mental',
#   'health',
#   'difficulties'],
#  ['The',
#   'Occupational',
#   'Health',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'assessing',
#   'at',
#   'enrolment',
#   'whether',
#   'those',
#   'students',
#   'attending',
#   'regulated',
#   'vocational',
#   'programmes',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'training',
#   'and',
#   'are',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   'to',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'studies',
#   'in',
#   'accordance',
#   'with',
#   'guidance',
#   'from',
#   'relevant',
#   'regulatory',
#   'bodies'],
#  ['In',
#   'addition',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'will',
#   'advise',
#   'programme',
#   'leaders',
#   'where',
#   'students',
#   'on',
#   'regulated',
#   'vocational',
#   'programmes',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'impairment',
#   'or',
#   'health',
#   'condition',
#   'if',
#   'they',
#   'may',
#   'need',
#   'any',
#   'adjustments',
#   'to',
#   'the',
#   'training',
#   'programme',
#   'or',
#   'programme',
#   'of',
#   'study',
#   'on',
#   'medical',
#   'grounds'],
#  ['The',
#   'programme',
#   'leader',
#   'will',
#   'liaise',
#   'through',
#   'the',
#   'DisCo',
#   'with',
#   'the',
#   'Disability',
#   'team',
#   'if',
#   'there',
#   'is',
#   'a',
#   'need',
#   'to',
#   'clarify',
#   'whether',
#   'adjustments',
#   'recommended',
#   'are',
#   'considered',
#   'to',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'circumstances',
#   'of',
#   'the',
#   'individual'],
#  ['Heads',
#   'of',
#   'all',
#   'other',
#   'departments',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'provisions',
#   'are',
#   'as',
#   'accessible',
#   'as',
#   'possible',
#   'eg',
#   'provision',
#   'of',
#   'alternative',
#   'formats'],
#  ['The',
#   'Manager',
#   'of',
#   'Health',
#   'Safety',
#   'and',
#   'Environment',
#   'Services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'procedures',
#   'for',
#   'Person',
#   'al',
#   'Emergency',
#   'Evacuation',
#   'Plans',
#   'are',
#   'available',
#   'on',
#   'the',
#   'University',
#   'intranet',
#   'and',
#   'for',
#   'maintaining',
#   'up',
#   'todate',
#   'evacuation',
#   'procedures',
#   'covering',
#   'all',
#   'University',
#   'buildings'],
#  ['She',
#   'is',
#   'responsible',
#   'for',
#   'training',
#   'evacuation',
#   'chair',
#   'operators',
#   'in',
#   'the',
#   'safe',
#   'use',
#   'of',
#   'equipment',
#   'to',
#   'assi',
#   'st',
#   'persons',
#   'with',
#   'mobility',
#   'impairments',
#   'in',
#   'an',
#   'evacuation',
#   'situation',
#   'and',
#   'for',
#   'publishing',
#   'up',
#   'to',
#   'date',
#   'lists',
#   'of',
#   'such',
#   'people',
#   'and',
#   'first',
#   'aiders',
#   'on',
#   'a',
#   'building',
#   'by',
#   'building',
#   'basis',
#   'on',
#   'the',
#   'intranet'],
#  ['All',
#   'students',
#   'and',
#   'applicants',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'inform',
#   'the',
#   'Univ',
#   'ersity',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'of',
#   'their',
#   'disability',
#   'or',
#   'medical',
#   'condition',
#   'in',
#   'order',
#   'that',
#   'support',
#   'can',
#   'be',
#   'provided'],
#  ['Objectives',
#   'The',
#   'University',
#   'observes',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability',
#   'which',
#   'views',
#   'disability',
#   'as',
#   'being',
#   'created',
#   'by',
#   'barriers',
#   'within',
#   'society',
#   'rather',
#   'than',
#   'by',
#   'the',
#   'disability',
#   'itself'],
#  ['Barriers',
#   'can',
#   'be',
#   'in',
#   'the',
#   'physical',
#   'environment',
#   'such',
#   'as',
#   'inaccessible',
#   'buildings',
#   'or',
#   'services',
#   'attitudinal',
#   'resulting',
#   'in',
#   'stereotypes',
#   'prejudices',
#   'and',
#   'assumptions',
#   'about',
#   'the',
#   'capabilities',
#   'of',
#   'di',
#   'sabled',
#   'people',
#   'or',
#   'organisational',
#   'such',
#   'as',
#   'having',
#   'inflexible',
#   'policies',
#   'and',
#   'procedures'],
#  ['The',
#   'University',
#   'aims',
#   'to',
#   'address',
#   'all',
#   'of',
#   'these',
#   'barriers',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'people',
#   'can',
#   'participate',
#   'in',
#   'all',
#   'aspects',
#   'of',
#   'University',
#   'life'],
#  ['The',
#   'University',
#   'recognises',
#   'its',
#   'responsibilities',
#   'to',
#   'make',
#   'provision',
#   'as',
#   'accessible',
#   'as',
#   'possible',
#   'and',
#   'will',
#   'aim',
#   'to',
#   'do',
#   'this',
#   'using',
#   'inclusive',
#   'approaches',
#   'to',
#   'provision',
#   'and',
#   'services',
#   'or',
#   'anticipatory',
#   'reasonable',
#   'adjustments',
#   'wherever',
#   'possible'],
#  ['The',
#   'University',
#   'aims',
#   'to',
#   'identify',
#   'the',
#   'most',
#   'common',
#   'barriers',
#   'experienced',
#   'by',
#   'disabled',
#   'students',
#   'and',
#   'wherever',
#   'possible',
#   'to',
#   'identify',
#   'appropriate',
#   'anticipatory',
#   'adjustments',
#   'to',
#   'overcome',
#   'these',
#   'barriers'],
#  ['Where',
#   'this',
#   'is',
#   'not',
#   'possible',
#   'andor',
#   'additional',
#   'needs',
#   'are',
#   'identified',
#   'the',
#   'University',
#   'will',
#   'seek',
#   'to',
#   'implement',
#   'appropriate',
#   'indiv',
#   'idual',
#   'reasonable',
#   'adjustments'],
#  ['Reasonable',
#   'adjustments',
#   'individual',
#   'and',
#   'anticipatory',
#   'can',
#   'be',
#   'made',
#   'to',
#   'provisions',
#   'or',
#   'practices',
#   'but',
#   'not',
#   'to',
#   'competence',
#   'standards'],
#  ['Competence',
#   'standards',
#   'are',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standards',
#   'which',
#   'are',
#   'required',
#   'for',
#   'the',
#   'programme'],
#  ['Competence',
#   'standards',
#   'must',
#   'be',
#   'directly',
#   'related',
#   'to',
#   'the',
#   'learning',
#   'outcomes',
#   'of',
#   'the',
#   'programme'],
#  ['There',
#   'is',
#   'therefore',
#   'no',
#   'requirement',
#   'to',
#   'alter',
#   'the',
#   'academic',
#   'standards',
#   'of',
#   'a',
#   'programme',
#   'for',
#   'a',
#   'disabled',
#   'student'],
#  ['However',
#   'it',
#   'may',
#   'be',
#   'necessary',
#   'to',
#   'adjust',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed'],
#  ['The',
#   'University',
#   'has',
#   'specialist',
#   'targeted',
#   'provision',
#   'to',
#   'support',
#   'this',
#   'approach'],
#  ['The',
#   'Disability',
#   'team',
#   'is',
#   'the',
#   'key',
#   'specialist',
#   'service',
#   'provided',
#   'by',
#   'the',
#   'University'],
#  ['Specialists',
#   'within',
#   'this',
#   'team',
#   'understand',
#   'the',
#   'barriers',
#   'which',
#   'can',
#   'impact',
#   'on',
#   'students',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'academic',
#   'studies',
#   'and',
#   'identify',
#   'inclusive',
#   'approaches',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustments',
#   'to',
#   'enable',
#   'individuals',
#   'to',
#   'participate',
#   'fully',
#   'in',
#   'university',
#   'life'],
#  ['On',
#   'some',
#   'occasions',
#   'this',
#   'provision',
#   'will',
#   'also',
#   'be',
#   'informed',
#   'by',
#   'an',
#   'external',
#   'third',
#   'party',
#   'with',
#   'appropriate',
#   'specialist',
#   'knowledge'],
#  ['Disability',
#   'Coordinators',
#   'DisCos',
#   'in',
#   'faculties',
#   'and',
#   'schools',
#   'provide',
#   'targeted',
#   'academic',
#   'support',
#   'for',
#   'disabled',
#   'students'],
#  ['DisCos',
#   'have',
#   'discipline',
#   'specific',
#   'knowledge',
#   'which',
#   'enab',
#   'les',
#   'them',
#   'to',
#   'apply',
#   'the',
#   'reasonable',
#   'adjustments',
#   'in',
#   'a',
#   'proportionate',
#   'and',
#   'appropriate',
#   'manner',
#   'in',
#   'consultation',
#   'with',
#   'Programme',
#   'and',
#   'Module',
#   'leaders'],
#  ['DisCos',
#   'are',
#   'also',
#   'a',
#   'local',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'staff',
#   'and',
#   'disabled',
#   'students',
#   'and',
#   'will',
#   'coordinate',
#   'support',
#   'within',
#   'the',
#   'facu',
#   'lty',
#   'or',
#   'school'],
#  ['All',
#   'students',
#   'have',
#   'access',
#   'to',
#   'a',
#   'Personal',
#   'Tutor',
#   'who',
#   'will',
#   'signpost',
#   'to',
#   'relevant',
#   'specialist',
#   'services',
#   'within',
#   'the',
#   'University'],
#  ['Disclosing',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'Students',
#   'are',
#   'able',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'their',
#   'time',
#   'at',
#   'the',
#   'University'],
#  ['All',
#   'applicants',
#   'to',
#   'the',
#   'University',
#   'will',
#   'be',
#   'given',
#   'the',
#   'opportunity',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'prior',
#   'to',
#   'commencement',
#   'of',
#   'a',
#   'programme'],
#  ['All',
#   'students',
#   'on',
#   'regulated',
#   'vocational',
#   'programmes',
#   'will',
#   'be',
#   'required',
#   'to',
#   'complete',
#   'a',
#   'health',
#   'declaration',
#   'prior',
#   'to',
#   'commencing',
#   'their',
#   'programme'],
#  ['This',
#   'will',
#   'include',
#   'a',
#   'requirement',
#   'to',
#   'notify',
#   'any',
#   'disability',
#   'which',
#   'may',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'complete',
#   'the',
#   'programme'],
#  ['This',
#   'will',
#   'result',
#   'in',
#   'an',
#   'assessment',
#   'by',
#   'the',
#   'Occupational',
#   'Hea',
#   'lth',
#   'team'],
#  ['Students',
#   'and',
#   'applicants',
#   'will',
#   'need',
#   'to',
#   'provide',
#   'relevant',
#   'consent',
#   'for',
#   'process',
#   'to',
#   'be',
#   'followed',
#   'and',
#   'must',
#   'engage',
#   'fully',
#   'in',
#   'this',
#   'process'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'contact',
#   'all',
#   'students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'through',
#   'recruitment',
#   'processes',
#   'prior',
#   't',
#   'o',
#   'their',
#   'arrival',
#   'in',
#   'order',
#   'that',
#   'the',
#   'support',
#   'process',
#   'can',
#   'be',
#   'in',
#   'place',
#   'for',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'programme'],
#  ['Students',
#   'will',
#   'be',
#   'given',
#   'a',
#   'further',
#   'opportunity',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'process'],
#  ['All',
#   'students',
#   'on',
#   'regulated',
#   'vo',
#   'cational',
#   'programmes',
#   'who',
#   'disclose',
#   'a',
#   'significant',
#   'disability',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'Programme',
#   'Leaders',
#   'or',
#   'others',
#   'will',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'for',
#   'assessment',
#   'of',
#   'the',
#   'potential',
#   'impact',
#   'on',
#   'study',
#   'and',
#   'practice'],
#  ['This',
#   'may',
#   'result',
#   'in',
#   'confirmation',
#   'th',
#   'at',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'have',
#   'already',
#   'addressed',
#   'the',
#   'issue',
#   'or',
#   'may',
#   'result',
#   'in',
#   'a',
#   'new',
#   'assessment'],
#  ['If',
#   'during',
#   'their',
#   'period',
#   'of',
#   'study',
#   'a',
#   'student',
#   'becomes',
#   'aware',
#   'of',
#   'a',
#   'previously',
#   'undiagnosed',
#   'disability',
#   'they',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'as',
#   'soon',
#   'as',
#   'pos',
#   'sible'],
#  ['If',
#   'at',
#   'any',
#   'time',
#   'any',
#   'member',
#   'of',
#   'staff',
#   'becomes',
#   'aware',
#   'of',
#   'serious',
#   'concerns',
#   'regarding',
#   'a',
#   'student',
#   'on',
#   'a',
#   'regulated',
#   'vocational',
#   'programme',
#   'which',
#   'might',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'meet',
#   'competence',
#   'standards',
#   'the',
#   'student',
#   'must',
#   'be',
#   'referred',
#   'for',
#   'an',
#   'occupational',
#   'health',
#   'assessment',
#   'through',
#   'the',
#   'Program',
#   'leader',
#   'utilising',
#   'the',
#   'Fitness',
#   'to',
#   'StudyPractice',
#   'policies'],
#  ['Students',
#   'who',
#   'wish',
#   'to',
#   'discuss',
#   'access',
#   'to',
#   'reasonable',
#   'adjustments',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'as',
#   'early',
#   'as',
#   'possible'],
#  ['Students',
#   'who',
#   'wish',
#   'to',
#   'access',
#   'reasonable',
#   'adjustments',
#   'will',
#   'be',
#   'required',
#   'to',
#   'provide',
#   'evidence',
#   'of',
#   'their',
#   'disability'],
#  ['Further',
#   'guidance',
#   'on',
#   'evidence',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'Disability',
#   'team'],
#  ['Students',
#   'with',
#   'specific',
#   'learning',
#   'difficulties',
#   'andor',
#   'dyslexia',
#   'should',
#   'refer',
#   'to',
#   'the',
#   'Specific',
#   'Learning',
#   'Di',
#   'fficulties',
#   'and',
#   'Dyslexia',
#   'guidance',
#   'contained',
#   'within',
#   'Appendix'],
#  ['Guidance',
#   'on',
#   'the',
#   'identification',
#   'and',
#   'implementation',
#   'of',
#   'Reasonable',
#   'Adjustments',
#   'The',
#   'University',
#   'has',
#   'a',
#   'range',
#   'of',
#   'established',
#   'inclusive',
#   'practices',
#   'in',
#   'place',
#   'across',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'students',
#   'can',
#   'access',
#   'programmes'],
#  ['Information',
#   'on',
#   'these',
#   'inclusive',
#   'practices',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'Disability',
#   'team',
#   'or',
#   'DisCos',
#   'within',
#   'individual',
#   'schools',
#   'and',
#   'faculties',
#   'and',
#   'will',
#   'be',
#   'highlighted',
#   'to',
#   'students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'by',
#   'the',
#   'Dis',
#   'ability',
#   'team'],
#  ['Inclusive',
#   'anticipatory',
#   'approaches',
#   'will',
#   'be',
#   'accessible',
#   'to',
#   'all',
#   'students',
#   'in',
#   'order',
#   'that',
#   'students',
#   'who',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'disclose',
#   'to',
#   'the',
#   'University',
#   'can',
#   'also',
#   'access',
#   'appropriate',
#   'provision'],
#  ['Whilst',
#   'inclusive',
#   'approaches',
#   'and',
#   'anticipatory',
#   'adjustments',
#   'will',
#   'meet',
#   'many',
#   'disabled',
#   'students',
#   'needs',
#   'some',
#   'students',
#   'will',
#   'still',
#   'require',
#   'additional',
#   'individual',
#   'adjustments'],
#  ['The',
#   'Disability',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'identifying',
#   'individual',
#   'reasonable',
#   'adjustments',
#   'to',
#   'programmes',
#   'of',
#   'study',
#   'for',
#   'individual',
#   'students',
#   'in',
#   'con',
#   'sultation',
#   'with',
#   'Programme',
#   'leaders',
#   'where',
#   'appropriate',
#   'and',
#   'within',
#   'the',
#   'wider',
#   'University',
#   'provision'],
#  ['Programme',
#   'teams',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'anticipatory',
#   'adjustments',
#   'to',
#   'programmes',
#   'of',
#   'study',
#   'are',
#   'in',
#   'place'],
#  ['If',
#   'a',
#   'student',
#   'has',
#   'an',
#   'independent',
#   'Assessment',
#   'o',
#   'f',
#   'Needs',
#   'report',
#   'for',
#   'Disabled',
#   'Students',
#   'Allowance',
#   'DSA',
#   'purposes',
#   'or',
#   'an',
#   'Educational',
#   'Psychologists',
#   'report',
#   'the',
#   'recommendations',
#   'from',
#   'these',
#   'reports',
#   'will',
#   'be',
#   'considered',
#   'when',
#   'identifying',
#   'reasonable',
#   'adjustments'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'firstly',
#   'consider',
#   'whether',
#   'anticipatory',
#   'adjustments',
#   'will',
#   'meet',
#   'the',
#   'specific',
#   'needs',
#   'of',
#   'the',
#   'individual',
#   'student',
#   'and',
#   'then',
#   'whether',
#   'individual',
#   'reasonable',
#   'adjustments',
#   'are',
#   'required'],
#  ['The',
#   'Disability',
#   'team',
#   'in',
#   'consultation',
#   'with',
#   'academic',
#   'colleagues',
#   'will',
#   'consider',
#   'a',
#   'number',
#   'of',
#   'factors',
#   'when',
#   'deciding',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'is',
#   'reasonable'],
#  ['Factors',
#   'may',
#   'include',
#   'but',
#   'not',
#   'be',
#   'limited',
#   'to',
#   'the',
#   'perceived',
#   'effectiveness',
#   'of',
#   'the',
#   'adjustment',
#   'the',
#   'time',
#   'or',
#   'resource',
#   'required',
#   'to',
#   'implement',
#   'the',
#   'adjustment',
#   'the',
#   'students',
#   'previous',
#   'experience',
#   'of',
#   'the',
#   'adjustment',
#   'and',
#   'whether',
#   'the',
#   'need',
#   'could',
#   'be',
#   'met',
#   'through',
#   'an',
#   'existing',
#   'inclusive',
#   'approach',
#   'or',
#   'anticipatory',
#   'adjustment'],
#  ['The',
#   'University',
#   'is',
#   'not',
#   'obliged',
#   'to',
#   'offer',
#   'the',
#   'student',
#   'their',
#   'preferred',
#   'adjustment',
#   'particularly',
#   'if',
#   'an',
#   'inclusive',
#   'approach',
#   'or',
#   'alternative',
#   'adjustment',
#   'is',
#   'available',
#   'whi',
#   'ch',
#   'would',
#   'provide',
#   'appropriate',
#   'support',
#   'for',
#   'the',
#   'student'],
#  ['For',
#   'information',
#   'regarding',
#   'the',
#   'complaints',
#   'process',
#   'to',
#   'be',
#   'used',
#   'when',
#   'a',
#   'student',
#   'disagrees',
#   'with',
#   'a',
#   'proposed',
#   'reasonable',
#   'adjustment',
#   'see',
#   'section',
#   'Where',
#   'appropriate',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'liaise',
#   'with',
#   'the',
#   'DisCo',
#   'to',
#   'discuss',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'may',
#   'conflict',
#   'with',
#   'the',
#   'competence',
#   'standards',
#   'for',
#   'the',
#   'programme',
#   'and',
#   'how',
#   'this',
#   'might',
#   'be',
#   'addressed',
#   'within',
#   'the',
#   'ISLP'],
#  ['For',
#   'students',
#   'who',
#   'are',
#   'able',
#   'to',
#   'ac',
#   'cess',
#   'external',
#   'funding',
#   'for',
#   'a',
#   'reasonable',
#   'adjustment',
#   'for',
#   'example',
#   'through',
#   'DSA',
#   'the',
#   'University',
#   'requires',
#   'the',
#   'student',
#   'to',
#   'access',
#   'such',
#   'funding'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'provide',
#   'guidance',
#   'and',
#   'advice',
#   'on',
#   'this',
#   'process',
#   'where',
#   'necessary'],
#  ['Where',
#   'external',
#   'financial',
#   'sources',
#   'are',
#   'not',
#   'available',
#   'and',
#   'the',
#   'Disability',
#   'team',
#   'identify',
#   'the',
#   'adjustment',
#   'to',
#   'be',
#   'reasonable',
#   'the',
#   'University',
#   'will',
#   'seek',
#   'to',
#   'fund',
#   'this',
#   'adjustment',
#   'where',
#   'possible'],
#  ['Annually',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'will',
#   'set',
#   'in',
#   'conjunction',
#   'with',
#   'the',
#   'Stu',
#   'dent',
#   'Support',
#   'Manager',
#   'and',
#   'the',
#   'Disability',
#   'team',
#   'an',
#   'upper',
#   'financial',
#   'limit',
#   'for',
#   'individual',
#   'reasonable',
#   'adjustments'],
#  ['In',
#   'the',
#   'majority',
#   'of',
#   'cases',
#   'this',
#   'will',
#   'ensure',
#   'that',
#   'reasonable',
#   'adjustments',
#   'can',
#   'be',
#   'put',
#   'in',
#   'place',
#   'without',
#   'onwards',
#   'referral',
#   'and',
#   'therefore',
#   'ease',
#   'the',
#   'speed',
#   'of',
#   'the',
#   'process'],
#  ['Where',
#   'the',
#   'upper',
#   'limit',
#   'is',
#   'breeched',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'refer',
#   'the',
#   'case',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'for',
#   'review',
#   'and',
#   'agreeme',
#   'nt',
#   'if',
#   'appropriate'],
#  ['If',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'does',
#   'not',
#   'think',
#   'that',
#   'the',
#   'proposed',
#   'adjustment',
#   'is',
#   'reasonable',
#   'she',
#   'will',
#   'discuss',
#   'alternative',
#   'options',
#   'with',
#   'the',
#   'Disability',
#   'team',
#   'who',
#   'may',
#   'then',
#   'discuss',
#   'these',
#   'with',
#   'the',
#   'student',
#   'before',
#   'any',
#   'adjustments',
#   'are',
#   'agreed'],
#  ['With',
#   'the',
#   'students',
#   'consent',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'produce',
#   'an',
#   'In',
#   'dividual',
#   'Student',
#   'Learning',
#   'Plan',
#   'ISLP',
#   'for',
#   'each',
#   'student',
#   'which',
#   'identifies',
#   'the',
#   'inclusive',
#   'approaches',
#   'and',
#   'reasonable',
#   'adjustments',
#   'required'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'then',
#   'forward',
#   'this',
#   'document',
#   'to',
#   'the',
#   'DisCo',
#   'in',
#   'the',
#   'relevant',
#   'academic',
#   'school',
#   'or',
#   'faculty'],
#  ['Without',
#   'consent',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'be',
#   'unable',
#   'to',
#   'progress',
#   'support',
#   'for',
#   'an',
#   'individual',
#   'student'],
#  ['A',
#   'copy',
#   'of',
#   'the',
#   'ISLP',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'relevant',
#   'DisCo',
#   'for',
#   'appropriate',
#   'circulation',
#   'within',
#   'the',
#   'schoolfaculty'],
#  ['Programme',
#   'leaders',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'relevant',
#   'academic',
#   'colleagues',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'reasonable',
#   'adjustment',
#   'required',
#   'for',
#   'students',
#   'within',
#   'their',
#   'cohorts'],
#  ['The',
#   'Disability',
#   'team',
#   'are',
#   'responsible',
#   'when',
#   'requested',
#   'to',
#   'by',
#   'a',
#   'student',
#   'for',
#   'ma',
#   'king',
#   'referrals',
#   'to',
#   'external',
#   'agencies',
#   'for',
#   'support',
#   'workers',
#   'and',
#   'should',
#   'be',
#   'considered',
#   'the',
#   'named',
#   'contact',
#   'for',
#   'this',
#   'element',
#   'of',
#   'provision'],
#  ['If',
#   'a',
#   'student',
#   'does',
#   'not',
#   'think',
#   'that',
#   'the',
#   'recommended',
#   'reasonable',
#   'adjustments',
#   'have',
#   'been',
#   'implemented',
#   'she',
#   'should',
#   'raise',
#   'this',
#   'wit',
#   'h',
#   'the',
#   'relevant',
#   'DisCo',
#   'in',
#   'the',
#   'first',
#   'instance'],
#  ['If',
#   'the',
#   'situation',
#   'is',
#   'not',
#   'resolved',
#   'through',
#   'this',
#   'approach',
#   'then',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'who',
#   'will',
#   'endeavour',
#   'to',
#   'work',
#   'with',
#   'the',
#   'appropriate',
#   'academic',
#   'area',
#   'and',
#   'find',
#   'an',
#   'appropriate',
#   'solution'],
#  ['If',
#   'the',
#   'student',
#   'remains',
#   'dissatisfied',
#   'then',
#   'she',
#   'should',
#   'make',
#   'a',
#   'complaint',
#   'using',
#   'the',
#   'student',
#   'complaints',
#   'procedure'],
#  ['The',
#   'impact',
#   'andor',
#   'nature',
#   'of',
#   'a',
#   'students',
#   'disability',
#   'may',
#   'change',
#   'over',
#   'the',
#   'course',
#   'of',
#   'their',
#   'period',
#   'of',
#   'study'],
#  ['This',
#   'may',
#   'result',
#   'in',
#   'the',
#   'anticipatory',
#   'suppo',
#   'rt',
#   'or',
#   'reasonable',
#   'adjustments',
#   'no',
#   'longer',
#   'being',
#   'appropriate'],
#  ['In',
#   'such',
#   'cases',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'at',
#   'the',
#   'earliest',
#   'opportunity',
#   'to',
#   'discuss',
#   'the',
#   'changes'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'identify',
#   'whether',
#   'there',
#   'are',
#   'additional',
#   'or',
#   'alternate',
#   'inclus',
#   'ive',
#   'approaches',
#   'or',
#   'reasonable',
#   'adjustments',
#   'needed'],
#  ['The', 'process', 'will', 'then', 'proceed', 'as', 'from', 'above'],
#  ['Occupational',
#   'health',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'students',
#   'on',
#   'regulated',
#   'vocational',
#   'programmes',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'study',
#   'and',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   't',
#   'o',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'studies'],
#  ['This',
#   'requires',
#   'them',
#   'to',
#   'meet',
#   'the',
#   'relevant',
#   'competence',
#   'standards',
#   'for',
#   'the',
#   'profession',
#   'with',
#   'reasonable',
#   'adjustments',
#   'if',
#   'required'],
#  ['Adjustments',
#   'which',
#   'may',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'context',
#   'of',
#   'study',
#   'may',
#   'not',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'c',
#   'ontext',
#   'of',
#   'professional',
#   'practice'],
#  ['Wherever',
#   'possible',
#   'the',
#   'fitness',
#   'to',
#   'practice',
#   'of',
#   'applicants',
#   'who',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'will',
#   'be',
#   'assessed',
#   'prior',
#   'to',
#   'the',
#   'applicant',
#   'entering',
#   'the',
#   'University'],
#  ['The',
#   'Occupational',
#   'Health',
#   'team',
#   'in',
#   'liaison',
#   'with',
#   'the',
#   'Programme',
#   'leader',
#   'm',
#   'ay',
#   'make',
#   'recommendations',
#   'for',
#   'reasonable',
#   'adjustments'],
#  ['Assistance',
#   'Animal',
#   's',
#   'The',
#   'Universitys',
#   'Health',
#   'and',
#   'Safety',
#   'policies',
#   'require',
#   'that',
#   'only',
#   'assistance',
#   'animals',
#   'be',
#   'allowed',
#   'onto',
#   'campus'],
#  ['For',
#   'this',
#   'purpose',
#   'therefore',
#   'only',
#   'assist',
#   'ance',
#   'animals',
#   'registered',
#   'with',
#   'an',
#   'appropriate',
#   'professio',
#   'nal',
#   'standards',
#   'body',
#   'will',
#   'be',
#   'allowed',
#   'into',
#   'University',
#   'buildings'],
#  ['If',
#   'a',
#   'request',
#   'is',
#   'made',
#   'through',
#   'the',
#   'Disability',
#   'team',
#   'this',
#   'information',
#   'will',
#   'be',
#   'passed',
#   'to',
#   'the',
#   'relevant',
#   'DisCo',
#   'and',
#   'to',
#   'the',
#   'Health',
#   'and',
#   'Safety',
#   'team',
#   'as',
#   'early',
#   'as',
#   'possible',
#   'to',
#   'allow',
#   'for',
#   'adjustments',
#   'such',
#   'as',
#   'spending',
#   'pens',
#   'to',
#   'be',
#   'made'],
#  ['The',
#   'owner',
#   'of',
#   'the',
#   'assistance',
#   'animal',
#   'will',
#   'be',
#   'asked',
#   'for',
#   'their',
#   'permission',
#   'to',
#   'communicate',
#   'this',
#   'fact',
#   'to',
#   'other',
#   'students',
#   'in',
#   'order',
#   'that',
#   'any',
#   'other',
#   'issues',
#   'can',
#   'be',
#   'circumvented',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'eg',
#   'allergies'],
#  ['The',
#   's',
#   'tudent',
#   'owner',
#   'of',
#   'the',
#   'animal',
#   'will',
#   'remain',
#   'responsible',
#   'for',
#   'the',
#   'animal',
#   'at',
#   'all',
#   'times'],
#  ['Complaints',
#   'In',
#   'the',
#   'first',
#   'instance',
#   'concerns',
#   'regarding',
#   'the',
#   'appropriate',
#   'andor',
#   'timely',
#   'nature',
#   'of',
#   'provision',
#   'of',
#   'support',
#   'should',
#   'b',
#   'e',
#   'directed',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'for',
#   'informal',
#   'resolution'],
#  ['If',
#   'a',
#   'student',
#   'having',
#   'first',
#   'referred',
#   'the',
#   'matter',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'services',
#   'believes',
#   'that',
#   'they',
#   'have',
#   'not',
#   'received',
#   'the',
#   'appropriate',
#   'reasonable',
#   'adjustments',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'can',
#   'study',
#   'effectively',
#   'the',
#   'matter',
#   'should',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'Student',
#   'Governance',
#   'team',
#   'to',
#   'be',
#   'addressed',
#   'through',
#   'the',
#   'Universitys',
#   'S',
#   'tudent',
#   'Complaints',
#   'procedure'],
#  ['This',
#   'can',
#   'be',
#   'accessed',
#   'using',
#   'the',
# ...
#   'on',
#   'the',
#   'number',
#   'of',
#   'disclosed',
#   'disabled',
#   'students',
#   'within',
#   'the',
#   'sch',
#   'ool',
#   'and',
#   'the',
#   'complexity',
#   'of',
#   'such',
#   'cases'],
#  ['A',
#   'Faculty',
#   'Department',
#   'or',
#   'School',
#   'should',
#   'al',
#   'low',
#   'for',
#   'multiple',
#   'individuals',
#   'to',
#   'undertake',
#   'the',
#   'DisCo',
#   'role',
#   'if',
#   'appropriate',
#   'to',
#   'local',
#   'circumstance',
#   's'],
#  ['The',
#   'Disability',
#   'Coordinator',
#   'will',
#   'Act',
#   'as',
#   'a',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'students',
#   'with',
#   'a',
#   'disability',
#   'support',
#   'need'],
#  ['Act',
#   'as',
#   'a',
#   'liaison',
#   'point',
#   'between',
#   'the',
#   'schooldepartment',
#   'and',
#   'the',
#   'Disability',
#   'team'],
#  ['Ensure',
#   'that',
#   'the',
#   'disclosure',
#   'of',
#   'disability',
#   'is',
#   'actively',
#   'encouraged',
#   'and',
#   'communicated',
#   'effectively',
#   'within',
#   'the',
#   'schooldepartment',
#   'including',
#   'from',
#   'academic',
#   'colleagues',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'and',
#   'in',
#   'reverse',
#   'where',
#   'appropriate'],
#  ['Liaise',
#   'with',
#   'relevant',
#   'colleagues',
#   'within',
#   'the',
#   'University',
#   'regarding',
#   'any',
#   'issues',
#   'relating',
#   'to',
#   'the',
#   'support',
#   'of',
#   'disabled',
#   'students'],
#  ['Raise',
#   'awareness',
#   'within',
#   'the',
#   'schooldepartment',
#   'of',
#   'issues',
#   'facing',
#   'students',
#   'with',
#   'disabilities',
#   'and',
#   'the',
#   'academic',
#   'implications',
#   'this',
#   'may',
#   'have'],
#  ['Work',
#   'with',
#   'standard',
#   'procedures',
#   'acros',
#   's',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'issues',
#   'of',
#   'disclosure',
#   'distribution',
#   'of',
#   'ISLPs',
#   'and',
#   'related',
#   'issues',
#   'are',
#   'dealt',
#   'with',
#   'in',
#   'a',
#   'consistent',
#   'and',
#   'systematic',
#   'manner',
#   'including',
#   'communication',
#   'with',
#   'relevant',
#   'academic',
#   'colleagues'],
#  ['Assist',
#   'the',
#   'DirectorHead',
#   'of',
#   'SchoolDepart',
#   'ment',
#   'to',
#   'ensure',
#   'that',
#   'a',
#   'robust',
#   'ISLP',
#   'records',
#   'system',
#   'is',
#   'in',
#   'operation',
#   'throughout',
#   'the',
#   'school'],
#  ['Coordinate',
#   'and',
#   'support',
#   'Schooldepartment',
#   'based',
#   'training',
#   'development',
#   'and',
#   'awareness',
#   'raising',
#   'activities',
#   'for',
#   'disability',
#   'support',
#   'liaising',
#   'with',
#   'relevant',
#   'Professional',
#   'serv',
#   'ices',
#   'staff',
#   'Disability',
#   'SupportEqual',
#   'Opportunities'],
#  ['Contribute',
#   'to',
#   'and',
#   'update',
#   'Disability',
#   'Support',
#   'infor',
#   'mation',
#   'on',
#   'the',
#   'Faculty',
#   'community',
#   'sites'],
#  ['Regularly',
#   'attend',
#   'meetings',
#   'of',
#   'the',
#   'University',
#   'DisCo',
#   'Steering',
#   'Group',
#   'and',
#   'cascade',
#   'relevant',
#   'information',
#   'within',
#   'the',
#   's',
#   'chool',
#   'or',
#   'faculty'],
#  ['Provide',
#   'support',
#   'and',
#   'advice',
#   'on',
#   'disability',
#   'matters',
#   'to',
#   'school',
#   'colleagues',
#   'ensuring',
#   'that',
#   'concerns',
#   'are',
#   'referred',
#   'effectively'],
#  [],
#  ['Appendix',
#   'Additional',
#   'Examination',
#   'Provision',
#   'In',
#   'certain',
#   'situations',
#   'it',
#   'is',
#   'appropriate',
#   'for',
#   'the',
#   'University',
#   'to',
#   'suppor',
#   't',
#   'students',
#   'through',
#   'formal',
#   'examinations',
#   'with',
#   'reasonable',
#   'adjustments'],
#  ['This',
#   'policy',
#   'document',
#   'outlines',
#   'the',
#   'provision',
#   'the',
#   'criteria',
#   'and',
#   'the',
#   'reasonable',
#   'adjustments',
#   'that',
#   'may',
#   'be',
#   'put',
#   'into',
#   'place'],
#  ['Provision',
#   'available',
#   'All',
#   'provision',
#   'will',
#   'be',
#   'facilitated',
#   'through',
#   'the',
#   'ISLP',
#   'Extra',
#   'time',
#   'this',
#   'will',
#   'be',
#   'available',
#   'for',
#   'all',
#   'students',
#   'able',
#   'to',
#   'demonstrate',
#   'need',
#   'within',
#   'the',
#   'main',
#   'sitting',
#   'of',
#   'the',
#   'exam',
#   'unless',
#   'combined',
#   'with',
#   'additional',
#   'reasonable',
#   'adjustments',
#   'A',
#   'Reader',
#   'this',
#   'will',
#   'provided',
#   'using',
#   'IT',
#   'facilities',
#   'within',
#   'each',
#   'faculty',
#   'and',
#   'will',
#   'be',
#   'prerecorded',
#   'by',
#   'a',
#   'member',
#   'of',
#   'staff',
#   'familiar',
#   'with',
#   'the',
#   'terminology',
#   'used'],
#  ['Amanuensis',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'Rest',
#   'Breaks',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'In',
#   'all',
#   'cases',
#   'where',
#   'a',
#   'separate',
#   'location',
#   'may',
#   'be',
#   'needed',
#   'it',
#   'would',
#   'also',
#   'be',
#   'appropriate',
#   'for',
#   'academic',
#   'colleagues',
#   'to',
#   'consider',
#   'alternative',
#   'assessment'],
#  ['It',
#   'may',
#   'be',
#   'that',
#   'the',
#   'learning',
#   'outcomes',
#   'can',
#   'be',
#   'addressed',
#   'via',
#   'an',
#   'alternative',
#   'method',
#   'of',
#   'assessment',
#   'and',
#   'this',
#   'should',
#   'be',
#   'discussed',
#   'as',
#   'early',
#   'as',
#   'possible',
#   'in',
#   'the',
#   'academic',
#   'year'],
#  ['Eligibility',
#   'for',
#   'Additional',
#   'examination',
#   'provision',
#   'AEP',
#   'Students',
#   'must',
#   'have',
#   'disclosed',
#   'a',
#   'disability',
#   'medical',
#   'condition',
#   'or',
#   'specific',
#   'learning',
#   'difficulty',
#   'to',
#   'the',
#   'University',
#   'as',
#   'soon',
#   'as',
#   'possible',
#   'after',
#   'diagno',
#   'sis',
#   'or',
#   'enrolment',
#   'at',
#   'the',
#   'institution',
#   'whichever',
#   'occurs',
#   'first',
#   'and',
#   'in',
#   'advance',
#   'of',
#   'the',
#   'assessment',
#   'period',
#   'as',
#   'per',
#   'the',
#   'process',
#   'below'],
#  ['Eligibility',
#   'for',
#   'AEP',
#   'will',
#   'be',
#   'documented',
#   'in',
#   'the',
#   'form',
#   'of',
#   'a',
#   'formal',
#   'Individual',
#   'Student',
#   'Learning',
#   'Plan',
#   'or',
#   'a',
#   'Needs',
#   'Assessment',
#   'document'],
#  ['No', 'other', 'evidence', 'will', 'be', 'accepted'],
#  ['In',
#   'the',
#   'event',
#   'of',
#   'a',
#   'temporary',
#   'or',
#   'newly',
#   'disclosed',
#   'disability',
#   'a',
#   'doctors',
#   'letter',
#   'will',
#   'be',
#   'acceptable',
#   'and',
#   'provision',
#   'will',
#   'be',
#   'put',
#   'into',
#   'place',
#   'for',
#   'the',
#   'impending',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'not',
#   'continue',
#   'for',
#   'the',
#   'duration',
#   'of',
#   'the',
#   'course'],
#  ['Please',
#   'note',
#   'applications',
#   'received',
#   'after',
#   'the',
#   'week',
#   'working',
#   'days',
#   'deadline',
#   'referred',
#   'to',
#   'in',
#   'Process',
#   'below',
#   'will',
#   'not',
#   'be',
#   'considered',
#   'for',
#   'the',
#   'immediate',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'be',
#   'actioned',
#   'prior',
#   'to',
#   'subsequent',
#   'periods'],
#  ['Please',
#   'note',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'a',
#   'review',
#   'will',
#   'be',
#   'carried',
#   'out',
#   'by',
#   'Faculty',
#   'Examination',
#   'officers',
#   'and',
#   'any',
#   'students',
#   'who',
#   'do',
#   'not',
#   'take',
#   'up',
#   'the',
#   'provision',
#   'allocated',
#   'to',
#   'them',
#   'will',
#   'be',
#   'asked',
#   'to',
#   'review',
#   'this',
#   'position'],
#  ['This', 'may', 'result', 'in', 'the', 'provision', 'being', 'withdrawn'],
#  ['Process',
#   'The',
#   'AEP',
#   'application',
#   'form',
#   'will',
#   'be',
#   'available',
#   'at',
#   'httpsmyservicesljmuacukFormsAdditionalExamProvisionsaspx'],
#  ['The', 'form', 'should', 'be', 'completed', 'and', 'submitted', 'online'],
#  ['The',
#   'completed',
#   'form',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'appropriate',
#   'Facu',
#   'lty',
#   'where',
#   'access',
#   'will',
#   'be',
#   'restricted',
#   'to',
#   'a',
#   'small',
#   'number',
#   'of',
#   'staff',
#   'working',
#   'on',
#   'a',
#   'need',
#   'to',
#   'know',
#   'basis'],
#  ['Applications',
#   'for',
#   'AEP',
#   'should',
#   'be',
#   'made',
#   'as',
#   'early',
#   'as',
#   'possible',
#   'and',
#   'no',
#   'later',
#   'than',
#   'weeks',
#   'working',
#   'days',
#   'prior',
#   'to',
#   'the',
#   'start',
#   'of',
#   'the',
#   'assessment',
#   'period'],
#  ['An',
#   'applicat',
#   'ion',
#   'for',
#   'AEP',
#   'will',
#   'remain',
#   'in',
#   'place',
#   'for',
#   'the',
#   'entirety',
#   'of',
#   'the',
#   'students',
#   'course',
#   'and',
#   'therefore',
#   'there',
#   'is',
#   'no',
#   'requirement',
#   'for',
#   'submission',
#   'every',
#   'year'],
#  ['However',
#   'should',
#   'AEP',
#   'be',
#   'in',
#   'place',
#   'but',
#   'not',
#   'utilised',
#   'this',
#   'may',
#   'result',
#   'in',
#   'withdrawal',
#   'of',
#   'this',
#   'provision'],
#  ['NB',
#   'Flexibility',
#   'will',
#   'be',
#   'needed',
#   'with',
#   'extra',
#   'time',
#   'as',
#   'this',
#   'may',
#   'not',
#   'be',
#   'used',
#   'at',
#   'every',
#   'opportunity',
#   'but',
#   'the',
#   'student',
#   'may',
#   'still',
#   'wish',
#   'to',
#   'retain',
#   'it'],
#  ['Faculty',
#   'Examinations',
#   'staff',
#   'will',
#   'review',
#   'usage',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'and',
#   'contact',
#   'students',
#   'accordingly'],
#  ['If',
#   'at',
#   'review',
#   'a',
#   'student',
#   'states',
#   'that',
#   'they',
#   'no',
#   'longer',
#   'need',
#   'the',
#   'provision',
#   'this',
#   'should',
#   'be',
#   'reported',
#   'in',
#   'writing',
#   'and',
#   'appended',
#   'to',
#   'the',
#   'ISLP'],
#  ['The',
#   'provision',
#   'can',
#   'be',
#   'cancelled',
#   'and',
#   'a',
#   'copy',
#   'of',
#   'the',
#   'correspondence',
#   'sent',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'for',
#   'completeness'],
#  ['If',
#   'at',
#   'r',
#   'eview',
#   'a',
#   'student',
#   'states',
#   'that',
#   'they',
#   'do',
#   'still',
#   'require',
#   'the',
#   'provision',
#   'provision',
#   'will',
#   'be',
#   'kept',
#   'in',
#   'place',
#   'for',
#   'a',
#   'subsequent',
#   'assessment',
#   'period'],
#  ['If',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'second',
#   'period',
#   'provision',
#   'has',
#   'not',
#   'been',
#   'utilised',
#   'the',
#   'University',
#   'will',
#   'withdraw',
#   'the',
#   'provision'],
#  ['Faculty',
#   'staff',
#   'should',
#   'send',
#   'written',
#   'confirmation',
#   'of',
#   'this',
#   'to',
#   'the',
#   'Disability',
#   'team'],
#  ['Faculty',
#   'administration',
#   'staff',
#   'will',
#   'contact',
#   'students',
#   'ahead',
#   'of',
#   'the',
#   'assessment',
#   'periods',
#   'each',
#   'year',
#   'to',
#   'update',
#   'module',
#   'choice',
#   'and',
#   'ascertain',
#   'if',
#   'provision',
#   'is',
#   'still',
#   'needed'],
#  ['Appendix',
#   'LJMU',
#   'Spe',
#   'cific',
#   'Learning',
#   'Difficulties',
#   'and',
#   'Dyslexia',
#   'Policy',
#   'Background',
#   'Institutions',
#   'are',
#   'expected',
#   'to',
#   'ensure',
#   'that',
#   'provision',
#   'and',
#   'support',
#   'is',
#   'available',
#   'both',
#   'within',
#   'the',
#   'curriculum',
#   'and',
#   'generally',
#   'through',
#   'learning',
#   'and',
#   'teaching',
#   'methods'],
#  ['LJMU',
#   'will',
#   'ensure',
#   'that',
#   'anticipatory',
#   'adjustments',
#   'and',
#   'provision',
#   'for',
#   'students',
#   'with',
#   'mild',
#   'dyslexia',
#   'is',
#   'incorporated',
#   'into',
#   'the',
#   'learning',
#   'environment',
#   'and',
#   'therefore',
#   'should',
#   'not',
#   'need',
#   'to',
#   'be',
#   'individually',
#   'addressed'],
#  ['Provision',
#   'for',
#   'those',
#   'students',
#   'with',
#   'moderate',
#   'to',
#   'severe',
#   'SpL',
#   'd',
#   'and',
#   'Dyslexia',
#   'will',
#   'continue',
#   'to',
#   'be',
#   'addressed',
#   'individually'],
#  ['LJMU',
#   'complies',
#   'with',
#   'the',
#   'Equality',
#   'Act',
#   'the',
#   'Disability',
#   'Discrimination',
#   'Act',
#   'and',
#   'Special',
#   'Educational',
#   'Needs',
#   'Disability',
#   'Act',
#   'in',
#   'ensuring',
#   'that',
#   'all',
#   'students',
#   'are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'provi',
#   'sion',
#   'of',
#   'education',
#   'and',
#   'associated',
#   'services'],
#  ['The',
#   'inclusion',
#   'of',
#   'the',
#   'anticipatory',
#   'duty',
#   'ensures',
#   'that',
#   'the',
#   'institution',
#   'continues',
#   'to',
#   'review',
#   'policy',
#   'and',
#   'procedure',
#   'regularly',
#   'and',
#   'through',
#   'student',
#   'partnership'],
#  ['This',
#   'policy',
#   'is',
#   'part',
#   'of',
#   'the',
#   'wider',
#   'institutional',
#   'policy',
#   'on',
#   'D',
#   'isability',
#   'provision',
#   'for',
#   'students',
#   'Diagnostic',
#   'Support',
#   'It',
#   'is',
#   'anticipated',
#   'that',
#   'the',
#   'majority',
#   'of',
#   'students',
#   'coming',
#   'into',
#   'higher',
#   'education',
#   'will',
#   'have',
#   'received',
#   'appropriate',
#   'support',
#   'and',
#   'assessment',
#   'whilst',
#   'in',
#   'primary',
#   'or',
#   'secondary',
#   'education'],
#  ['In',
#   'the',
#   'event',
#   'of',
#   'students',
#   'not',
#   'having',
#   'received',
#   'such',
#   'an',
#   'assessment',
#   'or',
#   'not',
#   'having',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'assessment',
#   'LJMU',
#   'will',
#   'm',
#   'ake',
#   'available',
#   'a',
#   'formal',
#   'assessment'],
#  ['Provision',
#   'of',
#   'support',
#   'Eligibility',
#   'for',
#   'formal',
#   'Educational',
#   'Psychologists',
#   'assessment',
#   'Undergraduate',
#   'and',
#   'post',
#   'graduate'],
#  ['Studying',
#   'on',
#   'a',
#   'programme',
#   'with',
#   'a',
#   'duration',
#   'of',
#   'an',
#   'academic',
#   'year',
#   'or',
#   'longer',
#   'First',
#   'language',
#   'must',
#   'be',
#   'English',
#   'defined',
#   'as',
#   'educated',
#   'in',
#   'the',
#   'UK',
#   'from',
#   'the',
#   'age',
#   'of'],
#  ['Translations',
#   'of',
#   'assessment',
#   'reports',
#   'will',
#   'be',
#   'accepted',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'but',
#   'due',
#   'to',
#   'the',
#   'inab',
#   'ility',
#   'of',
#   'the',
#   'tests',
#   'to',
#   'assess',
#   'dyslexia',
#   'versus',
#   'language',
#   'issues',
#   'we',
#   'are',
#   'unable',
#   'to',
#   'assess',
#   'those',
#   'with',
#   'another',
#   'first',
#   'language'],
#  ['Student',
#   'attending',
#   'a',
#   'course',
#   'with',
#   'a',
#   'collaborative',
#   'partner',
#   'should',
#   'access',
#   'support',
#   'through',
#   'the',
#   'provider',
#   'college'],
#  ['Internal',
#   'Screening',
#   'exer',
#   'cise',
#   'results',
#   'in',
#   'a',
#   'possibility',
#   'of',
#   'moderate',
#   'to',
#   'severe',
#   'dyslexia',
#   'Funding',
#   'implications',
#   'There',
#   'is',
#   'a',
#   'cost',
#   'associated',
#   'with',
#   'each',
#   'Educational',
#   'Psychologists',
#   'report'],
#  ['Students',
#   'are',
#   'expected',
#   'to',
#   'meet',
#   'the',
#   'eligibility',
#   'criteria',
#   'above',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'inform',
#   'LJMU',
#   'a',
#   't',
#   'least',
#   'hours',
#   'in',
#   'advance',
#   'if',
#   'they',
#   'unable',
#   'to',
#   'attend',
#   'the',
#   'assessment',
#   'meeting'],
#  ['Students',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'of',
#   'the',
#   'charge',
#   'due',
#   'for',
#   'an',
#   'assessment'],
#  ['LJMU',
#   'will',
#   'meet',
#   'the',
#   'remaining',
#   'costs',
#   'of',
#   'each',
#   'assessment',
#   'up',
#   'to',
#   'an',
#   'annual',
#   'pre',
#   'determined',
#   'maximum'],
#  ['Students',
#   'will',
#   'be',
#   'reminded',
#   'of',
#   'appointments',
#   'through',
#   'a',
#   'variety',
#   'of',
#   'timely',
#   'media',
#   'such',
#   'as',
#   'email',
#   'SMS',
#   'text',
#   'outlook',
#   'appointments',
#   'and',
#   'so',
#   'on'],
#  ['Students',
#   'who',
#   'fail',
#   'to',
#   'attend',
#   'their',
#   'assessment',
#   'appointment',
#   'w',
#   'ill',
#   'be',
#   'charged',
#   'the',
#   'full',
#   'fee',
#   'incurred',
#   'by',
#   'the',
#   'university',
#   'through',
#   'the',
#   'usual',
#   'charging',
#   'mechanisms',
#   'within',
#   'the',
#   'University'],
#  ['A',
#   'budget',
#   'will',
#   'be',
#   'established',
#   'to',
#   'ensure',
#   'that',
#   'this',
#   'is',
#   'not',
#   'a',
#   'first',
#   'come',
#   'first',
#   'served',
#   'budget',
#   'position',
#   'but',
#   'is',
#   'based',
#   'on',
#   'need'],
#  ['Irlen',
#   'SyndromeScotopic',
#   'Sensitivity',
#   'Funding',
#   'will',
#   'be',
#   'made',
#   'available',
#   'for',
#   'stu',
#   'dents',
#   'to',
#   'receive',
#   'this',
#   'test',
#   'should',
#   'it',
#   'be',
#   'deemed',
#   'appropriate',
#   'through',
#   'the',
#   'Educational',
#   'Psychologists',
#   'ass',
#   'essment'],
#  ['Coloured',
#   'overlays',
#   'can',
#   'be',
#   'purchased',
#   'to',
#   'assist',
#   'students',
#   'rather',
#   'than',
#   'the',
#   'provision',
#   'of',
#   'pastel',
#   'paper'],
#  []]

# %%
#lemmatize
postlemma = []

for i in cleaned_tokenized_p1: 
    postlemma.append([lemmatizer.lemmatize(j) for j in i])

# %%
postlemma
# Out:
# [['Disability',
#   'Policy',
#   'Students',
#   'Provision',
#   'of',
#   'support',
#   'Responsibility',
#   'for',
#   'Policy',
#   'University',
#   'Registrar',
#   'and',
#   'Chief',
#   'Operating',
#   'Officer',
#   'Relevant',
#   'to',
#   'All',
#   'LJMU',
#   'Staff',
#   'and',
#   'Students',
#   'Approved',
#   'by',
#   'Academic',
#   'Board',
#   'March',
#   'Responsibility',
#   'for',
#   'Document',
#   'Review',
#   'Director',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'Services'],
#  ['Date',
#   'introduced',
#   'January',
#   'Dates',
#   'modified',
#   'February',
#   'February',
#   'Next',
#   'Review',
#   'Date',
#   'February',
#   'RELEVANT',
#   'DOCUMENTS',
#   'Equality',
#   'Act',
#   'Special',
#   'Educational',
#   'Needs',
#   'and',
#   'Disability',
#   'Act',
#   'Disability',
#   'Discrimination',
#   'Act',
#   'Public',
#   'Sector',
#   'Bodies',
#   'Website',
#   'and',
#   'Mobile',
#   'Applications',
#   'Accessibility',
#   'regulation',
#   'RELATED',
#   'POLICIES',
#   'DOCUMENTS',
#   'LJMU',
#   'Equality',
#   'and',
#   'Diversity',
#   'policy',
#   'SCP',
#   'Evacuation',
#   'Procedures',
#   'SCP',
#   'Personal',
#   'Emergency',
#   'Evacuation',
#   'Plans',
#   'Student',
#   'Complaints',
#   'Procedure',
#   'Fitness',
#   'to',
#   'Study',
#   'policy',
#   'Fitness',
#   'to',
#   'Practice',
#   'Policy',
#   'Academic',
#   'Framework',
#   'Code',
#   'of',
#   'Practice',
#   'for',
#   'Placements',
#   'Policy',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'reasonable',
#   'adjustment',
#   'and',
#   'support',
#   'for',
#   'Disabled',
#   'student',
#   'Introduction',
#   'Liverpool',
#   'John',
#   'Moores',
#   'University',
#   'LJMU',
#   'is',
#   'committed',
#   'to',
#   'providing',
#   'an',
#   'inclusive',
#   'and',
#   'accessible',
#   'environment',
#   'which',
#   'enables',
#   'all',
#   'student',
#   'to',
#   'reach',
#   'their',
#   'potentia',
#   'l'],
#  ['A',
#   'wide',
#   'range',
#   'of',
#   'provision',
#   'is',
#   'available',
#   'to',
#   'support',
#   'student',
#   'including',
#   'specialist',
#   'support',
#   'support',
#   'through',
#   'academic',
#   'faculty',
#   'department',
#   'and',
#   'school',
#   'and',
#   'appropriate',
#   'policy',
#   'and',
#   'procedure'],
#  ['This',
#   'policy',
#   'set',
#   'out',
#   'how',
#   'LJMU',
#   'meet',
#   'it',
#   'obligation',
#   'under',
#   'th',
#   'e',
#   'Equality',
#   'Act'],
#  ['It',
#   'identifies',
#   'the',
#   'Universitys',
#   'approach',
#   'to',
#   'supporting',
#   'disabled',
#   'student',
#   'and',
#   'formalises',
#   'area',
#   'of',
#   'responsibility'],
#  ['The',
#   'policy',
#   'is',
#   'supported',
#   'by',
#   'the',
#   'procedure',
#   'within',
#   'this',
#   'document',
#   'either',
#   'appended',
#   'or',
#   'referenced'],
#  ['Duty',
#   'to',
#   'Make',
#   'Reasonable',
#   'A',
#   'djustments',
#   'As',
#   'provided',
#   'for',
#   'by',
#   'the',
#   'Equality',
#   'Act',
#   'LJMU',
#   'ha',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'for',
#   'disabled',
#   'student',
#   'and',
#   'this',
#   'duty',
#   'ha',
#   'been',
#   'further',
#   'highlighted',
#   'by',
#   'the',
#   'change',
#   'made',
#   'to',
#   'the',
#   'Disabled',
#   'Students',
#   'Allowance',
#   'DSA'],
#  ['The',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'requires',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'have',
#   'anticipated',
#   'and',
#   'taken',
#   'reasonable',
#   'step',
#   'to',
#   'address',
#   'barrier',
#   'which',
#   'put',
#   'disabled',
#   'student',
#   'at',
#   'a',
#   'substantial',
#   'disadvantage',
#   'in',
#   'relation',
#   'to',
#   'a',
#   'relevant',
#   'matter',
#   'when',
#   'compared',
#   'to',
#   'no',
#   'ndisabled',
#   'student'],
#  ['In',
#   'particular',
#   'there',
#   'is',
#   'a',
#   'requirement',
#   'on',
#   'institution',
#   'under',
#   'new',
#   'DSA',
#   'regulation',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'provision',
#   'of',
#   'non',
#   'medical',
#   'help',
#   'is',
#   'available',
#   'where',
#   'appropriate'],
#  ['This',
#   'provision',
#   'applies',
#   'to',
#   'delivery',
#   'of',
#   'LJMU',
#   'business',
#   'within',
#   'the',
#   'UK'],
#  ['The',
#   'intention',
#   'is',
#   'that',
#   'the',
#   'learning',
#   'environment',
#   'should',
#   'be',
#   'a',
#   'inclusive',
#   'a',
#   'possible',
#   'so',
#   'that',
#   'individual',
#   'intervention',
#   'are',
#   'the',
#   'exception',
#   'not',
#   'the',
#   'rule'],
#  ['Institutional',
#   'responsibility',
#   'LJMU',
#   'wish',
#   'to',
#   'maintain',
#   'an',
#   'environment',
#   'in',
#   'which',
#   'disabled',
#   'student',
#   'are',
#   'able',
#   'to',
#   'fully',
#   'participate',
#   'in',
#   'the',
#   'student',
#   'experience',
#   'and',
#   'will',
#   'therefore',
#   'take',
#   'all',
#   'reasonable',
#   'step',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'student',
#   'Have',
#   'access',
#   'to',
#   'appropriate',
#   'learning',
#   'and',
#   'teaching',
#   'support',
#   'for',
#   'mandatory',
#   'element',
#   'of',
#   'academic',
#   'programme',
#   'Mandatory',
#   'refers',
#   't',
#   'o',
#   'element',
#   'of',
#   'the',
#   'course',
#   'that',
#   'are',
#   'required',
#   'in',
#   'order',
#   'to',
#   'successfully',
#   'achieve',
#   'the',
#   'target',
#   'award',
#   'and',
#   'will',
#   'include',
#   'both',
#   'core',
#   'and',
#   'optional',
#   'module'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'estate',
#   'and',
#   'building',
#   'utilised',
#   'in',
#   'the',
#   'provision',
#   'of',
#   'teaching',
#   'and',
#   'learning',
#   'and',
#   'associated',
#   's',
#   'ervices'],
#  ['Have',
#   'access',
#   'to',
#   'specialist',
#   'staff',
#   'who',
#   'are',
#   'able',
#   'to',
#   'advise',
#   'on',
#   'the',
#   'range',
#   'and',
#   'extent',
#   'of',
#   'provision',
#   'available',
#   'throughout',
#   'the',
#   'institution'],
#  ['Have',
#   'documented',
#   'support',
#   'plan',
#   'in',
#   'place',
#   'including',
#   'where',
#   'appropriate',
#   'for',
#   'a',
#   'period',
#   'of',
#   'placement'],
#  ['Can', 'access', 'IT', 'facility', 'and', 'service'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'learning',
#   'material',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'whether',
#   'in',
#   'hardcopy',
#   'electronic',
#   'or',
#   'other',
#   'format'],
#  ['Are',
#   'able',
#   'to',
#   'access',
#   'additional',
#   'support',
#   'which',
#   'may',
#   'or',
#   'may',
#   'not',
#   'be',
#   'represented',
#   'in',
#   'a',
#   'formal',
#   'need',
#   'assessment',
#   'in',
#   'the',
#   'form',
#   'of',
#   'nonmedical',
#   'help'],
#  ['Have',
#   'access',
#   'to',
#   'quiet',
#   'or',
#   'le',
#   'formal',
#   'environment',
#   'to',
#   'enable',
#   'student',
#   'to',
#   'have',
#   'time',
#   'away',
#   'should',
#   'they',
#   'require',
#   'it'],
#  ['Non',
#   'medical',
#   'help',
#   'is',
#   'defined',
#   'a',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'assistant',
#   'such',
#   'a',
#   'scribe',
#   'reader',
#   'lab',
#   'assistant',
#   'etc',
#   'and',
#   'Enhanced',
#   'Support',
#   'Assistants',
#   'such',
#   'a',
#   'examination',
#   'support',
#   'worker',
#   'notetakers',
#   'study',
#   'assistant'],
#  ['These',
#   'were',
#   'previously',
#   'identified',
#   'a',
#   'Band',
#   'and',
#   'Band',
#   'NMH',
#   'Support'],
#  ['Scope',
#   'This',
#   'policy',
#   'address',
#   'all',
#   'aspect',
#   'of',
#   'support',
#   'for',
#   'disabled',
#   'applicant',
#   'and',
#   'student',
#   'at',
#   'LJMU'],
#  ['This',
#   'policy',
#   'applies',
#   'to',
#   'all',
#   'student',
#   'studying',
#   'with',
#   'LJMU',
#   'within',
#   'the',
#   'UK',
#   'regardless',
#   'of',
#   'mode',
#   'of',
#   'study'],
#  ['However',
#   'student',
#   'on',
#   's',
#   'hort',
#   'professional',
#   'CPD',
#   'course',
#   'will',
#   'be',
#   'advised',
#   'and',
#   'assessed',
#   'based',
#   'on',
#   'the',
#   'duration',
#   'and',
#   'intensity',
#   'of',
#   'their',
#   'study'],
#  ['The', 'principle', 'of', 'this', 'policy', 'apply', 'to', 'all', 'cohort'],
#  ['Students',
#   'who',
#   'disclosed',
#   'or',
#   'declared',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'prior',
#   'to',
#   'September',
#   'may',
#   'have',
#   'their',
#   'need',
#   'met',
#   'using',
#   'a',
#   'slightly',
#   'different',
#   'process',
#   'due',
#   'to',
#   'changing',
#   'external',
#   'student',
#   'finance',
#   'arrangement'],
#  ['Responsibilities',
#   'This',
#   'section',
#   'outline',
#   'the',
#   'role',
#   'an',
#   'd',
#   'responsibility',
#   'of',
#   'key',
#   'area',
#   'across',
#   'the',
#   'institution'],
#  ['It',
#   'doe',
#   'not',
#   'contain',
#   'operational',
#   'detail',
#   'of',
#   'these',
#   'responsibility'],
#  ['Further',
#   'information',
#   'about',
#   'relevant',
#   'procedure',
#   'should',
#   'be',
#   'available',
#   'from',
#   'the',
#   'relevant',
#   'area',
#   'andor',
#   'from',
#   'the',
#   'Disability',
#   'team',
#   'within',
#   'S',
#   'tudent',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service'],
#  ['ELT',
#   'are',
#   'responsible',
#   'for',
#   'the',
#   'Universitys',
#   'strategy',
#   'with',
#   'regard',
#   'to',
#   'disabled',
#   'student',
#   'ensuring',
#   'compliance',
#   'with',
#   'the',
#   'Equality',
#   'Act',
#   'and',
#   'regulating',
#   'the',
#   'associated',
#   'resource',
#   'to',
#   'fund',
#   'support',
#   'for',
#   'disabled',
#   'student'],
#  ['Equality',
#   'Diversity',
#   'and',
#   'Inclusivity',
#   'Committee',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'compli',
#   'ance',
#   'with',
#   'this',
#   'policy',
#   'requesting',
#   'appropriate',
#   'change',
#   'and',
#   'making',
#   'recommendation',
#   'to',
#   'EL',
#   'T',
#   'for',
#   'amendment',
#   'to',
#   'policy',
#   'and',
#   'practice'],
#  ['Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'advising',
#   'the',
#   'University',
#   'about',
#   'strategy',
#   'and',
#   'policy',
#   'in',
#   'relation',
#   'to',
#   'disabled',
#   'student',
#   'and',
#   'identifying',
#   'the',
#   'impact',
#   'of',
#   'change',
#   'in',
#   'the',
#   'external',
#   'environment',
#   'on',
#   'University',
#   'provision'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'contract',
#   'are',
#   'in',
#   'place',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'worker',
#   'and',
#   'hold',
#   'the',
#   'Disability',
#   'budget',
#   'to',
#   'ensure',
#   'additional',
#   'reasonable',
#   'adjustment',
#   'can',
#   'be',
#   'made',
#   'where',
#   'other',
#   'source',
#   'of',
#   'funding',
#   'are',
#   'not',
#   'available'],
#  ['The',
#   'Student',
#   'Support',
#   'M',
#   'anager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'them',
#   'through',
#   'the',
#   'Disability',
#   'team'],
#  ['Once',
#   'student',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'the',
#   'Student',
#   'Support',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'they',
#   'have',
#   'an',
#   'appropriate',
#   'Indivi',
#   'dual',
#   'Student',
#   'Learning',
#   'Plan',
#   'ISLP',
#   'which',
#   'identifies',
#   'relevant',
#   'inclusive',
#   'approach',
#   'to',
#   'provision',
#   'and',
#   'where',
#   'appropriate',
#   'identifies',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'reduce',
#   'barrier',
#   'to',
#   'the',
#   'student',
#   'participation',
#   'in',
#   'their',
#   'academic',
#   'program',
#   'me'],
#  ['The',
#   'Disability',
#   'team',
#   'are',
#   'responsible',
#   'for',
#   'engaging',
#   'with',
#   'and',
#   'receiving',
#   'consent',
#   'from',
#   'student',
#   'in',
#   'order',
#   'that',
#   'they',
#   'can',
#   'create',
#   'store',
#   'andor',
#   'communicate',
#   'the',
#   'ISLP',
#   'and',
#   'associated',
#   'document',
#   'to',
#   'all',
#   'relevant',
#   'party',
#   'and',
#   'are',
#   'responsible',
#   'for',
#   'providing',
#   'advice',
#   't',
#   'o',
#   'student',
#   'and',
#   'staff',
#   'on',
#   'disability',
#   'related',
#   'matter'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'store',
#   'the',
#   'master',
#   'copy',
#   'of',
#   'an',
#   'individual',
#   'student',
#   'ISLP',
#   'and',
#   'a',
#   'copy',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'student',
#   'and',
#   'the',
#   'relevant',
#   'Disability',
#   'Coordinator'],
#  ['The',
#   'Disability',
#   'team',
#   'also',
#   'cover',
#   'Specialist',
#   'Study',
#   'Skills',
#   'tutor',
#   'who',
#   'work',
#   'directly',
#   'with',
#   'student'],
#  ['Directors',
#   'of',
#   'SchoolHeads',
#   'of',
#   'Department',
#   'are',
#   'responsible',
#   'for',
#   'en',
#   'suring',
#   'that',
#   'an',
#   'ISLP',
#   'is',
#   'effectively',
#   'communicated',
#   'within',
#   'the',
#   'school',
#   'or',
#   'department',
#   'and',
#   'for',
#   'the',
#   'health',
#   'and',
#   'safety',
#   'of',
#   'disabled',
#   'student',
#   'includ',
#   'ing',
#   'ensuring',
#   'that',
#   'disabled',
#   'student',
#   'who',
#   'require',
#   'one',
#   'have',
#   'a',
#   'Personal',
#   'Emergency',
#   'Evacuation',
#   'Plan',
#   'PEEP'],
#  ['They',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'reasonable',
#   'adjustment',
#   'are',
#   'in',
#   'place',
#   'for',
#   'assessment',
#   'organised',
#   'within',
#   'the',
#   'departmentschool',
#   'including',
#   'in',
#   'class',
#   'test'],
#  ['DirectorsHeads',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'teaching',
#   'and',
#   'learning',
#   'material',
#   'and',
#   'practice',
#   'within',
#   'their',
#   'area',
#   'meet',
#   'the',
#   'agreed',
#   'need',
#   'of',
#   'disabled',
#   'student'],
#  ['DirectorsHeads',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'the',
#   'availability',
#   'and',
#   'remit',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   's',
#   'including',
#   'the',
#   'Disability',
#   'team'],
#  ['Disability',
#   'Coordinators',
#   'DisCo',
#   'are',
#   'school',
#   'and',
#   'faculty',
#   'based',
#   'staff',
#   'with',
#   'responsibility',
#   'for',
#   'ensuring',
#   'relevant',
#   'academic',
#   'and',
#   'admin',
#   'istrative',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'student',
#   's',
#   'support',
#   'need',
#   'and',
#   'for',
#   'coordinating',
#   'school',
#   'based',
#   'support'],
#  ['See',
#   'appendix',
#   'for',
#   'the',
#   'Disability',
#   'Coordinator',
#   'role',
#   'descriptor',
#   'Programme',
#   'Leaders',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'the',
#   'curriculum',
#   'of',
#   'their',
#   'programme',
#   'and',
#   'identifying',
#   'app',
#   'ropriate',
#   'inclusive',
#   'approach'],
#  ['Module',
#   'Leaders',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'student',
#   'on',
#   'the',
#   'module',
#   'require',
#   'reasonable',
#   'adjustment',
#   'and',
#   'ensuring',
#   'that',
#   'programme',
#   'colleague',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'requirement'],
#  ['This',
#   'information',
#   'is',
#   'available',
#   'from',
#   't',
#   'he',
#   'DisCo',
#   'and',
#   'Programme',
#   'Leaders',
#   'in',
#   'each',
#   'schooldepartment'],
#  ['Personal',
#   'tutor',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'student',
#   'within',
#   'their',
#   'tutee',
#   'group',
#   'require',
#   'reasonable',
#   'adjustment',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'student',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'the',
#   'm'],
#  ['All',
#   'Programme',
#   'staff',
#   'are',
#   'responsible',
#   'for',
#   'implementing',
#   'relevant',
#   'reasonable',
#   'adjustment',
#   'a',
#   'detailed',
#   'within',
#   'the',
#   'student',
#   'ISLP'],
#  ['The',
#   'ISLP',
#   'will',
#   'be',
#   'created',
#   'a',
#   'per',
#   'Section',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'in',
#   'consultation',
#   'between',
#   'all',
#   'relevant',
#   'party'],
#  ['The',
#   'Directo',
#   'r',
#   'of',
#   'Library',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'disabled',
#   'student',
#   'are',
#   'able',
#   'to',
#   'access',
#   'all',
#   'Library',
#   'provision',
#   'and',
#   'that',
#   'they',
#   'have',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'support',
#   'and',
#   'training'],
#  ['The',
#   'Director',
#   'of',
#   'Student',
#   'Advancement',
#   'is',
#   'responsible',
#   'for',
#   'ensu',
#   'ring',
#   'that',
#   'the',
#   'service',
#   'delivered',
#   'are',
#   'appropriate',
#   'to',
#   'the',
#   'need',
#   'of',
#   'disabled',
#   'student',
#   'and',
#   'graduate'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'Code',
#   'of',
#   'Practice',
#   'for',
#   'Placements',
#   'address',
#   'the',
#   'need',
#   'of',
#   'disabled',
#   'student'],
#  ['The',
#   'Director',
#   'of',
#   'IT',
#   'Services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'software',
#   'and',
#   'hardware',
#   'is',
#   'available',
#   'for',
#   'disabled',
#   'student',
#   'including',
#   'training',
#   'on',
#   'such',
#   'equipment'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'University',
#   'corporate',
#   'system',
#   'including',
#   'the',
#   'website',
#   'are',
#   'inclusi',
#   've',
#   'and',
#   'accessible'],
#  ['The',
#   'Director',
#   's',
#   'of',
#   'Estates',
#   'and',
#   'Facilities',
#   'Management',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'the',
#   'University',
#   'campus',
#   'including',
#   'all',
#   'University',
#   'building',
#   'is',
#   'physically',
#   'accessible',
#   'and',
#   'that',
#   'accessibility',
#   'equipment',
#   'and',
#   'ergonomic',
#   'furniture',
#   'is',
#   'manag',
#   'ed',
#   'effectively'],
#  ['She',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'campus',
#   'service',
#   'such',
#   'a',
#   'parki',
#   'ng',
#   'and',
#   'catering',
#   'are',
#   'accessible',
#   'and',
#   'that',
#   'timetabling',
#   'i',
#   'ssues',
#   'are',
#   'addressed',
#   'effectively',
#   'including',
#   'the',
#   'availability',
#   'of',
#   'quiet',
#   'space'],
#  ['The',
#   'Accommodation',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'accommodation',
#   'is',
#   'available',
#   'through',
#   'University',
#   'partner',
#   'Accommodation',
#   'provider',
#   'to',
#   'meet',
#   'the',
#   'need',
#   'of',
#   'student'],
#  ['This',
#   'is',
#   'a',
#   'sha',
#   'red',
#   'responsibility',
#   'with',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'and',
#   'is',
#   'identified',
#   'a',
#   'a',
#   'critical',
#   'factor',
#   'in',
#   'the',
#   'contractual',
#   'obligation',
#   'outlined',
#   'to',
#   'provider'],
#  ['The',
#   'Head',
#   'of',
#   'Operations',
#   'in',
#   'each',
#   'Faculty',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'inclusive',
#   'approach',
#   'and',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'are',
#   'available',
#   'for',
#   'formal',
#   'examination',
#   'and',
#   'assessment',
#   'period',
#   'whilst',
#   'working',
#   'within',
#   'the',
#   'University',
#   'policy',
#   'on',
#   'Assessment',
#   'and',
#   'examination',
#   'provision',
#   'Appendix'],
#  ['The',
#   'Head',
#   'of',
#   'Operations',
#   'would',
#   'also',
#   'be',
#   'responsible',
#   'for',
#   'resolving',
#   'issue',
#   'related',
#   'to',
#   'timetable',
#   'and',
#   'an',
#   'individual',
#   's',
#   'access',
#   'need'],
#  ['The',
#   'Head',
#   'of',
#   'Academic',
#   'Quality',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'accessibility',
#   'and',
#   'inclusive',
#   'practice',
#   'are',
#   'considered',
#   'a',
#   'part',
#   'of',
#   'the',
#   'module',
#   'approval',
#   'process',
#   'including',
#   'appropriate',
#   'consultation',
#   'during',
#   'course',
#   'validation'],
#  ['The',
#   'Dean',
#   'of',
#   'the',
#   'Learning',
#   'and',
#   'Teaching',
#   'Academy',
#   'is',
#   'responsible',
#   'for',
#   'updating',
#   'appropriate',
#   'information',
#   'including',
#   'Regulations',
#   'in',
#   'Practise',
#   'and',
#   'other',
#   'publication',
#   'on',
#   'inclusive',
#   'practice',
#   'in',
#   'higher',
#   'education'],
#  ['There',
#   'is',
#   'al',
#   'so',
#   'a',
#   'responsibility',
#   'here',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'institutional',
#   'Virtual',
#   'Learning',
#   'Environment',
#   'meet',
#   'appropriate',
#   'inclusivity',
#   'requirement'],
#  ['The',
#   'Director',
#   'of',
#   'Corporate',
#   'Communications',
#   'and',
#   'Stakeholder',
#   'Engagement',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'commun',
#   'ications',
#   'produced',
#   'by',
#   'the',
#   'Universi',
#   'ty',
#   'are',
#   'accessible'],
#  ['The',
#   'Director',
#   'of',
#   'Student',
#   'Recruitment',
#   'and',
#   'Admissions',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'University',
#   'event',
#   'such',
#   'a',
#   'open',
#   'day',
#   'are',
#   'accessible',
#   'to',
#   'all',
#   'participant',
#   'including',
#   'visitor',
#   'and',
#   'that',
#   'appropriate',
#   'pre',
#   'entry',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'is',
#   'forwarded',
#   'to',
#   'the',
#   'Disability',
#   'team'],
#  ['Preentry',
#   'disclosure',
#   'process',
#   'will',
#   'be',
#   'applied',
#   'to',
#   'all',
#   'level',
#   'and',
#   'category',
#   'of',
#   'student',
#   'to',
#   'ensure',
#   'consistency'],
#  ['The',
#   'Director',
#   'of',
#   'International',
#   'Relations',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'who',
#   'wish',
#   'to',
#   'participate',
#   'in',
#   'Study',
#   'Abroad',
#   'opportunity',
#   'are',
#   'able',
#   'to',
#   'declare',
#   'a',
#   'disability',
#   'if',
#   'not',
#   'already',
#   'known',
#   'to',
#   'the',
#   'University'],
#  ['She',
#   'is',
#   'responsible',
#   'for',
#   'working',
#   'with',
#   'the',
#   'relevant',
#   'team',
#   'within',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   's',
#   'the',
#   'student',
#   'and',
#   'relevant',
#   'academic',
#   'department',
#   'to',
#   'identify',
#   'what',
#   'adjustment',
#   'are',
#   'appropriate',
#   'and',
#   'reasonable',
#   'within',
#   'the',
#   'context',
#   'of',
#   'a',
#   'specific',
#   'study',
#   'abroad',
#   'opportunity'],
#  ['The',
#   'Academic',
#   'Registrar',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'effective',
#   'facilitation',
#   'of',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'process'],
#  ['The',
#   'Director',
#   'of',
#   'Human',
#   'Resources',
#   'through',
#   'th',
#   'e',
#   'Equality',
#   'and',
#   'Diversity',
#   'Manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'relevant',
#   'training',
#   'and',
#   'development',
#   'opportunity',
#   'related',
#   'to',
#   'issue',
#   'of',
#   'equality',
#   'a',
#   'nd',
#   'diversity',
#   'are',
#   'available',
#   'to',
#   'staff'],
#  ['The',
#   'Counselling',
#   'Manager',
#   'and',
#   'Mental',
#   'Wellbeing',
#   'Advisor',
#   's',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'provision',
#   'of',
#   'support',
#   'to',
#   'student',
#   'with',
#   'mental',
#   'health',
#   'difficulty'],
#  ['The',
#   'Occupational',
#   'Health',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'assessing',
#   'at',
#   'enrolment',
#   'whether',
#   'those',
#   'student',
#   'attending',
#   'regulated',
#   'vocational',
#   'programme',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'training',
#   'and',
#   'are',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   'to',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'study',
#   'in',
#   'accordance',
#   'with',
#   'guidance',
#   'from',
#   'relevant',
#   'regulatory',
#   'body'],
#  ['In',
#   'addition',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'will',
#   'advise',
#   'programme',
#   'leader',
#   'where',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'impairment',
#   'or',
#   'health',
#   'condition',
#   'if',
#   'they',
#   'may',
#   'need',
#   'any',
#   'adjustment',
#   'to',
#   'the',
#   'training',
#   'programme',
#   'or',
#   'programme',
#   'of',
#   'study',
#   'on',
#   'medical',
#   'ground'],
#  ['The',
#   'programme',
#   'leader',
#   'will',
#   'liaise',
#   'through',
#   'the',
#   'DisCo',
#   'with',
#   'the',
#   'Disability',
#   'team',
#   'if',
#   'there',
#   'is',
#   'a',
#   'need',
#   'to',
#   'clarify',
#   'whether',
#   'adjustment',
#   'recommended',
#   'are',
#   'considered',
#   'to',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'circumstance',
#   'of',
#   'the',
#   'individual'],
#  ['Heads',
#   'of',
#   'all',
#   'other',
#   'department',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'provision',
#   'are',
#   'a',
#   'accessible',
#   'a',
#   'possible',
#   'eg',
#   'provision',
#   'of',
#   'alternative',
#   'format'],
#  ['The',
#   'Manager',
#   'of',
#   'Health',
#   'Safety',
#   'and',
#   'Environment',
#   'Services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'procedure',
#   'for',
#   'Person',
#   'al',
#   'Emergency',
#   'Evacuation',
#   'Plans',
#   'are',
#   'available',
#   'on',
#   'the',
#   'University',
#   'intranet',
#   'and',
#   'for',
#   'maintaining',
#   'up',
#   'todate',
#   'evacuation',
#   'procedure',
#   'covering',
#   'all',
#   'University',
#   'building'],
#  ['She',
#   'is',
#   'responsible',
#   'for',
#   'training',
#   'evacuation',
#   'chair',
#   'operator',
#   'in',
#   'the',
#   'safe',
#   'use',
#   'of',
#   'equipment',
#   'to',
#   'assi',
#   'st',
#   'person',
#   'with',
#   'mobility',
#   'impairment',
#   'in',
#   'an',
#   'evacuation',
#   'situation',
#   'and',
#   'for',
#   'publishing',
#   'up',
#   'to',
#   'date',
#   'list',
#   'of',
#   'such',
#   'people',
#   'and',
#   'first',
#   'aiders',
#   'on',
#   'a',
#   'building',
#   'by',
#   'building',
#   'basis',
#   'on',
#   'the',
#   'intranet'],
#  ['All',
#   'student',
#   'and',
#   'applicant',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'inform',
#   'the',
#   'Univ',
#   'ersity',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'of',
#   'their',
#   'disability',
#   'or',
#   'medical',
#   'condition',
#   'in',
#   'order',
#   'that',
#   'support',
#   'can',
#   'be',
#   'provided'],
#  ['Objectives',
#   'The',
#   'University',
#   'observes',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability',
#   'which',
#   'view',
#   'disability',
#   'a',
#   'being',
#   'created',
#   'by',
#   'barrier',
#   'within',
#   'society',
#   'rather',
#   'than',
#   'by',
#   'the',
#   'disability',
#   'itself'],
#  ['Barriers',
#   'can',
#   'be',
#   'in',
#   'the',
#   'physical',
#   'environment',
#   'such',
#   'a',
#   'inaccessible',
#   'building',
#   'or',
#   'service',
#   'attitudinal',
#   'resulting',
#   'in',
#   'stereotype',
#   'prejudice',
#   'and',
#   'assumption',
#   'about',
#   'the',
#   'capability',
#   'of',
#   'di',
#   'sabled',
#   'people',
#   'or',
#   'organisational',
#   'such',
#   'a',
#   'having',
#   'inflexible',
#   'policy',
#   'and',
#   'procedure'],
#  ['The',
#   'University',
#   'aim',
#   'to',
#   'address',
#   'all',
#   'of',
#   'these',
#   'barrier',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'people',
#   'can',
#   'participate',
#   'in',
#   'all',
#   'aspect',
#   'of',
#   'University',
#   'life'],
#  ['The',
#   'University',
#   'recognises',
#   'it',
#   'responsibility',
#   'to',
#   'make',
#   'provision',
#   'a',
#   'accessible',
#   'a',
#   'possible',
#   'and',
#   'will',
#   'aim',
#   'to',
#   'do',
#   'this',
#   'using',
#   'inclusive',
#   'approach',
#   'to',
#   'provision',
#   'and',
#   'service',
#   'or',
#   'anticipatory',
#   'reasonable',
#   'adjustment',
#   'wherever',
#   'possible'],
#  ['The',
#   'University',
#   'aim',
#   'to',
#   'identify',
#   'the',
#   'most',
#   'common',
#   'barrier',
#   'experienced',
#   'by',
#   'disabled',
#   'student',
#   'and',
#   'wherever',
#   'possible',
#   'to',
#   'identify',
#   'appropriate',
#   'anticipatory',
#   'adjustment',
#   'to',
#   'overcome',
#   'these',
#   'barrier'],
#  ['Where',
#   'this',
#   'is',
#   'not',
#   'possible',
#   'andor',
#   'additional',
#   'need',
#   'are',
#   'identified',
#   'the',
#   'University',
#   'will',
#   'seek',
#   'to',
#   'implement',
#   'appropriate',
#   'indiv',
#   'idual',
#   'reasonable',
#   'adjustment'],
#  ['Reasonable',
#   'adjustment',
#   'individual',
#   'and',
#   'anticipatory',
#   'can',
#   'be',
#   'made',
#   'to',
#   'provision',
#   'or',
#   'practice',
#   'but',
#   'not',
#   'to',
#   'competence',
#   'standard'],
#  ['Competence',
#   'standard',
#   'are',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standard',
#   'which',
#   'are',
#   'required',
#   'for',
#   'the',
#   'programme'],
#  ['Competence',
#   'standard',
#   'must',
#   'be',
#   'directly',
#   'related',
#   'to',
#   'the',
#   'learning',
#   'outcome',
#   'of',
#   'the',
#   'programme'],
#  ['There',
#   'is',
#   'therefore',
#   'no',
#   'requirement',
#   'to',
#   'alter',
#   'the',
#   'academic',
#   'standard',
#   'of',
#   'a',
#   'programme',
#   'for',
#   'a',
#   'disabled',
#   'student'],
#  ['However',
#   'it',
#   'may',
#   'be',
#   'necessary',
#   'to',
#   'adjust',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed'],
#  ['The',
#   'University',
#   'ha',
#   'specialist',
#   'targeted',
#   'provision',
#   'to',
#   'support',
#   'this',
#   'approach'],
#  ['The',
#   'Disability',
#   'team',
#   'is',
#   'the',
#   'key',
#   'specialist',
#   'service',
#   'provided',
#   'by',
#   'the',
#   'University'],
#  ['Specialists',
#   'within',
#   'this',
#   'team',
#   'understand',
#   'the',
#   'barrier',
#   'which',
#   'can',
#   'impact',
#   'on',
#   'student',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'academic',
#   'study',
#   'and',
#   'identify',
#   'inclusive',
#   'approach',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'enable',
#   'individual',
#   'to',
#   'participate',
#   'fully',
#   'in',
#   'university',
#   'life'],
#  ['On',
#   'some',
#   'occasion',
#   'this',
#   'provision',
#   'will',
#   'also',
#   'be',
#   'informed',
#   'by',
#   'an',
#   'external',
#   'third',
#   'party',
#   'with',
#   'appropriate',
#   'specialist',
#   'knowledge'],
#  ['Disability',
#   'Coordinators',
#   'DisCos',
#   'in',
#   'faculty',
#   'and',
#   'school',
#   'provide',
#   'targeted',
#   'academic',
#   'support',
#   'for',
#   'disabled',
#   'student'],
#  ['DisCos',
#   'have',
#   'discipline',
#   'specific',
#   'knowledge',
#   'which',
#   'enab',
#   'le',
#   'them',
#   'to',
#   'apply',
#   'the',
#   'reasonable',
#   'adjustment',
#   'in',
#   'a',
#   'proportionate',
#   'and',
#   'appropriate',
#   'manner',
#   'in',
#   'consultation',
#   'with',
#   'Programme',
#   'and',
#   'Module',
#   'leader'],
#  ['DisCos',
#   'are',
#   'also',
#   'a',
#   'local',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'staff',
#   'and',
#   'disabled',
#   'student',
#   'and',
#   'will',
#   'coordinate',
#   'support',
#   'within',
#   'the',
#   'facu',
#   'lty',
#   'or',
#   'school'],
#  ['All',
#   'student',
#   'have',
#   'access',
#   'to',
#   'a',
#   'Personal',
#   'Tutor',
#   'who',
#   'will',
#   'signpost',
#   'to',
#   'relevant',
#   'specialist',
#   'service',
#   'within',
#   'the',
#   'University'],
#  ['Disclosing',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'Students',
#   'are',
#   'able',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'their',
#   'time',
#   'at',
#   'the',
#   'University'],
#  ['All',
#   'applicant',
#   'to',
#   'the',
#   'University',
#   'will',
#   'be',
#   'given',
#   'the',
#   'opportunity',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'to',
#   'the',
#   'University',
#   'prior',
#   'to',
#   'commencement',
#   'of',
#   'a',
#   'programme'],
#  ['All',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'will',
#   'be',
#   'required',
#   'to',
#   'complete',
#   'a',
#   'health',
#   'declaration',
#   'prior',
#   'to',
#   'commencing',
#   'their',
#   'programme'],
#  ['This',
#   'will',
#   'include',
#   'a',
#   'requirement',
#   'to',
#   'notify',
#   'any',
#   'disability',
#   'which',
#   'may',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'complete',
#   'the',
#   'programme'],
#  ['This',
#   'will',
#   'result',
#   'in',
#   'an',
#   'assessment',
#   'by',
#   'the',
#   'Occupational',
#   'Hea',
#   'lth',
#   'team'],
#  ['Students',
#   'and',
#   'applicant',
#   'will',
#   'need',
#   'to',
#   'provide',
#   'relevant',
#   'consent',
#   'for',
#   'process',
#   'to',
#   'be',
#   'followed',
#   'and',
#   'must',
#   'engage',
#   'fully',
#   'in',
#   'this',
#   'process'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'contact',
#   'all',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'through',
#   'recruitment',
#   'process',
#   'prior',
#   't',
#   'o',
#   'their',
#   'arrival',
#   'in',
#   'order',
#   'that',
#   'the',
#   'support',
#   'process',
#   'can',
#   'be',
#   'in',
#   'place',
#   'for',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'programme'],
#  ['Students',
#   'will',
#   'be',
#   'given',
#   'a',
#   'further',
#   'opportunity',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'process'],
#  ['All',
#   'student',
#   'on',
#   'regulated',
#   'vo',
#   'cational',
#   'programme',
#   'who',
#   'disclose',
#   'a',
#   'significant',
#   'disability',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'Programme',
#   'Leaders',
#   'or',
#   'others',
#   'will',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'for',
#   'assessment',
#   'of',
#   'the',
#   'potential',
#   'impact',
#   'on',
#   'study',
#   'and',
#   'practice'],
#  ['This',
#   'may',
#   'result',
#   'in',
#   'confirmation',
#   'th',
#   'at',
#   'the',
#   'Occupational',
#   'Health',
#   'team',
#   'have',
#   'already',
#   'addressed',
#   'the',
#   'issue',
#   'or',
#   'may',
#   'result',
#   'in',
#   'a',
#   'new',
#   'assessment'],
#  ['If',
#   'during',
#   'their',
#   'period',
#   'of',
#   'study',
#   'a',
#   'student',
#   'becomes',
#   'aware',
#   'of',
#   'a',
#   'previously',
#   'undiagnosed',
#   'disability',
#   'they',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'a',
#   'soon',
#   'a',
#   'po',
#   'sible'],
#  ['If',
#   'at',
#   'any',
#   'time',
#   'any',
#   'member',
#   'of',
#   'staff',
#   'becomes',
#   'aware',
#   'of',
#   'serious',
#   'concern',
#   'regarding',
#   'a',
#   'student',
#   'on',
#   'a',
#   'regulated',
#   'vocational',
#   'programme',
#   'which',
#   'might',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'meet',
#   'competence',
#   'standard',
#   'the',
#   'student',
#   'must',
#   'be',
#   'referred',
#   'for',
#   'an',
#   'occupational',
#   'health',
#   'assessment',
#   'through',
#   'the',
#   'Program',
#   'leader',
#   'utilising',
#   'the',
#   'Fitness',
#   'to',
#   'StudyPractice',
#   'policy'],
#  ['Students',
#   'who',
#   'wish',
#   'to',
#   'discus',
#   'access',
#   'to',
#   'reasonable',
#   'adjustment',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'a',
#   'early',
#   'a',
#   'possible'],
#  ['Students',
#   'who',
#   'wish',
#   'to',
#   'access',
#   'reasonable',
#   'adjustment',
#   'will',
#   'be',
#   'required',
#   'to',
#   'provide',
#   'evidence',
#   'of',
#   'their',
#   'disability'],
#  ['Further',
#   'guidance',
#   'on',
#   'evidence',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'Disability',
#   'team'],
#  ['Students',
#   'with',
#   'specific',
#   'learning',
#   'difficulty',
#   'andor',
#   'dyslexia',
#   'should',
#   'refer',
#   'to',
#   'the',
#   'Specific',
#   'Learning',
#   'Di',
#   'fficulties',
#   'and',
#   'Dyslexia',
#   'guidance',
#   'contained',
#   'within',
#   'Appendix'],
#  ['Guidance',
#   'on',
#   'the',
#   'identification',
#   'and',
#   'implementation',
#   'of',
#   'Reasonable',
#   'Adjustments',
#   'The',
#   'University',
#   'ha',
#   'a',
#   'range',
#   'of',
#   'established',
#   'inclusive',
#   'practice',
#   'in',
#   'place',
#   'across',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'student',
#   'can',
#   'access',
#   'programme'],
#  ['Information',
#   'on',
#   'these',
#   'inclusive',
#   'practice',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'Disability',
#   'team',
#   'or',
#   'DisCos',
#   'within',
#   'individual',
#   'school',
#   'and',
#   'faculty',
#   'and',
#   'will',
#   'be',
#   'highlighted',
#   'to',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'by',
#   'the',
#   'Dis',
#   'ability',
#   'team'],
#  ['Inclusive',
#   'anticipatory',
#   'approach',
#   'will',
#   'be',
#   'accessible',
#   'to',
#   'all',
#   'student',
#   'in',
#   'order',
#   'that',
#   'student',
#   'who',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'disclose',
#   'to',
#   'the',
#   'University',
#   'can',
#   'also',
#   'access',
#   'appropriate',
#   'provision'],
#  ['Whilst',
#   'inclusive',
#   'approach',
#   'and',
#   'anticipatory',
#   'adjustment',
#   'will',
#   'meet',
#   'many',
#   'disabled',
#   'student',
#   'need',
#   'some',
#   'student',
#   'will',
#   'still',
#   'require',
#   'additional',
#   'individual',
#   'adjustment'],
#  ['The',
#   'Disability',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'identifying',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'programme',
#   'of',
#   'study',
#   'for',
#   'individual',
#   'student',
#   'in',
#   'con',
#   'sultation',
#   'with',
#   'Programme',
#   'leader',
#   'where',
#   'appropriate',
#   'and',
#   'within',
#   'the',
#   'wider',
#   'University',
#   'provision'],
#  ['Programme',
#   'team',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'anticipatory',
#   'adjustment',
#   'to',
#   'programme',
#   'of',
#   'study',
#   'are',
#   'in',
#   'place'],
#  ['If',
#   'a',
#   'student',
#   'ha',
#   'an',
#   'independent',
#   'Assessment',
#   'o',
#   'f',
#   'Needs',
#   'report',
#   'for',
#   'Disabled',
#   'Students',
#   'Allowance',
#   'DSA',
#   'purpose',
#   'or',
#   'an',
#   'Educational',
#   'Psychologists',
#   'report',
#   'the',
#   'recommendation',
#   'from',
#   'these',
#   'report',
#   'will',
#   'be',
#   'considered',
#   'when',
#   'identifying',
#   'reasonable',
#   'adjustment'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'firstly',
#   'consider',
#   'whether',
#   'anticipatory',
#   'adjustment',
#   'will',
#   'meet',
#   'the',
#   'specific',
#   'need',
#   'of',
#   'the',
#   'individual',
#   'student',
#   'and',
#   'then',
#   'whether',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'are',
#   'required'],
#  ['The',
#   'Disability',
#   'team',
#   'in',
#   'consultation',
#   'with',
#   'academic',
#   'colleague',
#   'will',
#   'consider',
#   'a',
#   'number',
#   'of',
#   'factor',
#   'when',
#   'deciding',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'is',
#   'reasonable'],
#  ['Factors',
#   'may',
#   'include',
#   'but',
#   'not',
#   'be',
#   'limited',
#   'to',
#   'the',
#   'perceived',
#   'effectiveness',
#   'of',
#   'the',
#   'adjustment',
#   'the',
#   'time',
#   'or',
#   'resource',
#   'required',
#   'to',
#   'implement',
#   'the',
#   'adjustment',
#   'the',
#   'student',
#   'previous',
#   'experience',
#   'of',
#   'the',
#   'adjustment',
#   'and',
#   'whether',
#   'the',
#   'need',
#   'could',
#   'be',
#   'met',
#   'through',
#   'an',
#   'existing',
#   'inclusive',
#   'approach',
#   'or',
#   'anticipatory',
#   'adjustment'],
#  ['The',
#   'University',
#   'is',
#   'not',
#   'obliged',
#   'to',
#   'offer',
#   'the',
#   'student',
#   'their',
#   'preferred',
#   'adjustment',
#   'particularly',
#   'if',
#   'an',
#   'inclusive',
#   'approach',
#   'or',
#   'alternative',
#   'adjustment',
#   'is',
#   'available',
#   'whi',
#   'ch',
#   'would',
#   'provide',
#   'appropriate',
#   'support',
#   'for',
#   'the',
#   'student'],
#  ['For',
#   'information',
#   'regarding',
#   'the',
#   'complaint',
#   'process',
#   'to',
#   'be',
#   'used',
#   'when',
#   'a',
#   'student',
#   'disagrees',
#   'with',
#   'a',
#   'proposed',
#   'reasonable',
#   'adjustment',
#   'see',
#   'section',
#   'Where',
#   'appropriate',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'liaise',
#   'with',
#   'the',
#   'DisCo',
#   'to',
#   'discus',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'may',
#   'conflict',
#   'with',
#   'the',
#   'competence',
#   'standard',
#   'for',
#   'the',
#   'programme',
#   'and',
#   'how',
#   'this',
#   'might',
#   'be',
#   'addressed',
#   'within',
#   'the',
#   'ISLP'],
#  ['For',
#   'student',
#   'who',
#   'are',
#   'able',
#   'to',
#   'ac',
#   'ce',
#   'external',
#   'funding',
#   'for',
#   'a',
#   'reasonable',
#   'adjustment',
#   'for',
#   'example',
#   'through',
#   'DSA',
#   'the',
#   'University',
#   'requires',
#   'the',
#   'student',
#   'to',
#   'access',
#   'such',
#   'funding'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'provide',
#   'guidance',
#   'and',
#   'advice',
#   'on',
#   'this',
#   'process',
#   'where',
#   'necessary'],
#  ['Where',
#   'external',
#   'financial',
#   'source',
#   'are',
#   'not',
#   'available',
#   'and',
#   'the',
#   'Disability',
#   'team',
#   'identify',
#   'the',
#   'adjustment',
#   'to',
#   'be',
#   'reasonable',
#   'the',
#   'University',
#   'will',
#   'seek',
#   'to',
#   'fund',
#   'this',
#   'adjustment',
#   'where',
#   'possible'],
#  ['Annually',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'will',
#   'set',
#   'in',
#   'conjunction',
#   'with',
#   'the',
#   'Stu',
#   'dent',
#   'Support',
#   'Manager',
#   'and',
#   'the',
#   'Disability',
#   'team',
#   'an',
#   'upper',
#   'financial',
#   'limit',
#   'for',
#   'individual',
#   'reasonable',
#   'adjustment'],
#  ['In',
#   'the',
#   'majority',
#   'of',
#   'case',
#   'this',
#   'will',
#   'ensure',
#   'that',
#   'reasonable',
#   'adjustment',
#   'can',
#   'be',
#   'put',
#   'in',
#   'place',
#   'without',
#   'onwards',
#   'referral',
#   'and',
#   'therefore',
#   'ease',
#   'the',
#   'speed',
#   'of',
#   'the',
#   'process'],
#  ['Where',
#   'the',
#   'upper',
#   'limit',
#   'is',
#   'breeched',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'refer',
#   'the',
#   'case',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'for',
#   'review',
#   'and',
#   'agreeme',
#   'nt',
#   'if',
#   'appropriate'],
#  ['If',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'doe',
#   'not',
#   'think',
#   'that',
#   'the',
#   'proposed',
#   'adjustment',
#   'is',
#   'reasonable',
#   'she',
#   'will',
#   'discus',
#   'alternative',
#   'option',
#   'with',
#   'the',
#   'Disability',
#   'team',
#   'who',
#   'may',
#   'then',
#   'discus',
#   'these',
#   'with',
#   'the',
#   'student',
#   'before',
#   'any',
#   'adjustment',
#   'are',
#   'agreed'],
#  ['With',
#   'the',
#   'student',
#   'consent',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'produce',
#   'an',
#   'In',
#   'dividual',
#   'Student',
#   'Learning',
#   'Plan',
#   'ISLP',
#   'for',
#   'each',
#   'student',
#   'which',
#   'identifies',
#   'the',
#   'inclusive',
#   'approach',
#   'and',
#   'reasonable',
#   'adjustment',
#   'required'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'then',
#   'forward',
#   'this',
#   'document',
#   'to',
#   'the',
#   'DisCo',
#   'in',
#   'the',
#   'relevant',
#   'academic',
#   'school',
#   'or',
#   'faculty'],
#  ['Without',
#   'consent',
#   'the',
#   'Disability',
#   'team',
#   'will',
#   'be',
#   'unable',
#   'to',
#   'progress',
#   'support',
#   'for',
#   'an',
#   'individual',
#   'student'],
#  ['A',
#   'copy',
#   'of',
#   'the',
#   'ISLP',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'relevant',
#   'DisCo',
#   'for',
#   'appropriate',
#   'circulation',
#   'within',
#   'the',
#   'schoolfaculty'],
#  ['Programme',
#   'leader',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'relevant',
#   'academic',
#   'colleague',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'reasonable',
#   'adjustment',
#   'required',
#   'for',
#   'student',
#   'within',
#   'their',
#   'cohort'],
#  ['The',
#   'Disability',
#   'team',
#   'are',
#   'responsible',
#   'when',
#   'requested',
#   'to',
#   'by',
#   'a',
#   'student',
#   'for',
#   'ma',
#   'king',
#   'referral',
#   'to',
#   'external',
#   'agency',
#   'for',
#   'support',
#   'worker',
#   'and',
#   'should',
#   'be',
#   'considered',
#   'the',
#   'named',
#   'contact',
#   'for',
#   'this',
#   'element',
#   'of',
#   'provision'],
#  ['If',
#   'a',
#   'student',
#   'doe',
#   'not',
#   'think',
#   'that',
#   'the',
#   'recommended',
#   'reasonable',
#   'adjustment',
#   'have',
#   'been',
#   'implemented',
#   'she',
#   'should',
#   'raise',
#   'this',
#   'wit',
#   'h',
#   'the',
#   'relevant',
#   'DisCo',
#   'in',
#   'the',
#   'first',
#   'instance'],
#  ['If',
#   'the',
#   'situation',
#   'is',
#   'not',
#   'resolved',
#   'through',
#   'this',
#   'approach',
#   'then',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'who',
#   'will',
#   'endeavour',
#   'to',
#   'work',
#   'with',
#   'the',
#   'appropriate',
#   'academic',
#   'area',
#   'and',
#   'find',
#   'an',
#   'appropriate',
#   'solution'],
#  ['If',
#   'the',
#   'student',
#   'remains',
#   'dissatisfied',
#   'then',
#   'she',
#   'should',
#   'make',
#   'a',
#   'complaint',
#   'using',
#   'the',
#   'student',
#   'complaint',
#   'procedure'],
#  ['The',
#   'impact',
#   'andor',
#   'nature',
#   'of',
#   'a',
#   'student',
#   'disability',
#   'may',
#   'change',
#   'over',
#   'the',
#   'course',
#   'of',
#   'their',
#   'period',
#   'of',
#   'study'],
#  ['This',
#   'may',
#   'result',
#   'in',
#   'the',
#   'anticipatory',
#   'suppo',
#   'rt',
#   'or',
#   'reasonable',
#   'adjustment',
#   'no',
#   'longer',
#   'being',
#   'appropriate'],
#  ['In',
#   'such',
#   'case',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'Disability',
#   'team',
#   'at',
#   'the',
#   'earliest',
#   'opportunity',
#   'to',
#   'discus',
#   'the',
#   'change'],
#  ['The',
#   'Disability',
#   'team',
#   'will',
#   'identify',
#   'whether',
#   'there',
#   'are',
#   'additional',
#   'or',
#   'alternate',
#   'inclus',
#   'ive',
#   'approach',
#   'or',
#   'reasonable',
#   'adjustment',
#   'needed'],
#  ['The', 'process', 'will', 'then', 'proceed', 'a', 'from', 'above'],
#  ['Occupational',
#   'health',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'study',
#   'and',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   't',
#   'o',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'study'],
#  ['This',
#   'requires',
#   'them',
#   'to',
#   'meet',
#   'the',
#   'relevant',
#   'competence',
#   'standard',
#   'for',
#   'the',
#   'profession',
#   'with',
#   'reasonable',
#   'adjustment',
#   'if',
#   'required'],
#  ['Adjustments',
#   'which',
#   'may',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'context',
#   'of',
#   'study',
#   'may',
#   'not',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'c',
#   'ontext',
#   'of',
#   'professional',
#   'practice'],
#  ['Wherever',
#   'possible',
#   'the',
#   'fitness',
#   'to',
#   'practice',
#   'of',
#   'applicant',
#   'who',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'will',
#   'be',
#   'assessed',
#   'prior',
#   'to',
#   'the',
#   'applicant',
#   'entering',
#   'the',
#   'University'],
#  ['The',
#   'Occupational',
#   'Health',
#   'team',
#   'in',
#   'liaison',
#   'with',
#   'the',
#   'Programme',
#   'leader',
#   'm',
#   'ay',
#   'make',
#   'recommendation',
#   'for',
#   'reasonable',
#   'adjustment'],
#  ['Assistance',
#   'Animal',
#   's',
#   'The',
#   'Universitys',
#   'Health',
#   'and',
#   'Safety',
#   'policy',
#   'require',
#   'that',
#   'only',
#   'assistance',
#   'animal',
#   'be',
#   'allowed',
#   'onto',
#   'campus'],
#  ['For',
#   'this',
#   'purpose',
#   'therefore',
#   'only',
#   'assist',
#   'ance',
#   'animal',
#   'registered',
#   'with',
#   'an',
#   'appropriate',
#   'professio',
#   'nal',
#   'standard',
#   'body',
#   'will',
#   'be',
#   'allowed',
#   'into',
#   'University',
#   'building'],
#  ['If',
#   'a',
#   'request',
#   'is',
#   'made',
#   'through',
#   'the',
#   'Disability',
#   'team',
#   'this',
#   'information',
#   'will',
#   'be',
#   'passed',
#   'to',
#   'the',
#   'relevant',
#   'DisCo',
#   'and',
#   'to',
#   'the',
#   'Health',
#   'and',
#   'Safety',
#   'team',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'to',
#   'allow',
#   'for',
#   'adjustment',
#   'such',
#   'a',
#   'spending',
#   'pen',
#   'to',
#   'be',
#   'made'],
#  ['The',
#   'owner',
#   'of',
#   'the',
#   'assistance',
#   'animal',
#   'will',
#   'be',
#   'asked',
#   'for',
#   'their',
#   'permission',
#   'to',
#   'communicate',
#   'this',
#   'fact',
#   'to',
#   'other',
#   'student',
#   'in',
#   'order',
#   'that',
#   'any',
#   'other',
#   'issue',
#   'can',
#   'be',
#   'circumvented',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'eg',
#   'allergy'],
#  ['The',
#   's',
#   'tudent',
#   'owner',
#   'of',
#   'the',
#   'animal',
#   'will',
#   'remain',
#   'responsible',
#   'for',
#   'the',
#   'animal',
#   'at',
#   'all',
#   'time'],
#  ['Complaints',
#   'In',
#   'the',
#   'first',
#   'instance',
#   'concern',
#   'regarding',
#   'the',
#   'appropriate',
#   'andor',
#   'timely',
#   'nature',
#   'of',
#   'provision',
#   'of',
#   'support',
#   'should',
#   'b',
#   'e',
#   'directed',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'for',
#   'informal',
#   'resolution'],
#  ['If',
#   'a',
#   'student',
#   'having',
#   'first',
#   'referred',
#   'the',
#   'matter',
#   'to',
#   'the',
#   'Director',
#   'of',
#   'Student',
#   'Advice',
#   'and',
#   'Wellbeing',
#   'service',
#   'belief',
#   'that',
#   'they',
#   'have',
#   'not',
#   'received',
#   'the',
#   'appropriate',
#   'reasonable',
#   'adjustment',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'can',
#   'study',
#   'effectively',
#   'the',
#   'matter',
#   'should',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'Student',
#   'Governance',
#   'team',
#   'to',
#   'be',
#   'addressed',
#   'through',
#   'the',
#   'Universitys',
#   'S',
#   'tudent',
#   'Complaints',
#   'procedure'],
#  ['This',
#   'can',
#   'be',
#   'accessed',
#   'using',
#   'the',
#   'following',
#   'link',
#   'httpswwwljmuacukabout',
#   'uspublic',
#   'informationstudent',
#   'regulationsappeals',
#   'and',
#   'complaint',
#   'Related',
#   'Policies',
#   'The',
#   'University',
#   'ha',
#   'a',
#   'number',
#   'of',
#   'policy',
#   'designed',
#   'to',
#   'support',
#   'all',
#   'student',
#   'some',
#   'of',
#   'which',
#   'may',
#   'have',
#   'particular',
#   'relevance',
#   'to',
#   'disabled',
#   'student'],
# ...
#   'per',
#   'academic',
#   'year',
#   'but',
#   't',
#   'his',
#   'will',
#   'vary',
#   'depending',
#   'on',
#   'the',
#   'number',
#   'of',
#   'disclosed',
#   'disabled',
#   'student',
#   'within',
#   'the',
#   'sch',
#   'ool',
#   'and',
#   'the',
#   'complexity',
#   'of',
#   'such',
#   'case'],
#  ['A',
#   'Faculty',
#   'Department',
#   'or',
#   'School',
#   'should',
#   'al',
#   'low',
#   'for',
#   'multiple',
#   'individual',
#   'to',
#   'undertake',
#   'the',
#   'DisCo',
#   'role',
#   'if',
#   'appropriate',
#   'to',
#   'local',
#   'circumstance',
#   's'],
#  ['The',
#   'Disability',
#   'Coordinator',
#   'will',
#   'Act',
#   'a',
#   'a',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'support',
#   'need'],
#  ['Act',
#   'a',
#   'a',
#   'liaison',
#   'point',
#   'between',
#   'the',
#   'schooldepartment',
#   'and',
#   'the',
#   'Disability',
#   'team'],
#  ['Ensure',
#   'that',
#   'the',
#   'disclosure',
#   'of',
#   'disability',
#   'is',
#   'actively',
#   'encouraged',
#   'and',
#   'communicated',
#   'effectively',
#   'within',
#   'the',
#   'schooldepartment',
#   'including',
#   'from',
#   'academic',
#   'colleague',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'and',
#   'in',
#   'reverse',
#   'where',
#   'appropriate'],
#  ['Liaise',
#   'with',
#   'relevant',
#   'colleague',
#   'within',
#   'the',
#   'University',
#   'regarding',
#   'any',
#   'issue',
#   'relating',
#   'to',
#   'the',
#   'support',
#   'of',
#   'disabled',
#   'student'],
#  ['Raise',
#   'awareness',
#   'within',
#   'the',
#   'schooldepartment',
#   'of',
#   'issue',
#   'facing',
#   'student',
#   'with',
#   'disability',
#   'and',
#   'the',
#   'academic',
#   'implication',
#   'this',
#   'may',
#   'have'],
#  ['Work',
#   'with',
#   'standard',
#   'procedure',
#   'acros',
#   's',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'issue',
#   'of',
#   'disclosure',
#   'distribution',
#   'of',
#   'ISLPs',
#   'and',
#   'related',
#   'issue',
#   'are',
#   'dealt',
#   'with',
#   'in',
#   'a',
#   'consistent',
#   'and',
#   'systematic',
#   'manner',
#   'including',
#   'communication',
#   'with',
#   'relevant',
#   'academic',
#   'colleague'],
#  ['Assist',
#   'the',
#   'DirectorHead',
#   'of',
#   'SchoolDepart',
#   'ment',
#   'to',
#   'ensure',
#   'that',
#   'a',
#   'robust',
#   'ISLP',
#   'record',
#   'system',
#   'is',
#   'in',
#   'operation',
#   'throughout',
#   'the',
#   'school'],
#  ['Coordinate',
#   'and',
#   'support',
#   'Schooldepartment',
#   'based',
#   'training',
#   'development',
#   'and',
#   'awareness',
#   'raising',
#   'activity',
#   'for',
#   'disability',
#   'support',
#   'liaising',
#   'with',
#   'relevant',
#   'Professional',
#   'serv',
#   'ice',
#   'staff',
#   'Disability',
#   'SupportEqual',
#   'Opportunities'],
#  ['Contribute',
#   'to',
#   'and',
#   'update',
#   'Disability',
#   'Support',
#   'infor',
#   'mation',
#   'on',
#   'the',
#   'Faculty',
#   'community',
#   'site'],
#  ['Regularly',
#   'attend',
#   'meeting',
#   'of',
#   'the',
#   'University',
#   'DisCo',
#   'Steering',
#   'Group',
#   'and',
#   'cascade',
#   'relevant',
#   'information',
#   'within',
#   'the',
#   's',
#   'chool',
#   'or',
#   'faculty'],
#  ['Provide',
#   'support',
#   'and',
#   'advice',
#   'on',
#   'disability',
#   'matter',
#   'to',
#   'school',
#   'colleague',
#   'ensuring',
#   'that',
#   'concern',
#   'are',
#   'referred',
#   'effectively'],
#  [],
#  ['Appendix',
#   'Additional',
#   'Examination',
#   'Provision',
#   'In',
#   'certain',
#   'situation',
#   'it',
#   'is',
#   'appropriate',
#   'for',
#   'the',
#   'University',
#   'to',
#   'suppor',
#   't',
#   'student',
#   'through',
#   'formal',
#   'examination',
#   'with',
#   'reasonable',
#   'adjustment'],
#  ['This',
#   'policy',
#   'document',
#   'outline',
#   'the',
#   'provision',
#   'the',
#   'criterion',
#   'and',
#   'the',
#   'reasonable',
#   'adjustment',
#   'that',
#   'may',
#   'be',
#   'put',
#   'into',
#   'place'],
#  ['Provision',
#   'available',
#   'All',
#   'provision',
#   'will',
#   'be',
#   'facilitated',
#   'through',
#   'the',
#   'ISLP',
#   'Extra',
#   'time',
#   'this',
#   'will',
#   'be',
#   'available',
#   'for',
#   'all',
#   'student',
#   'able',
#   'to',
#   'demonstrate',
#   'need',
#   'within',
#   'the',
#   'main',
#   'sitting',
#   'of',
#   'the',
#   'exam',
#   'unless',
#   'combined',
#   'with',
#   'additional',
#   'reasonable',
#   'adjustment',
#   'A',
#   'Reader',
#   'this',
#   'will',
#   'provided',
#   'using',
#   'IT',
#   'facility',
#   'within',
#   'each',
#   'faculty',
#   'and',
#   'will',
#   'be',
#   'prerecorded',
#   'by',
#   'a',
#   'member',
#   'of',
#   'staff',
#   'familiar',
#   'with',
#   'the',
#   'terminology',
#   'used'],
#  ['Amanuensis',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'Rest',
#   'Breaks',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'In',
#   'all',
#   'case',
#   'where',
#   'a',
#   'separate',
#   'location',
#   'may',
#   'be',
#   'needed',
#   'it',
#   'would',
#   'also',
#   'be',
#   'appropriate',
#   'for',
#   'academic',
#   'colleague',
#   'to',
#   'consider',
#   'alternative',
#   'assessment'],
#  ['It',
#   'may',
#   'be',
#   'that',
#   'the',
#   'learning',
#   'outcome',
#   'can',
#   'be',
#   'addressed',
#   'via',
#   'an',
#   'alternative',
#   'method',
#   'of',
#   'assessment',
#   'and',
#   'this',
#   'should',
#   'be',
#   'discussed',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'in',
#   'the',
#   'academic',
#   'year'],
#  ['Eligibility',
#   'for',
#   'Additional',
#   'examination',
#   'provision',
#   'AEP',
#   'Students',
#   'must',
#   'have',
#   'disclosed',
#   'a',
#   'disability',
#   'medical',
#   'condition',
#   'or',
#   'specific',
#   'learning',
#   'difficulty',
#   'to',
#   'the',
#   'University',
#   'a',
#   'soon',
#   'a',
#   'possible',
#   'after',
#   'diagno',
#   'si',
#   'or',
#   'enrolment',
#   'at',
#   'the',
#   'institution',
#   'whichever',
#   'occurs',
#   'first',
#   'and',
#   'in',
#   'advance',
#   'of',
#   'the',
#   'assessment',
#   'period',
#   'a',
#   'per',
#   'the',
#   'process',
#   'below'],
#  ['Eligibility',
#   'for',
#   'AEP',
#   'will',
#   'be',
#   'documented',
#   'in',
#   'the',
#   'form',
#   'of',
#   'a',
#   'formal',
#   'Individual',
#   'Student',
#   'Learning',
#   'Plan',
#   'or',
#   'a',
#   'Needs',
#   'Assessment',
#   'document'],
#  ['No', 'other', 'evidence', 'will', 'be', 'accepted'],
#  ['In',
#   'the',
#   'event',
#   'of',
#   'a',
#   'temporary',
#   'or',
#   'newly',
#   'disclosed',
#   'disability',
#   'a',
#   'doctor',
#   'letter',
#   'will',
#   'be',
#   'acceptable',
#   'and',
#   'provision',
#   'will',
#   'be',
#   'put',
#   'into',
#   'place',
#   'for',
#   'the',
#   'impending',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'not',
#   'continue',
#   'for',
#   'the',
#   'duration',
#   'of',
#   'the',
#   'course'],
#  ['Please',
#   'note',
#   'application',
#   'received',
#   'after',
#   'the',
#   'week',
#   'working',
#   'day',
#   'deadline',
#   'referred',
#   'to',
#   'in',
#   'Process',
#   'below',
#   'will',
#   'not',
#   'be',
#   'considered',
#   'for',
#   'the',
#   'immediate',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'be',
#   'actioned',
#   'prior',
#   'to',
#   'subsequent',
#   'period'],
#  ['Please',
#   'note',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'a',
#   'review',
#   'will',
#   'be',
#   'carried',
#   'out',
#   'by',
#   'Faculty',
#   'Examination',
#   'officer',
#   'and',
#   'any',
#   'student',
#   'who',
#   'do',
#   'not',
#   'take',
#   'up',
#   'the',
#   'provision',
#   'allocated',
#   'to',
#   'them',
#   'will',
#   'be',
#   'asked',
#   'to',
#   'review',
#   'this',
#   'position'],
#  ['This', 'may', 'result', 'in', 'the', 'provision', 'being', 'withdrawn'],
#  ['Process',
#   'The',
#   'AEP',
#   'application',
#   'form',
#   'will',
#   'be',
#   'available',
#   'at',
#   'httpsmyservicesljmuacukFormsAdditionalExamProvisionsaspx'],
#  ['The', 'form', 'should', 'be', 'completed', 'and', 'submitted', 'online'],
#  ['The',
#   'completed',
#   'form',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'appropriate',
#   'Facu',
#   'lty',
#   'where',
#   'access',
#   'will',
#   'be',
#   'restricted',
#   'to',
#   'a',
#   'small',
#   'number',
#   'of',
#   'staff',
#   'working',
#   'on',
#   'a',
#   'need',
#   'to',
#   'know',
#   'basis'],
#  ['Applications',
#   'for',
#   'AEP',
#   'should',
#   'be',
#   'made',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'and',
#   'no',
#   'later',
#   'than',
#   'week',
#   'working',
#   'day',
#   'prior',
#   'to',
#   'the',
#   'start',
#   'of',
#   'the',
#   'assessment',
#   'period'],
#  ['An',
#   'applicat',
#   'ion',
#   'for',
#   'AEP',
#   'will',
#   'remain',
#   'in',
#   'place',
#   'for',
#   'the',
#   'entirety',
#   'of',
#   'the',
#   'student',
#   'course',
#   'and',
#   'therefore',
#   'there',
#   'is',
#   'no',
#   'requirement',
#   'for',
#   'submission',
#   'every',
#   'year'],
#  ['However',
#   'should',
#   'AEP',
#   'be',
#   'in',
#   'place',
#   'but',
#   'not',
#   'utilised',
#   'this',
#   'may',
#   'result',
#   'in',
#   'withdrawal',
#   'of',
#   'this',
#   'provision'],
#  ['NB',
#   'Flexibility',
#   'will',
#   'be',
#   'needed',
#   'with',
#   'extra',
#   'time',
#   'a',
#   'this',
#   'may',
#   'not',
#   'be',
#   'used',
#   'at',
#   'every',
#   'opportunity',
#   'but',
#   'the',
#   'student',
#   'may',
#   'still',
#   'wish',
#   'to',
#   'retain',
#   'it'],
#  ['Faculty',
#   'Examinations',
#   'staff',
#   'will',
#   'review',
#   'usage',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'and',
#   'contact',
#   'student',
#   'accordingly'],
#  ['If',
#   'at',
#   'review',
#   'a',
#   'student',
#   'state',
#   'that',
#   'they',
#   'no',
#   'longer',
#   'need',
#   'the',
#   'provision',
#   'this',
#   'should',
#   'be',
#   'reported',
#   'in',
#   'writing',
#   'and',
#   'appended',
#   'to',
#   'the',
#   'ISLP'],
#  ['The',
#   'provision',
#   'can',
#   'be',
#   'cancelled',
#   'and',
#   'a',
#   'copy',
#   'of',
#   'the',
#   'correspondence',
#   'sent',
#   'to',
#   'the',
#   'Disability',
#   'team',
#   'for',
#   'completeness'],
#  ['If',
#   'at',
#   'r',
#   'eview',
#   'a',
#   'student',
#   'state',
#   'that',
#   'they',
#   'do',
#   'still',
#   'require',
#   'the',
#   'provision',
#   'provision',
#   'will',
#   'be',
#   'kept',
#   'in',
#   'place',
#   'for',
#   'a',
#   'subsequent',
#   'assessment',
#   'period'],
#  ['If',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'second',
#   'period',
#   'provision',
#   'ha',
#   'not',
#   'been',
#   'utilised',
#   'the',
#   'University',
#   'will',
#   'withdraw',
#   'the',
#   'provision'],
#  ['Faculty',
#   'staff',
#   'should',
#   'send',
#   'written',
#   'confirmation',
#   'of',
#   'this',
#   'to',
#   'the',
#   'Disability',
#   'team'],
#  ['Faculty',
#   'administration',
#   'staff',
#   'will',
#   'contact',
#   'student',
#   'ahead',
#   'of',
#   'the',
#   'assessment',
#   'period',
#   'each',
#   'year',
#   'to',
#   'update',
#   'module',
#   'choice',
#   'and',
#   'ascertain',
#   'if',
#   'provision',
#   'is',
#   'still',
#   'needed'],
#  ['Appendix',
#   'LJMU',
#   'Spe',
#   'cific',
#   'Learning',
#   'Difficulties',
#   'and',
#   'Dyslexia',
#   'Policy',
#   'Background',
#   'Institutions',
#   'are',
#   'expected',
#   'to',
#   'ensure',
#   'that',
#   'provision',
#   'and',
#   'support',
#   'is',
#   'available',
#   'both',
#   'within',
#   'the',
#   'curriculum',
#   'and',
#   'generally',
#   'through',
#   'learning',
#   'and',
#   'teaching',
#   'method'],
#  ['LJMU',
#   'will',
#   'ensure',
#   'that',
#   'anticipatory',
#   'adjustment',
#   'and',
#   'provision',
#   'for',
#   'student',
#   'with',
#   'mild',
#   'dyslexia',
#   'is',
#   'incorporated',
#   'into',
#   'the',
#   'learning',
#   'environment',
#   'and',
#   'therefore',
#   'should',
#   'not',
#   'need',
#   'to',
#   'be',
#   'individually',
#   'addressed'],
#  ['Provision',
#   'for',
#   'those',
#   'student',
#   'with',
#   'moderate',
#   'to',
#   'severe',
#   'SpL',
#   'd',
#   'and',
#   'Dyslexia',
#   'will',
#   'continue',
#   'to',
#   'be',
#   'addressed',
#   'individually'],
#  ['LJMU',
#   'complies',
#   'with',
#   'the',
#   'Equality',
#   'Act',
#   'the',
#   'Disability',
#   'Discrimination',
#   'Act',
#   'and',
#   'Special',
#   'Educational',
#   'Needs',
#   'Disability',
#   'Act',
#   'in',
#   'ensuring',
#   'that',
#   'all',
#   'student',
#   'are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'provi',
#   'sion',
#   'of',
#   'education',
#   'and',
#   'associated',
#   'service'],
#  ['The',
#   'inclusion',
#   'of',
#   'the',
#   'anticipatory',
#   'duty',
#   'ensures',
#   'that',
#   'the',
#   'institution',
#   'continues',
#   'to',
#   'review',
#   'policy',
#   'and',
#   'procedure',
#   'regularly',
#   'and',
#   'through',
#   'student',
#   'partnership'],
#  ['This',
#   'policy',
#   'is',
#   'part',
#   'of',
#   'the',
#   'wider',
#   'institutional',
#   'policy',
#   'on',
#   'D',
#   'isability',
#   'provision',
#   'for',
#   'student',
#   'Diagnostic',
#   'Support',
#   'It',
#   'is',
#   'anticipated',
#   'that',
#   'the',
#   'majority',
#   'of',
#   'student',
#   'coming',
#   'into',
#   'higher',
#   'education',
#   'will',
#   'have',
#   'received',
#   'appropriate',
#   'support',
#   'and',
#   'assessment',
#   'whilst',
#   'in',
#   'primary',
#   'or',
#   'secondary',
#   'education'],
#  ['In',
#   'the',
#   'event',
#   'of',
#   'student',
#   'not',
#   'having',
#   'received',
#   'such',
#   'an',
#   'assessment',
#   'or',
#   'not',
#   'having',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'assessment',
#   'LJMU',
#   'will',
#   'm',
#   'ake',
#   'available',
#   'a',
#   'formal',
#   'assessment'],
#  ['Provision',
#   'of',
#   'support',
#   'Eligibility',
#   'for',
#   'formal',
#   'Educational',
#   'Psychologists',
#   'assessment',
#   'Undergraduate',
#   'and',
#   'post',
#   'graduate'],
#  ['Studying',
#   'on',
#   'a',
#   'programme',
#   'with',
#   'a',
#   'duration',
#   'of',
#   'an',
#   'academic',
#   'year',
#   'or',
#   'longer',
#   'First',
#   'language',
#   'must',
#   'be',
#   'English',
#   'defined',
#   'a',
#   'educated',
#   'in',
#   'the',
#   'UK',
#   'from',
#   'the',
#   'age',
#   'of'],
#  ['Translations',
#   'of',
#   'assessment',
#   'report',
#   'will',
#   'be',
#   'accepted',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'but',
#   'due',
#   'to',
#   'the',
#   'inab',
#   'ility',
#   'of',
#   'the',
#   'test',
#   'to',
#   'ass',
#   'dyslexia',
#   'versus',
#   'language',
#   'issue',
#   'we',
#   'are',
#   'unable',
#   'to',
#   'ass',
#   'those',
#   'with',
#   'another',
#   'first',
#   'language'],
#  ['Student',
#   'attending',
#   'a',
#   'course',
#   'with',
#   'a',
#   'collaborative',
#   'partner',
#   'should',
#   'access',
#   'support',
#   'through',
#   'the',
#   'provider',
#   'college'],
#  ['Internal',
#   'Screening',
#   'exer',
#   'cise',
#   'result',
#   'in',
#   'a',
#   'possibility',
#   'of',
#   'moderate',
#   'to',
#   'severe',
#   'dyslexia',
#   'Funding',
#   'implication',
#   'There',
#   'is',
#   'a',
#   'cost',
#   'associated',
#   'with',
#   'each',
#   'Educational',
#   'Psychologists',
#   'report'],
#  ['Students',
#   'are',
#   'expected',
#   'to',
#   'meet',
#   'the',
#   'eligibility',
#   'criterion',
#   'above',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'inform',
#   'LJMU',
#   'a',
#   't',
#   'least',
#   'hour',
#   'in',
#   'advance',
#   'if',
#   'they',
#   'unable',
#   'to',
#   'attend',
#   'the',
#   'assessment',
#   'meeting'],
#  ['Students',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'of',
#   'the',
#   'charge',
#   'due',
#   'for',
#   'an',
#   'assessment'],
#  ['LJMU',
#   'will',
#   'meet',
#   'the',
#   'remaining',
#   'cost',
#   'of',
#   'each',
#   'assessment',
#   'up',
#   'to',
#   'an',
#   'annual',
#   'pre',
#   'determined',
#   'maximum'],
#  ['Students',
#   'will',
#   'be',
#   'reminded',
#   'of',
#   'appointment',
#   'through',
#   'a',
#   'variety',
#   'of',
#   'timely',
#   'medium',
#   'such',
#   'a',
#   'email',
#   'SMS',
#   'text',
#   'outlook',
#   'appointment',
#   'and',
#   'so',
#   'on'],
#  ['Students',
#   'who',
#   'fail',
#   'to',
#   'attend',
#   'their',
#   'assessment',
#   'appointment',
#   'w',
#   'ill',
#   'be',
#   'charged',
#   'the',
#   'full',
#   'fee',
#   'incurred',
#   'by',
#   'the',
#   'university',
#   'through',
#   'the',
#   'usual',
#   'charging',
#   'mechanism',
#   'within',
#   'the',
#   'University'],
#  ['A',
#   'budget',
#   'will',
#   'be',
#   'established',
#   'to',
#   'ensure',
#   'that',
#   'this',
#   'is',
#   'not',
#   'a',
#   'first',
#   'come',
#   'first',
#   'served',
#   'budget',
#   'position',
#   'but',
#   'is',
#   'based',
#   'on',
#   'need'],
#  ['Irlen',
#   'SyndromeScotopic',
#   'Sensitivity',
#   'Funding',
#   'will',
#   'be',
#   'made',
#   'available',
#   'for',
#   'stu',
#   'dent',
#   'to',
#   'receive',
#   'this',
#   'test',
#   'should',
#   'it',
#   'be',
#   'deemed',
#   'appropriate',
#   'through',
#   'the',
#   'Educational',
#   'Psychologists',
#   'as',
#   'essment'],
#  ['Coloured',
#   'overlay',
#   'can',
#   'be',
#   'purchased',
#   'to',
#   'assist',
#   'student',
#   'rather',
#   'than',
#   'the',
#   'provision',
#   'of',
#   'pastel',
#   'paper'],
#  []]

# %%
#lower all cases
postfin1 = [[j.lower() for j in i] for i in postlemma]

# %%
postfin1
# Out:
# [['disability',
#   'policy',
#   'students',
#   'provision',
#   'of',
#   'support',
#   'responsibility',
#   'for',
#   'policy',
#   'university',
#   'registrar',
#   'and',
#   'chief',
#   'operating',
#   'officer',
#   'relevant',
#   'to',
#   'all',
#   'ljmu',
#   'staff',
#   'and',
#   'students',
#   'approved',
#   'by',
#   'academic',
#   'board',
#   'march',
#   'responsibility',
#   'for',
#   'document',
#   'review',
#   'director',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'services'],
#  ['date',
#   'introduced',
#   'january',
#   'dates',
#   'modified',
#   'february',
#   'february',
#   'next',
#   'review',
#   'date',
#   'february',
#   'relevant',
#   'documents',
#   'equality',
#   'act',
#   'special',
#   'educational',
#   'needs',
#   'and',
#   'disability',
#   'act',
#   'disability',
#   'discrimination',
#   'act',
#   'public',
#   'sector',
#   'bodies',
#   'website',
#   'and',
#   'mobile',
#   'applications',
#   'accessibility',
#   'regulation',
#   'related',
#   'policies',
#   'documents',
#   'ljmu',
#   'equality',
#   'and',
#   'diversity',
#   'policy',
#   'scp',
#   'evacuation',
#   'procedures',
#   'scp',
#   'personal',
#   'emergency',
#   'evacuation',
#   'plans',
#   'student',
#   'complaints',
#   'procedure',
#   'fitness',
#   'to',
#   'study',
#   'policy',
#   'fitness',
#   'to',
#   'practice',
#   'policy',
#   'academic',
#   'framework',
#   'code',
#   'of',
#   'practice',
#   'for',
#   'placements',
#   'policy',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'reasonable',
#   'adjustment',
#   'and',
#   'support',
#   'for',
#   'disabled',
#   'student',
#   'introduction',
#   'liverpool',
#   'john',
#   'moores',
#   'university',
#   'ljmu',
#   'is',
#   'committed',
#   'to',
#   'providing',
#   'an',
#   'inclusive',
#   'and',
#   'accessible',
#   'environment',
#   'which',
#   'enables',
#   'all',
#   'student',
#   'to',
#   'reach',
#   'their',
#   'potentia',
#   'l'],
#  ['a',
#   'wide',
#   'range',
#   'of',
#   'provision',
#   'is',
#   'available',
#   'to',
#   'support',
#   'student',
#   'including',
#   'specialist',
#   'support',
#   'support',
#   'through',
#   'academic',
#   'faculty',
#   'department',
#   'and',
#   'school',
#   'and',
#   'appropriate',
#   'policy',
#   'and',
#   'procedure'],
#  ['this',
#   'policy',
#   'set',
#   'out',
#   'how',
#   'ljmu',
#   'meet',
#   'it',
#   'obligation',
#   'under',
#   'th',
#   'e',
#   'equality',
#   'act'],
#  ['it',
#   'identifies',
#   'the',
#   'universitys',
#   'approach',
#   'to',
#   'supporting',
#   'disabled',
#   'student',
#   'and',
#   'formalises',
#   'area',
#   'of',
#   'responsibility'],
#  ['the',
#   'policy',
#   'is',
#   'supported',
#   'by',
#   'the',
#   'procedure',
#   'within',
#   'this',
#   'document',
#   'either',
#   'appended',
#   'or',
#   'referenced'],
#  ['duty',
#   'to',
#   'make',
#   'reasonable',
#   'a',
#   'djustments',
#   'as',
#   'provided',
#   'for',
#   'by',
#   'the',
#   'equality',
#   'act',
#   'ljmu',
#   'ha',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'for',
#   'disabled',
#   'student',
#   'and',
#   'this',
#   'duty',
#   'ha',
#   'been',
#   'further',
#   'highlighted',
#   'by',
#   'the',
#   'change',
#   'made',
#   'to',
#   'the',
#   'disabled',
#   'students',
#   'allowance',
#   'dsa'],
#  ['the',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'requires',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'have',
#   'anticipated',
#   'and',
#   'taken',
#   'reasonable',
#   'step',
#   'to',
#   'address',
#   'barrier',
#   'which',
#   'put',
#   'disabled',
#   'student',
#   'at',
#   'a',
#   'substantial',
#   'disadvantage',
#   'in',
#   'relation',
#   'to',
#   'a',
#   'relevant',
#   'matter',
#   'when',
#   'compared',
#   'to',
#   'no',
#   'ndisabled',
#   'student'],
#  ['in',
#   'particular',
#   'there',
#   'is',
#   'a',
#   'requirement',
#   'on',
#   'institution',
#   'under',
#   'new',
#   'dsa',
#   'regulation',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'provision',
#   'of',
#   'non',
#   'medical',
#   'help',
#   'is',
#   'available',
#   'where',
#   'appropriate'],
#  ['this',
#   'provision',
#   'applies',
#   'to',
#   'delivery',
#   'of',
#   'ljmu',
#   'business',
#   'within',
#   'the',
#   'uk'],
#  ['the',
#   'intention',
#   'is',
#   'that',
#   'the',
#   'learning',
#   'environment',
#   'should',
#   'be',
#   'a',
#   'inclusive',
#   'a',
#   'possible',
#   'so',
#   'that',
#   'individual',
#   'intervention',
#   'are',
#   'the',
#   'exception',
#   'not',
#   'the',
#   'rule'],
#  ['institutional',
#   'responsibility',
#   'ljmu',
#   'wish',
#   'to',
#   'maintain',
#   'an',
#   'environment',
#   'in',
#   'which',
#   'disabled',
#   'student',
#   'are',
#   'able',
#   'to',
#   'fully',
#   'participate',
#   'in',
#   'the',
#   'student',
#   'experience',
#   'and',
#   'will',
#   'therefore',
#   'take',
#   'all',
#   'reasonable',
#   'step',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'student',
#   'have',
#   'access',
#   'to',
#   'appropriate',
#   'learning',
#   'and',
#   'teaching',
#   'support',
#   'for',
#   'mandatory',
#   'element',
#   'of',
#   'academic',
#   'programme',
#   'mandatory',
#   'refers',
#   't',
#   'o',
#   'element',
#   'of',
#   'the',
#   'course',
#   'that',
#   'are',
#   'required',
#   'in',
#   'order',
#   'to',
#   'successfully',
#   'achieve',
#   'the',
#   'target',
#   'award',
#   'and',
#   'will',
#   'include',
#   'both',
#   'core',
#   'and',
#   'optional',
#   'module'],
#  ['are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'estate',
#   'and',
#   'building',
#   'utilised',
#   'in',
#   'the',
#   'provision',
#   'of',
#   'teaching',
#   'and',
#   'learning',
#   'and',
#   'associated',
#   's',
#   'ervices'],
#  ['have',
#   'access',
#   'to',
#   'specialist',
#   'staff',
#   'who',
#   'are',
#   'able',
#   'to',
#   'advise',
#   'on',
#   'the',
#   'range',
#   'and',
#   'extent',
#   'of',
#   'provision',
#   'available',
#   'throughout',
#   'the',
#   'institution'],
#  ['have',
#   'documented',
#   'support',
#   'plan',
#   'in',
#   'place',
#   'including',
#   'where',
#   'appropriate',
#   'for',
#   'a',
#   'period',
#   'of',
#   'placement'],
#  ['can', 'access', 'it', 'facility', 'and', 'service'],
#  ['are',
#   'able',
#   'to',
#   'access',
#   'learning',
#   'material',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'whether',
#   'in',
#   'hardcopy',
#   'electronic',
#   'or',
#   'other',
#   'format'],
#  ['are',
#   'able',
#   'to',
#   'access',
#   'additional',
#   'support',
#   'which',
#   'may',
#   'or',
#   'may',
#   'not',
#   'be',
#   'represented',
#   'in',
#   'a',
#   'formal',
#   'need',
#   'assessment',
#   'in',
#   'the',
#   'form',
#   'of',
#   'nonmedical',
#   'help'],
#  ['have',
#   'access',
#   'to',
#   'quiet',
#   'or',
#   'le',
#   'formal',
#   'environment',
#   'to',
#   'enable',
#   'student',
#   'to',
#   'have',
#   'time',
#   'away',
#   'should',
#   'they',
#   'require',
#   'it'],
#  ['non',
#   'medical',
#   'help',
#   'is',
#   'defined',
#   'a',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'assistant',
#   'such',
#   'a',
#   'scribe',
#   'reader',
#   'lab',
#   'assistant',
#   'etc',
#   'and',
#   'enhanced',
#   'support',
#   'assistants',
#   'such',
#   'a',
#   'examination',
#   'support',
#   'worker',
#   'notetakers',
#   'study',
#   'assistant'],
#  ['these',
#   'were',
#   'previously',
#   'identified',
#   'a',
#   'band',
#   'and',
#   'band',
#   'nmh',
#   'support'],
#  ['scope',
#   'this',
#   'policy',
#   'address',
#   'all',
#   'aspect',
#   'of',
#   'support',
#   'for',
#   'disabled',
#   'applicant',
#   'and',
#   'student',
#   'at',
#   'ljmu'],
#  ['this',
#   'policy',
#   'applies',
#   'to',
#   'all',
#   'student',
#   'studying',
#   'with',
#   'ljmu',
#   'within',
#   'the',
#   'uk',
#   'regardless',
#   'of',
#   'mode',
#   'of',
#   'study'],
#  ['however',
#   'student',
#   'on',
#   's',
#   'hort',
#   'professional',
#   'cpd',
#   'course',
#   'will',
#   'be',
#   'advised',
#   'and',
#   'assessed',
#   'based',
#   'on',
#   'the',
#   'duration',
#   'and',
#   'intensity',
#   'of',
#   'their',
#   'study'],
#  ['the', 'principle', 'of', 'this', 'policy', 'apply', 'to', 'all', 'cohort'],
#  ['students',
#   'who',
#   'disclosed',
#   'or',
#   'declared',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'prior',
#   'to',
#   'september',
#   'may',
#   'have',
#   'their',
#   'need',
#   'met',
#   'using',
#   'a',
#   'slightly',
#   'different',
#   'process',
#   'due',
#   'to',
#   'changing',
#   'external',
#   'student',
#   'finance',
#   'arrangement'],
#  ['responsibilities',
#   'this',
#   'section',
#   'outline',
#   'the',
#   'role',
#   'an',
#   'd',
#   'responsibility',
#   'of',
#   'key',
#   'area',
#   'across',
#   'the',
#   'institution'],
#  ['it',
#   'doe',
#   'not',
#   'contain',
#   'operational',
#   'detail',
#   'of',
#   'these',
#   'responsibility'],
#  ['further',
#   'information',
#   'about',
#   'relevant',
#   'procedure',
#   'should',
#   'be',
#   'available',
#   'from',
#   'the',
#   'relevant',
#   'area',
#   'andor',
#   'from',
#   'the',
#   'disability',
#   'team',
#   'within',
#   's',
#   'tudent',
#   'advice',
#   'and',
#   'wellbeing',
#   'service'],
#  ['elt',
#   'are',
#   'responsible',
#   'for',
#   'the',
#   'universitys',
#   'strategy',
#   'with',
#   'regard',
#   'to',
#   'disabled',
#   'student',
#   'ensuring',
#   'compliance',
#   'with',
#   'the',
#   'equality',
#   'act',
#   'and',
#   'regulating',
#   'the',
#   'associated',
#   'resource',
#   'to',
#   'fund',
#   'support',
#   'for',
#   'disabled',
#   'student'],
#  ['equality',
#   'diversity',
#   'and',
#   'inclusivity',
#   'committee',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'compli',
#   'ance',
#   'with',
#   'this',
#   'policy',
#   'requesting',
#   'appropriate',
#   'change',
#   'and',
#   'making',
#   'recommendation',
#   'to',
#   'el',
#   't',
#   'for',
#   'amendment',
#   'to',
#   'policy',
#   'and',
#   'practice'],
#  ['director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'advising',
#   'the',
#   'university',
#   'about',
#   'strategy',
#   'and',
#   'policy',
#   'in',
#   'relation',
#   'to',
#   'disabled',
#   'student',
#   'and',
#   'identifying',
#   'the',
#   'impact',
#   'of',
#   'change',
#   'in',
#   'the',
#   'external',
#   'environment',
#   'on',
#   'university',
#   'provision'],
#  ['she',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'contract',
#   'are',
#   'in',
#   'place',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'worker',
#   'and',
#   'hold',
#   'the',
#   'disability',
#   'budget',
#   'to',
#   'ensure',
#   'additional',
#   'reasonable',
#   'adjustment',
#   'can',
#   'be',
#   'made',
#   'where',
#   'other',
#   'source',
#   'of',
#   'funding',
#   'are',
#   'not',
#   'available'],
#  ['the',
#   'student',
#   'support',
#   'm',
#   'anager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'them',
#   'through',
#   'the',
#   'disability',
#   'team'],
#  ['once',
#   'student',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'the',
#   'student',
#   'support',
#   'manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'they',
#   'have',
#   'an',
#   'appropriate',
#   'indivi',
#   'dual',
#   'student',
#   'learning',
#   'plan',
#   'islp',
#   'which',
#   'identifies',
#   'relevant',
#   'inclusive',
#   'approach',
#   'to',
#   'provision',
#   'and',
#   'where',
#   'appropriate',
#   'identifies',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'reduce',
#   'barrier',
#   'to',
#   'the',
#   'student',
#   'participation',
#   'in',
#   'their',
#   'academic',
#   'program',
#   'me'],
#  ['the',
#   'disability',
#   'team',
#   'are',
#   'responsible',
#   'for',
#   'engaging',
#   'with',
#   'and',
#   'receiving',
#   'consent',
#   'from',
#   'student',
#   'in',
#   'order',
#   'that',
#   'they',
#   'can',
#   'create',
#   'store',
#   'andor',
#   'communicate',
#   'the',
#   'islp',
#   'and',
#   'associated',
#   'document',
#   'to',
#   'all',
#   'relevant',
#   'party',
#   'and',
#   'are',
#   'responsible',
#   'for',
#   'providing',
#   'advice',
#   't',
#   'o',
#   'student',
#   'and',
#   'staff',
#   'on',
#   'disability',
#   'related',
#   'matter'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'store',
#   'the',
#   'master',
#   'copy',
#   'of',
#   'an',
#   'individual',
#   'student',
#   'islp',
#   'and',
#   'a',
#   'copy',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'student',
#   'and',
#   'the',
#   'relevant',
#   'disability',
#   'coordinator'],
#  ['the',
#   'disability',
#   'team',
#   'also',
#   'cover',
#   'specialist',
#   'study',
#   'skills',
#   'tutor',
#   'who',
#   'work',
#   'directly',
#   'with',
#   'student'],
#  ['directors',
#   'of',
#   'schoolheads',
#   'of',
#   'department',
#   'are',
#   'responsible',
#   'for',
#   'en',
#   'suring',
#   'that',
#   'an',
#   'islp',
#   'is',
#   'effectively',
#   'communicated',
#   'within',
#   'the',
#   'school',
#   'or',
#   'department',
#   'and',
#   'for',
#   'the',
#   'health',
#   'and',
#   'safety',
#   'of',
#   'disabled',
#   'student',
#   'includ',
#   'ing',
#   'ensuring',
#   'that',
#   'disabled',
#   'student',
#   'who',
#   'require',
#   'one',
#   'have',
#   'a',
#   'personal',
#   'emergency',
#   'evacuation',
#   'plan',
#   'peep'],
#  ['they',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'reasonable',
#   'adjustment',
#   'are',
#   'in',
#   'place',
#   'for',
#   'assessment',
#   'organised',
#   'within',
#   'the',
#   'departmentschool',
#   'including',
#   'in',
#   'class',
#   'test'],
#  ['directorsheads',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'teaching',
#   'and',
#   'learning',
#   'material',
#   'and',
#   'practice',
#   'within',
#   'their',
#   'area',
#   'meet',
#   'the',
#   'agreed',
#   'need',
#   'of',
#   'disabled',
#   'student'],
#  ['directorsheads',
#   'are',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'the',
#   'availability',
#   'and',
#   'remit',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   's',
#   'including',
#   'the',
#   'disability',
#   'team'],
#  ['disability',
#   'coordinators',
#   'disco',
#   'are',
#   'school',
#   'and',
#   'faculty',
#   'based',
#   'staff',
#   'with',
#   'responsibility',
#   'for',
#   'ensuring',
#   'relevant',
#   'academic',
#   'and',
#   'admin',
#   'istrative',
#   'staff',
#   'are',
#   'aware',
#   'of',
#   'student',
#   's',
#   'support',
#   'need',
#   'and',
#   'for',
#   'coordinating',
#   'school',
#   'based',
#   'support'],
#  ['see',
#   'appendix',
#   'for',
#   'the',
#   'disability',
#   'coordinator',
#   'role',
#   'descriptor',
#   'programme',
#   'leaders',
#   'are',
#   'responsible',
#   'for',
#   'reviewing',
#   'the',
#   'curriculum',
#   'of',
#   'their',
#   'programme',
#   'and',
#   'identifying',
#   'app',
#   'ropriate',
#   'inclusive',
#   'approach'],
#  ['module',
#   'leaders',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'student',
#   'on',
#   'the',
#   'module',
#   'require',
#   'reasonable',
#   'adjustment',
#   'and',
#   'ensuring',
#   'that',
#   'programme',
#   'colleague',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'requirement'],
#  ['this',
#   'information',
#   'is',
#   'available',
#   'from',
#   't',
#   'he',
#   'disco',
#   'and',
#   'programme',
#   'leaders',
#   'in',
#   'each',
#   'schooldepartment'],
#  ['personal',
#   'tutor',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'be',
#   'aware',
#   'of',
#   'which',
#   'student',
#   'within',
#   'their',
#   'tutee',
#   'group',
#   'require',
#   'reasonable',
#   'adjustment',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'student',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'support',
#   'available',
#   'to',
#   'the',
#   'm'],
#  ['all',
#   'programme',
#   'staff',
#   'are',
#   'responsible',
#   'for',
#   'implementing',
#   'relevant',
#   'reasonable',
#   'adjustment',
#   'a',
#   'detailed',
#   'within',
#   'the',
#   'student',
#   'islp'],
#  ['the',
#   'islp',
#   'will',
#   'be',
#   'created',
#   'a',
#   'per',
#   'section',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'in',
#   'consultation',
#   'between',
#   'all',
#   'relevant',
#   'party'],
#  ['the',
#   'directo',
#   'r',
#   'of',
#   'library',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'disabled',
#   'student',
#   'are',
#   'able',
#   'to',
#   'access',
#   'all',
#   'library',
#   'provision',
#   'and',
#   'that',
#   'they',
#   'have',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'support',
#   'and',
#   'training'],
#  ['the',
#   'director',
#   'of',
#   'student',
#   'advancement',
#   'is',
#   'responsible',
#   'for',
#   'ensu',
#   'ring',
#   'that',
#   'the',
#   'service',
#   'delivered',
#   'are',
#   'appropriate',
#   'to',
#   'the',
#   'need',
#   'of',
#   'disabled',
#   'student',
#   'and',
#   'graduate'],
#  ['she',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'code',
#   'of',
#   'practice',
#   'for',
#   'placements',
#   'address',
#   'the',
#   'need',
#   'of',
#   'disabled',
#   'student'],
#  ['the',
#   'director',
#   'of',
#   'it',
#   'services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'software',
#   'and',
#   'hardware',
#   'is',
#   'available',
#   'for',
#   'disabled',
#   'student',
#   'including',
#   'training',
#   'on',
#   'such',
#   'equipment'],
#  ['she',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'university',
#   'corporate',
#   'system',
#   'including',
#   'the',
#   'website',
#   'are',
#   'inclusi',
#   've',
#   'and',
#   'accessible'],
#  ['the',
#   'director',
#   's',
#   'of',
#   'estates',
#   'and',
#   'facilities',
#   'management',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'the',
#   'university',
#   'campus',
#   'including',
#   'all',
#   'university',
#   'building',
#   'is',
#   'physically',
#   'accessible',
#   'and',
#   'that',
#   'accessibility',
#   'equipment',
#   'and',
#   'ergonomic',
#   'furniture',
#   'is',
#   'manag',
#   'ed',
#   'effectively'],
#  ['she',
#   'is',
#   'also',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'campus',
#   'service',
#   'such',
#   'a',
#   'parki',
#   'ng',
#   'and',
#   'catering',
#   'are',
#   'accessible',
#   'and',
#   'that',
#   'timetabling',
#   'i',
#   'ssues',
#   'are',
#   'addressed',
#   'effectively',
#   'including',
#   'the',
#   'availability',
#   'of',
#   'quiet',
#   'space'],
#  ['the',
#   'accommodation',
#   'manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'accessible',
#   'accommodation',
#   'is',
#   'available',
#   'through',
#   'university',
#   'partner',
#   'accommodation',
#   'provider',
#   'to',
#   'meet',
#   'the',
#   'need',
#   'of',
#   'student'],
#  ['this',
#   'is',
#   'a',
#   'sha',
#   'red',
#   'responsibility',
#   'with',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'and',
#   'is',
#   'identified',
#   'a',
#   'a',
#   'critical',
#   'factor',
#   'in',
#   'the',
#   'contractual',
#   'obligation',
#   'outlined',
#   'to',
#   'provider'],
#  ['the',
#   'head',
#   'of',
#   'operations',
#   'in',
#   'each',
#   'faculty',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'appropriate',
#   'inclusive',
#   'approach',
#   'and',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'are',
#   'available',
#   'for',
#   'formal',
#   'examination',
#   'and',
#   'assessment',
#   'period',
#   'whilst',
#   'working',
#   'within',
#   'the',
#   'university',
#   'policy',
#   'on',
#   'assessment',
#   'and',
#   'examination',
#   'provision',
#   'appendix'],
#  ['the',
#   'head',
#   'of',
#   'operations',
#   'would',
#   'also',
#   'be',
#   'responsible',
#   'for',
#   'resolving',
#   'issue',
#   'related',
#   'to',
#   'timetable',
#   'and',
#   'an',
#   'individual',
#   's',
#   'access',
#   'need'],
#  ['the',
#   'head',
#   'of',
#   'academic',
#   'quality',
#   'service',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'accessibility',
#   'and',
#   'inclusive',
#   'practice',
#   'are',
#   'considered',
#   'a',
#   'part',
#   'of',
#   'the',
#   'module',
#   'approval',
#   'process',
#   'including',
#   'appropriate',
#   'consultation',
#   'during',
#   'course',
#   'validation'],
#  ['the',
#   'dean',
#   'of',
#   'the',
#   'learning',
#   'and',
#   'teaching',
#   'academy',
#   'is',
#   'responsible',
#   'for',
#   'updating',
#   'appropriate',
#   'information',
#   'including',
#   'regulations',
#   'in',
#   'practise',
#   'and',
#   'other',
#   'publication',
#   'on',
#   'inclusive',
#   'practice',
#   'in',
#   'higher',
#   'education'],
#  ['there',
#   'is',
#   'al',
#   'so',
#   'a',
#   'responsibility',
#   'here',
#   'to',
#   'ensure',
#   'that',
#   'the',
#   'institutional',
#   'virtual',
#   'learning',
#   'environment',
#   'meet',
#   'appropriate',
#   'inclusivity',
#   'requirement'],
#  ['the',
#   'director',
#   'of',
#   'corporate',
#   'communications',
#   'and',
#   'stakeholder',
#   'engagement',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'commun',
#   'ications',
#   'produced',
#   'by',
#   'the',
#   'universi',
#   'ty',
#   'are',
#   'accessible'],
#  ['the',
#   'director',
#   'of',
#   'student',
#   'recruitment',
#   'and',
#   'admissions',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'university',
#   'event',
#   'such',
#   'a',
#   'open',
#   'day',
#   'are',
#   'accessible',
#   'to',
#   'all',
#   'participant',
#   'including',
#   'visitor',
#   'and',
#   'that',
#   'appropriate',
#   'pre',
#   'entry',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'is',
#   'forwarded',
#   'to',
#   'the',
#   'disability',
#   'team'],
#  ['preentry',
#   'disclosure',
#   'process',
#   'will',
#   'be',
#   'applied',
#   'to',
#   'all',
#   'level',
#   'and',
#   'category',
#   'of',
#   'student',
#   'to',
#   'ensure',
#   'consistency'],
#  ['the',
#   'director',
#   'of',
#   'international',
#   'relations',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'who',
#   'wish',
#   'to',
#   'participate',
#   'in',
#   'study',
#   'abroad',
#   'opportunity',
#   'are',
#   'able',
#   'to',
#   'declare',
#   'a',
#   'disability',
#   'if',
#   'not',
#   'already',
#   'known',
#   'to',
#   'the',
#   'university'],
#  ['she',
#   'is',
#   'responsible',
#   'for',
#   'working',
#   'with',
#   'the',
#   'relevant',
#   'team',
#   'within',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   's',
#   'the',
#   'student',
#   'and',
#   'relevant',
#   'academic',
#   'department',
#   'to',
#   'identify',
#   'what',
#   'adjustment',
#   'are',
#   'appropriate',
#   'and',
#   'reasonable',
#   'within',
#   'the',
#   'context',
#   'of',
#   'a',
#   'specific',
#   'study',
#   'abroad',
#   'opportunity'],
#  ['the',
#   'academic',
#   'registrar',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'effective',
#   'facilitation',
#   'of',
#   'disclos',
#   'ure',
#   'of',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'process'],
#  ['the',
#   'director',
#   'of',
#   'human',
#   'resources',
#   'through',
#   'th',
#   'e',
#   'equality',
#   'and',
#   'diversity',
#   'manager',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'relevant',
#   'training',
#   'and',
#   'development',
#   'opportunity',
#   'related',
#   'to',
#   'issue',
#   'of',
#   'equality',
#   'a',
#   'nd',
#   'diversity',
#   'are',
#   'available',
#   'to',
#   'staff'],
#  ['the',
#   'counselling',
#   'manager',
#   'and',
#   'mental',
#   'wellbeing',
#   'advisor',
#   's',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'appropriate',
#   'provision',
#   'of',
#   'support',
#   'to',
#   'student',
#   'with',
#   'mental',
#   'health',
#   'difficulty'],
#  ['the',
#   'occupational',
#   'health',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'assessing',
#   'at',
#   'enrolment',
#   'whether',
#   'those',
#   'student',
#   'attending',
#   'regulated',
#   'vocational',
#   'programme',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'training',
#   'and',
#   'are',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   'to',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'study',
#   'in',
#   'accordance',
#   'with',
#   'guidance',
#   'from',
#   'relevant',
#   'regulatory',
#   'body'],
#  ['in',
#   'addition',
#   'the',
#   'occupational',
#   'health',
#   'team',
#   'will',
#   'advise',
#   'programme',
#   'leader',
#   'where',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'impairment',
#   'or',
#   'health',
#   'condition',
#   'if',
#   'they',
#   'may',
#   'need',
#   'any',
#   'adjustment',
#   'to',
#   'the',
#   'training',
#   'programme',
#   'or',
#   'programme',
#   'of',
#   'study',
#   'on',
#   'medical',
#   'ground'],
#  ['the',
#   'programme',
#   'leader',
#   'will',
#   'liaise',
#   'through',
#   'the',
#   'disco',
#   'with',
#   'the',
#   'disability',
#   'team',
#   'if',
#   'there',
#   'is',
#   'a',
#   'need',
#   'to',
#   'clarify',
#   'whether',
#   'adjustment',
#   'recommended',
#   'are',
#   'considered',
#   'to',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'circumstance',
#   'of',
#   'the',
#   'individual'],
#  ['heads',
#   'of',
#   'all',
#   'other',
#   'department',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'their',
#   'provision',
#   'are',
#   'a',
#   'accessible',
#   'a',
#   'possible',
#   'eg',
#   'provision',
#   'of',
#   'alternative',
#   'format'],
#  ['the',
#   'manager',
#   'of',
#   'health',
#   'safety',
#   'and',
#   'environment',
#   'services',
#   'is',
#   'responsible',
#   'for',
#   'ensuring',
#   'procedure',
#   'for',
#   'person',
#   'al',
#   'emergency',
#   'evacuation',
#   'plans',
#   'are',
#   'available',
#   'on',
#   'the',
#   'university',
#   'intranet',
#   'and',
#   'for',
#   'maintaining',
#   'up',
#   'todate',
#   'evacuation',
#   'procedure',
#   'covering',
#   'all',
#   'university',
#   'building'],
#  ['she',
#   'is',
#   'responsible',
#   'for',
#   'training',
#   'evacuation',
#   'chair',
#   'operator',
#   'in',
#   'the',
#   'safe',
#   'use',
#   'of',
#   'equipment',
#   'to',
#   'assi',
#   'st',
#   'person',
#   'with',
#   'mobility',
#   'impairment',
#   'in',
#   'an',
#   'evacuation',
#   'situation',
#   'and',
#   'for',
#   'publishing',
#   'up',
#   'to',
#   'date',
#   'list',
#   'of',
#   'such',
#   'people',
#   'and',
#   'first',
#   'aiders',
#   'on',
#   'a',
#   'building',
#   'by',
#   'building',
#   'basis',
#   'on',
#   'the',
#   'intranet'],
#  ['all',
#   'student',
#   'and',
#   'applicant',
#   'have',
#   'a',
#   'responsibility',
#   'to',
#   'inform',
#   'the',
#   'univ',
#   'ersity',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'of',
#   'their',
#   'disability',
#   'or',
#   'medical',
#   'condition',
#   'in',
#   'order',
#   'that',
#   'support',
#   'can',
#   'be',
#   'provided'],
#  ['objectives',
#   'the',
#   'university',
#   'observes',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability',
#   'which',
#   'view',
#   'disability',
#   'a',
#   'being',
#   'created',
#   'by',
#   'barrier',
#   'within',
#   'society',
#   'rather',
#   'than',
#   'by',
#   'the',
#   'disability',
#   'itself'],
#  ['barriers',
#   'can',
#   'be',
#   'in',
#   'the',
#   'physical',
#   'environment',
#   'such',
#   'a',
#   'inaccessible',
#   'building',
#   'or',
#   'service',
#   'attitudinal',
#   'resulting',
#   'in',
#   'stereotype',
#   'prejudice',
#   'and',
#   'assumption',
#   'about',
#   'the',
#   'capability',
#   'of',
#   'di',
#   'sabled',
#   'people',
#   'or',
#   'organisational',
#   'such',
#   'a',
#   'having',
#   'inflexible',
#   'policy',
#   'and',
#   'procedure'],
#  ['the',
#   'university',
#   'aim',
#   'to',
#   'address',
#   'all',
#   'of',
#   'these',
#   'barrier',
#   'to',
#   'ensure',
#   'that',
#   'disabled',
#   'people',
#   'can',
#   'participate',
#   'in',
#   'all',
#   'aspect',
#   'of',
#   'university',
#   'life'],
#  ['the',
#   'university',
#   'recognises',
#   'it',
#   'responsibility',
#   'to',
#   'make',
#   'provision',
#   'a',
#   'accessible',
#   'a',
#   'possible',
#   'and',
#   'will',
#   'aim',
#   'to',
#   'do',
#   'this',
#   'using',
#   'inclusive',
#   'approach',
#   'to',
#   'provision',
#   'and',
#   'service',
#   'or',
#   'anticipatory',
#   'reasonable',
#   'adjustment',
#   'wherever',
#   'possible'],
#  ['the',
#   'university',
#   'aim',
#   'to',
#   'identify',
#   'the',
#   'most',
#   'common',
#   'barrier',
#   'experienced',
#   'by',
#   'disabled',
#   'student',
#   'and',
#   'wherever',
#   'possible',
#   'to',
#   'identify',
#   'appropriate',
#   'anticipatory',
#   'adjustment',
#   'to',
#   'overcome',
#   'these',
#   'barrier'],
#  ['where',
#   'this',
#   'is',
#   'not',
#   'possible',
#   'andor',
#   'additional',
#   'need',
#   'are',
#   'identified',
#   'the',
#   'university',
#   'will',
#   'seek',
#   'to',
#   'implement',
#   'appropriate',
#   'indiv',
#   'idual',
#   'reasonable',
#   'adjustment'],
#  ['reasonable',
#   'adjustment',
#   'individual',
#   'and',
#   'anticipatory',
#   'can',
#   'be',
#   'made',
#   'to',
#   'provision',
#   'or',
#   'practice',
#   'but',
#   'not',
#   'to',
#   'competence',
#   'standard'],
#  ['competence',
#   'standard',
#   'are',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standard',
#   'which',
#   'are',
#   'required',
#   'for',
#   'the',
#   'programme'],
#  ['competence',
#   'standard',
#   'must',
#   'be',
#   'directly',
#   'related',
#   'to',
#   'the',
#   'learning',
#   'outcome',
#   'of',
#   'the',
#   'programme'],
#  ['there',
#   'is',
#   'therefore',
#   'no',
#   'requirement',
#   'to',
#   'alter',
#   'the',
#   'academic',
#   'standard',
#   'of',
#   'a',
#   'programme',
#   'for',
#   'a',
#   'disabled',
#   'student'],
#  ['however',
#   'it',
#   'may',
#   'be',
#   'necessary',
#   'to',
#   'adjust',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed'],
#  ['the',
#   'university',
#   'ha',
#   'specialist',
#   'targeted',
#   'provision',
#   'to',
#   'support',
#   'this',
#   'approach'],
#  ['the',
#   'disability',
#   'team',
#   'is',
#   'the',
#   'key',
#   'specialist',
#   'service',
#   'provided',
#   'by',
#   'the',
#   'university'],
#  ['specialists',
#   'within',
#   'this',
#   'team',
#   'understand',
#   'the',
#   'barrier',
#   'which',
#   'can',
#   'impact',
#   'on',
#   'student',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'academic',
#   'study',
#   'and',
#   'identify',
#   'inclusive',
#   'approach',
#   'anticipatory',
#   'and',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'enable',
#   'individual',
#   'to',
#   'participate',
#   'fully',
#   'in',
#   'university',
#   'life'],
#  ['on',
#   'some',
#   'occasion',
#   'this',
#   'provision',
#   'will',
#   'also',
#   'be',
#   'informed',
#   'by',
#   'an',
#   'external',
#   'third',
#   'party',
#   'with',
#   'appropriate',
#   'specialist',
#   'knowledge'],
#  ['disability',
#   'coordinators',
#   'discos',
#   'in',
#   'faculty',
#   'and',
#   'school',
#   'provide',
#   'targeted',
#   'academic',
#   'support',
#   'for',
#   'disabled',
#   'student'],
#  ['discos',
#   'have',
#   'discipline',
#   'specific',
#   'knowledge',
#   'which',
#   'enab',
#   'le',
#   'them',
#   'to',
#   'apply',
#   'the',
#   'reasonable',
#   'adjustment',
#   'in',
#   'a',
#   'proportionate',
#   'and',
#   'appropriate',
#   'manner',
#   'in',
#   'consultation',
#   'with',
#   'programme',
#   'and',
#   'module',
#   'leader'],
#  ['discos',
#   'are',
#   'also',
#   'a',
#   'local',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'staff',
#   'and',
#   'disabled',
#   'student',
#   'and',
#   'will',
#   'coordinate',
#   'support',
#   'within',
#   'the',
#   'facu',
#   'lty',
#   'or',
#   'school'],
#  ['all',
#   'student',
#   'have',
#   'access',
#   'to',
#   'a',
#   'personal',
#   'tutor',
#   'who',
#   'will',
#   'signpost',
#   'to',
#   'relevant',
#   'specialist',
#   'service',
#   'within',
#   'the',
#   'university'],
#  ['disclosing',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'students',
#   'are',
#   'able',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'their',
#   'time',
#   'at',
#   'the',
#   'university'],
#  ['all',
#   'applicant',
#   'to',
#   'the',
#   'university',
#   'will',
#   'be',
#   'given',
#   'the',
#   'opportunity',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'prior',
#   'to',
#   'commencement',
#   'of',
#   'a',
#   'programme'],
#  ['all',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'will',
#   'be',
#   'required',
#   'to',
#   'complete',
#   'a',
#   'health',
#   'declaration',
#   'prior',
#   'to',
#   'commencing',
#   'their',
#   'programme'],
#  ['this',
#   'will',
#   'include',
#   'a',
#   'requirement',
#   'to',
#   'notify',
#   'any',
#   'disability',
#   'which',
#   'may',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'complete',
#   'the',
#   'programme'],
#  ['this',
#   'will',
#   'result',
#   'in',
#   'an',
#   'assessment',
#   'by',
#   'the',
#   'occupational',
#   'hea',
#   'lth',
#   'team'],
#  ['students',
#   'and',
#   'applicant',
#   'will',
#   'need',
#   'to',
#   'provide',
#   'relevant',
#   'consent',
#   'for',
#   'process',
#   'to',
#   'be',
#   'followed',
#   'and',
#   'must',
#   'engage',
#   'fully',
#   'in',
#   'this',
#   'process'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'contact',
#   'all',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'through',
#   'recruitment',
#   'process',
#   'prior',
#   't',
#   'o',
#   'their',
#   'arrival',
#   'in',
#   'order',
#   'that',
#   'the',
#   'support',
#   'process',
#   'can',
#   'be',
#   'in',
#   'place',
#   'for',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'programme'],
#  ['students',
#   'will',
#   'be',
#   'given',
#   'a',
#   'further',
#   'opportunity',
#   'to',
#   'disclose',
#   'a',
#   'disability',
#   'during',
#   'the',
#   'registration',
#   'and',
#   'enrolment',
#   'process'],
#  ['all',
#   'student',
#   'on',
#   'regulated',
#   'vo',
#   'cational',
#   'programme',
#   'who',
#   'disclose',
#   'a',
#   'significant',
#   'disability',
#   'to',
#   'the',
#   'disability',
#   'team',
#   'programme',
#   'leaders',
#   'or',
#   'others',
#   'will',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'occupational',
#   'health',
#   'team',
#   'for',
#   'assessment',
#   'of',
#   'the',
#   'potential',
#   'impact',
#   'on',
#   'study',
#   'and',
#   'practice'],
#  ['this',
#   'may',
#   'result',
#   'in',
#   'confirmation',
#   'th',
#   'at',
#   'the',
#   'occupational',
#   'health',
#   'team',
#   'have',
#   'already',
#   'addressed',
#   'the',
#   'issue',
#   'or',
#   'may',
#   'result',
#   'in',
#   'a',
#   'new',
#   'assessment'],
#  ['if',
#   'during',
#   'their',
#   'period',
#   'of',
#   'study',
#   'a',
#   'student',
#   'becomes',
#   'aware',
#   'of',
#   'a',
#   'previously',
#   'undiagnosed',
#   'disability',
#   'they',
#   'should',
#   'contact',
#   'the',
#   'disability',
#   'team',
#   'a',
#   'soon',
#   'a',
#   'po',
#   'sible'],
#  ['if',
#   'at',
#   'any',
#   'time',
#   'any',
#   'member',
#   'of',
#   'staff',
#   'becomes',
#   'aware',
#   'of',
#   'serious',
#   'concern',
#   'regarding',
#   'a',
#   'student',
#   'on',
#   'a',
#   'regulated',
#   'vocational',
#   'programme',
#   'which',
#   'might',
#   'impact',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'meet',
#   'competence',
#   'standard',
#   'the',
#   'student',
#   'must',
#   'be',
#   'referred',
#   'for',
#   'an',
#   'occupational',
#   'health',
#   'assessment',
#   'through',
#   'the',
#   'program',
#   'leader',
#   'utilising',
#   'the',
#   'fitness',
#   'to',
#   'studypractice',
#   'policy'],
#  ['students',
#   'who',
#   'wish',
#   'to',
#   'discus',
#   'access',
#   'to',
#   'reasonable',
#   'adjustment',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'disability',
#   'team',
#   'a',
#   'early',
#   'a',
#   'possible'],
#  ['students',
#   'who',
#   'wish',
#   'to',
#   'access',
#   'reasonable',
#   'adjustment',
#   'will',
#   'be',
#   'required',
#   'to',
#   'provide',
#   'evidence',
#   'of',
#   'their',
#   'disability'],
#  ['further',
#   'guidance',
#   'on',
#   'evidence',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'disability',
#   'team'],
#  ['students',
#   'with',
#   'specific',
#   'learning',
#   'difficulty',
#   'andor',
#   'dyslexia',
#   'should',
#   'refer',
#   'to',
#   'the',
#   'specific',
#   'learning',
#   'di',
#   'fficulties',
#   'and',
#   'dyslexia',
#   'guidance',
#   'contained',
#   'within',
#   'appendix'],
#  ['guidance',
#   'on',
#   'the',
#   'identification',
#   'and',
#   'implementation',
#   'of',
#   'reasonable',
#   'adjustments',
#   'the',
#   'university',
#   'ha',
#   'a',
#   'range',
#   'of',
#   'established',
#   'inclusive',
#   'practice',
#   'in',
#   'place',
#   'across',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'student',
#   'can',
#   'access',
#   'programme'],
#  ['information',
#   'on',
#   'these',
#   'inclusive',
#   'practice',
#   'can',
#   'be',
#   'obtained',
#   'from',
#   'the',
#   'disability',
#   'team',
#   'or',
#   'discos',
#   'within',
#   'individual',
#   'school',
#   'and',
#   'faculty',
#   'and',
#   'will',
#   'be',
#   'highlighted',
#   'to',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'to',
#   'the',
#   'university',
#   'by',
#   'the',
#   'dis',
#   'ability',
#   'team'],
#  ['inclusive',
#   'anticipatory',
#   'approach',
#   'will',
#   'be',
#   'accessible',
#   'to',
#   'all',
#   'student',
#   'in',
#   'order',
#   'that',
#   'student',
#   'who',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'disclose',
#   'to',
#   'the',
#   'university',
#   'can',
#   'also',
#   'access',
#   'appropriate',
#   'provision'],
#  ['whilst',
#   'inclusive',
#   'approach',
#   'and',
#   'anticipatory',
#   'adjustment',
#   'will',
#   'meet',
#   'many',
#   'disabled',
#   'student',
#   'need',
#   'some',
#   'student',
#   'will',
#   'still',
#   'require',
#   'additional',
#   'individual',
#   'adjustment'],
#  ['the',
#   'disability',
#   'team',
#   'is',
#   'responsible',
#   'for',
#   'identifying',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'to',
#   'programme',
#   'of',
#   'study',
#   'for',
#   'individual',
#   'student',
#   'in',
#   'con',
#   'sultation',
#   'with',
#   'programme',
#   'leader',
#   'where',
#   'appropriate',
#   'and',
#   'within',
#   'the',
#   'wider',
#   'university',
#   'provision'],
#  ['programme',
#   'team',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'anticipatory',
#   'adjustment',
#   'to',
#   'programme',
#   'of',
#   'study',
#   'are',
#   'in',
#   'place'],
#  ['if',
#   'a',
#   'student',
#   'ha',
#   'an',
#   'independent',
#   'assessment',
#   'o',
#   'f',
#   'needs',
#   'report',
#   'for',
#   'disabled',
#   'students',
#   'allowance',
#   'dsa',
#   'purpose',
#   'or',
#   'an',
#   'educational',
#   'psychologists',
#   'report',
#   'the',
#   'recommendation',
#   'from',
#   'these',
#   'report',
#   'will',
#   'be',
#   'considered',
#   'when',
#   'identifying',
#   'reasonable',
#   'adjustment'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'firstly',
#   'consider',
#   'whether',
#   'anticipatory',
#   'adjustment',
#   'will',
#   'meet',
#   'the',
#   'specific',
#   'need',
#   'of',
#   'the',
#   'individual',
#   'student',
#   'and',
#   'then',
#   'whether',
#   'individual',
#   'reasonable',
#   'adjustment',
#   'are',
#   'required'],
#  ['the',
#   'disability',
#   'team',
#   'in',
#   'consultation',
#   'with',
#   'academic',
#   'colleague',
#   'will',
#   'consider',
#   'a',
#   'number',
#   'of',
#   'factor',
#   'when',
#   'deciding',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'is',
#   'reasonable'],
#  ['factors',
#   'may',
#   'include',
#   'but',
#   'not',
#   'be',
#   'limited',
#   'to',
#   'the',
#   'perceived',
#   'effectiveness',
#   'of',
#   'the',
#   'adjustment',
#   'the',
#   'time',
#   'or',
#   'resource',
#   'required',
#   'to',
#   'implement',
#   'the',
#   'adjustment',
#   'the',
#   'student',
#   'previous',
#   'experience',
#   'of',
#   'the',
#   'adjustment',
#   'and',
#   'whether',
#   'the',
#   'need',
#   'could',
#   'be',
#   'met',
#   'through',
#   'an',
#   'existing',
#   'inclusive',
#   'approach',
#   'or',
#   'anticipatory',
#   'adjustment'],
#  ['the',
#   'university',
#   'is',
#   'not',
#   'obliged',
#   'to',
#   'offer',
#   'the',
#   'student',
#   'their',
#   'preferred',
#   'adjustment',
#   'particularly',
#   'if',
#   'an',
#   'inclusive',
#   'approach',
#   'or',
#   'alternative',
#   'adjustment',
#   'is',
#   'available',
#   'whi',
#   'ch',
#   'would',
#   'provide',
#   'appropriate',
#   'support',
#   'for',
#   'the',
#   'student'],
#  ['for',
#   'information',
#   'regarding',
#   'the',
#   'complaint',
#   'process',
#   'to',
#   'be',
#   'used',
#   'when',
#   'a',
#   'student',
#   'disagrees',
#   'with',
#   'a',
#   'proposed',
#   'reasonable',
#   'adjustment',
#   'see',
#   'section',
#   'where',
#   'appropriate',
#   'the',
#   'disability',
#   'team',
#   'will',
#   'liaise',
#   'with',
#   'the',
#   'disco',
#   'to',
#   'discus',
#   'whether',
#   'an',
#   'individual',
#   'adjustment',
#   'may',
#   'conflict',
#   'with',
#   'the',
#   'competence',
#   'standard',
#   'for',
#   'the',
#   'programme',
#   'and',
#   'how',
#   'this',
#   'might',
#   'be',
#   'addressed',
#   'within',
#   'the',
#   'islp'],
#  ['for',
#   'student',
#   'who',
#   'are',
#   'able',
#   'to',
#   'ac',
#   'ce',
#   'external',
#   'funding',
#   'for',
#   'a',
#   'reasonable',
#   'adjustment',
#   'for',
#   'example',
#   'through',
#   'dsa',
#   'the',
#   'university',
#   'requires',
#   'the',
#   'student',
#   'to',
#   'access',
#   'such',
#   'funding'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'provide',
#   'guidance',
#   'and',
#   'advice',
#   'on',
#   'this',
#   'process',
#   'where',
#   'necessary'],
#  ['where',
#   'external',
#   'financial',
#   'source',
#   'are',
#   'not',
#   'available',
#   'and',
#   'the',
#   'disability',
#   'team',
#   'identify',
#   'the',
#   'adjustment',
#   'to',
#   'be',
#   'reasonable',
#   'the',
#   'university',
#   'will',
#   'seek',
#   'to',
#   'fund',
#   'this',
#   'adjustment',
#   'where',
#   'possible'],
#  ['annually',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'will',
#   'set',
#   'in',
#   'conjunction',
#   'with',
#   'the',
#   'stu',
#   'dent',
#   'support',
#   'manager',
#   'and',
#   'the',
#   'disability',
#   'team',
#   'an',
#   'upper',
#   'financial',
#   'limit',
#   'for',
#   'individual',
#   'reasonable',
#   'adjustment'],
#  ['in',
#   'the',
#   'majority',
#   'of',
#   'case',
#   'this',
#   'will',
#   'ensure',
#   'that',
#   'reasonable',
#   'adjustment',
#   'can',
#   'be',
#   'put',
#   'in',
#   'place',
#   'without',
#   'onwards',
#   'referral',
#   'and',
#   'therefore',
#   'ease',
#   'the',
#   'speed',
#   'of',
#   'the',
#   'process'],
#  ['where',
#   'the',
#   'upper',
#   'limit',
#   'is',
#   'breeched',
#   'the',
#   'disability',
#   'team',
#   'will',
#   'refer',
#   'the',
#   'case',
#   'to',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'for',
#   'review',
#   'and',
#   'agreeme',
#   'nt',
#   'if',
#   'appropriate'],
#  ['if',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'doe',
#   'not',
#   'think',
#   'that',
#   'the',
#   'proposed',
#   'adjustment',
#   'is',
#   'reasonable',
#   'she',
#   'will',
#   'discus',
#   'alternative',
#   'option',
#   'with',
#   'the',
#   'disability',
#   'team',
#   'who',
#   'may',
#   'then',
#   'discus',
#   'these',
#   'with',
#   'the',
#   'student',
#   'before',
#   'any',
#   'adjustment',
#   'are',
#   'agreed'],
#  ['with',
#   'the',
#   'student',
#   'consent',
#   'the',
#   'disability',
#   'team',
#   'will',
#   'produce',
#   'an',
#   'in',
#   'dividual',
#   'student',
#   'learning',
#   'plan',
#   'islp',
#   'for',
#   'each',
#   'student',
#   'which',
#   'identifies',
#   'the',
#   'inclusive',
#   'approach',
#   'and',
#   'reasonable',
#   'adjustment',
#   'required'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'then',
#   'forward',
#   'this',
#   'document',
#   'to',
#   'the',
#   'disco',
#   'in',
#   'the',
#   'relevant',
#   'academic',
#   'school',
#   'or',
#   'faculty'],
#  ['without',
#   'consent',
#   'the',
#   'disability',
#   'team',
#   'will',
#   'be',
#   'unable',
#   'to',
#   'progress',
#   'support',
#   'for',
#   'an',
#   'individual',
#   'student'],
#  ['a',
#   'copy',
#   'of',
#   'the',
#   'islp',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'relevant',
#   'disco',
#   'for',
#   'appropriate',
#   'circulation',
#   'within',
#   'the',
#   'schoolfaculty'],
#  ['programme',
#   'leader',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'all',
#   'relevant',
#   'academic',
#   'colleague',
#   'are',
#   'aware',
#   'of',
#   'the',
#   'reasonable',
#   'adjustment',
#   'required',
#   'for',
#   'student',
#   'within',
#   'their',
#   'cohort'],
#  ['the',
#   'disability',
#   'team',
#   'are',
#   'responsible',
#   'when',
#   'requested',
#   'to',
#   'by',
#   'a',
#   'student',
#   'for',
#   'ma',
#   'king',
#   'referral',
#   'to',
#   'external',
#   'agency',
#   'for',
#   'support',
#   'worker',
#   'and',
#   'should',
#   'be',
#   'considered',
#   'the',
#   'named',
#   'contact',
#   'for',
#   'this',
#   'element',
#   'of',
#   'provision'],
#  ['if',
#   'a',
#   'student',
#   'doe',
#   'not',
#   'think',
#   'that',
#   'the',
#   'recommended',
#   'reasonable',
#   'adjustment',
#   'have',
#   'been',
#   'implemented',
#   'she',
#   'should',
#   'raise',
#   'this',
#   'wit',
#   'h',
#   'the',
#   'relevant',
#   'disco',
#   'in',
#   'the',
#   'first',
#   'instance'],
#  ['if',
#   'the',
#   'situation',
#   'is',
#   'not',
#   'resolved',
#   'through',
#   'this',
#   'approach',
#   'then',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'disability',
#   'team',
#   'who',
#   'will',
#   'endeavour',
#   'to',
#   'work',
#   'with',
#   'the',
#   'appropriate',
#   'academic',
#   'area',
#   'and',
#   'find',
#   'an',
#   'appropriate',
#   'solution'],
#  ['if',
#   'the',
#   'student',
#   'remains',
#   'dissatisfied',
#   'then',
#   'she',
#   'should',
#   'make',
#   'a',
#   'complaint',
#   'using',
#   'the',
#   'student',
#   'complaint',
#   'procedure'],
#  ['the',
#   'impact',
#   'andor',
#   'nature',
#   'of',
#   'a',
#   'student',
#   'disability',
#   'may',
#   'change',
#   'over',
#   'the',
#   'course',
#   'of',
#   'their',
#   'period',
#   'of',
#   'study'],
#  ['this',
#   'may',
#   'result',
#   'in',
#   'the',
#   'anticipatory',
#   'suppo',
#   'rt',
#   'or',
#   'reasonable',
#   'adjustment',
#   'no',
#   'longer',
#   'being',
#   'appropriate'],
#  ['in',
#   'such',
#   'case',
#   'the',
#   'student',
#   'should',
#   'contact',
#   'the',
#   'disability',
#   'team',
#   'at',
#   'the',
#   'earliest',
#   'opportunity',
#   'to',
#   'discus',
#   'the',
#   'change'],
#  ['the',
#   'disability',
#   'team',
#   'will',
#   'identify',
#   'whether',
#   'there',
#   'are',
#   'additional',
#   'or',
#   'alternate',
#   'inclus',
#   'ive',
#   'approach',
#   'or',
#   'reasonable',
#   'adjustment',
#   'needed'],
#  ['the', 'process', 'will', 'then', 'proceed', 'a', 'from', 'above'],
#  ['occupational',
#   'health',
#   'are',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'student',
#   'on',
#   'regulated',
#   'vocational',
#   'programme',
#   'are',
#   'suitable',
#   'to',
#   'commence',
#   'study',
#   'and',
#   'likely',
#   'to',
#   'be',
#   'fit',
#   't',
#   'o',
#   'practice',
#   'on',
#   'completion',
#   'of',
#   'their',
#   'study'],
#  ['this',
#   'requires',
#   'them',
#   'to',
#   'meet',
#   'the',
#   'relevant',
#   'competence',
#   'standard',
#   'for',
#   'the',
#   'profession',
#   'with',
#   'reasonable',
#   'adjustment',
#   'if',
#   'required'],
#  ['adjustments',
#   'which',
#   'may',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'context',
#   'of',
#   'study',
#   'may',
#   'not',
#   'be',
#   'reasonable',
#   'in',
#   'the',
#   'c',
#   'ontext',
#   'of',
#   'professional',
#   'practice'],
#  ['wherever',
#   'possible',
#   'the',
#   'fitness',
#   'to',
#   'practice',
#   'of',
#   'applicant',
#   'who',
#   'have',
#   'declared',
#   'a',
#   'disability',
#   'will',
#   'be',
#   'assessed',
#   'prior',
#   'to',
#   'the',
#   'applicant',
#   'entering',
#   'the',
#   'university'],
#  ['the',
#   'occupational',
#   'health',
#   'team',
#   'in',
#   'liaison',
#   'with',
#   'the',
#   'programme',
#   'leader',
#   'm',
#   'ay',
#   'make',
#   'recommendation',
#   'for',
#   'reasonable',
#   'adjustment'],
#  ['assistance',
#   'animal',
#   's',
#   'the',
#   'universitys',
#   'health',
#   'and',
#   'safety',
#   'policy',
#   'require',
#   'that',
#   'only',
#   'assistance',
#   'animal',
#   'be',
#   'allowed',
#   'onto',
#   'campus'],
#  ['for',
#   'this',
#   'purpose',
#   'therefore',
#   'only',
#   'assist',
#   'ance',
#   'animal',
#   'registered',
#   'with',
#   'an',
#   'appropriate',
#   'professio',
#   'nal',
#   'standard',
#   'body',
#   'will',
#   'be',
#   'allowed',
#   'into',
#   'university',
#   'building'],
#  ['if',
#   'a',
#   'request',
#   'is',
#   'made',
#   'through',
#   'the',
#   'disability',
#   'team',
#   'this',
#   'information',
#   'will',
#   'be',
#   'passed',
#   'to',
#   'the',
#   'relevant',
#   'disco',
#   'and',
#   'to',
#   'the',
#   'health',
#   'and',
#   'safety',
#   'team',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'to',
#   'allow',
#   'for',
#   'adjustment',
#   'such',
#   'a',
#   'spending',
#   'pen',
#   'to',
#   'be',
#   'made'],
#  ['the',
#   'owner',
#   'of',
#   'the',
#   'assistance',
#   'animal',
#   'will',
#   'be',
#   'asked',
#   'for',
#   'their',
#   'permission',
#   'to',
#   'communicate',
#   'this',
#   'fact',
#   'to',
#   'other',
#   'student',
#   'in',
#   'order',
#   'that',
#   'any',
#   'other',
#   'issue',
#   'can',
#   'be',
#   'circumvented',
#   'in',
#   'a',
#   'timely',
#   'manner',
#   'eg',
#   'allergy'],
#  ['the',
#   's',
#   'tudent',
#   'owner',
#   'of',
#   'the',
#   'animal',
#   'will',
#   'remain',
#   'responsible',
#   'for',
#   'the',
#   'animal',
#   'at',
#   'all',
#   'time'],
#  ['complaints',
#   'in',
#   'the',
#   'first',
#   'instance',
#   'concern',
#   'regarding',
#   'the',
#   'appropriate',
#   'andor',
#   'timely',
#   'nature',
#   'of',
#   'provision',
#   'of',
#   'support',
#   'should',
#   'b',
#   'e',
#   'directed',
#   'to',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'for',
#   'informal',
#   'resolution'],
#  ['if',
#   'a',
#   'student',
#   'having',
#   'first',
#   'referred',
#   'the',
#   'matter',
#   'to',
#   'the',
#   'director',
#   'of',
#   'student',
#   'advice',
#   'and',
#   'wellbeing',
#   'service',
#   'belief',
#   'that',
#   'they',
#   'have',
#   'not',
#   'received',
#   'the',
#   'appropriate',
#   'reasonable',
#   'adjustment',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'can',
#   'study',
#   'effectively',
#   'the',
#   'matter',
#   'should',
#   'be',
#   'referred',
#   'to',
#   'the',
#   'student',
#   'governance',
#   'team',
#   'to',
#   'be',
#   'addressed',
#   'through',
#   'the',
#   'universitys',
#   's',
#   'tudent',
#   'complaints',
#   'procedure'],
#  ['this',
#   'can',
#   'be',
#   'accessed',
#   'using',
#   'the',
#   'following',
#   'link',
#   'httpswwwljmuacukabout',
#   'uspublic',
#   'informationstudent',
#   'regulationsappeals',
#   'and',
#   'complaint',
#   'related',
#   'policies',
#   'the',
#   'university',
#   'ha',
#   'a',
#   'number',
#   'of',
#   'policy',
#   'designed',
#   'to',
#   'support',
#   'all',
#   'student',
#   'some',
#   'of',
#   'which',
#   'may',
#   'have',
#   'particular',
#   'relevance',
#   'to',
#   'disabled',
#   'student'],
# ...
#   'per',
#   'academic',
#   'year',
#   'but',
#   't',
#   'his',
#   'will',
#   'vary',
#   'depending',
#   'on',
#   'the',
#   'number',
#   'of',
#   'disclosed',
#   'disabled',
#   'student',
#   'within',
#   'the',
#   'sch',
#   'ool',
#   'and',
#   'the',
#   'complexity',
#   'of',
#   'such',
#   'case'],
#  ['a',
#   'faculty',
#   'department',
#   'or',
#   'school',
#   'should',
#   'al',
#   'low',
#   'for',
#   'multiple',
#   'individual',
#   'to',
#   'undertake',
#   'the',
#   'disco',
#   'role',
#   'if',
#   'appropriate',
#   'to',
#   'local',
#   'circumstance',
#   's'],
#  ['the',
#   'disability',
#   'coordinator',
#   'will',
#   'act',
#   'a',
#   'a',
#   'point',
#   'of',
#   'contact',
#   'for',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'support',
#   'need'],
#  ['act',
#   'a',
#   'a',
#   'liaison',
#   'point',
#   'between',
#   'the',
#   'schooldepartment',
#   'and',
#   'the',
#   'disability',
#   'team'],
#  ['ensure',
#   'that',
#   'the',
#   'disclosure',
#   'of',
#   'disability',
#   'is',
#   'actively',
#   'encouraged',
#   'and',
#   'communicated',
#   'effectively',
#   'within',
#   'the',
#   'schooldepartment',
#   'including',
#   'from',
#   'academic',
#   'colleague',
#   'to',
#   'the',
#   'disability',
#   'team',
#   'and',
#   'in',
#   'reverse',
#   'where',
#   'appropriate'],
#  ['liaise',
#   'with',
#   'relevant',
#   'colleague',
#   'within',
#   'the',
#   'university',
#   'regarding',
#   'any',
#   'issue',
#   'relating',
#   'to',
#   'the',
#   'support',
#   'of',
#   'disabled',
#   'student'],
#  ['raise',
#   'awareness',
#   'within',
#   'the',
#   'schooldepartment',
#   'of',
#   'issue',
#   'facing',
#   'student',
#   'with',
#   'disability',
#   'and',
#   'the',
#   'academic',
#   'implication',
#   'this',
#   'may',
#   'have'],
#  ['work',
#   'with',
#   'standard',
#   'procedure',
#   'acros',
#   's',
#   'the',
#   'institution',
#   'to',
#   'ensure',
#   'that',
#   'all',
#   'issue',
#   'of',
#   'disclosure',
#   'distribution',
#   'of',
#   'islps',
#   'and',
#   'related',
#   'issue',
#   'are',
#   'dealt',
#   'with',
#   'in',
#   'a',
#   'consistent',
#   'and',
#   'systematic',
#   'manner',
#   'including',
#   'communication',
#   'with',
#   'relevant',
#   'academic',
#   'colleague'],
#  ['assist',
#   'the',
#   'directorhead',
#   'of',
#   'schooldepart',
#   'ment',
#   'to',
#   'ensure',
#   'that',
#   'a',
#   'robust',
#   'islp',
#   'record',
#   'system',
#   'is',
#   'in',
#   'operation',
#   'throughout',
#   'the',
#   'school'],
#  ['coordinate',
#   'and',
#   'support',
#   'schooldepartment',
#   'based',
#   'training',
#   'development',
#   'and',
#   'awareness',
#   'raising',
#   'activity',
#   'for',
#   'disability',
#   'support',
#   'liaising',
#   'with',
#   'relevant',
#   'professional',
#   'serv',
#   'ice',
#   'staff',
#   'disability',
#   'supportequal',
#   'opportunities'],
#  ['contribute',
#   'to',
#   'and',
#   'update',
#   'disability',
#   'support',
#   'infor',
#   'mation',
#   'on',
#   'the',
#   'faculty',
#   'community',
#   'site'],
#  ['regularly',
#   'attend',
#   'meeting',
#   'of',
#   'the',
#   'university',
#   'disco',
#   'steering',
#   'group',
#   'and',
#   'cascade',
#   'relevant',
#   'information',
#   'within',
#   'the',
#   's',
#   'chool',
#   'or',
#   'faculty'],
#  ['provide',
#   'support',
#   'and',
#   'advice',
#   'on',
#   'disability',
#   'matter',
#   'to',
#   'school',
#   'colleague',
#   'ensuring',
#   'that',
#   'concern',
#   'are',
#   'referred',
#   'effectively'],
#  [],
#  ['appendix',
#   'additional',
#   'examination',
#   'provision',
#   'in',
#   'certain',
#   'situation',
#   'it',
#   'is',
#   'appropriate',
#   'for',
#   'the',
#   'university',
#   'to',
#   'suppor',
#   't',
#   'student',
#   'through',
#   'formal',
#   'examination',
#   'with',
#   'reasonable',
#   'adjustment'],
#  ['this',
#   'policy',
#   'document',
#   'outline',
#   'the',
#   'provision',
#   'the',
#   'criterion',
#   'and',
#   'the',
#   'reasonable',
#   'adjustment',
#   'that',
#   'may',
#   'be',
#   'put',
#   'into',
#   'place'],
#  ['provision',
#   'available',
#   'all',
#   'provision',
#   'will',
#   'be',
#   'facilitated',
#   'through',
#   'the',
#   'islp',
#   'extra',
#   'time',
#   'this',
#   'will',
#   'be',
#   'available',
#   'for',
#   'all',
#   'student',
#   'able',
#   'to',
#   'demonstrate',
#   'need',
#   'within',
#   'the',
#   'main',
#   'sitting',
#   'of',
#   'the',
#   'exam',
#   'unless',
#   'combined',
#   'with',
#   'additional',
#   'reasonable',
#   'adjustment',
#   'a',
#   'reader',
#   'this',
#   'will',
#   'provided',
#   'using',
#   'it',
#   'facility',
#   'within',
#   'each',
#   'faculty',
#   'and',
#   'will',
#   'be',
#   'prerecorded',
#   'by',
#   'a',
#   'member',
#   'of',
#   'staff',
#   'familiar',
#   'with',
#   'the',
#   'terminology',
#   'used'],
#  ['amanuensis',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'rest',
#   'breaks',
#   'this',
#   'facility',
#   'will',
#   'be',
#   'offered',
#   'in',
#   'a',
#   'separate',
#   'space',
#   'from',
#   'the',
#   'main',
#   'sitting',
#   'in',
#   'all',
#   'case',
#   'where',
#   'a',
#   'separate',
#   'location',
#   'may',
#   'be',
#   'needed',
#   'it',
#   'would',
#   'also',
#   'be',
#   'appropriate',
#   'for',
#   'academic',
#   'colleague',
#   'to',
#   'consider',
#   'alternative',
#   'assessment'],
#  ['it',
#   'may',
#   'be',
#   'that',
#   'the',
#   'learning',
#   'outcome',
#   'can',
#   'be',
#   'addressed',
#   'via',
#   'an',
#   'alternative',
#   'method',
#   'of',
#   'assessment',
#   'and',
#   'this',
#   'should',
#   'be',
#   'discussed',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'in',
#   'the',
#   'academic',
#   'year'],
#  ['eligibility',
#   'for',
#   'additional',
#   'examination',
#   'provision',
#   'aep',
#   'students',
#   'must',
#   'have',
#   'disclosed',
#   'a',
#   'disability',
#   'medical',
#   'condition',
#   'or',
#   'specific',
#   'learning',
#   'difficulty',
#   'to',
#   'the',
#   'university',
#   'a',
#   'soon',
#   'a',
#   'possible',
#   'after',
#   'diagno',
#   'si',
#   'or',
#   'enrolment',
#   'at',
#   'the',
#   'institution',
#   'whichever',
#   'occurs',
#   'first',
#   'and',
#   'in',
#   'advance',
#   'of',
#   'the',
#   'assessment',
#   'period',
#   'a',
#   'per',
#   'the',
#   'process',
#   'below'],
#  ['eligibility',
#   'for',
#   'aep',
#   'will',
#   'be',
#   'documented',
#   'in',
#   'the',
#   'form',
#   'of',
#   'a',
#   'formal',
#   'individual',
#   'student',
#   'learning',
#   'plan',
#   'or',
#   'a',
#   'needs',
#   'assessment',
#   'document'],
#  ['no', 'other', 'evidence', 'will', 'be', 'accepted'],
#  ['in',
#   'the',
#   'event',
#   'of',
#   'a',
#   'temporary',
#   'or',
#   'newly',
#   'disclosed',
#   'disability',
#   'a',
#   'doctor',
#   'letter',
#   'will',
#   'be',
#   'acceptable',
#   'and',
#   'provision',
#   'will',
#   'be',
#   'put',
#   'into',
#   'place',
#   'for',
#   'the',
#   'impending',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'not',
#   'continue',
#   'for',
#   'the',
#   'duration',
#   'of',
#   'the',
#   'course'],
#  ['please',
#   'note',
#   'application',
#   'received',
#   'after',
#   'the',
#   'week',
#   'working',
#   'day',
#   'deadline',
#   'referred',
#   'to',
#   'in',
#   'process',
#   'below',
#   'will',
#   'not',
#   'be',
#   'considered',
#   'for',
#   'the',
#   'immediate',
#   'assessment',
#   'period',
#   'but',
#   'will',
#   'be',
#   'actioned',
#   'prior',
#   'to',
#   'subsequent',
#   'period'],
#  ['please',
#   'note',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'a',
#   'review',
#   'will',
#   'be',
#   'carried',
#   'out',
#   'by',
#   'faculty',
#   'examination',
#   'officer',
#   'and',
#   'any',
#   'student',
#   'who',
#   'do',
#   'not',
#   'take',
#   'up',
#   'the',
#   'provision',
#   'allocated',
#   'to',
#   'them',
#   'will',
#   'be',
#   'asked',
#   'to',
#   'review',
#   'this',
#   'position'],
#  ['this', 'may', 'result', 'in', 'the', 'provision', 'being', 'withdrawn'],
#  ['process',
#   'the',
#   'aep',
#   'application',
#   'form',
#   'will',
#   'be',
#   'available',
#   'at',
#   'httpsmyservicesljmuacukformsadditionalexamprovisionsaspx'],
#  ['the', 'form', 'should', 'be', 'completed', 'and', 'submitted', 'online'],
#  ['the',
#   'completed',
#   'form',
#   'will',
#   'be',
#   'sent',
#   'to',
#   'the',
#   'appropriate',
#   'facu',
#   'lty',
#   'where',
#   'access',
#   'will',
#   'be',
#   'restricted',
#   'to',
#   'a',
#   'small',
#   'number',
#   'of',
#   'staff',
#   'working',
#   'on',
#   'a',
#   'need',
#   'to',
#   'know',
#   'basis'],
#  ['applications',
#   'for',
#   'aep',
#   'should',
#   'be',
#   'made',
#   'a',
#   'early',
#   'a',
#   'possible',
#   'and',
#   'no',
#   'later',
#   'than',
#   'week',
#   'working',
#   'day',
#   'prior',
#   'to',
#   'the',
#   'start',
#   'of',
#   'the',
#   'assessment',
#   'period'],
#  ['an',
#   'applicat',
#   'ion',
#   'for',
#   'aep',
#   'will',
#   'remain',
#   'in',
#   'place',
#   'for',
#   'the',
#   'entirety',
#   'of',
#   'the',
#   'student',
#   'course',
#   'and',
#   'therefore',
#   'there',
#   'is',
#   'no',
#   'requirement',
#   'for',
#   'submission',
#   'every',
#   'year'],
#  ['however',
#   'should',
#   'aep',
#   'be',
#   'in',
#   'place',
#   'but',
#   'not',
#   'utilised',
#   'this',
#   'may',
#   'result',
#   'in',
#   'withdrawal',
#   'of',
#   'this',
#   'provision'],
#  ['nb',
#   'flexibility',
#   'will',
#   'be',
#   'needed',
#   'with',
#   'extra',
#   'time',
#   'a',
#   'this',
#   'may',
#   'not',
#   'be',
#   'used',
#   'at',
#   'every',
#   'opportunity',
#   'but',
#   'the',
#   'student',
#   'may',
#   'still',
#   'wish',
#   'to',
#   'retain',
#   'it'],
#  ['faculty',
#   'examinations',
#   'staff',
#   'will',
#   'review',
#   'usage',
#   'at',
#   'the',
#   'end',
#   'of',
#   'each',
#   'assessment',
#   'period',
#   'and',
#   'contact',
#   'student',
#   'accordingly'],
#  ['if',
#   'at',
#   'review',
#   'a',
#   'student',
#   'state',
#   'that',
#   'they',
#   'no',
#   'longer',
#   'need',
#   'the',
#   'provision',
#   'this',
#   'should',
#   'be',
#   'reported',
#   'in',
#   'writing',
#   'and',
#   'appended',
#   'to',
#   'the',
#   'islp'],
#  ['the',
#   'provision',
#   'can',
#   'be',
#   'cancelled',
#   'and',
#   'a',
#   'copy',
#   'of',
#   'the',
#   'correspondence',
#   'sent',
#   'to',
#   'the',
#   'disability',
#   'team',
#   'for',
#   'completeness'],
#  ['if',
#   'at',
#   'r',
#   'eview',
#   'a',
#   'student',
#   'state',
#   'that',
#   'they',
#   'do',
#   'still',
#   'require',
#   'the',
#   'provision',
#   'provision',
#   'will',
#   'be',
#   'kept',
#   'in',
#   'place',
#   'for',
#   'a',
#   'subsequent',
#   'assessment',
#   'period'],
#  ['if',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'second',
#   'period',
#   'provision',
#   'ha',
#   'not',
#   'been',
#   'utilised',
#   'the',
#   'university',
#   'will',
#   'withdraw',
#   'the',
#   'provision'],
#  ['faculty',
#   'staff',
#   'should',
#   'send',
#   'written',
#   'confirmation',
#   'of',
#   'this',
#   'to',
#   'the',
#   'disability',
#   'team'],
#  ['faculty',
#   'administration',
#   'staff',
#   'will',
#   'contact',
#   'student',
#   'ahead',
#   'of',
#   'the',
#   'assessment',
#   'period',
#   'each',
#   'year',
#   'to',
#   'update',
#   'module',
#   'choice',
#   'and',
#   'ascertain',
#   'if',
#   'provision',
#   'is',
#   'still',
#   'needed'],
#  ['appendix',
#   'ljmu',
#   'spe',
#   'cific',
#   'learning',
#   'difficulties',
#   'and',
#   'dyslexia',
#   'policy',
#   'background',
#   'institutions',
#   'are',
#   'expected',
#   'to',
#   'ensure',
#   'that',
#   'provision',
#   'and',
#   'support',
#   'is',
#   'available',
#   'both',
#   'within',
#   'the',
#   'curriculum',
#   'and',
#   'generally',
#   'through',
#   'learning',
#   'and',
#   'teaching',
#   'method'],
#  ['ljmu',
#   'will',
#   'ensure',
#   'that',
#   'anticipatory',
#   'adjustment',
#   'and',
#   'provision',
#   'for',
#   'student',
#   'with',
#   'mild',
#   'dyslexia',
#   'is',
#   'incorporated',
#   'into',
#   'the',
#   'learning',
#   'environment',
#   'and',
#   'therefore',
#   'should',
#   'not',
#   'need',
#   'to',
#   'be',
#   'individually',
#   'addressed'],
#  ['provision',
#   'for',
#   'those',
#   'student',
#   'with',
#   'moderate',
#   'to',
#   'severe',
#   'spl',
#   'd',
#   'and',
#   'dyslexia',
#   'will',
#   'continue',
#   'to',
#   'be',
#   'addressed',
#   'individually'],
#  ['ljmu',
#   'complies',
#   'with',
#   'the',
#   'equality',
#   'act',
#   'the',
#   'disability',
#   'discrimination',
#   'act',
#   'and',
#   'special',
#   'educational',
#   'needs',
#   'disability',
#   'act',
#   'in',
#   'ensuring',
#   'that',
#   'all',
#   'student',
#   'are',
#   'able',
#   'to',
#   'access',
#   'the',
#   'provi',
#   'sion',
#   'of',
#   'education',
#   'and',
#   'associated',
#   'service'],
#  ['the',
#   'inclusion',
#   'of',
#   'the',
#   'anticipatory',
#   'duty',
#   'ensures',
#   'that',
#   'the',
#   'institution',
#   'continues',
#   'to',
#   'review',
#   'policy',
#   'and',
#   'procedure',
#   'regularly',
#   'and',
#   'through',
#   'student',
#   'partnership'],
#  ['this',
#   'policy',
#   'is',
#   'part',
#   'of',
#   'the',
#   'wider',
#   'institutional',
#   'policy',
#   'on',
#   'd',
#   'isability',
#   'provision',
#   'for',
#   'student',
#   'diagnostic',
#   'support',
#   'it',
#   'is',
#   'anticipated',
#   'that',
#   'the',
#   'majority',
#   'of',
#   'student',
#   'coming',
#   'into',
#   'higher',
#   'education',
#   'will',
#   'have',
#   'received',
#   'appropriate',
#   'support',
#   'and',
#   'assessment',
#   'whilst',
#   'in',
#   'primary',
#   'or',
#   'secondary',
#   'education'],
#  ['in',
#   'the',
#   'event',
#   'of',
#   'student',
#   'not',
#   'having',
#   'received',
#   'such',
#   'an',
#   'assessment',
#   'or',
#   'not',
#   'having',
#   'the',
#   'appropriate',
#   'level',
#   'of',
#   'assessment',
#   'ljmu',
#   'will',
#   'm',
#   'ake',
#   'available',
#   'a',
#   'formal',
#   'assessment'],
#  ['provision',
#   'of',
#   'support',
#   'eligibility',
#   'for',
#   'formal',
#   'educational',
#   'psychologists',
#   'assessment',
#   'undergraduate',
#   'and',
#   'post',
#   'graduate'],
#  ['studying',
#   'on',
#   'a',
#   'programme',
#   'with',
#   'a',
#   'duration',
#   'of',
#   'an',
#   'academic',
#   'year',
#   'or',
#   'longer',
#   'first',
#   'language',
#   'must',
#   'be',
#   'english',
#   'defined',
#   'a',
#   'educated',
#   'in',
#   'the',
#   'uk',
#   'from',
#   'the',
#   'age',
#   'of'],
#  ['translations',
#   'of',
#   'assessment',
#   'report',
#   'will',
#   'be',
#   'accepted',
#   'for',
#   'the',
#   'provision',
#   'of',
#   'support',
#   'but',
#   'due',
#   'to',
#   'the',
#   'inab',
#   'ility',
#   'of',
#   'the',
#   'test',
#   'to',
#   'ass',
#   'dyslexia',
#   'versus',
#   'language',
#   'issue',
#   'we',
#   'are',
#   'unable',
#   'to',
#   'ass',
#   'those',
#   'with',
#   'another',
#   'first',
#   'language'],
#  ['student',
#   'attending',
#   'a',
#   'course',
#   'with',
#   'a',
#   'collaborative',
#   'partner',
#   'should',
#   'access',
#   'support',
#   'through',
#   'the',
#   'provider',
#   'college'],
#  ['internal',
#   'screening',
#   'exer',
#   'cise',
#   'result',
#   'in',
#   'a',
#   'possibility',
#   'of',
#   'moderate',
#   'to',
#   'severe',
#   'dyslexia',
#   'funding',
#   'implication',
#   'there',
#   'is',
#   'a',
#   'cost',
#   'associated',
#   'with',
#   'each',
#   'educational',
#   'psychologists',
#   'report'],
#  ['students',
#   'are',
#   'expected',
#   'to',
#   'meet',
#   'the',
#   'eligibility',
#   'criterion',
#   'above',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'inform',
#   'ljmu',
#   'a',
#   't',
#   'least',
#   'hour',
#   'in',
#   'advance',
#   'if',
#   'they',
#   'unable',
#   'to',
#   'attend',
#   'the',
#   'assessment',
#   'meeting'],
#  ['students',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'of',
#   'the',
#   'charge',
#   'due',
#   'for',
#   'an',
#   'assessment'],
#  ['ljmu',
#   'will',
#   'meet',
#   'the',
#   'remaining',
#   'cost',
#   'of',
#   'each',
#   'assessment',
#   'up',
#   'to',
#   'an',
#   'annual',
#   'pre',
#   'determined',
#   'maximum'],
#  ['students',
#   'will',
#   'be',
#   'reminded',
#   'of',
#   'appointment',
#   'through',
#   'a',
#   'variety',
#   'of',
#   'timely',
#   'medium',
#   'such',
#   'a',
#   'email',
#   'sms',
#   'text',
#   'outlook',
#   'appointment',
#   'and',
#   'so',
#   'on'],
#  ['students',
#   'who',
#   'fail',
#   'to',
#   'attend',
#   'their',
#   'assessment',
#   'appointment',
#   'w',
#   'ill',
#   'be',
#   'charged',
#   'the',
#   'full',
#   'fee',
#   'incurred',
#   'by',
#   'the',
#   'university',
#   'through',
#   'the',
#   'usual',
#   'charging',
#   'mechanism',
#   'within',
#   'the',
#   'university'],
#  ['a',
#   'budget',
#   'will',
#   'be',
#   'established',
#   'to',
#   'ensure',
#   'that',
#   'this',
#   'is',
#   'not',
#   'a',
#   'first',
#   'come',
#   'first',
#   'served',
#   'budget',
#   'position',
#   'but',
#   'is',
#   'based',
#   'on',
#   'need'],
#  ['irlen',
#   'syndromescotopic',
#   'sensitivity',
#   'funding',
#   'will',
#   'be',
#   'made',
#   'available',
#   'for',
#   'stu',
#   'dent',
#   'to',
#   'receive',
#   'this',
#   'test',
#   'should',
#   'it',
#   'be',
#   'deemed',
#   'appropriate',
#   'through',
#   'the',
#   'educational',
#   'psychologists',
#   'as',
#   'essment'],
#  ['coloured',
#   'overlay',
#   'can',
#   'be',
#   'purchased',
#   'to',
#   'assist',
#   'student',
#   'rather',
#   'than',
#   'the',
#   'provision',
#   'of',
#   'pastel',
#   'paper'],
#  []]

# %%
# replace the old comments with the new pre-processed comments
data = {'Sentence': postfin1}
p1 = pd.DataFrame(data)

# %%
p1
# Out:
#                                               Sentence
# 0    [disability, policy, students, provision, of, ...
# 1    [date, introduced, january, dates, modified, f...
# 2    [a, wide, range, of, provision, is, available,...
# 3    [this, policy, set, out, how, ljmu, meet, it, ...
# 4    [it, identifies, the, universitys, approach, t...
# ..                                                 ...
# 220  [students, who, fail, to, attend, their, asses...
# 221  [a, budget, will, be, established, to, ensure,...
# 222  [irlen, syndromescotopic, sensitivity, funding...
# 223  [coloured, overlay, can, be, purchased, to, as...
# 224                                                 []
#
# [225 rows x 1 columns]

# %%
# set display options to show all columns and rows in the dataframe so i can quickly scan through
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# display the dataframe
print(p1)
# Out:
#                                               Sentence
# 0    [disability, policy, students, provision, of, ...
# 1    [date, introduced, january, dates, modified, f...
# 2    [a, wide, range, of, provision, is, available,...
# 3    [this, policy, set, out, how, ljmu, meet, it, ...
# 4    [it, identifies, the, universitys, approach, t...
# 5    [the, policy, is, supported, by, the, procedur...
# 6    [duty, to, make, reasonable, a, djustments, as...
# 7    [the, duty, to, make, reasonable, adjustment, ...
# 8    [in, particular, there, is, a, requirement, on...
# 9    [this, provision, applies, to, delivery, of, l...
# 10   [the, intention, is, that, the, learning, envi...
# 11   [institutional, responsibility, ljmu, wish, to...
# 12   [are, able, to, access, the, estate, and, buil...
# 13   [have, access, to, specialist, staff, who, are...
# 14   [have, documented, support, plan, in, place, i...
# 15           [can, access, it, facility, and, service]
# 16   [are, able, to, access, learning, material, in...
# 17   [are, able, to, access, additional, support, w...
# 18   [have, access, to, quiet, or, le, formal, envi...
# 19   [non, medical, help, is, defined, a, the, prov...
# 20   [these, were, previously, identified, a, band,...
# 21   [scope, this, policy, address, all, aspect, of...
# 22   [this, policy, applies, to, all, student, stud...
# 23   [however, student, on, s, hort, professional, ...
# 24   [the, principle, of, this, policy, apply, to, ...
# 25   [students, who, disclosed, or, declared, a, di...
# 26   [responsibilities, this, section, outline, the...
# 27   [it, doe, not, contain, operational, detail, o...
# 28   [further, information, about, relevant, proced...
# 29   [elt, are, responsible, for, the, universitys,...
# 30   [equality, diversity, and, inclusivity, commit...
# 31   [director, of, student, advice, and, wellbeing...
# 32   [she, is, also, responsible, for, ensuring, th...
# 33   [the, student, support, m, anager, is, respons...
# 34   [once, student, have, declared, a, disability,...
# 35   [the, disability, team, are, responsible, for,...
# 36   [the, disability, team, will, store, the, mast...
# 37   [the, disability, team, also, cover, specialis...
# 38   [directors, of, schoolheads, of, department, a...
# 39   [they, are, also, responsible, for, ensuring, ...
# 40   [directorsheads, have, a, responsibility, to, ...
# 41   [directorsheads, are, also, responsible, for, ...
# 42   [disability, coordinators, disco, are, school,...
# 43   [see, appendix, for, the, disability, coordina...
# 44   [module, leaders, have, a, responsibility, to,...
# 45   [this, information, is, available, from, t, he...
# 46   [personal, tutor, have, a, responsibility, to,...
# 47   [all, programme, staff, are, responsible, for,...
# 48   [the, islp, will, be, created, a, per, section...
# 49   [the, directo, r, of, library, service, is, re...
# 50   [the, director, of, student, advancement, is, ...
# 51   [she, is, also, responsible, for, ensuring, th...
# 52   [the, director, of, it, services, is, responsi...
# 53   [she, is, also, responsible, for, ensuring, th...
# 54   [the, director, s, of, estates, and, facilitie...
# 55   [she, is, also, responsible, for, ensuring, th...
# 56   [the, accommodation, manager, is, responsible,...
# 57   [this, is, a, sha, red, responsibility, with, ...
# 58   [the, head, of, operations, in, each, faculty,...
# 59   [the, head, of, operations, would, also, be, r...
# 60   [the, head, of, academic, quality, service, is...
# 61   [the, dean, of, the, learning, and, teaching, ...
# 62   [there, is, al, so, a, responsibility, here, t...
# 63   [the, director, of, corporate, communications,...
# 64   [the, director, of, student, recruitment, and,...
# 65   [preentry, disclosure, process, will, be, appl...
# 66   [the, director, of, international, relations, ...
# 67   [she, is, responsible, for, working, with, the...
# 68   [the, academic, registrar, is, responsible, fo...
# 69   [the, director, of, human, resources, through,...
# 70   [the, counselling, manager, and, mental, wellb...
# 71   [the, occupational, health, team, is, responsi...
# 72   [in, addition, the, occupational, health, team...
# 73   [the, programme, leader, will, liaise, through...
# 74   [heads, of, all, other, department, are, respo...
# 75   [the, manager, of, health, safety, and, enviro...
# 76   [she, is, responsible, for, training, evacuati...
# 77   [all, student, and, applicant, have, a, respon...
# 78   [objectives, the, university, observes, the, s...
# 79   [barriers, can, be, in, the, physical, environ...
# 80   [the, university, aim, to, address, all, of, t...
# 81   [the, university, recognises, it, responsibili...
# 82   [the, university, aim, to, identify, the, most...
# 83   [where, this, is, not, possible, andor, additi...
# 84   [reasonable, adjustment, individual, and, anti...
# 85   [competence, standard, are, academic, medical,...
# 86   [competence, standard, must, be, directly, rel...
# 87   [there, is, therefore, no, requirement, to, al...
# 88   [however, it, may, be, necessary, to, adjust, ...
# 89   [the, university, ha, specialist, targeted, pr...
# 90   [the, disability, team, is, the, key, speciali...
# 91   [specialists, within, this, team, understand, ...
# 92   [on, some, occasion, this, provision, will, al...
# 93   [disability, coordinators, discos, in, faculty...
# 94   [discos, have, discipline, specific, knowledge...
# 95   [discos, are, also, a, local, point, of, conta...
# 96   [all, student, have, access, to, a, personal, ...
# 97   [disclosing, a, disability, to, the, universit...
# 98   [all, applicant, to, the, university, will, be...
# 99   [all, student, on, regulated, vocational, prog...
# 100  [this, will, include, a, requirement, to, noti...
# 101  [this, will, result, in, an, assessment, by, t...
# 102  [students, and, applicant, will, need, to, pro...
# 103  [the, disability, team, will, contact, all, st...
# 104  [students, will, be, given, a, further, opport...
# 105  [all, student, on, regulated, vo, cational, pr...
# 106  [this, may, result, in, confirmation, th, at, ...
# 107  [if, during, their, period, of, study, a, stud...
# 108  [if, at, any, time, any, member, of, staff, be...
# 109  [students, who, wish, to, discus, access, to, ...
# 110  [students, who, wish, to, access, reasonable, ...
# 111  [further, guidance, on, evidence, can, be, obt...
# 112  [students, with, specific, learning, difficult...
# 113  [guidance, on, the, identification, and, imple...
# 114  [information, on, these, inclusive, practice, ...
# 115  [inclusive, anticipatory, approach, will, be, ...
# 116  [whilst, inclusive, approach, and, anticipator...
# 117  [the, disability, team, is, responsible, for, ...
# 118  [programme, team, will, be, responsible, for, ...
# 119  [if, a, student, ha, an, independent, assessme...
# 120  [the, disability, team, will, firstly, conside...
# 121  [the, disability, team, in, consultation, with...
# 122  [factors, may, include, but, not, be, limited,...
# 123  [the, university, is, not, obliged, to, offer,...
# 124  [for, information, regarding, the, complaint, ...
# 125  [for, student, who, are, able, to, ac, ce, ext...
# 126  [the, disability, team, will, provide, guidanc...
# 127  [where, external, financial, source, are, not,...
# 128  [annually, the, director, of, student, advice,...
# 129  [in, the, majority, of, case, this, will, ensu...
# 130  [where, the, upper, limit, is, breeched, the, ...
# 131  [if, the, director, of, student, advice, and, ...
# 132  [with, the, student, consent, the, disability,...
# 133  [the, disability, team, will, then, forward, t...
# 134  [without, consent, the, disability, team, will...
# 135  [a, copy, of, the, islp, will, be, sent, to, t...
# 136  [programme, leader, will, be, responsible, for...
# 137  [the, disability, team, are, responsible, when...
# 138  [if, a, student, doe, not, think, that, the, r...
# 139  [if, the, situation, is, not, resolved, throug...
# 140  [if, the, student, remains, dissatisfied, then...
# 141  [the, impact, andor, nature, of, a, student, d...
# 142  [this, may, result, in, the, anticipatory, sup...
# 143  [in, such, case, the, student, should, contact...
# 144  [the, disability, team, will, identify, whethe...
# 145  [the, process, will, then, proceed, a, from, a...
# 146  [occupational, health, are, responsible, for, ...
# 147  [this, requires, them, to, meet, the, relevant...
# 148  [adjustments, which, may, be, reasonable, in, ...
# 149  [wherever, possible, the, fitness, to, practic...
# 150  [the, occupational, health, team, in, liaison,...
# 151  [assistance, animal, s, the, universitys, heal...
# 152  [for, this, purpose, therefore, only, assist, ...
# 153  [if, a, request, is, made, through, the, disab...
# 154  [the, owner, of, the, assistance, animal, will...
# 155  [the, s, tudent, owner, of, the, animal, will,...
# 156  [complaints, in, the, first, instance, concern...
# 157  [if, a, student, having, first, referred, the,...
# 158  [this, can, be, accessed, using, the, followin...
# 159   [links, are, provided, to, these, policy, below]
# 160  [please, note, policy, are, updated, on, a, re...
# 161  [special, examination, provision, appendix, of...
# 162  [the, role, descriptor, is, intended, to, give...
# 163  [it, is, expected, that, faculties, department...
# 164  [the, average, should, be, hour, per, academic...
# 165  [a, faculty, department, or, school, should, a...
# 166  [the, disability, coordinator, will, act, a, a...
# 167  [act, a, a, liaison, point, between, the, scho...
# 168  [ensure, that, the, disclosure, of, disability...
# 169  [liaise, with, relevant, colleague, within, th...
# 170  [raise, awareness, within, the, schooldepartme...
# 171  [work, with, standard, procedure, acros, s, th...
# 172  [assist, the, directorhead, of, schooldepart, ...
# 173  [coordinate, and, support, schooldepartment, b...
# 174  [contribute, to, and, update, disability, supp...
# 175  [regularly, attend, meeting, of, the, universi...
# 176  [provide, support, and, advice, on, disability...
# 177                                                 []
# 178  [appendix, additional, examination, provision,...
# 179  [this, policy, document, outline, the, provisi...
# 180  [provision, available, all, provision, will, b...
# 181  [amanuensis, this, facility, will, be, offered...
# 182  [it, may, be, that, the, learning, outcome, ca...
# 183  [eligibility, for, additional, examination, pr...
# 184  [eligibility, for, aep, will, be, documented, ...
# 185          [no, other, evidence, will, be, accepted]
# 186  [in, the, event, of, a, temporary, or, newly, ...
# 187  [please, note, application, received, after, t...
# 188  [please, note, at, the, end, of, each, assessm...
# 189  [this, may, result, in, the, provision, being,...
# 190  [process, the, aep, application, form, will, b...
# 191  [the, form, should, be, completed, and, submit...
# 192  [the, completed, form, will, be, sent, to, the...
# 193  [applications, for, aep, should, be, made, a, ...
# 194  [an, applicat, ion, for, aep, will, remain, in...
# 195  [however, should, aep, be, in, place, but, not...
# 196  [nb, flexibility, will, be, needed, with, extr...
# 197  [faculty, examinations, staff, will, review, u...
# 198  [if, at, review, a, student, state, that, they...
# 199  [the, provision, can, be, cancelled, and, a, c...
# 200  [if, at, r, eview, a, student, state, that, th...
# 201  [if, at, the, end, of, the, second, period, pr...
# 202  [faculty, staff, should, send, written, confir...
# 203  [faculty, administration, staff, will, contact...
# 204  [appendix, ljmu, spe, cific, learning, difficu...
# 205  [ljmu, will, ensure, that, anticipatory, adjus...
# 206  [provision, for, those, student, with, moderat...
# 207  [ljmu, complies, with, the, equality, act, the...
# 208  [the, inclusion, of, the, anticipatory, duty, ...
# 209  [this, policy, is, part, of, the, wider, insti...
# 210  [in, the, event, of, student, not, having, rec...
# 211  [provision, of, support, eligibility, for, for...
# 212  [studying, on, a, programme, with, a, duration...
# 213  [translations, of, assessment, report, will, b...
# 214  [student, attending, a, course, with, a, colla...
# 215  [internal, screening, exer, cise, result, in, ...
# 216  [students, are, expected, to, meet, the, eligi...
# 217  [students, will, be, responsible, for, of, the...
# 218  [ljmu, will, meet, the, remaining, cost, of, e...
# 219  [students, will, be, reminded, of, appointment...
# 220  [students, who, fail, to, attend, their, asses...
# 221  [a, budget, will, be, established, to, ensure,...
# 222  [irlen, syndromescotopic, sensitivity, funding...
# 223  [coloured, overlay, can, be, purchased, to, as...
# 224                                                 []

# %%
# Doing so helped me notice that there are a bunch of empty lists, so we will remove those now
# find rows with empty lists in the 'Sentence' column
rows_with_empty_lists = p1[p1['Sentence'].apply(len) == 0]

# display rows with empty lists
print(rows_with_empty_lists)
# Out:
#     Sentence
# 177       []
# 224       []

# %%
# remove rows with empty lists in the 'Sentence' column
p1 = p1[p1['Sentence'].apply(len) > 0]

# reset index
p1.reset_index(drop=True, inplace=True)

# display the modified DataFrame
print(p1)
# Out:
#                                               Sentence
# 0    [disability, policy, students, provision, of, ...
# 1    [date, introduced, january, dates, modified, f...
# 2    [a, wide, range, of, provision, is, available,...
# 3    [this, policy, set, out, how, ljmu, meet, it, ...
# 4    [it, identifies, the, universitys, approach, t...
# 5    [the, policy, is, supported, by, the, procedur...
# 6    [duty, to, make, reasonable, a, djustments, as...
# 7    [the, duty, to, make, reasonable, adjustment, ...
# 8    [in, particular, there, is, a, requirement, on...
# 9    [this, provision, applies, to, delivery, of, l...
# 10   [the, intention, is, that, the, learning, envi...
# 11   [institutional, responsibility, ljmu, wish, to...
# 12   [are, able, to, access, the, estate, and, buil...
# 13   [have, access, to, specialist, staff, who, are...
# 14   [have, documented, support, plan, in, place, i...
# 15           [can, access, it, facility, and, service]
# 16   [are, able, to, access, learning, material, in...
# 17   [are, able, to, access, additional, support, w...
# 18   [have, access, to, quiet, or, le, formal, envi...
# 19   [non, medical, help, is, defined, a, the, prov...
# 20   [these, were, previously, identified, a, band,...
# 21   [scope, this, policy, address, all, aspect, of...
# 22   [this, policy, applies, to, all, student, stud...
# 23   [however, student, on, s, hort, professional, ...
# 24   [the, principle, of, this, policy, apply, to, ...
# 25   [students, who, disclosed, or, declared, a, di...
# 26   [responsibilities, this, section, outline, the...
# 27   [it, doe, not, contain, operational, detail, o...
# 28   [further, information, about, relevant, proced...
# 29   [elt, are, responsible, for, the, universitys,...
# 30   [equality, diversity, and, inclusivity, commit...
# 31   [director, of, student, advice, and, wellbeing...
# 32   [she, is, also, responsible, for, ensuring, th...
# 33   [the, student, support, m, anager, is, respons...
# 34   [once, student, have, declared, a, disability,...
# 35   [the, disability, team, are, responsible, for,...
# 36   [the, disability, team, will, store, the, mast...
# 37   [the, disability, team, also, cover, specialis...
# 38   [directors, of, schoolheads, of, department, a...
# 39   [they, are, also, responsible, for, ensuring, ...
# 40   [directorsheads, have, a, responsibility, to, ...
# 41   [directorsheads, are, also, responsible, for, ...
# 42   [disability, coordinators, disco, are, school,...
# 43   [see, appendix, for, the, disability, coordina...
# 44   [module, leaders, have, a, responsibility, to,...
# 45   [this, information, is, available, from, t, he...
# 46   [personal, tutor, have, a, responsibility, to,...
# 47   [all, programme, staff, are, responsible, for,...
# 48   [the, islp, will, be, created, a, per, section...
# 49   [the, directo, r, of, library, service, is, re...
# 50   [the, director, of, student, advancement, is, ...
# 51   [she, is, also, responsible, for, ensuring, th...
# 52   [the, director, of, it, services, is, responsi...
# 53   [she, is, also, responsible, for, ensuring, th...
# 54   [the, director, s, of, estates, and, facilitie...
# 55   [she, is, also, responsible, for, ensuring, th...
# 56   [the, accommodation, manager, is, responsible,...
# 57   [this, is, a, sha, red, responsibility, with, ...
# 58   [the, head, of, operations, in, each, faculty,...
# 59   [the, head, of, operations, would, also, be, r...
# 60   [the, head, of, academic, quality, service, is...
# 61   [the, dean, of, the, learning, and, teaching, ...
# 62   [there, is, al, so, a, responsibility, here, t...
# 63   [the, director, of, corporate, communications,...
# 64   [the, director, of, student, recruitment, and,...
# 65   [preentry, disclosure, process, will, be, appl...
# 66   [the, director, of, international, relations, ...
# 67   [she, is, responsible, for, working, with, the...
# 68   [the, academic, registrar, is, responsible, fo...
# 69   [the, director, of, human, resources, through,...
# 70   [the, counselling, manager, and, mental, wellb...
# 71   [the, occupational, health, team, is, responsi...
# 72   [in, addition, the, occupational, health, team...
# 73   [the, programme, leader, will, liaise, through...
# 74   [heads, of, all, other, department, are, respo...
# 75   [the, manager, of, health, safety, and, enviro...
# 76   [she, is, responsible, for, training, evacuati...
# 77   [all, student, and, applicant, have, a, respon...
# 78   [objectives, the, university, observes, the, s...
# 79   [barriers, can, be, in, the, physical, environ...
# 80   [the, university, aim, to, address, all, of, t...
# 81   [the, university, recognises, it, responsibili...
# 82   [the, university, aim, to, identify, the, most...
# 83   [where, this, is, not, possible, andor, additi...
# 84   [reasonable, adjustment, individual, and, anti...
# 85   [competence, standard, are, academic, medical,...
# 86   [competence, standard, must, be, directly, rel...
# 87   [there, is, therefore, no, requirement, to, al...
# 88   [however, it, may, be, necessary, to, adjust, ...
# 89   [the, university, ha, specialist, targeted, pr...
# 90   [the, disability, team, is, the, key, speciali...
# 91   [specialists, within, this, team, understand, ...
# 92   [on, some, occasion, this, provision, will, al...
# 93   [disability, coordinators, discos, in, faculty...
# 94   [discos, have, discipline, specific, knowledge...
# 95   [discos, are, also, a, local, point, of, conta...
# 96   [all, student, have, access, to, a, personal, ...
# 97   [disclosing, a, disability, to, the, universit...
# 98   [all, applicant, to, the, university, will, be...
# 99   [all, student, on, regulated, vocational, prog...
# 100  [this, will, include, a, requirement, to, noti...
# 101  [this, will, result, in, an, assessment, by, t...
# 102  [students, and, applicant, will, need, to, pro...
# 103  [the, disability, team, will, contact, all, st...
# 104  [students, will, be, given, a, further, opport...
# 105  [all, student, on, regulated, vo, cational, pr...
# 106  [this, may, result, in, confirmation, th, at, ...
# 107  [if, during, their, period, of, study, a, stud...
# 108  [if, at, any, time, any, member, of, staff, be...
# 109  [students, who, wish, to, discus, access, to, ...
# 110  [students, who, wish, to, access, reasonable, ...
# 111  [further, guidance, on, evidence, can, be, obt...
# 112  [students, with, specific, learning, difficult...
# 113  [guidance, on, the, identification, and, imple...
# 114  [information, on, these, inclusive, practice, ...
# 115  [inclusive, anticipatory, approach, will, be, ...
# 116  [whilst, inclusive, approach, and, anticipator...
# 117  [the, disability, team, is, responsible, for, ...
# 118  [programme, team, will, be, responsible, for, ...
# 119  [if, a, student, ha, an, independent, assessme...
# 120  [the, disability, team, will, firstly, conside...
# 121  [the, disability, team, in, consultation, with...
# 122  [factors, may, include, but, not, be, limited,...
# 123  [the, university, is, not, obliged, to, offer,...
# 124  [for, information, regarding, the, complaint, ...
# 125  [for, student, who, are, able, to, ac, ce, ext...
# 126  [the, disability, team, will, provide, guidanc...
# 127  [where, external, financial, source, are, not,...
# 128  [annually, the, director, of, student, advice,...
# 129  [in, the, majority, of, case, this, will, ensu...
# 130  [where, the, upper, limit, is, breeched, the, ...
# 131  [if, the, director, of, student, advice, and, ...
# 132  [with, the, student, consent, the, disability,...
# 133  [the, disability, team, will, then, forward, t...
# 134  [without, consent, the, disability, team, will...
# 135  [a, copy, of, the, islp, will, be, sent, to, t...
# 136  [programme, leader, will, be, responsible, for...
# 137  [the, disability, team, are, responsible, when...
# 138  [if, a, student, doe, not, think, that, the, r...
# 139  [if, the, situation, is, not, resolved, throug...
# 140  [if, the, student, remains, dissatisfied, then...
# 141  [the, impact, andor, nature, of, a, student, d...
# 142  [this, may, result, in, the, anticipatory, sup...
# 143  [in, such, case, the, student, should, contact...
# 144  [the, disability, team, will, identify, whethe...
# 145  [the, process, will, then, proceed, a, from, a...
# 146  [occupational, health, are, responsible, for, ...
# 147  [this, requires, them, to, meet, the, relevant...
# 148  [adjustments, which, may, be, reasonable, in, ...
# 149  [wherever, possible, the, fitness, to, practic...
# 150  [the, occupational, health, team, in, liaison,...
# 151  [assistance, animal, s, the, universitys, heal...
# 152  [for, this, purpose, therefore, only, assist, ...
# 153  [if, a, request, is, made, through, the, disab...
# 154  [the, owner, of, the, assistance, animal, will...
# 155  [the, s, tudent, owner, of, the, animal, will,...
# 156  [complaints, in, the, first, instance, concern...
# 157  [if, a, student, having, first, referred, the,...
# 158  [this, can, be, accessed, using, the, followin...
# 159   [links, are, provided, to, these, policy, below]
# 160  [please, note, policy, are, updated, on, a, re...
# 161  [special, examination, provision, appendix, of...
# 162  [the, role, descriptor, is, intended, to, give...
# 163  [it, is, expected, that, faculties, department...
# 164  [the, average, should, be, hour, per, academic...
# 165  [a, faculty, department, or, school, should, a...
# 166  [the, disability, coordinator, will, act, a, a...
# 167  [act, a, a, liaison, point, between, the, scho...
# 168  [ensure, that, the, disclosure, of, disability...
# 169  [liaise, with, relevant, colleague, within, th...
# 170  [raise, awareness, within, the, schooldepartme...
# 171  [work, with, standard, procedure, acros, s, th...
# 172  [assist, the, directorhead, of, schooldepart, ...
# 173  [coordinate, and, support, schooldepartment, b...
# 174  [contribute, to, and, update, disability, supp...
# 175  [regularly, attend, meeting, of, the, universi...
# 176  [provide, support, and, advice, on, disability...
# 177  [appendix, additional, examination, provision,...
# 178  [this, policy, document, outline, the, provisi...
# 179  [provision, available, all, provision, will, b...
# 180  [amanuensis, this, facility, will, be, offered...
# 181  [it, may, be, that, the, learning, outcome, ca...
# 182  [eligibility, for, additional, examination, pr...
# 183  [eligibility, for, aep, will, be, documented, ...
# 184          [no, other, evidence, will, be, accepted]
# 185  [in, the, event, of, a, temporary, or, newly, ...
# 186  [please, note, application, received, after, t...
# 187  [please, note, at, the, end, of, each, assessm...
# 188  [this, may, result, in, the, provision, being,...
# 189  [process, the, aep, application, form, will, b...
# 190  [the, form, should, be, completed, and, submit...
# 191  [the, completed, form, will, be, sent, to, the...
# 192  [applications, for, aep, should, be, made, a, ...
# 193  [an, applicat, ion, for, aep, will, remain, in...
# 194  [however, should, aep, be, in, place, but, not...
# 195  [nb, flexibility, will, be, needed, with, extr...
# 196  [faculty, examinations, staff, will, review, u...
# 197  [if, at, review, a, student, state, that, they...
# 198  [the, provision, can, be, cancelled, and, a, c...
# 199  [if, at, r, eview, a, student, state, that, th...
# 200  [if, at, the, end, of, the, second, period, pr...
# 201  [faculty, staff, should, send, written, confir...
# 202  [faculty, administration, staff, will, contact...
# 203  [appendix, ljmu, spe, cific, learning, difficu...
# 204  [ljmu, will, ensure, that, anticipatory, adjus...
# 205  [provision, for, those, student, with, moderat...
# 206  [ljmu, complies, with, the, equality, act, the...
# 207  [the, inclusion, of, the, anticipatory, duty, ...
# 208  [this, policy, is, part, of, the, wider, insti...
# 209  [in, the, event, of, student, not, having, rec...
# 210  [provision, of, support, eligibility, for, for...
# 211  [studying, on, a, programme, with, a, duration...
# 212  [translations, of, assessment, report, will, b...
# 213  [student, attending, a, course, with, a, colla...
# 214  [internal, screening, exer, cise, result, in, ...
# 215  [students, are, expected, to, meet, the, eligi...
# 216  [students, will, be, responsible, for, of, the...
# 217  [ljmu, will, meet, the, remaining, cost, of, e...
# 218  [students, will, be, reminded, of, appointment...
# 219  [students, who, fail, to, attend, their, asses...
# 220  [a, budget, will, be, established, to, ensure,...
# 221  [irlen, syndromescotopic, sensitivity, funding...
# 222  [coloured, overlay, can, be, purchased, to, as...

# %%
# just to check it is still all good in this format too (can't be too careful)
p1
# Out:
#                                               Sentence
# 0    [disability, policy, students, provision, of, ...
# 1    [date, introduced, january, dates, modified, f...
# 2    [a, wide, range, of, provision, is, available,...
# 3    [this, policy, set, out, how, ljmu, meet, it, ...
# 4    [it, identifies, the, universitys, approach, t...
# 5    [the, policy, is, supported, by, the, procedur...
# 6    [duty, to, make, reasonable, a, djustments, as...
# 7    [the, duty, to, make, reasonable, adjustment, ...
# 8    [in, particular, there, is, a, requirement, on...
# 9    [this, provision, applies, to, delivery, of, l...
# 10   [the, intention, is, that, the, learning, envi...
# 11   [institutional, responsibility, ljmu, wish, to...
# 12   [are, able, to, access, the, estate, and, buil...
# 13   [have, access, to, specialist, staff, who, are...
# 14   [have, documented, support, plan, in, place, i...
# 15           [can, access, it, facility, and, service]
# 16   [are, able, to, access, learning, material, in...
# 17   [are, able, to, access, additional, support, w...
# 18   [have, access, to, quiet, or, le, formal, envi...
# 19   [non, medical, help, is, defined, a, the, prov...
# 20   [these, were, previously, identified, a, band,...
# 21   [scope, this, policy, address, all, aspect, of...
# 22   [this, policy, applies, to, all, student, stud...
# 23   [however, student, on, s, hort, professional, ...
# 24   [the, principle, of, this, policy, apply, to, ...
# 25   [students, who, disclosed, or, declared, a, di...
# 26   [responsibilities, this, section, outline, the...
# 27   [it, doe, not, contain, operational, detail, o...
# 28   [further, information, about, relevant, proced...
# 29   [elt, are, responsible, for, the, universitys,...
# 30   [equality, diversity, and, inclusivity, commit...
# 31   [director, of, student, advice, and, wellbeing...
# 32   [she, is, also, responsible, for, ensuring, th...
# 33   [the, student, support, m, anager, is, respons...
# 34   [once, student, have, declared, a, disability,...
# 35   [the, disability, team, are, responsible, for,...
# 36   [the, disability, team, will, store, the, mast...
# 37   [the, disability, team, also, cover, specialis...
# 38   [directors, of, schoolheads, of, department, a...
# 39   [they, are, also, responsible, for, ensuring, ...
# 40   [directorsheads, have, a, responsibility, to, ...
# 41   [directorsheads, are, also, responsible, for, ...
# 42   [disability, coordinators, disco, are, school,...
# 43   [see, appendix, for, the, disability, coordina...
# 44   [module, leaders, have, a, responsibility, to,...
# 45   [this, information, is, available, from, t, he...
# 46   [personal, tutor, have, a, responsibility, to,...
# 47   [all, programme, staff, are, responsible, for,...
# 48   [the, islp, will, be, created, a, per, section...
# 49   [the, directo, r, of, library, service, is, re...
# 50   [the, director, of, student, advancement, is, ...
# 51   [she, is, also, responsible, for, ensuring, th...
# 52   [the, director, of, it, services, is, responsi...
# 53   [she, is, also, responsible, for, ensuring, th...
# 54   [the, director, s, of, estates, and, facilitie...
# 55   [she, is, also, responsible, for, ensuring, th...
# 56   [the, accommodation, manager, is, responsible,...
# 57   [this, is, a, sha, red, responsibility, with, ...
# 58   [the, head, of, operations, in, each, faculty,...
# 59   [the, head, of, operations, would, also, be, r...
# 60   [the, head, of, academic, quality, service, is...
# 61   [the, dean, of, the, learning, and, teaching, ...
# 62   [there, is, al, so, a, responsibility, here, t...
# 63   [the, director, of, corporate, communications,...
# 64   [the, director, of, student, recruitment, and,...
# 65   [preentry, disclosure, process, will, be, appl...
# 66   [the, director, of, international, relations, ...
# 67   [she, is, responsible, for, working, with, the...
# 68   [the, academic, registrar, is, responsible, fo...
# 69   [the, director, of, human, resources, through,...
# 70   [the, counselling, manager, and, mental, wellb...
# 71   [the, occupational, health, team, is, responsi...
# 72   [in, addition, the, occupational, health, team...
# 73   [the, programme, leader, will, liaise, through...
# 74   [heads, of, all, other, department, are, respo...
# 75   [the, manager, of, health, safety, and, enviro...
# 76   [she, is, responsible, for, training, evacuati...
# 77   [all, student, and, applicant, have, a, respon...
# 78   [objectives, the, university, observes, the, s...
# 79   [barriers, can, be, in, the, physical, environ...
# 80   [the, university, aim, to, address, all, of, t...
# 81   [the, university, recognises, it, responsibili...
# 82   [the, university, aim, to, identify, the, most...
# 83   [where, this, is, not, possible, andor, additi...
# 84   [reasonable, adjustment, individual, and, anti...
# 85   [competence, standard, are, academic, medical,...
# 86   [competence, standard, must, be, directly, rel...
# 87   [there, is, therefore, no, requirement, to, al...
# 88   [however, it, may, be, necessary, to, adjust, ...
# 89   [the, university, ha, specialist, targeted, pr...
# 90   [the, disability, team, is, the, key, speciali...
# 91   [specialists, within, this, team, understand, ...
# 92   [on, some, occasion, this, provision, will, al...
# 93   [disability, coordinators, discos, in, faculty...
# 94   [discos, have, discipline, specific, knowledge...
# 95   [discos, are, also, a, local, point, of, conta...
# 96   [all, student, have, access, to, a, personal, ...
# 97   [disclosing, a, disability, to, the, universit...
# 98   [all, applicant, to, the, university, will, be...
# 99   [all, student, on, regulated, vocational, prog...
# 100  [this, will, include, a, requirement, to, noti...
# 101  [this, will, result, in, an, assessment, by, t...
# 102  [students, and, applicant, will, need, to, pro...
# 103  [the, disability, team, will, contact, all, st...
# 104  [students, will, be, given, a, further, opport...
# 105  [all, student, on, regulated, vo, cational, pr...
# 106  [this, may, result, in, confirmation, th, at, ...
# 107  [if, during, their, period, of, study, a, stud...
# 108  [if, at, any, time, any, member, of, staff, be...
# 109  [students, who, wish, to, discus, access, to, ...
# 110  [students, who, wish, to, access, reasonable, ...
# 111  [further, guidance, on, evidence, can, be, obt...
# 112  [students, with, specific, learning, difficult...
# 113  [guidance, on, the, identification, and, imple...
# 114  [information, on, these, inclusive, practice, ...
# 115  [inclusive, anticipatory, approach, will, be, ...
# 116  [whilst, inclusive, approach, and, anticipator...
# 117  [the, disability, team, is, responsible, for, ...
# 118  [programme, team, will, be, responsible, for, ...
# 119  [if, a, student, ha, an, independent, assessme...
# 120  [the, disability, team, will, firstly, conside...
# 121  [the, disability, team, in, consultation, with...
# 122  [factors, may, include, but, not, be, limited,...
# 123  [the, university, is, not, obliged, to, offer,...
# 124  [for, information, regarding, the, complaint, ...
# 125  [for, student, who, are, able, to, ac, ce, ext...
# 126  [the, disability, team, will, provide, guidanc...
# 127  [where, external, financial, source, are, not,...
# 128  [annually, the, director, of, student, advice,...
# 129  [in, the, majority, of, case, this, will, ensu...
# 130  [where, the, upper, limit, is, breeched, the, ...
# 131  [if, the, director, of, student, advice, and, ...
# 132  [with, the, student, consent, the, disability,...
# 133  [the, disability, team, will, then, forward, t...
# 134  [without, consent, the, disability, team, will...
# 135  [a, copy, of, the, islp, will, be, sent, to, t...
# 136  [programme, leader, will, be, responsible, for...
# 137  [the, disability, team, are, responsible, when...
# 138  [if, a, student, doe, not, think, that, the, r...
# 139  [if, the, situation, is, not, resolved, throug...
# 140  [if, the, student, remains, dissatisfied, then...
# 141  [the, impact, andor, nature, of, a, student, d...
# 142  [this, may, result, in, the, anticipatory, sup...
# 143  [in, such, case, the, student, should, contact...
# 144  [the, disability, team, will, identify, whethe...
# 145  [the, process, will, then, proceed, a, from, a...
# 146  [occupational, health, are, responsible, for, ...
# 147  [this, requires, them, to, meet, the, relevant...
# 148  [adjustments, which, may, be, reasonable, in, ...
# 149  [wherever, possible, the, fitness, to, practic...
# 150  [the, occupational, health, team, in, liaison,...
# 151  [assistance, animal, s, the, universitys, heal...
# 152  [for, this, purpose, therefore, only, assist, ...
# 153  [if, a, request, is, made, through, the, disab...
# 154  [the, owner, of, the, assistance, animal, will...
# 155  [the, s, tudent, owner, of, the, animal, will,...
# 156  [complaints, in, the, first, instance, concern...
# 157  [if, a, student, having, first, referred, the,...
# 158  [this, can, be, accessed, using, the, followin...
# 159   [links, are, provided, to, these, policy, below]
# 160  [please, note, policy, are, updated, on, a, re...
# 161  [special, examination, provision, appendix, of...
# 162  [the, role, descriptor, is, intended, to, give...
# 163  [it, is, expected, that, faculties, department...
# 164  [the, average, should, be, hour, per, academic...
# 165  [a, faculty, department, or, school, should, a...
# 166  [the, disability, coordinator, will, act, a, a...
# 167  [act, a, a, liaison, point, between, the, scho...
# 168  [ensure, that, the, disclosure, of, disability...
# 169  [liaise, with, relevant, colleague, within, th...
# 170  [raise, awareness, within, the, schooldepartme...
# 171  [work, with, standard, procedure, acros, s, th...
# 172  [assist, the, directorhead, of, schooldepart, ...
# 173  [coordinate, and, support, schooldepartment, b...
# 174  [contribute, to, and, update, disability, supp...
# 175  [regularly, attend, meeting, of, the, universi...
# 176  [provide, support, and, advice, on, disability...
# 177  [appendix, additional, examination, provision,...
# 178  [this, policy, document, outline, the, provisi...
# 179  [provision, available, all, provision, will, b...
# 180  [amanuensis, this, facility, will, be, offered...
# 181  [it, may, be, that, the, learning, outcome, ca...
# 182  [eligibility, for, additional, examination, pr...
# 183  [eligibility, for, aep, will, be, documented, ...
# 184          [no, other, evidence, will, be, accepted]
# 185  [in, the, event, of, a, temporary, or, newly, ...
# 186  [please, note, application, received, after, t...
# 187  [please, note, at, the, end, of, each, assessm...
# 188  [this, may, result, in, the, provision, being,...
# 189  [process, the, aep, application, form, will, b...
# 190  [the, form, should, be, completed, and, submit...
# 191  [the, completed, form, will, be, sent, to, the...
# 192  [applications, for, aep, should, be, made, a, ...
# 193  [an, applicat, ion, for, aep, will, remain, in...
# 194  [however, should, aep, be, in, place, but, not...
# 195  [nb, flexibility, will, be, needed, with, extr...
# 196  [faculty, examinations, staff, will, review, u...
# 197  [if, at, review, a, student, state, that, they...
# 198  [the, provision, can, be, cancelled, and, a, c...
# 199  [if, at, r, eview, a, student, state, that, th...
# 200  [if, at, the, end, of, the, second, period, pr...
# 201  [faculty, staff, should, send, written, confir...
# 202  [faculty, administration, staff, will, contact...
# 203  [appendix, ljmu, spe, cific, learning, difficu...
# 204  [ljmu, will, ensure, that, anticipatory, adjus...
# 205  [provision, for, those, student, with, moderat...
# 206  [ljmu, complies, with, the, equality, act, the...
# 207  [the, inclusion, of, the, anticipatory, duty, ...
# 208  [this, policy, is, part, of, the, wider, insti...
# 209  [in, the, event, of, student, not, having, rec...
# 210  [provision, of, support, eligibility, for, for...
# 211  [studying, on, a, programme, with, a, duration...
# 212  [translations, of, assessment, report, will, b...
# 213  [student, attending, a, course, with, a, colla...
# 214  [internal, screening, exer, cise, result, in, ...
# 215  [students, are, expected, to, meet, the, eligi...
# 216  [students, will, be, responsible, for, of, the...
# 217  [ljmu, will, meet, the, remaining, cost, of, e...
# 218  [students, will, be, reminded, of, appointment...
# 219  [students, who, fail, to, attend, their, asses...
# 220  [a, budget, will, be, established, to, ensure,...
# 221  [irlen, syndromescotopic, sensitivity, funding...
# 222  [coloured, overlay, can, be, purchased, to, as...

# %%
# save the dataset to be able to use in analysis

#export to excel file
p1.to_excel('p3.xlsx')

#export to csv file
p1.to_csv('p3.csv', index=False)
