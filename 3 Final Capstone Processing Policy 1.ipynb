# %%
#import all the necessary packages

import pandas as pd
import random

import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk import stem
stemmer = stem.PorterStemmer()
from nltk import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))
import string
punct = list(string.punctuation)
from collections import Counter
import requests
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import numpy as np
import praw
import datetime
import json
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import PyPDF2

# %%
# open the PDF file
policy = open(r'C:\Users\aoife\Documents\Capstone\Capstone Quant Policies\Bristol Disability.pdf', 'rb')

# create a PDF reader object
pdf_reader = PyPDF2.PdfReader(policy)

# %%
# read the text from each page
text = ''
for page_num in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[page_num]
    text += page.extract_text()

# close the PDF file
policy.close()

# %%
# split the text into sentences
sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)

# create a dataframe with the sentences as rows
df = pd.DataFrame({'Sentence': sentences})

# %%
df
# Out:
#                                              Sentence
# 0     \n  \n  \n Version 1.0  14 August 2020  Page...
# 1   Introduction  \nThe University of Bristol is c...
# 2   As a provider of \neducation, we value the div...
# 3    We aim to create an environment where disable...
# 4                                            \n  \n2.
# 5   Legal context  \nFor the purpose of this polic...
# 6                                                \n3.
# 7   The Reasonab le Adjustment Duty  \nThe Equalit...
# 8    This duty is also anticipatory, meaning \ntha...
# 9      Further details \nabout reasonable adjustme...
# 10    \n \n The term provision, criterion or pract...
# 11   In determining what is reasonable, the Univer...
# 12   Consideration will be given to adjusting the ...
# 13     \n  \nIn determining what is reasonable in ...
# 14     \n  \n  \n  \n  \n Version 1.0  14 August 2...
# 15  Disability Disclosure  \nStudents who disclose...
# 16   A  \nDisability Support Summary  (DSS) may  b...
# 17   It is expected that staff will engage fully w...
# 18     \n  \nStudents can disclose a disability  a...
# 19   The reasonable \nadjustment duty applies to t...
# 20    \n  \nA disabled student has a right to requ...
# 21  In such cases, the recommended support can be ...
# 22   In some instances,  \nthis will limit the Uni...
# 23                                         \n    \n5.
# 24  Responsibilities  \nThe University Board of Tr...
# 25   As such, all University staff are expected to...
# 26     \n  \nThe success of the support that both ...
# 27   The general expectation is that the student w...
# 28   \n       \n  \n  \n Version 1.0  14 August 20...
# 29   \nScope - This document applies to:  \nAll st...
# 30   \n  \nFor applicants \nentering in:  2020/21 ...
# 31  Disability Services Manager  \nType  Policy  S...

# %%
#check to see if any rows are empty
rows_with_nan = df[df.isna().any(axis=1)]

len(rows_with_nan)
# Out:
# 0

# %%
#check the length of the dataframe
len(df)
# Out:
# 32

# %%
# convert each row in the dataframe to a string and then convert the datadrame to a list of strings
p1 = df.apply(lambda row: ' '.join(row.astype(str)), axis=1).tolist()

# %%
p1
# Out:
# ['  \n  \n  \n Version 1.0  14 August 2020  Page 1 of 5  Year of Entry: 2020 - 2021   \nUniversity Policy on Supporting Disabled Students  \n1.',
#  'Introduction  \nThe University of Bristol is committed to creating and sustaining an excellent teaching and learning \nexperience for our students, offering a high- quality, research- led education that encourages \nindependence of mind, where students are encouraged to thrive academically.',
#  'As a provider of \neducation, we value the diversity of our students and remain committed to sustaining a fair, equitable \nand mutually supportive learning environment.',
#  ' We aim to create an environment where disabled \nstudents are supported to ac hieve their full potential, to contribute fully, and to derive maximum \nbenefit and enjoyment from their involvement in the life of the University.',
#  ' \n  \n2.',
#  "Legal context  \nFor the purpose of this policy the following definition of a disability will apply as set out in the Equality \nAct 2010:   \n'A person has a disability if they have a physical or mental impairment, and the impairment \nhas a substantial and long- term adverse effect on their ability to carry out normal day -to-day \nactivities .'  \nThe definition of disability  is wid er than is commonly understood and may include conditions many \nmight not consider a disability , including students with  dyslexia, dyspraxia, attention deficit \nconditions, mental health conditions, autism and other long- term health conditions.",
#  '  \n3.',
#  'The Reasonab le Adjustment Duty  \nThe Equality Act  places the University under a duty to make reasonable adjustments to support \nindividual disabled students in realising their full potential and to ensure that they are not disadvantaged in comparison with non- disabled students.',
#  ' This duty is also anticipatory, meaning \nthat the University is required to consider and take action in relation to barriers that impede disabled people generally prior to an i ndividual disabled person seeking to become a student.',
#  '   Further details \nabout reasonable adjustments  whilst at University are \nhere.',
#  '  \n \n The term provision, criterion or practice covers all aspects of the student experience, access to \neducation, other benefits, facilities and services, as well as all University policies, procedures and \nregulations.',
#  ' In determining what is reasonable, the University will not compromise \nacademic/competence standards\n1 and the expectation is that disabled students will achieve the \nsame learning outc omes as non- disabled students.',
#  ' Consideration will be given to adjusting the way \nin which a competence standard is assessed unless the passing of the assessment is conditional \nupon having a practical skill or ability which must be demonstrated by completin g a practical \ncomponent or demonstrating fitness to practise.',
#  '   \n  \nIn determining what is reasonable in each individual case, the University may consider factors \nincluding but not limited to:  \n \n1 A competence standard is defined as ‘ an academic, medical, or other standard applied by or on behalf of an education provider for \nthe purpose of determining whether or not a person has a particular level of  competence or ability ’.',
#  '   \n  \n  \n  \n  \n Version 1.0  14 August 2020  Page 2 of 5  Year of Entry: 2020 - 2021 • whether taking any particular steps would be effective in overc oming the substantial \ndisadvantage that disabled people face in accessing the education or other benefit, facility \nor service in question  \n• the extent to which it is practicable to take such steps  \n• the type of education or other benefit, facility or service being provided  \n• the effect of the disability on the individual  \n• the financial and other costs of making the adjustment  \n• the availability of grants, loans and other assistance to disabled students  \n• the extent to which aids and services will otherwise be provided to disabled people or students   \n• the resources of the education provider and the availability of financial or other assistance  \n• health and safety requirements (the Act does not override health and safety requirements)  \n• the relevant interests of other people, including other students  \n  \n4.',
#  'Disability Disclosure  \nStudents who disclose a disability should be encouraged to c ontact  Disability Services\n where further \ndiscussion can take place with a Disability Advisor on issues connected to support and to explore funding that may be available to cover the cos ts of reasonable adjustments where appropriate.',
#  ' A  \nDisability Support Summary  (DSS) may  be produced to assist staff in determining what adjustments \nshould be considered and to assist the University in meeting the requirements of their  reasonable \nadjustment duty.',
#  ' It is expected that staff will engage fully with this process and familiarise themselves with any associated University guidance.',
#  '   \n  \nStudents can disclose a disability  at any point during the course of their studies.',
#  ' The reasonable \nadjustment duty applies to the individual student from this point of disclosure.',
#  '  \n  \nA disabled student has a right to request that the existence or nature of their disability be treated as \nconfidential .',
#  'In such cases, the recommended support can be shared (as agreed with the student in \nterms of what is shared) but the nature of the disability must remain confidential.',
#  ' In some instances,  \nthis will limit the University’s ability to implement satisfactory adjustments or result in no adjustments being provided.',
#  ' \n    \n5.',
#  'Responsibilities  \nThe University Board of Trustees is legally responsible for ensuring that the University properly \ndischarges its duties under the Equality Act.',
#  ' As such, all University staff are expected to operate \nwithin the parameters of this policy and any associated guidance.',
#  '   \n  \nThe success of the support that both the school and Disability Services are able to provide relies \non the student’s willingness to engage with it.',
#  ' The general expectation is that the student will assume an element of personal responsibility and work in partnership with their School and Faculty to ensure that any adjustments make a positive contribution to their ability to engage with their studies and to complete their programme successfully.',
#  ' \n       \n  \n  \n Version 1.0  14 August 2020  Page 3 of 5  Year of Entry: 2020 - 2021 University Policy on Supporting Disabled \nStudents  \nDocument control     \nSummary  \nThis policy defines how the University manages disability disclosure and reasonable \nadjustments to support disabled students.',
#  ' \nScope - This document applies to:  \nAll staff and students, for compliance.',
#  ' \n  \nFor applicants \nentering in:  2020/21   Applies to \nacademic year:  2018/19 onwards  \nDocument Control  \nOwner  Paula Coonerty,  \nExecutive Director for Education & Student Experience & Academic Registrar  \nDivision  Education & Student Experience   \nLead contact  Karen Hocking.',
#  'Disability Services Manager  \nType  Policy  Status  Approved  \nAsset number  EPIR00015  Version  V1.0  \nApproved by    Date current \nversion \napproved    \nDate current \nversion \npublished   Date first \npublished     \nRevision \nschedule  1 year  Next review \ndate  June 2021  \nSuperseded \ndocuments    \nRelated \ndocuments    \nKeywords  Disabled students, disclosure  \n  \n']

# %%
# define a function to remove punctuation and numbers from a string
def remove_punctuation_and_numbers(text):
    # define a regular expression pattern to match punctuation characters and numbers
    pattern = r'[^A-Za-z\s]'
    # replace punctuation characters and numbers with an empty string
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

# apply the previously created function to each string in the list
cleaned_p1 = [remove_punctuation_and_numbers(string) for string in p1]

# display the cleaned list of strings
print(cleaned_p1)
# Out:
# ['  \n  \n  \n Version    August   Page  of   Year of Entry      \nUniversity Policy on Supporting Disabled Students  \n', 'Introduction  \nThe University of Bristol is committed to creating and sustaining an excellent teaching and learning \nexperience for our students offering a high quality research led education that encourages \nindependence of mind where students are encouraged to thrive academically', 'As a provider of \neducation we value the diversity of our students and remain committed to sustaining a fair equitable \nand mutually supportive learning environment', ' We aim to create an environment where disabled \nstudents are supported to ac hieve their full potential to contribute fully and to derive maximum \nbenefit and enjoyment from their involvement in the life of the University', ' \n  \n', 'Legal context  \nFor the purpose of this policy the following definition of a disability will apply as set out in the Equality \nAct    \nA person has a disability if they have a physical or mental impairment and the impairment \nhas a substantial and long term adverse effect on their ability to carry out normal day today \nactivities   \nThe definition of disability  is wid er than is commonly understood and may include conditions many \nmight not consider a disability  including students with  dyslexia dyspraxia attention deficit \nconditions mental health conditions autism and other long term health conditions', '  \n', 'The Reasonab le Adjustment Duty  \nThe Equality Act  places the University under a duty to make reasonable adjustments to support \nindividual disabled students in realising their full potential and to ensure that they are not disadvantaged in comparison with non disabled students', ' This duty is also anticipatory meaning \nthat the University is required to consider and take action in relation to barriers that impede disabled people generally prior to an i ndividual disabled person seeking to become a student', '   Further details \nabout reasonable adjustments  whilst at University are \nhere', '  \n \n The term provision criterion or practice covers all aspects of the student experience access to \neducation other benefits facilities and services as well as all University policies procedures and \nregulations', ' In determining what is reasonable the University will not compromise \nacademiccompetence standards\n and the expectation is that disabled students will achieve the \nsame learning outc omes as non disabled students', ' Consideration will be given to adjusting the way \nin which a competence standard is assessed unless the passing of the assessment is conditional \nupon having a practical skill or ability which must be demonstrated by completin g a practical \ncomponent or demonstrating fitness to practise', '   \n  \nIn determining what is reasonable in each individual case the University may consider factors \nincluding but not limited to  \n \n A competence standard is defined as  an academic medical or other standard applied by or on behalf of an education provider for \nthe purpose of determining whether or not a person has a particular level of  competence or ability ', '   \n  \n  \n  \n  \n Version    August   Page  of   Year of Entry     whether taking any particular steps would be effective in overc oming the substantial \ndisadvantage that disabled people face in accessing the education or other benefit facility \nor service in question  \n the extent to which it is practicable to take such steps  \n the type of education or other benefit facility or service being provided  \n the effect of the disability on the individual  \n the financial and other costs of making the adjustment  \n the availability of grants loans and other assistance to disabled students  \n the extent to which aids and services will otherwise be provided to disabled people or students   \n the resources of the education provider and the availability of financial or other assistance  \n health and safety re ...

# %%
# tokenize each string in the list of strings
tokenized_p1 = [word_tokenize(string) for string in cleaned_p1]

# display the tokenized list of strings
print(tokenized_p1)
# Out:
# [['Version', 'August', 'Page', 'of', 'Year', 'of', 'Entry', 'University', 'Policy', 'on', 'Supporting', 'Disabled', 'Students'], ['Introduction', 'The', 'University', 'of', 'Bristol', 'is', 'committed', 'to', 'creating', 'and', 'sustaining', 'an', 'excellent', 'teaching', 'and', 'learning', 'experience', 'for', 'our', 'students', 'offering', 'a', 'high', 'quality', 'research', 'led', 'education', 'that', 'encourages', 'independence', 'of', 'mind', 'where', 'students', 'are', 'encouraged', 'to', 'thrive', 'academically'], ['As', 'a', 'provider', 'of', 'education', 'we', 'value', 'the', 'diversity', 'of', 'our', 'students', 'and', 'remain', 'committed', 'to', 'sustaining', 'a', 'fair', 'equitable', 'and', 'mutually', 'supportive', 'learning', 'environment'], ['We', 'aim', 'to', 'create', 'an', 'environment', 'where', 'disabled', 'students', 'are', 'supported', 'to', 'ac', 'hieve', 'their', 'full', 'potential', 'to', 'contribute', 'fully', 'and', 'to', 'derive', 'maximum', 'benefit', 'and', 'enjoyment', 'from', 'their', 'involvement', 'in', 'the', 'life', 'of', 'the', 'University'], [], ['Legal', 'context', 'For', 'the', 'purpose', 'of', 'this', 'policy', 'the', 'following', 'definition', 'of', 'a', 'disability', 'will', 'apply', 'as', 'set', 'out', 'in', 'the', 'Equality', 'Act', 'A', 'person', 'has', 'a', 'disability', 'if', 'they', 'have', 'a', 'physical', 'or', 'mental', 'impairment', 'and', 'the', 'impairment', 'has', 'a', 'substantial', 'and', 'long', 'term', 'adverse', 'effect', 'on', 'their', 'ability', 'to', 'carry', 'out', 'normal', 'day', 'today', 'activities', 'The', 'definition', 'of', 'disability', 'is', 'wid', 'er', 'than', 'is', 'commonly', 'understood', 'and', 'may', 'include', 'conditions', 'many', 'might', 'not', 'consider', 'a', 'disability', 'including', 'students', 'with', 'dyslexia', 'dyspraxia', 'attention', 'deficit', 'conditions', 'mental', 'health', 'conditions', 'autism', 'and', 'other', 'long', 'term', 'health', 'conditions'], [], ['The', 'Reasonab', 'le', 'Adjustment', 'Duty', 'The', 'Equality', 'Act', 'places', 'the', 'University', 'under', 'a', 'duty', 'to', 'make', 'reasonable', 'adjustments', 'to', 'support', 'individual', 'disabled', 'students', 'in', 'realising', 'their', 'full', 'potential', 'and', 'to', 'ensure', 'that', 'they', 'are', 'not', 'disadvantaged', 'in', 'comparison', 'with', 'non', 'disabled', 'students'], ['This', 'duty', 'is', 'also', 'anticipatory', 'meaning', 'that', 'the', 'University', 'is', 'required', 'to', 'consider', 'and', 'take', 'action', 'in', 'relation', 'to', 'barriers', 'that', 'impede', 'disabled', 'people', 'generally', 'prior', 'to', 'an', 'i', 'ndividual', 'disabled', 'person', 'seeking', 'to', 'become', 'a', 'student'], ['Further', 'details', 'about', 'reasonable', 'adjustments', 'whilst', 'at', 'University', 'are', 'here'], ['The', 'term', 'provision', 'criterion', 'or', 'practice', 'covers', 'all', 'aspects', 'of', 'the', 'student', 'experience', 'access', 'to', 'education', 'other', 'benefits', 'facilities', 'and', 'services', 'as', 'well', 'as', 'all', 'University', 'policies', 'procedures', 'and', 'regulations'], ['In', 'determining', 'what', 'is', 'reasonable', 'the', 'University', 'will', 'not', 'compromise', 'academiccompetence', 'standards', 'and', 'the', 'expectation', 'is', 'that', 'disabled', 'students', 'will', 'achieve', 'the', 'same', 'learning', 'outc', 'omes', 'as', 'non', 'disabled', 'students'], ['Consideration', 'will', 'be', 'given', 'to', 'adjusting', 'the', 'way', 'in', 'which', 'a', 'competence', 'standard', 'is', 'assessed', 'unless', 'the', 'passing', 'of', 'the', 'assessment', 'is', 'conditional', 'upon', 'having', 'a', 'practical', 'skill', 'or', 'ability', 'which', 'must', 'be', 'demonstrated', 'by', 'completin', 'g', 'a', 'practical', 'component', 'or', 'demonstrating', 'fitness', 'to', 'practise'], ['In', 'determining', 'what', 'is', 'reasonable', 'in', 'each', 'individual', 'case', 'the', 'University', 'may', 'consider', 'facto ...

# %%
# as some strings are now empty, remove empty strings from a list of strings
cleaned_list_of_strings = [string for string in tokenized_p1 if string]

# and just in case that doesn't work,, remove empty strings from a list of lists of strings
cleaned_tokenized_p1 = [[token for token in tokens if token] for tokens in tokenized_p1]

# %%
cleaned_tokenized_p1
# Out:
# [['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'University',
#   'Policy',
#   'on',
#   'Supporting',
#   'Disabled',
#   'Students'],
#  ['Introduction',
#   'The',
#   'University',
#   'of',
#   'Bristol',
#   'is',
#   'committed',
#   'to',
#   'creating',
#   'and',
#   'sustaining',
#   'an',
#   'excellent',
#   'teaching',
#   'and',
#   'learning',
#   'experience',
#   'for',
#   'our',
#   'students',
#   'offering',
#   'a',
#   'high',
#   'quality',
#   'research',
#   'led',
#   'education',
#   'that',
#   'encourages',
#   'independence',
#   'of',
#   'mind',
#   'where',
#   'students',
#   'are',
#   'encouraged',
#   'to',
#   'thrive',
#   'academically'],
#  ['As',
#   'a',
#   'provider',
#   'of',
#   'education',
#   'we',
#   'value',
#   'the',
#   'diversity',
#   'of',
#   'our',
#   'students',
#   'and',
#   'remain',
#   'committed',
#   'to',
#   'sustaining',
#   'a',
#   'fair',
#   'equitable',
#   'and',
#   'mutually',
#   'supportive',
#   'learning',
#   'environment'],
#  ['We',
#   'aim',
#   'to',
#   'create',
#   'an',
#   'environment',
#   'where',
#   'disabled',
#   'students',
#   'are',
#   'supported',
#   'to',
#   'ac',
#   'hieve',
#   'their',
#   'full',
#   'potential',
#   'to',
#   'contribute',
#   'fully',
#   'and',
#   'to',
#   'derive',
#   'maximum',
#   'benefit',
#   'and',
#   'enjoyment',
#   'from',
#   'their',
#   'involvement',
#   'in',
#   'the',
#   'life',
#   'of',
#   'the',
#   'University'],
#  [],
#  ['Legal',
#   'context',
#   'For',
#   'the',
#   'purpose',
#   'of',
#   'this',
#   'policy',
#   'the',
#   'following',
#   'definition',
#   'of',
#   'a',
#   'disability',
#   'will',
#   'apply',
#   'as',
#   'set',
#   'out',
#   'in',
#   'the',
#   'Equality',
#   'Act',
#   'A',
#   'person',
#   'has',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'and',
#   'the',
#   'impairment',
#   'has',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'today',
#   'activities',
#   'The',
#   'definition',
#   'of',
#   'disability',
#   'is',
#   'wid',
#   'er',
#   'than',
#   'is',
#   'commonly',
#   'understood',
#   'and',
#   'may',
#   'include',
#   'conditions',
#   'many',
#   'might',
#   'not',
#   'consider',
#   'a',
#   'disability',
#   'including',
#   'students',
#   'with',
#   'dyslexia',
#   'dyspraxia',
#   'attention',
#   'deficit',
#   'conditions',
#   'mental',
#   'health',
#   'conditions',
#   'autism',
#   'and',
#   'other',
#   'long',
#   'term',
#   'health',
#   'conditions'],
#  [],
#  ['The',
#   'Reasonab',
#   'le',
#   'Adjustment',
#   'Duty',
#   'The',
#   'Equality',
#   'Act',
#   'places',
#   'the',
#   'University',
#   'under',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustments',
#   'to',
#   'support',
#   'individual',
#   'disabled',
#   'students',
#   'in',
#   'realising',
#   'their',
#   'full',
#   'potential',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'are',
#   'not',
#   'disadvantaged',
#   'in',
#   'comparison',
#   'with',
#   'non',
#   'disabled',
#   'students'],
#  ['This',
#   'duty',
#   'is',
#   'also',
#   'anticipatory',
#   'meaning',
#   'that',
#   'the',
#   'University',
#   'is',
#   'required',
#   'to',
#   'consider',
#   'and',
#   'take',
#   'action',
#   'in',
#   'relation',
#   'to',
#   'barriers',
#   'that',
#   'impede',
#   'disabled',
#   'people',
#   'generally',
#   'prior',
#   'to',
#   'an',
#   'i',
#   'ndividual',
#   'disabled',
#   'person',
#   'seeking',
#   'to',
#   'become',
#   'a',
#   'student'],
#  ['Further',
#   'details',
#   'about',
#   'reasonable',
#   'adjustments',
#   'whilst',
#   'at',
#   'University',
#   'are',
#   'here'],
#  ['The',
#   'term',
#   'provision',
#   'criterion',
#   'or',
#   'practice',
#   'covers',
#   'all',
#   'aspects',
#   'of',
#   'the',
#   'student',
#   'experience',
#   'access',
#   'to',
#   'education',
#   'other',
#   'benefits',
#   'facilities',
#   'and',
#   'services',
#   'as',
#   'well',
#   'as',
#   'all',
#   'University',
#   'policies',
#   'procedures',
#   'and',
#   'regulations'],
#  ['In',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'the',
#   'University',
#   'will',
#   'not',
#   'compromise',
#   'academiccompetence',
#   'standards',
#   'and',
#   'the',
#   'expectation',
#   'is',
#   'that',
#   'disabled',
#   'students',
#   'will',
#   'achieve',
#   'the',
#   'same',
#   'learning',
#   'outc',
#   'omes',
#   'as',
#   'non',
#   'disabled',
#   'students'],
#  ['Consideration',
#   'will',
#   'be',
#   'given',
#   'to',
#   'adjusting',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed',
#   'unless',
#   'the',
#   'passing',
#   'of',
#   'the',
#   'assessment',
#   'is',
#   'conditional',
#   'upon',
#   'having',
#   'a',
#   'practical',
#   'skill',
#   'or',
#   'ability',
#   'which',
#   'must',
#   'be',
#   'demonstrated',
#   'by',
#   'completin',
#   'g',
#   'a',
#   'practical',
#   'component',
#   'or',
#   'demonstrating',
#   'fitness',
#   'to',
#   'practise'],
#  ['In',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'in',
#   'each',
#   'individual',
#   'case',
#   'the',
#   'University',
#   'may',
#   'consider',
#   'factors',
#   'including',
#   'but',
#   'not',
#   'limited',
#   'to',
#   'A',
#   'competence',
#   'standard',
#   'is',
#   'defined',
#   'as',
#   'an',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standard',
#   'applied',
#   'by',
#   'or',
#   'on',
#   'behalf',
#   'of',
#   'an',
#   'education',
#   'provider',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'determining',
#   'whether',
#   'or',
#   'not',
#   'a',
#   'person',
#   'has',
#   'a',
#   'particular',
#   'level',
#   'of',
#   'competence',
#   'or',
#   'ability'],
#  ['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'whether',
#   'taking',
#   'any',
#   'particular',
#   'steps',
#   'would',
#   'be',
#   'effective',
#   'in',
#   'overc',
#   'oming',
#   'the',
#   'substantial',
#   'disadvantage',
#   'that',
#   'disabled',
#   'people',
#   'face',
#   'in',
#   'accessing',
#   'the',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'in',
#   'question',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'it',
#   'is',
#   'practicable',
#   'to',
#   'take',
#   'such',
#   'steps',
#   'the',
#   'type',
#   'of',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'being',
#   'provided',
#   'the',
#   'effect',
#   'of',
#   'the',
#   'disability',
#   'on',
#   'the',
#   'individual',
#   'the',
#   'financial',
#   'and',
#   'other',
#   'costs',
#   'of',
#   'making',
#   'the',
#   'adjustment',
#   'the',
#   'availability',
#   'of',
#   'grants',
#   'loans',
#   'and',
#   'other',
#   'assistance',
#   'to',
#   'disabled',
#   'students',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'aids',
#   'and',
#   'services',
#   'will',
#   'otherwise',
#   'be',
#   'provided',
#   'to',
#   'disabled',
#   'people',
#   'or',
#   'students',
#   'the',
#   'resources',
#   'of',
#   'the',
#   'education',
#   'provider',
#   'and',
#   'the',
#   'availability',
#   'of',
#   'financial',
#   'or',
#   'other',
#   'assistance',
#   'health',
#   'and',
#   'safety',
#   'requirements',
#   'the',
#   'Act',
#   'does',
#   'not',
#   'override',
#   'health',
#   'and',
#   'safety',
#   'requirements',
#   'the',
#   'relevant',
#   'interests',
#   'of',
#   'other',
#   'people',
#   'including',
#   'other',
#   'students'],
#  ['Disability',
#   'Disclosure',
#   'Students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'should',
#   'be',
#   'encouraged',
#   'to',
#   'c',
#   'ontact',
#   'Disability',
#   'Services',
#   'where',
#   'further',
#   'discussion',
#   'can',
#   'take',
#   'place',
#   'with',
#   'a',
#   'Disability',
#   'Advisor',
#   'on',
#   'issues',
#   'connected',
#   'to',
#   'support',
#   'and',
#   'to',
#   'explore',
#   'funding',
#   'that',
#   'may',
#   'be',
#   'available',
#   'to',
#   'cover',
#   'the',
#   'cos',
#   'ts',
#   'of',
#   'reasonable',
#   'adjustments',
#   'where',
#   'appropriate'],
#  ['A',
#   'Disability',
#   'Support',
#   'Summary',
#   'DSS',
#   'may',
#   'be',
#   'produced',
#   'to',
#   'assist',
#   'staff',
#   'in',
#   'determining',
#   'what',
#   'adjustments',
#   'should',
#   'be',
#   'considered',
#   'and',
#   'to',
#   'assist',
#   'the',
#   'University',
#   'in',
#   'meeting',
#   'the',
#   'requirements',
#   'of',
#   'their',
#   'reasonable',
#   'adjustment',
#   'duty'],
#  ['It',
#   'is',
#   'expected',
#   'that',
#   'staff',
#   'will',
#   'engage',
#   'fully',
#   'with',
#   'this',
#   'process',
#   'and',
#   'familiarise',
#   'themselves',
#   'with',
#   'any',
#   'associated',
#   'University',
#   'guidance'],
#  ['Students',
#   'can',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'the',
#   'course',
#   'of',
#   'their',
#   'studies'],
#  ['The',
#   'reasonable',
#   'adjustment',
#   'duty',
#   'applies',
#   'to',
#   'the',
#   'individual',
#   'student',
#   'from',
#   'this',
#   'point',
#   'of',
#   'disclosure'],
#  ['A',
#   'disabled',
#   'student',
#   'has',
#   'a',
#   'right',
#   'to',
#   'request',
#   'that',
#   'the',
#   'existence',
#   'or',
#   'nature',
#   'of',
#   'their',
#   'disability',
#   'be',
#   'treated',
#   'as',
#   'confidential'],
#  ['In',
#   'such',
#   'cases',
#   'the',
#   'recommended',
#   'support',
#   'can',
#   'be',
#   'shared',
#   'as',
#   'agreed',
#   'with',
#   'the',
#   'student',
#   'in',
#   'terms',
#   'of',
#   'what',
#   'is',
#   'shared',
#   'but',
#   'the',
#   'nature',
#   'of',
#   'the',
#   'disability',
#   'must',
#   'remain',
#   'confidential'],
#  ['In',
#   'some',
#   'instances',
#   'this',
#   'will',
#   'limit',
#   'the',
#   'Universitys',
#   'ability',
#   'to',
#   'implement',
#   'satisfactory',
#   'adjustments',
#   'or',
#   'result',
#   'in',
#   'no',
#   'adjustments',
#   'being',
#   'provided'],
#  [],
#  ['Responsibilities',
#   'The',
#   'University',
#   'Board',
#   'of',
#   'Trustees',
#   'is',
#   'legally',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'University',
#   'properly',
#   'discharges',
#   'its',
#   'duties',
#   'under',
#   'the',
#   'Equality',
#   'Act'],
#  ['As',
#   'such',
#   'all',
#   'University',
#   'staff',
#   'are',
#   'expected',
#   'to',
#   'operate',
#   'within',
#   'the',
#   'parameters',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'any',
#   'associated',
#   'guidance'],
#  ['The',
#   'success',
#   'of',
#   'the',
#   'support',
#   'that',
#   'both',
#   'the',
#   'school',
#   'and',
#   'Disability',
#   'Services',
#   'are',
#   'able',
#   'to',
#   'provide',
#   'relies',
#   'on',
#   'the',
#   'students',
#   'willingness',
#   'to',
#   'engage',
#   'with',
#   'it'],
#  ['The',
#   'general',
#   'expectation',
#   'is',
#   'that',
#   'the',
#   'student',
#   'will',
#   'assume',
#   'an',
#   'element',
#   'of',
#   'personal',
#   'responsibility',
#   'and',
#   'work',
#   'in',
#   'partnership',
#   'with',
#   'their',
#   'School',
#   'and',
#   'Faculty',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'adjustments',
#   'make',
#   'a',
#   'positive',
#   'contribution',
#   'to',
#   'their',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'studies',
#   'and',
#   'to',
#   'complete',
#   'their',
#   'programme',
#   'successfully'],
#  ['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'University',
#   'Policy',
#   'on',
#   'Supporting',
#   'Disabled',
#   'Students',
#   'Document',
#   'control',
#   'Summary',
#   'This',
#   'policy',
#   'defines',
#   'how',
#   'the',
#   'University',
#   'manages',
#   'disability',
#   'disclosure',
#   'and',
#   'reasonable',
#   'adjustments',
#   'to',
#   'support',
#   'disabled',
#   'students'],
#  ['Scope',
#   'This',
#   'document',
#   'applies',
#   'to',
#   'All',
#   'staff',
#   'and',
#   'students',
#   'for',
#   'compliance'],
#  ['For',
#   'applicants',
#   'entering',
#   'in',
#   'Applies',
#   'to',
#   'academic',
#   'year',
#   'onwards',
#   'Document',
#   'Control',
#   'Owner',
#   'Paula',
#   'Coonerty',
#   'Executive',
#   'Director',
#   'for',
#   'Education',
#   'Student',
#   'Experience',
#   'Academic',
#   'Registrar',
#   'Division',
#   'Education',
#   'Student',
#   'Experience',
#   'Lead',
#   'contact',
#   'Karen',
#   'Hocking'],
#  ['Disability',
#   'Services',
#   'Manager',
#   'Type',
#   'Policy',
#   'Status',
#   'Approved',
#   'Asset',
#   'number',
#   'EPIR',
#   'Version',
#   'V',
#   'Approved',
#   'by',
#   'Date',
#   'current',
#   'version',
#   'approved',
#   'Date',
#   'current',
#   'version',
#   'published',
#   'Date',
#   'first',
#   'published',
#   'Revision',
#   'schedule',
#   'year',
#   'Next',
#   'review',
#   'date',
#   'June',
#   'Superseded',
#   'documents',
#   'Related',
#   'documents',
#   'Keywords',
#   'Disabled',
#   'students',
#   'disclosure']]

# %%
#lemmatize
postlemma = []

for i in cleaned_tokenized_p1: 
    postlemma.append([lemmatizer.lemmatize(j) for j in i])

# %%
postlemma
# Out:
# [['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'University',
#   'Policy',
#   'on',
#   'Supporting',
#   'Disabled',
#   'Students'],
#  ['Introduction',
#   'The',
#   'University',
#   'of',
#   'Bristol',
#   'is',
#   'committed',
#   'to',
#   'creating',
#   'and',
#   'sustaining',
#   'an',
#   'excellent',
#   'teaching',
#   'and',
#   'learning',
#   'experience',
#   'for',
#   'our',
#   'student',
#   'offering',
#   'a',
#   'high',
#   'quality',
#   'research',
#   'led',
#   'education',
#   'that',
#   'encourages',
#   'independence',
#   'of',
#   'mind',
#   'where',
#   'student',
#   'are',
#   'encouraged',
#   'to',
#   'thrive',
#   'academically'],
#  ['As',
#   'a',
#   'provider',
#   'of',
#   'education',
#   'we',
#   'value',
#   'the',
#   'diversity',
#   'of',
#   'our',
#   'student',
#   'and',
#   'remain',
#   'committed',
#   'to',
#   'sustaining',
#   'a',
#   'fair',
#   'equitable',
#   'and',
#   'mutually',
#   'supportive',
#   'learning',
#   'environment'],
#  ['We',
#   'aim',
#   'to',
#   'create',
#   'an',
#   'environment',
#   'where',
#   'disabled',
#   'student',
#   'are',
#   'supported',
#   'to',
#   'ac',
#   'hieve',
#   'their',
#   'full',
#   'potential',
#   'to',
#   'contribute',
#   'fully',
#   'and',
#   'to',
#   'derive',
#   'maximum',
#   'benefit',
#   'and',
#   'enjoyment',
#   'from',
#   'their',
#   'involvement',
#   'in',
#   'the',
#   'life',
#   'of',
#   'the',
#   'University'],
#  [],
#  ['Legal',
#   'context',
#   'For',
#   'the',
#   'purpose',
#   'of',
#   'this',
#   'policy',
#   'the',
#   'following',
#   'definition',
#   'of',
#   'a',
#   'disability',
#   'will',
#   'apply',
#   'a',
#   'set',
#   'out',
#   'in',
#   'the',
#   'Equality',
#   'Act',
#   'A',
#   'person',
#   'ha',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'and',
#   'the',
#   'impairment',
#   'ha',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'today',
#   'activity',
#   'The',
#   'definition',
#   'of',
#   'disability',
#   'is',
#   'wid',
#   'er',
#   'than',
#   'is',
#   'commonly',
#   'understood',
#   'and',
#   'may',
#   'include',
#   'condition',
#   'many',
#   'might',
#   'not',
#   'consider',
#   'a',
#   'disability',
#   'including',
#   'student',
#   'with',
#   'dyslexia',
#   'dyspraxia',
#   'attention',
#   'deficit',
#   'condition',
#   'mental',
#   'health',
#   'condition',
#   'autism',
#   'and',
#   'other',
#   'long',
#   'term',
#   'health',
#   'condition'],
#  [],
#  ['The',
#   'Reasonab',
#   'le',
#   'Adjustment',
#   'Duty',
#   'The',
#   'Equality',
#   'Act',
#   'place',
#   'the',
#   'University',
#   'under',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'to',
#   'support',
#   'individual',
#   'disabled',
#   'student',
#   'in',
#   'realising',
#   'their',
#   'full',
#   'potential',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'are',
#   'not',
#   'disadvantaged',
#   'in',
#   'comparison',
#   'with',
#   'non',
#   'disabled',
#   'student'],
#  ['This',
#   'duty',
#   'is',
#   'also',
#   'anticipatory',
#   'meaning',
#   'that',
#   'the',
#   'University',
#   'is',
#   'required',
#   'to',
#   'consider',
#   'and',
#   'take',
#   'action',
#   'in',
#   'relation',
#   'to',
#   'barrier',
#   'that',
#   'impede',
#   'disabled',
#   'people',
#   'generally',
#   'prior',
#   'to',
#   'an',
#   'i',
#   'ndividual',
#   'disabled',
#   'person',
#   'seeking',
#   'to',
#   'become',
#   'a',
#   'student'],
#  ['Further',
#   'detail',
#   'about',
#   'reasonable',
#   'adjustment',
#   'whilst',
#   'at',
#   'University',
#   'are',
#   'here'],
#  ['The',
#   'term',
#   'provision',
#   'criterion',
#   'or',
#   'practice',
#   'cover',
#   'all',
#   'aspect',
#   'of',
#   'the',
#   'student',
#   'experience',
#   'access',
#   'to',
#   'education',
#   'other',
#   'benefit',
#   'facility',
#   'and',
#   'service',
#   'a',
#   'well',
#   'a',
#   'all',
#   'University',
#   'policy',
#   'procedure',
#   'and',
#   'regulation'],
#  ['In',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'the',
#   'University',
#   'will',
#   'not',
#   'compromise',
#   'academiccompetence',
#   'standard',
#   'and',
#   'the',
#   'expectation',
#   'is',
#   'that',
#   'disabled',
#   'student',
#   'will',
#   'achieve',
#   'the',
#   'same',
#   'learning',
#   'outc',
#   'omes',
#   'a',
#   'non',
#   'disabled',
#   'student'],
#  ['Consideration',
#   'will',
#   'be',
#   'given',
#   'to',
#   'adjusting',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed',
#   'unless',
#   'the',
#   'passing',
#   'of',
#   'the',
#   'assessment',
#   'is',
#   'conditional',
#   'upon',
#   'having',
#   'a',
#   'practical',
#   'skill',
#   'or',
#   'ability',
#   'which',
#   'must',
#   'be',
#   'demonstrated',
#   'by',
#   'completin',
#   'g',
#   'a',
#   'practical',
#   'component',
#   'or',
#   'demonstrating',
#   'fitness',
#   'to',
#   'practise'],
#  ['In',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'in',
#   'each',
#   'individual',
#   'case',
#   'the',
#   'University',
#   'may',
#   'consider',
#   'factor',
#   'including',
#   'but',
#   'not',
#   'limited',
#   'to',
#   'A',
#   'competence',
#   'standard',
#   'is',
#   'defined',
#   'a',
#   'an',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standard',
#   'applied',
#   'by',
#   'or',
#   'on',
#   'behalf',
#   'of',
#   'an',
#   'education',
#   'provider',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'determining',
#   'whether',
#   'or',
#   'not',
#   'a',
#   'person',
#   'ha',
#   'a',
#   'particular',
#   'level',
#   'of',
#   'competence',
#   'or',
#   'ability'],
#  ['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'whether',
#   'taking',
#   'any',
#   'particular',
#   'step',
#   'would',
#   'be',
#   'effective',
#   'in',
#   'overc',
#   'oming',
#   'the',
#   'substantial',
#   'disadvantage',
#   'that',
#   'disabled',
#   'people',
#   'face',
#   'in',
#   'accessing',
#   'the',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'in',
#   'question',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'it',
#   'is',
#   'practicable',
#   'to',
#   'take',
#   'such',
#   'step',
#   'the',
#   'type',
#   'of',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'being',
#   'provided',
#   'the',
#   'effect',
#   'of',
#   'the',
#   'disability',
#   'on',
#   'the',
#   'individual',
#   'the',
#   'financial',
#   'and',
#   'other',
#   'cost',
#   'of',
#   'making',
#   'the',
#   'adjustment',
#   'the',
#   'availability',
#   'of',
#   'grant',
#   'loan',
#   'and',
#   'other',
#   'assistance',
#   'to',
#   'disabled',
#   'student',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'aid',
#   'and',
#   'service',
#   'will',
#   'otherwise',
#   'be',
#   'provided',
#   'to',
#   'disabled',
#   'people',
#   'or',
#   'student',
#   'the',
#   'resource',
#   'of',
#   'the',
#   'education',
#   'provider',
#   'and',
#   'the',
#   'availability',
#   'of',
#   'financial',
#   'or',
#   'other',
#   'assistance',
#   'health',
#   'and',
#   'safety',
#   'requirement',
#   'the',
#   'Act',
#   'doe',
#   'not',
#   'override',
#   'health',
#   'and',
#   'safety',
#   'requirement',
#   'the',
#   'relevant',
#   'interest',
#   'of',
#   'other',
#   'people',
#   'including',
#   'other',
#   'student'],
#  ['Disability',
#   'Disclosure',
#   'Students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'should',
#   'be',
#   'encouraged',
#   'to',
#   'c',
#   'ontact',
#   'Disability',
#   'Services',
#   'where',
#   'further',
#   'discussion',
#   'can',
#   'take',
#   'place',
#   'with',
#   'a',
#   'Disability',
#   'Advisor',
#   'on',
#   'issue',
#   'connected',
#   'to',
#   'support',
#   'and',
#   'to',
#   'explore',
#   'funding',
#   'that',
#   'may',
#   'be',
#   'available',
#   'to',
#   'cover',
#   'the',
#   'co',
#   't',
#   'of',
#   'reasonable',
#   'adjustment',
#   'where',
#   'appropriate'],
#  ['A',
#   'Disability',
#   'Support',
#   'Summary',
#   'DSS',
#   'may',
#   'be',
#   'produced',
#   'to',
#   'assist',
#   'staff',
#   'in',
#   'determining',
#   'what',
#   'adjustment',
#   'should',
#   'be',
#   'considered',
#   'and',
#   'to',
#   'assist',
#   'the',
#   'University',
#   'in',
#   'meeting',
#   'the',
#   'requirement',
#   'of',
#   'their',
#   'reasonable',
#   'adjustment',
#   'duty'],
#  ['It',
#   'is',
#   'expected',
#   'that',
#   'staff',
#   'will',
#   'engage',
#   'fully',
#   'with',
#   'this',
#   'process',
#   'and',
#   'familiarise',
#   'themselves',
#   'with',
#   'any',
#   'associated',
#   'University',
#   'guidance'],
#  ['Students',
#   'can',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'the',
#   'course',
#   'of',
#   'their',
#   'study'],
#  ['The',
#   'reasonable',
#   'adjustment',
#   'duty',
#   'applies',
#   'to',
#   'the',
#   'individual',
#   'student',
#   'from',
#   'this',
#   'point',
#   'of',
#   'disclosure'],
#  ['A',
#   'disabled',
#   'student',
#   'ha',
#   'a',
#   'right',
#   'to',
#   'request',
#   'that',
#   'the',
#   'existence',
#   'or',
#   'nature',
#   'of',
#   'their',
#   'disability',
#   'be',
#   'treated',
#   'a',
#   'confidential'],
#  ['In',
#   'such',
#   'case',
#   'the',
#   'recommended',
#   'support',
#   'can',
#   'be',
#   'shared',
#   'a',
#   'agreed',
#   'with',
#   'the',
#   'student',
#   'in',
#   'term',
#   'of',
#   'what',
#   'is',
#   'shared',
#   'but',
#   'the',
#   'nature',
#   'of',
#   'the',
#   'disability',
#   'must',
#   'remain',
#   'confidential'],
#  ['In',
#   'some',
#   'instance',
#   'this',
#   'will',
#   'limit',
#   'the',
#   'Universitys',
#   'ability',
#   'to',
#   'implement',
#   'satisfactory',
#   'adjustment',
#   'or',
#   'result',
#   'in',
#   'no',
#   'adjustment',
#   'being',
#   'provided'],
#  [],
#  ['Responsibilities',
#   'The',
#   'University',
#   'Board',
#   'of',
#   'Trustees',
#   'is',
#   'legally',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'University',
#   'properly',
#   'discharge',
#   'it',
#   'duty',
#   'under',
#   'the',
#   'Equality',
#   'Act'],
#  ['As',
#   'such',
#   'all',
#   'University',
#   'staff',
#   'are',
#   'expected',
#   'to',
#   'operate',
#   'within',
#   'the',
#   'parameter',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'any',
#   'associated',
#   'guidance'],
#  ['The',
#   'success',
#   'of',
#   'the',
#   'support',
#   'that',
#   'both',
#   'the',
#   'school',
#   'and',
#   'Disability',
#   'Services',
#   'are',
#   'able',
#   'to',
#   'provide',
#   'relies',
#   'on',
#   'the',
#   'student',
#   'willingness',
#   'to',
#   'engage',
#   'with',
#   'it'],
#  ['The',
#   'general',
#   'expectation',
#   'is',
#   'that',
#   'the',
#   'student',
#   'will',
#   'assume',
#   'an',
#   'element',
#   'of',
#   'personal',
#   'responsibility',
#   'and',
#   'work',
#   'in',
#   'partnership',
#   'with',
#   'their',
#   'School',
#   'and',
#   'Faculty',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'adjustment',
#   'make',
#   'a',
#   'positive',
#   'contribution',
#   'to',
#   'their',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'study',
#   'and',
#   'to',
#   'complete',
#   'their',
#   'programme',
#   'successfully'],
#  ['Version',
#   'August',
#   'Page',
#   'of',
#   'Year',
#   'of',
#   'Entry',
#   'University',
#   'Policy',
#   'on',
#   'Supporting',
#   'Disabled',
#   'Students',
#   'Document',
#   'control',
#   'Summary',
#   'This',
#   'policy',
#   'defines',
#   'how',
#   'the',
#   'University',
#   'manages',
#   'disability',
#   'disclosure',
#   'and',
#   'reasonable',
#   'adjustment',
#   'to',
#   'support',
#   'disabled',
#   'student'],
#  ['Scope',
#   'This',
#   'document',
#   'applies',
#   'to',
#   'All',
#   'staff',
#   'and',
#   'student',
#   'for',
#   'compliance'],
#  ['For',
#   'applicant',
#   'entering',
#   'in',
#   'Applies',
#   'to',
#   'academic',
#   'year',
#   'onwards',
#   'Document',
#   'Control',
#   'Owner',
#   'Paula',
#   'Coonerty',
#   'Executive',
#   'Director',
#   'for',
#   'Education',
#   'Student',
#   'Experience',
#   'Academic',
#   'Registrar',
#   'Division',
#   'Education',
#   'Student',
#   'Experience',
#   'Lead',
#   'contact',
#   'Karen',
#   'Hocking'],
#  ['Disability',
#   'Services',
#   'Manager',
#   'Type',
#   'Policy',
#   'Status',
#   'Approved',
#   'Asset',
#   'number',
#   'EPIR',
#   'Version',
#   'V',
#   'Approved',
#   'by',
#   'Date',
#   'current',
#   'version',
#   'approved',
#   'Date',
#   'current',
#   'version',
#   'published',
#   'Date',
#   'first',
#   'published',
#   'Revision',
#   'schedule',
#   'year',
#   'Next',
#   'review',
#   'date',
#   'June',
#   'Superseded',
#   'document',
#   'Related',
#   'document',
#   'Keywords',
#   'Disabled',
#   'student',
#   'disclosure']]

# %%
#lower all cases
postfin1 = [[j.lower() for j in i] for i in postlemma]

# %%
postfin1
# Out:
# [['version',
#   'august',
#   'page',
#   'of',
#   'year',
#   'of',
#   'entry',
#   'university',
#   'policy',
#   'on',
#   'supporting',
#   'disabled',
#   'students'],
#  ['introduction',
#   'the',
#   'university',
#   'of',
#   'bristol',
#   'is',
#   'committed',
#   'to',
#   'creating',
#   'and',
#   'sustaining',
#   'an',
#   'excellent',
#   'teaching',
#   'and',
#   'learning',
#   'experience',
#   'for',
#   'our',
#   'student',
#   'offering',
#   'a',
#   'high',
#   'quality',
#   'research',
#   'led',
#   'education',
#   'that',
#   'encourages',
#   'independence',
#   'of',
#   'mind',
#   'where',
#   'student',
#   'are',
#   'encouraged',
#   'to',
#   'thrive',
#   'academically'],
#  ['as',
#   'a',
#   'provider',
#   'of',
#   'education',
#   'we',
#   'value',
#   'the',
#   'diversity',
#   'of',
#   'our',
#   'student',
#   'and',
#   'remain',
#   'committed',
#   'to',
#   'sustaining',
#   'a',
#   'fair',
#   'equitable',
#   'and',
#   'mutually',
#   'supportive',
#   'learning',
#   'environment'],
#  ['we',
#   'aim',
#   'to',
#   'create',
#   'an',
#   'environment',
#   'where',
#   'disabled',
#   'student',
#   'are',
#   'supported',
#   'to',
#   'ac',
#   'hieve',
#   'their',
#   'full',
#   'potential',
#   'to',
#   'contribute',
#   'fully',
#   'and',
#   'to',
#   'derive',
#   'maximum',
#   'benefit',
#   'and',
#   'enjoyment',
#   'from',
#   'their',
#   'involvement',
#   'in',
#   'the',
#   'life',
#   'of',
#   'the',
#   'university'],
#  [],
#  ['legal',
#   'context',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'this',
#   'policy',
#   'the',
#   'following',
#   'definition',
#   'of',
#   'a',
#   'disability',
#   'will',
#   'apply',
#   'a',
#   'set',
#   'out',
#   'in',
#   'the',
#   'equality',
#   'act',
#   'a',
#   'person',
#   'ha',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'and',
#   'the',
#   'impairment',
#   'ha',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'their',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'today',
#   'activity',
#   'the',
#   'definition',
#   'of',
#   'disability',
#   'is',
#   'wid',
#   'er',
#   'than',
#   'is',
#   'commonly',
#   'understood',
#   'and',
#   'may',
#   'include',
#   'condition',
#   'many',
#   'might',
#   'not',
#   'consider',
#   'a',
#   'disability',
#   'including',
#   'student',
#   'with',
#   'dyslexia',
#   'dyspraxia',
#   'attention',
#   'deficit',
#   'condition',
#   'mental',
#   'health',
#   'condition',
#   'autism',
#   'and',
#   'other',
#   'long',
#   'term',
#   'health',
#   'condition'],
#  [],
#  ['the',
#   'reasonab',
#   'le',
#   'adjustment',
#   'duty',
#   'the',
#   'equality',
#   'act',
#   'place',
#   'the',
#   'university',
#   'under',
#   'a',
#   'duty',
#   'to',
#   'make',
#   'reasonable',
#   'adjustment',
#   'to',
#   'support',
#   'individual',
#   'disabled',
#   'student',
#   'in',
#   'realising',
#   'their',
#   'full',
#   'potential',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'they',
#   'are',
#   'not',
#   'disadvantaged',
#   'in',
#   'comparison',
#   'with',
#   'non',
#   'disabled',
#   'student'],
#  ['this',
#   'duty',
#   'is',
#   'also',
#   'anticipatory',
#   'meaning',
#   'that',
#   'the',
#   'university',
#   'is',
#   'required',
#   'to',
#   'consider',
#   'and',
#   'take',
#   'action',
#   'in',
#   'relation',
#   'to',
#   'barrier',
#   'that',
#   'impede',
#   'disabled',
#   'people',
#   'generally',
#   'prior',
#   'to',
#   'an',
#   'i',
#   'ndividual',
#   'disabled',
#   'person',
#   'seeking',
#   'to',
#   'become',
#   'a',
#   'student'],
#  ['further',
#   'detail',
#   'about',
#   'reasonable',
#   'adjustment',
#   'whilst',
#   'at',
#   'university',
#   'are',
#   'here'],
#  ['the',
#   'term',
#   'provision',
#   'criterion',
#   'or',
#   'practice',
#   'cover',
#   'all',
#   'aspect',
#   'of',
#   'the',
#   'student',
#   'experience',
#   'access',
#   'to',
#   'education',
#   'other',
#   'benefit',
#   'facility',
#   'and',
#   'service',
#   'a',
#   'well',
#   'a',
#   'all',
#   'university',
#   'policy',
#   'procedure',
#   'and',
#   'regulation'],
#  ['in',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'the',
#   'university',
#   'will',
#   'not',
#   'compromise',
#   'academiccompetence',
#   'standard',
#   'and',
#   'the',
#   'expectation',
#   'is',
#   'that',
#   'disabled',
#   'student',
#   'will',
#   'achieve',
#   'the',
#   'same',
#   'learning',
#   'outc',
#   'omes',
#   'a',
#   'non',
#   'disabled',
#   'student'],
#  ['consideration',
#   'will',
#   'be',
#   'given',
#   'to',
#   'adjusting',
#   'the',
#   'way',
#   'in',
#   'which',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'assessed',
#   'unless',
#   'the',
#   'passing',
#   'of',
#   'the',
#   'assessment',
#   'is',
#   'conditional',
#   'upon',
#   'having',
#   'a',
#   'practical',
#   'skill',
#   'or',
#   'ability',
#   'which',
#   'must',
#   'be',
#   'demonstrated',
#   'by',
#   'completin',
#   'g',
#   'a',
#   'practical',
#   'component',
#   'or',
#   'demonstrating',
#   'fitness',
#   'to',
#   'practise'],
#  ['in',
#   'determining',
#   'what',
#   'is',
#   'reasonable',
#   'in',
#   'each',
#   'individual',
#   'case',
#   'the',
#   'university',
#   'may',
#   'consider',
#   'factor',
#   'including',
#   'but',
#   'not',
#   'limited',
#   'to',
#   'a',
#   'competence',
#   'standard',
#   'is',
#   'defined',
#   'a',
#   'an',
#   'academic',
#   'medical',
#   'or',
#   'other',
#   'standard',
#   'applied',
#   'by',
#   'or',
#   'on',
#   'behalf',
#   'of',
#   'an',
#   'education',
#   'provider',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'determining',
#   'whether',
#   'or',
#   'not',
#   'a',
#   'person',
#   'ha',
#   'a',
#   'particular',
#   'level',
#   'of',
#   'competence',
#   'or',
#   'ability'],
#  ['version',
#   'august',
#   'page',
#   'of',
#   'year',
#   'of',
#   'entry',
#   'whether',
#   'taking',
#   'any',
#   'particular',
#   'step',
#   'would',
#   'be',
#   'effective',
#   'in',
#   'overc',
#   'oming',
#   'the',
#   'substantial',
#   'disadvantage',
#   'that',
#   'disabled',
#   'people',
#   'face',
#   'in',
#   'accessing',
#   'the',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'in',
#   'question',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'it',
#   'is',
#   'practicable',
#   'to',
#   'take',
#   'such',
#   'step',
#   'the',
#   'type',
#   'of',
#   'education',
#   'or',
#   'other',
#   'benefit',
#   'facility',
#   'or',
#   'service',
#   'being',
#   'provided',
#   'the',
#   'effect',
#   'of',
#   'the',
#   'disability',
#   'on',
#   'the',
#   'individual',
#   'the',
#   'financial',
#   'and',
#   'other',
#   'cost',
#   'of',
#   'making',
#   'the',
#   'adjustment',
#   'the',
#   'availability',
#   'of',
#   'grant',
#   'loan',
#   'and',
#   'other',
#   'assistance',
#   'to',
#   'disabled',
#   'student',
#   'the',
#   'extent',
#   'to',
#   'which',
#   'aid',
#   'and',
#   'service',
#   'will',
#   'otherwise',
#   'be',
#   'provided',
#   'to',
#   'disabled',
#   'people',
#   'or',
#   'student',
#   'the',
#   'resource',
#   'of',
#   'the',
#   'education',
#   'provider',
#   'and',
#   'the',
#   'availability',
#   'of',
#   'financial',
#   'or',
#   'other',
#   'assistance',
#   'health',
#   'and',
#   'safety',
#   'requirement',
#   'the',
#   'act',
#   'doe',
#   'not',
#   'override',
#   'health',
#   'and',
#   'safety',
#   'requirement',
#   'the',
#   'relevant',
#   'interest',
#   'of',
#   'other',
#   'people',
#   'including',
#   'other',
#   'student'],
#  ['disability',
#   'disclosure',
#   'students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'should',
#   'be',
#   'encouraged',
#   'to',
#   'c',
#   'ontact',
#   'disability',
#   'services',
#   'where',
#   'further',
#   'discussion',
#   'can',
#   'take',
#   'place',
#   'with',
#   'a',
#   'disability',
#   'advisor',
#   'on',
#   'issue',
#   'connected',
#   'to',
#   'support',
#   'and',
#   'to',
#   'explore',
#   'funding',
#   'that',
#   'may',
#   'be',
#   'available',
#   'to',
#   'cover',
#   'the',
#   'co',
#   't',
#   'of',
#   'reasonable',
#   'adjustment',
#   'where',
#   'appropriate'],
#  ['a',
#   'disability',
#   'support',
#   'summary',
#   'dss',
#   'may',
#   'be',
#   'produced',
#   'to',
#   'assist',
#   'staff',
#   'in',
#   'determining',
#   'what',
#   'adjustment',
#   'should',
#   'be',
#   'considered',
#   'and',
#   'to',
#   'assist',
#   'the',
#   'university',
#   'in',
#   'meeting',
#   'the',
#   'requirement',
#   'of',
#   'their',
#   'reasonable',
#   'adjustment',
#   'duty'],
#  ['it',
#   'is',
#   'expected',
#   'that',
#   'staff',
#   'will',
#   'engage',
#   'fully',
#   'with',
#   'this',
#   'process',
#   'and',
#   'familiarise',
#   'themselves',
#   'with',
#   'any',
#   'associated',
#   'university',
#   'guidance'],
#  ['students',
#   'can',
#   'disclose',
#   'a',
#   'disability',
#   'at',
#   'any',
#   'point',
#   'during',
#   'the',
#   'course',
#   'of',
#   'their',
#   'study'],
#  ['the',
#   'reasonable',
#   'adjustment',
#   'duty',
#   'applies',
#   'to',
#   'the',
#   'individual',
#   'student',
#   'from',
#   'this',
#   'point',
#   'of',
#   'disclosure'],
#  ['a',
#   'disabled',
#   'student',
#   'ha',
#   'a',
#   'right',
#   'to',
#   'request',
#   'that',
#   'the',
#   'existence',
#   'or',
#   'nature',
#   'of',
#   'their',
#   'disability',
#   'be',
#   'treated',
#   'a',
#   'confidential'],
#  ['in',
#   'such',
#   'case',
#   'the',
#   'recommended',
#   'support',
#   'can',
#   'be',
#   'shared',
#   'a',
#   'agreed',
#   'with',
#   'the',
#   'student',
#   'in',
#   'term',
#   'of',
#   'what',
#   'is',
#   'shared',
#   'but',
#   'the',
#   'nature',
#   'of',
#   'the',
#   'disability',
#   'must',
#   'remain',
#   'confidential'],
#  ['in',
#   'some',
#   'instance',
#   'this',
#   'will',
#   'limit',
#   'the',
#   'universitys',
#   'ability',
#   'to',
#   'implement',
#   'satisfactory',
#   'adjustment',
#   'or',
#   'result',
#   'in',
#   'no',
#   'adjustment',
#   'being',
#   'provided'],
#  [],
#  ['responsibilities',
#   'the',
#   'university',
#   'board',
#   'of',
#   'trustees',
#   'is',
#   'legally',
#   'responsible',
#   'for',
#   'ensuring',
#   'that',
#   'the',
#   'university',
#   'properly',
#   'discharge',
#   'it',
#   'duty',
#   'under',
#   'the',
#   'equality',
#   'act'],
#  ['as',
#   'such',
#   'all',
#   'university',
#   'staff',
#   'are',
#   'expected',
#   'to',
#   'operate',
#   'within',
#   'the',
#   'parameter',
#   'of',
#   'this',
#   'policy',
#   'and',
#   'any',
#   'associated',
#   'guidance'],
#  ['the',
#   'success',
#   'of',
#   'the',
#   'support',
#   'that',
#   'both',
#   'the',
#   'school',
#   'and',
#   'disability',
#   'services',
#   'are',
#   'able',
#   'to',
#   'provide',
#   'relies',
#   'on',
#   'the',
#   'student',
#   'willingness',
#   'to',
#   'engage',
#   'with',
#   'it'],
#  ['the',
#   'general',
#   'expectation',
#   'is',
#   'that',
#   'the',
#   'student',
#   'will',
#   'assume',
#   'an',
#   'element',
#   'of',
#   'personal',
#   'responsibility',
#   'and',
#   'work',
#   'in',
#   'partnership',
#   'with',
#   'their',
#   'school',
#   'and',
#   'faculty',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'adjustment',
#   'make',
#   'a',
#   'positive',
#   'contribution',
#   'to',
#   'their',
#   'ability',
#   'to',
#   'engage',
#   'with',
#   'their',
#   'study',
#   'and',
#   'to',
#   'complete',
#   'their',
#   'programme',
#   'successfully'],
#  ['version',
#   'august',
#   'page',
#   'of',
#   'year',
#   'of',
#   'entry',
#   'university',
#   'policy',
#   'on',
#   'supporting',
#   'disabled',
#   'students',
#   'document',
#   'control',
#   'summary',
#   'this',
#   'policy',
#   'defines',
#   'how',
#   'the',
#   'university',
#   'manages',
#   'disability',
#   'disclosure',
#   'and',
#   'reasonable',
#   'adjustment',
#   'to',
#   'support',
#   'disabled',
#   'student'],
#  ['scope',
#   'this',
#   'document',
#   'applies',
#   'to',
#   'all',
#   'staff',
#   'and',
#   'student',
#   'for',
#   'compliance'],
#  ['for',
#   'applicant',
#   'entering',
#   'in',
#   'applies',
#   'to',
#   'academic',
#   'year',
#   'onwards',
#   'document',
#   'control',
#   'owner',
#   'paula',
#   'coonerty',
#   'executive',
#   'director',
#   'for',
#   'education',
#   'student',
#   'experience',
#   'academic',
#   'registrar',
#   'division',
#   'education',
#   'student',
#   'experience',
#   'lead',
#   'contact',
#   'karen',
#   'hocking'],
#  ['disability',
#   'services',
#   'manager',
#   'type',
#   'policy',
#   'status',
#   'approved',
#   'asset',
#   'number',
#   'epir',
#   'version',
#   'v',
#   'approved',
#   'by',
#   'date',
#   'current',
#   'version',
#   'approved',
#   'date',
#   'current',
#   'version',
#   'published',
#   'date',
#   'first',
#   'published',
#   'revision',
#   'schedule',
#   'year',
#   'next',
#   'review',
#   'date',
#   'june',
#   'superseded',
#   'document',
#   'related',
#   'document',
#   'keywords',
#   'disabled',
#   'student',
#   'disclosure']]

# %%
# replace the old comments with the new pre-processed comments
data = {'Sentence': postfin1}
p1 = pd.DataFrame(data)

# %%
p1
# Out:
#                                              Sentence
# 0   [version, august, page, of, year, of, entry, u...
# 1   [introduction, the, university, of, bristol, i...
# 2   [as, a, provider, of, education, we, value, th...
# 3   [we, aim, to, create, an, environment, where, ...
# 4                                                  []
# 5   [legal, context, for, the, purpose, of, this, ...
# 6                                                  []
# 7   [the, reasonab, le, adjustment, duty, the, equ...
# 8   [this, duty, is, also, anticipatory, meaning, ...
# 9   [further, detail, about, reasonable, adjustmen...
# 10  [the, term, provision, criterion, or, practice...
# 11  [in, determining, what, is, reasonable, the, u...
# 12  [consideration, will, be, given, to, adjusting...
# 13  [in, determining, what, is, reasonable, in, ea...
# 14  [version, august, page, of, year, of, entry, w...
# 15  [disability, disclosure, students, who, disclo...
# 16  [a, disability, support, summary, dss, may, be...
# 17  [it, is, expected, that, staff, will, engage, ...
# 18  [students, can, disclose, a, disability, at, a...
# 19  [the, reasonable, adjustment, duty, applies, t...
# 20  [a, disabled, student, ha, a, right, to, reque...
# 21  [in, such, case, the, recommended, support, ca...
# 22  [in, some, instance, this, will, limit, the, u...
# 23                                                 []
# 24  [responsibilities, the, university, board, of,...
# 25  [as, such, all, university, staff, are, expect...
# 26  [the, success, of, the, support, that, both, t...
# 27  [the, general, expectation, is, that, the, stu...
# 28  [version, august, page, of, year, of, entry, u...
# 29  [scope, this, document, applies, to, all, staf...
# 30  [for, applicant, entering, in, applies, to, ac...
# 31  [disability, services, manager, type, policy, ...

# %%
# set display options to show all columns and rows in the dataframe so i can quickly scan through
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# display the dataframe
print(p1)
# Out:
#                                              Sentence
# 0   [version, august, page, of, year, of, entry, u...
# 1   [introduction, the, university, of, bristol, i...
# 2   [as, a, provider, of, education, we, value, th...
# 3   [we, aim, to, create, an, environment, where, ...
# 4                                                  []
# 5   [legal, context, for, the, purpose, of, this, ...
# 6                                                  []
# 7   [the, reasonab, le, adjustment, duty, the, equ...
# 8   [this, duty, is, also, anticipatory, meaning, ...
# 9   [further, detail, about, reasonable, adjustmen...
# 10  [the, term, provision, criterion, or, practice...
# 11  [in, determining, what, is, reasonable, the, u...
# 12  [consideration, will, be, given, to, adjusting...
# 13  [in, determining, what, is, reasonable, in, ea...
# 14  [version, august, page, of, year, of, entry, w...
# 15  [disability, disclosure, students, who, disclo...
# 16  [a, disability, support, summary, dss, may, be...
# 17  [it, is, expected, that, staff, will, engage, ...
# 18  [students, can, disclose, a, disability, at, a...
# 19  [the, reasonable, adjustment, duty, applies, t...
# 20  [a, disabled, student, ha, a, right, to, reque...
# 21  [in, such, case, the, recommended, support, ca...
# 22  [in, some, instance, this, will, limit, the, u...
# 23                                                 []
# 24  [responsibilities, the, university, board, of,...
# 25  [as, such, all, university, staff, are, expect...
# 26  [the, success, of, the, support, that, both, t...
# 27  [the, general, expectation, is, that, the, stu...
# 28  [version, august, page, of, year, of, entry, u...
# 29  [scope, this, document, applies, to, all, staf...
# 30  [for, applicant, entering, in, applies, to, ac...
# 31  [disability, services, manager, type, policy, ...

# %%
# Doing so helped me notice that there are a bunch of empty lists, so we will remove those now
# find rows with empty lists in the 'Sentence' column
rows_with_empty_lists = p1[p1['Sentence'].apply(len) == 0]

# display rows with empty lists
print(rows_with_empty_lists)
# Out:
#    Sentence
# 4        []
# 6        []
# 23       []

# %%
# remove rows with empty lists in the 'Sentence' column
p1 = p1[p1['Sentence'].apply(len) > 0]

# reset index
p1.reset_index(drop=True, inplace=True)

# display the modified DataFrame
print(p1)
# Out:
#                                              Sentence
# 0   [version, august, page, of, year, of, entry, u...
# 1   [introduction, the, university, of, bristol, i...
# 2   [as, a, provider, of, education, we, value, th...
# 3   [we, aim, to, create, an, environment, where, ...
# 4   [legal, context, for, the, purpose, of, this, ...
# 5   [the, reasonab, le, adjustment, duty, the, equ...
# 6   [this, duty, is, also, anticipatory, meaning, ...
# 7   [further, detail, about, reasonable, adjustmen...
# 8   [the, term, provision, criterion, or, practice...
# 9   [in, determining, what, is, reasonable, the, u...
# 10  [consideration, will, be, given, to, adjusting...
# 11  [in, determining, what, is, reasonable, in, ea...
# 12  [version, august, page, of, year, of, entry, w...
# 13  [disability, disclosure, students, who, disclo...
# 14  [a, disability, support, summary, dss, may, be...
# 15  [it, is, expected, that, staff, will, engage, ...
# 16  [students, can, disclose, a, disability, at, a...
# 17  [the, reasonable, adjustment, duty, applies, t...
# 18  [a, disabled, student, ha, a, right, to, reque...
# 19  [in, such, case, the, recommended, support, ca...
# 20  [in, some, instance, this, will, limit, the, u...
# 21  [responsibilities, the, university, board, of,...
# 22  [as, such, all, university, staff, are, expect...
# 23  [the, success, of, the, support, that, both, t...
# 24  [the, general, expectation, is, that, the, stu...
# 25  [version, august, page, of, year, of, entry, u...
# 26  [scope, this, document, applies, to, all, staf...
# 27  [for, applicant, entering, in, applies, to, ac...
# 28  [disability, services, manager, type, policy, ...

# %%
# just to check it is still all good in this format too (can't be too careful)
p1
# Out:
#                                              Sentence
# 0   [version, august, page, of, year, of, entry, u...
# 1   [introduction, the, university, of, bristol, i...
# 2   [as, a, provider, of, education, we, value, th...
# 3   [we, aim, to, create, an, environment, where, ...
# 4   [legal, context, for, the, purpose, of, this, ...
# 5   [the, reasonab, le, adjustment, duty, the, equ...
# 6   [this, duty, is, also, anticipatory, meaning, ...
# 7   [further, detail, about, reasonable, adjustmen...
# 8   [the, term, provision, criterion, or, practice...
# 9   [in, determining, what, is, reasonable, the, u...
# 10  [consideration, will, be, given, to, adjusting...
# 11  [in, determining, what, is, reasonable, in, ea...
# 12  [version, august, page, of, year, of, entry, w...
# 13  [disability, disclosure, students, who, disclo...
# 14  [a, disability, support, summary, dss, may, be...
# 15  [it, is, expected, that, staff, will, engage, ...
# 16  [students, can, disclose, a, disability, at, a...
# 17  [the, reasonable, adjustment, duty, applies, t...
# 18  [a, disabled, student, ha, a, right, to, reque...
# 19  [in, such, case, the, recommended, support, ca...
# 20  [in, some, instance, this, will, limit, the, u...
# 21  [responsibilities, the, university, board, of,...
# 22  [as, such, all, university, staff, are, expect...
# 23  [the, success, of, the, support, that, both, t...
# 24  [the, general, expectation, is, that, the, stu...
# 25  [version, august, page, of, year, of, entry, u...
# 26  [scope, this, document, applies, to, all, staf...
# 27  [for, applicant, entering, in, applies, to, ac...
# 28  [disability, services, manager, type, policy, ...

# %%
# save the dataset to be able to use in analysis

#export to excel file
p1.to_excel('p1.xlsx')

#export to csv file
p1.to_csv('p1.csv', index=False)
