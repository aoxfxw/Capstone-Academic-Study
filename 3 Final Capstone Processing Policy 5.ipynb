# %%
#import all the necessary packages

import pandas as pd
import random

import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk import stem
stemmer = stem.PorterStemmer()
from nltk import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))
import string
punct = list(string.punctuation)
from collections import Counter
import requests
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import numpy as np
import praw
import datetime
import json
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aoife\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import PyPDF2

# %%
# open the PDF file
policy = open(r'C:\Users\aoife\Documents\Capstone\Capstone Quant Policies\Regents Disability.pdf', 'rb')

# create a PDF reader object
pdf_reader = PyPDF2.PdfReader(policy)

# %%
# read the text from each page
text = ''
for page_num in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[page_num]
    text += page.extract_text()

# close the PDF file
policy.close()

# %%
# split the text into sentences
sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)

# create a dataframe with the sentences as rows
df = pd.DataFrame({'Sentence': sentences})

# %%
df
# Out:
#                                              Sentence
# 0    \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ...
# 1   Aims and objectives  \nThe aim of this policy ...
# 2    \nThe University works with the Equality Act’...
# 3                                          \n \n \n2.
# 4   Guiding  principles  \n \nThe Student Disabili...
# 5   The policy is based on the social model of dis...
# 6                                          \n \n \n3.
# 7   Policy  statement  \n \nRegent's University Lo...
# 8    \n \nAll staff and students at Regent's Unive...
# 9    Student Disability Policy \nDisability Servic...
# 10  Implementation of this  policy  \n \nAll staff...
# 11  \nThis policy will be available to all staff a...
# 12                                         \n \n \n5.
# 13  Procedure and Process  \n \nA student with a d...
# 14  Information on disability  disclosure procedur...
# 15  Students are advised to contact the Student Di...
# 16  A student with a disability is usually require...
# 17   \n \nIf adjustments are agreed, a Student Sup...
# 18  Students are responsible for s ending their St...
# 19                                         \n \n \n6.
# 20  Measurement of policy’s  success  \n \nFeedbac...
# 21  Any student complaints that relate to \ndisabi...
# 22  The measures of \nsuccess for this policy will...
# 23   \nThe Student Dis ability and Mental Health C...
# 24  Review \nwill take place at a minimum on an an...
# 25                                         \n \n \n7.
# 26  Monitoring of the policy  \n \nThe Student D i...
# 27   Student Disability Policy \nDisability Servic...
# 28  Review of the policy  \n \nThe policy will be ...
# 29

# %%
#check to see if any rows are empty
rows_with_nan = df[df.isna().any(axis=1)]

len(rows_with_nan)
# Out:
# 0

# %%
#check the length of the dataframe
len(df)
# Out:
# 30

# %%
# convert each row in the dataframe to a string and then convert the datadrame to a list of strings
p1 = df.apply(lambda row: ' '.join(row.astype(str)), axis=1).tolist()

# %%
p1
# Out:
# [' \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nStudent Disability Policy  \nAuthor: Disability Officer  \nApproved by: Directorate on 20th June 2011  \nVersion: 5 Reviewed and approved by Senate July 2018 \nUpdated: Disability Services Committee May 2020  \nVersion: 6 Reviewed and approved by Senate July 2020  Student Disability Policy \nDisability Services Committee  Page 2  \n  \n \n \n \n \nStudent Disability Policy  \n \n \n1.',
#  'Aims and objectives  \nThe aim of this policy is:  \n \nTo embed a culture of inclusion for students with disabilities.',
#  ' \nThe University works with the Equality Act’s (2010) definition of a disabled person: \n‘A person has a disability if they have a physical or mental impairment that has a  \nsubstantial and long -term adverse effect on his or her ability to carry out normal day -to- \nday activities.’  \nThe objectives of this policy are:  \n \n• To commit to having an inclusive environment, which facilitates disclosure of \ndisability and gives all applicants and students the opportunity to  demonstrate \nand realise their full  potential;  \n• To provide fa ir and equal treatment of all applicants and  students;  \n• To comply  with the legislative  requirements  under  the Equality  Act (2010), \nin particular the need to avoid discrimination and to provide reasonable \nadjustments for disabled  students.',
#  ' \n \n \n2.',
#  'Guiding  principles  \n \nThe Student Disability Policy is concerned primarily with ensuring that students with disabilities \nare given fair and equal treatment so that they have the opportunity to demonstrate and realise \ntheir full potential.',
#  'The policy is based on the social model of disability.',
#  ' \n \n \n3.',
#  "Policy  statement  \n \nRegent's University London will ensure:  \n \n• That the requirements of those students who disclose a disability  are \nassessed on an individual  basis;  \n• That all discussions  and information  regarding a  disability  are treated  in a \nconfidential manner and abide by the University's confidentiality  policy;  \n• In the case of non -standard adjustments for disabled students, the Heads of \nProgrammes will be involved in any discussions regarding adjustments to \nensure  that academic rigour is maintained and that the necessary  resources \nare available.",
#  " \n \nAll staff and students at Regent's University London are expected to be \nresponsible for implementing this policy.",
#  ' Student Disability Policy \nDisability Services Committee  Page 3  \n  \n \n \n \n \n4.',
#  'Implementation of this  policy  \n \nAll staff at Regent’s University London are expected to be responsible for implementing this policy.',
#  '\nThis policy will be available to all staff and students and will be monitored by the Senate Student \nExperience Committee (SSEC).',
#  ' \n \n \n5.',
#  'Procedure and Process  \n \nA student with a disability is encouraged to disclose their disability at an early stage, such as \napplication or enrolment.',
#  'Information on disability  disclosure procedure is available on the \nUniversity’s website.',
#  'Students are advised to contact the Student Disability and Mental Health \nCoordinator so their support can be arranged.',
#  'A student with a disability is usually required to \nprovide written eviden ce of their disability (such as an educational psychologist’s report) if they are \nrequesting any reasonable adjustments.',
#  ' \n \nIf adjustments are agreed, a Student Support Agreement (SSA) will be completed and sent to \nthe student.',
#  'Students are responsible for s ending their Student Support Agreement to \nrelevant staff, so that they are aware of their needs and to ensure that any necessary \nadjustments are put in place.',
#  ' \n \n \n6.',
#  'Measurement of policy’s  success  \n \nFeedback from disabled students will be sought by the University and passed on to the \nStudent Disability and Mental Health Coordinator.',
#  'Any student complaints that relate to \ndisability issues should be directed to the Student Disability and Mental Health Coordinator, \neither on an individual basis or via the D isability Services Committee.',
#  'The measures of \nsuccess for this policy will be a decrease in the number of complaints regarding disability \nmatters, as well as an increase in the amount of positive feedback received from one year \nto the next.',
#  ' \nThe Student Dis ability and Mental Health Coordinator will liaise with individual students in \norder to review the success of adjustments agreed in Student Support Agreements.',
#  'Review \nwill take place at a minimum on an annual basis.',
#  ' \n \n \n7.',
#  'Monitoring of the policy  \n \nThe Student D isability and Mental Health Coordinator will collate feedback received \nfrom disabled students, in order to monitor the effectiveness of the policy, and will \nreport findings to the Disability Services Committee.',
#  ' Student Disability Policy \nDisability Services Committee  Page 4  \n  \n \n \n \n \n8.',
#  'Review of the policy  \n \nThe policy will be reviewed on a regular basis at the Disability Services \nCommittee, where any amendments or improvements will be discussed.',
#  ' ']

# %%
# define a function to remove punctuation and numbers from a string
def remove_punctuation_and_numbers(text):
    # define a regular expression pattern to match punctuation characters and numbers
    pattern = r'[^A-Za-z\s]'
    # replace punctuation characters and numbers with an empty string
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

# apply the previously created function to each string in the list
cleaned_p1 = [remove_punctuation_and_numbers(string) for string in p1]

# display the cleaned list of strings
print(cleaned_p1)
# Out:
# [' \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nStudent Disability Policy  \nAuthor Disability Officer  \nApproved by Directorate on th June   \nVersion  Reviewed and approved by Senate July  \nUpdated Disability Services Committee May   \nVersion  Reviewed and approved by Senate July   Student Disability Policy \nDisability Services Committee  Page   \n  \n \n \n \n \nStudent Disability Policy  \n \n \n', 'Aims and objectives  \nThe aim of this policy is  \n \nTo embed a culture of inclusion for students with disabilities', ' \nThe University works with the Equality Acts  definition of a disabled person \nA person has a disability if they have a physical or mental impairment that has a  \nsubstantial and long term adverse effect on his or her ability to carry out normal day to \nday activities  \nThe objectives of this policy are  \n \n To commit to having an inclusive environment which facilitates disclosure of \ndisability and gives all applicants and students the opportunity to  demonstrate \nand realise their full  potential  \n To provide fa ir and equal treatment of all applicants and  students  \n To comply  with the legislative  requirements  under  the Equality  Act  \nin particular the need to avoid discrimination and to provide reasonable \nadjustments for disabled  students', ' \n \n \n', 'Guiding  principles  \n \nThe Student Disability Policy is concerned primarily with ensuring that students with disabilities \nare given fair and equal treatment so that they have the opportunity to demonstrate and realise \ntheir full potential', 'The policy is based on the social model of disability', ' \n \n \n', 'Policy  statement  \n \nRegents University London will ensure  \n \n That the requirements of those students who disclose a disability  are \nassessed on an individual  basis  \n That all discussions  and information  regarding a  disability  are treated  in a \nconfidential manner and abide by the Universitys confidentiality  policy  \n In the case of non standard adjustments for disabled students the Heads of \nProgrammes will be involved in any discussions regarding adjustments to \nensure  that academic rigour is maintained and that the necessary  resources \nare available', ' \n \nAll staff and students at Regents University London are expected to be \nresponsible for implementing this policy', ' Student Disability Policy \nDisability Services Committee  Page   \n  \n \n \n \n \n', 'Implementation of this  policy  \n \nAll staff at Regents University London are expected to be responsible for implementing this policy', '\nThis policy will be available to all staff and students and will be monitored by the Senate Student \nExperience Committee SSEC', ' \n \n \n', 'Procedure and Process  \n \nA student with a disability is encouraged to disclose their disability at an early stage such as \napplication or enrolment', 'Information on disability  disclosure procedure is available on the \nUniversitys website', 'Students are advised to contact the Student Disability and Mental Health \nCoordinator so their support can be arranged', 'A student with a disability is usually required to \nprovide written eviden ce of their disability such as an educational psychologists report if they are \nrequesting any reasonable adjustments', ' \n \nIf adjustments are agreed a Student Support Agreement SSA will be completed and sent to \nthe student', 'Students are responsible for s ending their Student Support Agreement to \nrelevant staff so that they are aware of their needs and to ensure that any necessary \nadjustments are put in place', ' \n \n \n', 'Measurement of policys  success  \n \nFeedback from disabled students will be sought by the University and passed on to the \nStudent Disability and Mental Health Coordinator', 'Any student complaints that relate to \ndisability issues should be directed to the Student Disability and Mental Health Coordinator \neither on an indivi ...

# %%
# tokenize each string in the list of strings
tokenized_p1 = [word_tokenize(string) for string in cleaned_p1]

# display the tokenized list of strings
print(tokenized_p1)
# Out:
# [['Student', 'Disability', 'Policy', 'Author', 'Disability', 'Officer', 'Approved', 'by', 'Directorate', 'on', 'th', 'June', 'Version', 'Reviewed', 'and', 'approved', 'by', 'Senate', 'July', 'Updated', 'Disability', 'Services', 'Committee', 'May', 'Version', 'Reviewed', 'and', 'approved', 'by', 'Senate', 'July', 'Student', 'Disability', 'Policy', 'Disability', 'Services', 'Committee', 'Page', 'Student', 'Disability', 'Policy'], ['Aims', 'and', 'objectives', 'The', 'aim', 'of', 'this', 'policy', 'is', 'To', 'embed', 'a', 'culture', 'of', 'inclusion', 'for', 'students', 'with', 'disabilities'], ['The', 'University', 'works', 'with', 'the', 'Equality', 'Acts', 'definition', 'of', 'a', 'disabled', 'person', 'A', 'person', 'has', 'a', 'disability', 'if', 'they', 'have', 'a', 'physical', 'or', 'mental', 'impairment', 'that', 'has', 'a', 'substantial', 'and', 'long', 'term', 'adverse', 'effect', 'on', 'his', 'or', 'her', 'ability', 'to', 'carry', 'out', 'normal', 'day', 'to', 'day', 'activities', 'The', 'objectives', 'of', 'this', 'policy', 'are', 'To', 'commit', 'to', 'having', 'an', 'inclusive', 'environment', 'which', 'facilitates', 'disclosure', 'of', 'disability', 'and', 'gives', 'all', 'applicants', 'and', 'students', 'the', 'opportunity', 'to', 'demonstrate', 'and', 'realise', 'their', 'full', 'potential', 'To', 'provide', 'fa', 'ir', 'and', 'equal', 'treatment', 'of', 'all', 'applicants', 'and', 'students', 'To', 'comply', 'with', 'the', 'legislative', 'requirements', 'under', 'the', 'Equality', 'Act', 'in', 'particular', 'the', 'need', 'to', 'avoid', 'discrimination', 'and', 'to', 'provide', 'reasonable', 'adjustments', 'for', 'disabled', 'students'], [], ['Guiding', 'principles', 'The', 'Student', 'Disability', 'Policy', 'is', 'concerned', 'primarily', 'with', 'ensuring', 'that', 'students', 'with', 'disabilities', 'are', 'given', 'fair', 'and', 'equal', 'treatment', 'so', 'that', 'they', 'have', 'the', 'opportunity', 'to', 'demonstrate', 'and', 'realise', 'their', 'full', 'potential'], ['The', 'policy', 'is', 'based', 'on', 'the', 'social', 'model', 'of', 'disability'], [], ['Policy', 'statement', 'Regents', 'University', 'London', 'will', 'ensure', 'That', 'the', 'requirements', 'of', 'those', 'students', 'who', 'disclose', 'a', 'disability', 'are', 'assessed', 'on', 'an', 'individual', 'basis', 'That', 'all', 'discussions', 'and', 'information', 'regarding', 'a', 'disability', 'are', 'treated', 'in', 'a', 'confidential', 'manner', 'and', 'abide', 'by', 'the', 'Universitys', 'confidentiality', 'policy', 'In', 'the', 'case', 'of', 'non', 'standard', 'adjustments', 'for', 'disabled', 'students', 'the', 'Heads', 'of', 'Programmes', 'will', 'be', 'involved', 'in', 'any', 'discussions', 'regarding', 'adjustments', 'to', 'ensure', 'that', 'academic', 'rigour', 'is', 'maintained', 'and', 'that', 'the', 'necessary', 'resources', 'are', 'available'], ['All', 'staff', 'and', 'students', 'at', 'Regents', 'University', 'London', 'are', 'expected', 'to', 'be', 'responsible', 'for', 'implementing', 'this', 'policy'], ['Student', 'Disability', 'Policy', 'Disability', 'Services', 'Committee', 'Page'], ['Implementation', 'of', 'this', 'policy', 'All', 'staff', 'at', 'Regents', 'University', 'London', 'are', 'expected', 'to', 'be', 'responsible', 'for', 'implementing', 'this', 'policy'], ['This', 'policy', 'will', 'be', 'available', 'to', 'all', 'staff', 'and', 'students', 'and', 'will', 'be', 'monitored', 'by', 'the', 'Senate', 'Student', 'Experience', 'Committee', 'SSEC'], [], ['Procedure', 'and', 'Process', 'A', 'student', 'with', 'a', 'disability', 'is', 'encouraged', 'to', 'disclose', 'their', 'disability', 'at', 'an', 'early', 'stage', 'such', 'as', 'application', 'or', 'enrolment'], ['Information', 'on', 'disability', 'disclosure', 'procedure', 'is', 'available', 'on', 'the', 'Universitys', 'website'], ['Students', 'are', 'advised', 'to', 'contact', 'the', 'Student', 'Disability', 'and', 'Mental', 'Health', 'Coordinator', 'so', 'the ...

# %%
# as some strings are now empty, remove empty strings from a list of strings
cleaned_list_of_strings = [string for string in tokenized_p1 if string]

# and just in case that doesn't work,, remove empty strings from a list of lists of strings
cleaned_tokenized_p1 = [[token for token in tokens if token] for tokens in tokenized_p1]

# %%
cleaned_tokenized_p1
# Out:
# [['Student',
#   'Disability',
#   'Policy',
#   'Author',
#   'Disability',
#   'Officer',
#   'Approved',
#   'by',
#   'Directorate',
#   'on',
#   'th',
#   'June',
#   'Version',
#   'Reviewed',
#   'and',
#   'approved',
#   'by',
#   'Senate',
#   'July',
#   'Updated',
#   'Disability',
#   'Services',
#   'Committee',
#   'May',
#   'Version',
#   'Reviewed',
#   'and',
#   'approved',
#   'by',
#   'Senate',
#   'July',
#   'Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page',
#   'Student',
#   'Disability',
#   'Policy'],
#  ['Aims',
#   'and',
#   'objectives',
#   'The',
#   'aim',
#   'of',
#   'this',
#   'policy',
#   'is',
#   'To',
#   'embed',
#   'a',
#   'culture',
#   'of',
#   'inclusion',
#   'for',
#   'students',
#   'with',
#   'disabilities'],
#  ['The',
#   'University',
#   'works',
#   'with',
#   'the',
#   'Equality',
#   'Acts',
#   'definition',
#   'of',
#   'a',
#   'disabled',
#   'person',
#   'A',
#   'person',
#   'has',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'that',
#   'has',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'his',
#   'or',
#   'her',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'to',
#   'day',
#   'activities',
#   'The',
#   'objectives',
#   'of',
#   'this',
#   'policy',
#   'are',
#   'To',
#   'commit',
#   'to',
#   'having',
#   'an',
#   'inclusive',
#   'environment',
#   'which',
#   'facilitates',
#   'disclosure',
#   'of',
#   'disability',
#   'and',
#   'gives',
#   'all',
#   'applicants',
#   'and',
#   'students',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential',
#   'To',
#   'provide',
#   'fa',
#   'ir',
#   'and',
#   'equal',
#   'treatment',
#   'of',
#   'all',
#   'applicants',
#   'and',
#   'students',
#   'To',
#   'comply',
#   'with',
#   'the',
#   'legislative',
#   'requirements',
#   'under',
#   'the',
#   'Equality',
#   'Act',
#   'in',
#   'particular',
#   'the',
#   'need',
#   'to',
#   'avoid',
#   'discrimination',
#   'and',
#   'to',
#   'provide',
#   'reasonable',
#   'adjustments',
#   'for',
#   'disabled',
#   'students'],
#  [],
#  ['Guiding',
#   'principles',
#   'The',
#   'Student',
#   'Disability',
#   'Policy',
#   'is',
#   'concerned',
#   'primarily',
#   'with',
#   'ensuring',
#   'that',
#   'students',
#   'with',
#   'disabilities',
#   'are',
#   'given',
#   'fair',
#   'and',
#   'equal',
#   'treatment',
#   'so',
#   'that',
#   'they',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential'],
#  ['The',
#   'policy',
#   'is',
#   'based',
#   'on',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability'],
#  [],
#  ['Policy',
#   'statement',
#   'Regents',
#   'University',
#   'London',
#   'will',
#   'ensure',
#   'That',
#   'the',
#   'requirements',
#   'of',
#   'those',
#   'students',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'are',
#   'assessed',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'That',
#   'all',
#   'discussions',
#   'and',
#   'information',
#   'regarding',
#   'a',
#   'disability',
#   'are',
#   'treated',
#   'in',
#   'a',
#   'confidential',
#   'manner',
#   'and',
#   'abide',
#   'by',
#   'the',
#   'Universitys',
#   'confidentiality',
#   'policy',
#   'In',
#   'the',
#   'case',
#   'of',
#   'non',
#   'standard',
#   'adjustments',
#   'for',
#   'disabled',
#   'students',
#   'the',
#   'Heads',
#   'of',
#   'Programmes',
#   'will',
#   'be',
#   'involved',
#   'in',
#   'any',
#   'discussions',
#   'regarding',
#   'adjustments',
#   'to',
#   'ensure',
#   'that',
#   'academic',
#   'rigour',
#   'is',
#   'maintained',
#   'and',
#   'that',
#   'the',
#   'necessary',
#   'resources',
#   'are',
#   'available'],
#  ['All',
#   'staff',
#   'and',
#   'students',
#   'at',
#   'Regents',
#   'University',
#   'London',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page'],
#  ['Implementation',
#   'of',
#   'this',
#   'policy',
#   'All',
#   'staff',
#   'at',
#   'Regents',
#   'University',
#   'London',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['This',
#   'policy',
#   'will',
#   'be',
#   'available',
#   'to',
#   'all',
#   'staff',
#   'and',
#   'students',
#   'and',
#   'will',
#   'be',
#   'monitored',
#   'by',
#   'the',
#   'Senate',
#   'Student',
#   'Experience',
#   'Committee',
#   'SSEC'],
#  [],
#  ['Procedure',
#   'and',
#   'Process',
#   'A',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'encouraged',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'at',
#   'an',
#   'early',
#   'stage',
#   'such',
#   'as',
#   'application',
#   'or',
#   'enrolment'],
#  ['Information',
#   'on',
#   'disability',
#   'disclosure',
#   'procedure',
#   'is',
#   'available',
#   'on',
#   'the',
#   'Universitys',
#   'website'],
#  ['Students',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'so',
#   'their',
#   'support',
#   'can',
#   'be',
#   'arranged'],
#  ['A',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'usually',
#   'required',
#   'to',
#   'provide',
#   'written',
#   'eviden',
#   'ce',
#   'of',
#   'their',
#   'disability',
#   'such',
#   'as',
#   'an',
#   'educational',
#   'psychologists',
#   'report',
#   'if',
#   'they',
#   'are',
#   'requesting',
#   'any',
#   'reasonable',
#   'adjustments'],
#  ['If',
#   'adjustments',
#   'are',
#   'agreed',
#   'a',
#   'Student',
#   'Support',
#   'Agreement',
#   'SSA',
#   'will',
#   'be',
#   'completed',
#   'and',
#   'sent',
#   'to',
#   'the',
#   'student'],
#  ['Students',
#   'are',
#   'responsible',
#   'for',
#   's',
#   'ending',
#   'their',
#   'Student',
#   'Support',
#   'Agreement',
#   'to',
#   'relevant',
#   'staff',
#   'so',
#   'that',
#   'they',
#   'are',
#   'aware',
#   'of',
#   'their',
#   'needs',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'necessary',
#   'adjustments',
#   'are',
#   'put',
#   'in',
#   'place'],
#  [],
#  ['Measurement',
#   'of',
#   'policys',
#   'success',
#   'Feedback',
#   'from',
#   'disabled',
#   'students',
#   'will',
#   'be',
#   'sought',
#   'by',
#   'the',
#   'University',
#   'and',
#   'passed',
#   'on',
#   'to',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator'],
#  ['Any',
#   'student',
#   'complaints',
#   'that',
#   'relate',
#   'to',
#   'disability',
#   'issues',
#   'should',
#   'be',
#   'directed',
#   'to',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'either',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'or',
#   'via',
#   'the',
#   'D',
#   'isability',
#   'Services',
#   'Committee'],
#  ['The',
#   'measures',
#   'of',
#   'success',
#   'for',
#   'this',
#   'policy',
#   'will',
#   'be',
#   'a',
#   'decrease',
#   'in',
#   'the',
#   'number',
#   'of',
#   'complaints',
#   'regarding',
#   'disability',
#   'matters',
#   'as',
#   'well',
#   'as',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'positive',
#   'feedback',
#   'received',
#   'from',
#   'one',
#   'year',
#   'to',
#   'the',
#   'next'],
#  ['The',
#   'Student',
#   'Dis',
#   'ability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'will',
#   'liaise',
#   'with',
#   'individual',
#   'students',
#   'in',
#   'order',
#   'to',
#   'review',
#   'the',
#   'success',
#   'of',
#   'adjustments',
#   'agreed',
#   'in',
#   'Student',
#   'Support',
#   'Agreements'],
#  ['Review',
#   'will',
#   'take',
#   'place',
#   'at',
#   'a',
#   'minimum',
#   'on',
#   'an',
#   'annual',
#   'basis'],
#  [],
#  ['Monitoring',
#   'of',
#   'the',
#   'policy',
#   'The',
#   'Student',
#   'D',
#   'isability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'will',
#   'collate',
#   'feedback',
#   'received',
#   'from',
#   'disabled',
#   'students',
#   'in',
#   'order',
#   'to',
#   'monitor',
#   'the',
#   'effectiveness',
#   'of',
#   'the',
#   'policy',
#   'and',
#   'will',
#   'report',
#   'findings',
#   'to',
#   'the',
#   'Disability',
#   'Services',
#   'Committee'],
#  ['Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page'],
#  ['Review',
#   'of',
#   'the',
#   'policy',
#   'The',
#   'policy',
#   'will',
#   'be',
#   'reviewed',
#   'on',
#   'a',
#   'regular',
#   'basis',
#   'at',
#   'the',
#   'Disability',
#   'Services',
#   'Committee',
#   'where',
#   'any',
#   'amendments',
#   'or',
#   'improvements',
#   'will',
#   'be',
#   'discussed'],
#  []]

# %%
#lemmatize
postlemma = []

for i in cleaned_tokenized_p1: 
    postlemma.append([lemmatizer.lemmatize(j) for j in i])

# %%
postlemma
# Out:
# [['Student',
#   'Disability',
#   'Policy',
#   'Author',
#   'Disability',
#   'Officer',
#   'Approved',
#   'by',
#   'Directorate',
#   'on',
#   'th',
#   'June',
#   'Version',
#   'Reviewed',
#   'and',
#   'approved',
#   'by',
#   'Senate',
#   'July',
#   'Updated',
#   'Disability',
#   'Services',
#   'Committee',
#   'May',
#   'Version',
#   'Reviewed',
#   'and',
#   'approved',
#   'by',
#   'Senate',
#   'July',
#   'Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page',
#   'Student',
#   'Disability',
#   'Policy'],
#  ['Aims',
#   'and',
#   'objective',
#   'The',
#   'aim',
#   'of',
#   'this',
#   'policy',
#   'is',
#   'To',
#   'embed',
#   'a',
#   'culture',
#   'of',
#   'inclusion',
#   'for',
#   'student',
#   'with',
#   'disability'],
#  ['The',
#   'University',
#   'work',
#   'with',
#   'the',
#   'Equality',
#   'Acts',
#   'definition',
#   'of',
#   'a',
#   'disabled',
#   'person',
#   'A',
#   'person',
#   'ha',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'that',
#   'ha',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'his',
#   'or',
#   'her',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'to',
#   'day',
#   'activity',
#   'The',
#   'objective',
#   'of',
#   'this',
#   'policy',
#   'are',
#   'To',
#   'commit',
#   'to',
#   'having',
#   'an',
#   'inclusive',
#   'environment',
#   'which',
#   'facilitates',
#   'disclosure',
#   'of',
#   'disability',
#   'and',
#   'give',
#   'all',
#   'applicant',
#   'and',
#   'student',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential',
#   'To',
#   'provide',
#   'fa',
#   'ir',
#   'and',
#   'equal',
#   'treatment',
#   'of',
#   'all',
#   'applicant',
#   'and',
#   'student',
#   'To',
#   'comply',
#   'with',
#   'the',
#   'legislative',
#   'requirement',
#   'under',
#   'the',
#   'Equality',
#   'Act',
#   'in',
#   'particular',
#   'the',
#   'need',
#   'to',
#   'avoid',
#   'discrimination',
#   'and',
#   'to',
#   'provide',
#   'reasonable',
#   'adjustment',
#   'for',
#   'disabled',
#   'student'],
#  [],
#  ['Guiding',
#   'principle',
#   'The',
#   'Student',
#   'Disability',
#   'Policy',
#   'is',
#   'concerned',
#   'primarily',
#   'with',
#   'ensuring',
#   'that',
#   'student',
#   'with',
#   'disability',
#   'are',
#   'given',
#   'fair',
#   'and',
#   'equal',
#   'treatment',
#   'so',
#   'that',
#   'they',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential'],
#  ['The',
#   'policy',
#   'is',
#   'based',
#   'on',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability'],
#  [],
#  ['Policy',
#   'statement',
#   'Regents',
#   'University',
#   'London',
#   'will',
#   'ensure',
#   'That',
#   'the',
#   'requirement',
#   'of',
#   'those',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'are',
#   'assessed',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'That',
#   'all',
#   'discussion',
#   'and',
#   'information',
#   'regarding',
#   'a',
#   'disability',
#   'are',
#   'treated',
#   'in',
#   'a',
#   'confidential',
#   'manner',
#   'and',
#   'abide',
#   'by',
#   'the',
#   'Universitys',
#   'confidentiality',
#   'policy',
#   'In',
#   'the',
#   'case',
#   'of',
#   'non',
#   'standard',
#   'adjustment',
#   'for',
#   'disabled',
#   'student',
#   'the',
#   'Heads',
#   'of',
#   'Programmes',
#   'will',
#   'be',
#   'involved',
#   'in',
#   'any',
#   'discussion',
#   'regarding',
#   'adjustment',
#   'to',
#   'ensure',
#   'that',
#   'academic',
#   'rigour',
#   'is',
#   'maintained',
#   'and',
#   'that',
#   'the',
#   'necessary',
#   'resource',
#   'are',
#   'available'],
#  ['All',
#   'staff',
#   'and',
#   'student',
#   'at',
#   'Regents',
#   'University',
#   'London',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page'],
#  ['Implementation',
#   'of',
#   'this',
#   'policy',
#   'All',
#   'staff',
#   'at',
#   'Regents',
#   'University',
#   'London',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['This',
#   'policy',
#   'will',
#   'be',
#   'available',
#   'to',
#   'all',
#   'staff',
#   'and',
#   'student',
#   'and',
#   'will',
#   'be',
#   'monitored',
#   'by',
#   'the',
#   'Senate',
#   'Student',
#   'Experience',
#   'Committee',
#   'SSEC'],
#  [],
#  ['Procedure',
#   'and',
#   'Process',
#   'A',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'encouraged',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'at',
#   'an',
#   'early',
#   'stage',
#   'such',
#   'a',
#   'application',
#   'or',
#   'enrolment'],
#  ['Information',
#   'on',
#   'disability',
#   'disclosure',
#   'procedure',
#   'is',
#   'available',
#   'on',
#   'the',
#   'Universitys',
#   'website'],
#  ['Students',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'so',
#   'their',
#   'support',
#   'can',
#   'be',
#   'arranged'],
#  ['A',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'usually',
#   'required',
#   'to',
#   'provide',
#   'written',
#   'eviden',
#   'ce',
#   'of',
#   'their',
#   'disability',
#   'such',
#   'a',
#   'an',
#   'educational',
#   'psychologist',
#   'report',
#   'if',
#   'they',
#   'are',
#   'requesting',
#   'any',
#   'reasonable',
#   'adjustment'],
#  ['If',
#   'adjustment',
#   'are',
#   'agreed',
#   'a',
#   'Student',
#   'Support',
#   'Agreement',
#   'SSA',
#   'will',
#   'be',
#   'completed',
#   'and',
#   'sent',
#   'to',
#   'the',
#   'student'],
#  ['Students',
#   'are',
#   'responsible',
#   'for',
#   's',
#   'ending',
#   'their',
#   'Student',
#   'Support',
#   'Agreement',
#   'to',
#   'relevant',
#   'staff',
#   'so',
#   'that',
#   'they',
#   'are',
#   'aware',
#   'of',
#   'their',
#   'need',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'necessary',
#   'adjustment',
#   'are',
#   'put',
#   'in',
#   'place'],
#  [],
#  ['Measurement',
#   'of',
#   'policy',
#   'success',
#   'Feedback',
#   'from',
#   'disabled',
#   'student',
#   'will',
#   'be',
#   'sought',
#   'by',
#   'the',
#   'University',
#   'and',
#   'passed',
#   'on',
#   'to',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator'],
#  ['Any',
#   'student',
#   'complaint',
#   'that',
#   'relate',
#   'to',
#   'disability',
#   'issue',
#   'should',
#   'be',
#   'directed',
#   'to',
#   'the',
#   'Student',
#   'Disability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'either',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'or',
#   'via',
#   'the',
#   'D',
#   'isability',
#   'Services',
#   'Committee'],
#  ['The',
#   'measure',
#   'of',
#   'success',
#   'for',
#   'this',
#   'policy',
#   'will',
#   'be',
#   'a',
#   'decrease',
#   'in',
#   'the',
#   'number',
#   'of',
#   'complaint',
#   'regarding',
#   'disability',
#   'matter',
#   'a',
#   'well',
#   'a',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'positive',
#   'feedback',
#   'received',
#   'from',
#   'one',
#   'year',
#   'to',
#   'the',
#   'next'],
#  ['The',
#   'Student',
#   'Dis',
#   'ability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'will',
#   'liaise',
#   'with',
#   'individual',
#   'student',
#   'in',
#   'order',
#   'to',
#   'review',
#   'the',
#   'success',
#   'of',
#   'adjustment',
#   'agreed',
#   'in',
#   'Student',
#   'Support',
#   'Agreements'],
#  ['Review',
#   'will',
#   'take',
#   'place',
#   'at',
#   'a',
#   'minimum',
#   'on',
#   'an',
#   'annual',
#   'basis'],
#  [],
#  ['Monitoring',
#   'of',
#   'the',
#   'policy',
#   'The',
#   'Student',
#   'D',
#   'isability',
#   'and',
#   'Mental',
#   'Health',
#   'Coordinator',
#   'will',
#   'collate',
#   'feedback',
#   'received',
#   'from',
#   'disabled',
#   'student',
#   'in',
#   'order',
#   'to',
#   'monitor',
#   'the',
#   'effectiveness',
#   'of',
#   'the',
#   'policy',
#   'and',
#   'will',
#   'report',
#   'finding',
#   'to',
#   'the',
#   'Disability',
#   'Services',
#   'Committee'],
#  ['Student',
#   'Disability',
#   'Policy',
#   'Disability',
#   'Services',
#   'Committee',
#   'Page'],
#  ['Review',
#   'of',
#   'the',
#   'policy',
#   'The',
#   'policy',
#   'will',
#   'be',
#   'reviewed',
#   'on',
#   'a',
#   'regular',
#   'basis',
#   'at',
#   'the',
#   'Disability',
#   'Services',
#   'Committee',
#   'where',
#   'any',
#   'amendment',
#   'or',
#   'improvement',
#   'will',
#   'be',
#   'discussed'],
#  []]

# %%
#lower all cases
postfin1 = [[j.lower() for j in i] for i in postlemma]

# %%
postfin1
# Out:
# [['student',
#   'disability',
#   'policy',
#   'author',
#   'disability',
#   'officer',
#   'approved',
#   'by',
#   'directorate',
#   'on',
#   'th',
#   'june',
#   'version',
#   'reviewed',
#   'and',
#   'approved',
#   'by',
#   'senate',
#   'july',
#   'updated',
#   'disability',
#   'services',
#   'committee',
#   'may',
#   'version',
#   'reviewed',
#   'and',
#   'approved',
#   'by',
#   'senate',
#   'july',
#   'student',
#   'disability',
#   'policy',
#   'disability',
#   'services',
#   'committee',
#   'page',
#   'student',
#   'disability',
#   'policy'],
#  ['aims',
#   'and',
#   'objective',
#   'the',
#   'aim',
#   'of',
#   'this',
#   'policy',
#   'is',
#   'to',
#   'embed',
#   'a',
#   'culture',
#   'of',
#   'inclusion',
#   'for',
#   'student',
#   'with',
#   'disability'],
#  ['the',
#   'university',
#   'work',
#   'with',
#   'the',
#   'equality',
#   'acts',
#   'definition',
#   'of',
#   'a',
#   'disabled',
#   'person',
#   'a',
#   'person',
#   'ha',
#   'a',
#   'disability',
#   'if',
#   'they',
#   'have',
#   'a',
#   'physical',
#   'or',
#   'mental',
#   'impairment',
#   'that',
#   'ha',
#   'a',
#   'substantial',
#   'and',
#   'long',
#   'term',
#   'adverse',
#   'effect',
#   'on',
#   'his',
#   'or',
#   'her',
#   'ability',
#   'to',
#   'carry',
#   'out',
#   'normal',
#   'day',
#   'to',
#   'day',
#   'activity',
#   'the',
#   'objective',
#   'of',
#   'this',
#   'policy',
#   'are',
#   'to',
#   'commit',
#   'to',
#   'having',
#   'an',
#   'inclusive',
#   'environment',
#   'which',
#   'facilitates',
#   'disclosure',
#   'of',
#   'disability',
#   'and',
#   'give',
#   'all',
#   'applicant',
#   'and',
#   'student',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential',
#   'to',
#   'provide',
#   'fa',
#   'ir',
#   'and',
#   'equal',
#   'treatment',
#   'of',
#   'all',
#   'applicant',
#   'and',
#   'student',
#   'to',
#   'comply',
#   'with',
#   'the',
#   'legislative',
#   'requirement',
#   'under',
#   'the',
#   'equality',
#   'act',
#   'in',
#   'particular',
#   'the',
#   'need',
#   'to',
#   'avoid',
#   'discrimination',
#   'and',
#   'to',
#   'provide',
#   'reasonable',
#   'adjustment',
#   'for',
#   'disabled',
#   'student'],
#  [],
#  ['guiding',
#   'principle',
#   'the',
#   'student',
#   'disability',
#   'policy',
#   'is',
#   'concerned',
#   'primarily',
#   'with',
#   'ensuring',
#   'that',
#   'student',
#   'with',
#   'disability',
#   'are',
#   'given',
#   'fair',
#   'and',
#   'equal',
#   'treatment',
#   'so',
#   'that',
#   'they',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'demonstrate',
#   'and',
#   'realise',
#   'their',
#   'full',
#   'potential'],
#  ['the',
#   'policy',
#   'is',
#   'based',
#   'on',
#   'the',
#   'social',
#   'model',
#   'of',
#   'disability'],
#  [],
#  ['policy',
#   'statement',
#   'regents',
#   'university',
#   'london',
#   'will',
#   'ensure',
#   'that',
#   'the',
#   'requirement',
#   'of',
#   'those',
#   'student',
#   'who',
#   'disclose',
#   'a',
#   'disability',
#   'are',
#   'assessed',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'that',
#   'all',
#   'discussion',
#   'and',
#   'information',
#   'regarding',
#   'a',
#   'disability',
#   'are',
#   'treated',
#   'in',
#   'a',
#   'confidential',
#   'manner',
#   'and',
#   'abide',
#   'by',
#   'the',
#   'universitys',
#   'confidentiality',
#   'policy',
#   'in',
#   'the',
#   'case',
#   'of',
#   'non',
#   'standard',
#   'adjustment',
#   'for',
#   'disabled',
#   'student',
#   'the',
#   'heads',
#   'of',
#   'programmes',
#   'will',
#   'be',
#   'involved',
#   'in',
#   'any',
#   'discussion',
#   'regarding',
#   'adjustment',
#   'to',
#   'ensure',
#   'that',
#   'academic',
#   'rigour',
#   'is',
#   'maintained',
#   'and',
#   'that',
#   'the',
#   'necessary',
#   'resource',
#   'are',
#   'available'],
#  ['all',
#   'staff',
#   'and',
#   'student',
#   'at',
#   'regents',
#   'university',
#   'london',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['student',
#   'disability',
#   'policy',
#   'disability',
#   'services',
#   'committee',
#   'page'],
#  ['implementation',
#   'of',
#   'this',
#   'policy',
#   'all',
#   'staff',
#   'at',
#   'regents',
#   'university',
#   'london',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'responsible',
#   'for',
#   'implementing',
#   'this',
#   'policy'],
#  ['this',
#   'policy',
#   'will',
#   'be',
#   'available',
#   'to',
#   'all',
#   'staff',
#   'and',
#   'student',
#   'and',
#   'will',
#   'be',
#   'monitored',
#   'by',
#   'the',
#   'senate',
#   'student',
#   'experience',
#   'committee',
#   'ssec'],
#  [],
#  ['procedure',
#   'and',
#   'process',
#   'a',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'encouraged',
#   'to',
#   'disclose',
#   'their',
#   'disability',
#   'at',
#   'an',
#   'early',
#   'stage',
#   'such',
#   'a',
#   'application',
#   'or',
#   'enrolment'],
#  ['information',
#   'on',
#   'disability',
#   'disclosure',
#   'procedure',
#   'is',
#   'available',
#   'on',
#   'the',
#   'universitys',
#   'website'],
#  ['students',
#   'are',
#   'advised',
#   'to',
#   'contact',
#   'the',
#   'student',
#   'disability',
#   'and',
#   'mental',
#   'health',
#   'coordinator',
#   'so',
#   'their',
#   'support',
#   'can',
#   'be',
#   'arranged'],
#  ['a',
#   'student',
#   'with',
#   'a',
#   'disability',
#   'is',
#   'usually',
#   'required',
#   'to',
#   'provide',
#   'written',
#   'eviden',
#   'ce',
#   'of',
#   'their',
#   'disability',
#   'such',
#   'a',
#   'an',
#   'educational',
#   'psychologist',
#   'report',
#   'if',
#   'they',
#   'are',
#   'requesting',
#   'any',
#   'reasonable',
#   'adjustment'],
#  ['if',
#   'adjustment',
#   'are',
#   'agreed',
#   'a',
#   'student',
#   'support',
#   'agreement',
#   'ssa',
#   'will',
#   'be',
#   'completed',
#   'and',
#   'sent',
#   'to',
#   'the',
#   'student'],
#  ['students',
#   'are',
#   'responsible',
#   'for',
#   's',
#   'ending',
#   'their',
#   'student',
#   'support',
#   'agreement',
#   'to',
#   'relevant',
#   'staff',
#   'so',
#   'that',
#   'they',
#   'are',
#   'aware',
#   'of',
#   'their',
#   'need',
#   'and',
#   'to',
#   'ensure',
#   'that',
#   'any',
#   'necessary',
#   'adjustment',
#   'are',
#   'put',
#   'in',
#   'place'],
#  [],
#  ['measurement',
#   'of',
#   'policy',
#   'success',
#   'feedback',
#   'from',
#   'disabled',
#   'student',
#   'will',
#   'be',
#   'sought',
#   'by',
#   'the',
#   'university',
#   'and',
#   'passed',
#   'on',
#   'to',
#   'the',
#   'student',
#   'disability',
#   'and',
#   'mental',
#   'health',
#   'coordinator'],
#  ['any',
#   'student',
#   'complaint',
#   'that',
#   'relate',
#   'to',
#   'disability',
#   'issue',
#   'should',
#   'be',
#   'directed',
#   'to',
#   'the',
#   'student',
#   'disability',
#   'and',
#   'mental',
#   'health',
#   'coordinator',
#   'either',
#   'on',
#   'an',
#   'individual',
#   'basis',
#   'or',
#   'via',
#   'the',
#   'd',
#   'isability',
#   'services',
#   'committee'],
#  ['the',
#   'measure',
#   'of',
#   'success',
#   'for',
#   'this',
#   'policy',
#   'will',
#   'be',
#   'a',
#   'decrease',
#   'in',
#   'the',
#   'number',
#   'of',
#   'complaint',
#   'regarding',
#   'disability',
#   'matter',
#   'a',
#   'well',
#   'a',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'positive',
#   'feedback',
#   'received',
#   'from',
#   'one',
#   'year',
#   'to',
#   'the',
#   'next'],
#  ['the',
#   'student',
#   'dis',
#   'ability',
#   'and',
#   'mental',
#   'health',
#   'coordinator',
#   'will',
#   'liaise',
#   'with',
#   'individual',
#   'student',
#   'in',
#   'order',
#   'to',
#   'review',
#   'the',
#   'success',
#   'of',
#   'adjustment',
#   'agreed',
#   'in',
#   'student',
#   'support',
#   'agreements'],
#  ['review',
#   'will',
#   'take',
#   'place',
#   'at',
#   'a',
#   'minimum',
#   'on',
#   'an',
#   'annual',
#   'basis'],
#  [],
#  ['monitoring',
#   'of',
#   'the',
#   'policy',
#   'the',
#   'student',
#   'd',
#   'isability',
#   'and',
#   'mental',
#   'health',
#   'coordinator',
#   'will',
#   'collate',
#   'feedback',
#   'received',
#   'from',
#   'disabled',
#   'student',
#   'in',
#   'order',
#   'to',
#   'monitor',
#   'the',
#   'effectiveness',
#   'of',
#   'the',
#   'policy',
#   'and',
#   'will',
#   'report',
#   'finding',
#   'to',
#   'the',
#   'disability',
#   'services',
#   'committee'],
#  ['student',
#   'disability',
#   'policy',
#   'disability',
#   'services',
#   'committee',
#   'page'],
#  ['review',
#   'of',
#   'the',
#   'policy',
#   'the',
#   'policy',
#   'will',
#   'be',
#   'reviewed',
#   'on',
#   'a',
#   'regular',
#   'basis',
#   'at',
#   'the',
#   'disability',
#   'services',
#   'committee',
#   'where',
#   'any',
#   'amendment',
#   'or',
#   'improvement',
#   'will',
#   'be',
#   'discussed'],
#  []]

# %%
# replace the old comments with the new pre-processed comments
data = {'Sentence': postfin1}
p1 = pd.DataFrame(data)

# %%
p1
# Out:
#                                              Sentence
# 0   [student, disability, policy, author, disabili...
# 1   [aims, and, objective, the, aim, of, this, pol...
# 2   [the, university, work, with, the, equality, a...
# 3                                                  []
# 4   [guiding, principle, the, student, disability,...
# 5   [the, policy, is, based, on, the, social, mode...
# 6                                                  []
# 7   [policy, statement, regents, university, londo...
# 8   [all, staff, and, student, at, regents, univer...
# 9   [student, disability, policy, disability, serv...
# 10  [implementation, of, this, policy, all, staff,...
# 11  [this, policy, will, be, available, to, all, s...
# 12                                                 []
# 13  [procedure, and, process, a, student, with, a,...
# 14  [information, on, disability, disclosure, proc...
# 15  [students, are, advised, to, contact, the, stu...
# 16  [a, student, with, a, disability, is, usually,...
# 17  [if, adjustment, are, agreed, a, student, supp...
# 18  [students, are, responsible, for, s, ending, t...
# 19                                                 []
# 20  [measurement, of, policy, success, feedback, f...
# 21  [any, student, complaint, that, relate, to, di...
# 22  [the, measure, of, success, for, this, policy,...
# 23  [the, student, dis, ability, and, mental, heal...
# 24  [review, will, take, place, at, a, minimum, on...
# 25                                                 []
# 26  [monitoring, of, the, policy, the, student, d,...
# 27  [student, disability, policy, disability, serv...
# 28  [review, of, the, policy, the, policy, will, b...
# 29                                                 []

# %%
# set display options to show all columns and rows in the dataframe so i can quickly scan through
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# display the dataframe
print(p1)
# Out:
#                                              Sentence
# 0   [student, disability, policy, author, disabili...
# 1   [aims, and, objective, the, aim, of, this, pol...
# 2   [the, university, work, with, the, equality, a...
# 3                                                  []
# 4   [guiding, principle, the, student, disability,...
# 5   [the, policy, is, based, on, the, social, mode...
# 6                                                  []
# 7   [policy, statement, regents, university, londo...
# 8   [all, staff, and, student, at, regents, univer...
# 9   [student, disability, policy, disability, serv...
# 10  [implementation, of, this, policy, all, staff,...
# 11  [this, policy, will, be, available, to, all, s...
# 12                                                 []
# 13  [procedure, and, process, a, student, with, a,...
# 14  [information, on, disability, disclosure, proc...
# 15  [students, are, advised, to, contact, the, stu...
# 16  [a, student, with, a, disability, is, usually,...
# 17  [if, adjustment, are, agreed, a, student, supp...
# 18  [students, are, responsible, for, s, ending, t...
# 19                                                 []
# 20  [measurement, of, policy, success, feedback, f...
# 21  [any, student, complaint, that, relate, to, di...
# 22  [the, measure, of, success, for, this, policy,...
# 23  [the, student, dis, ability, and, mental, heal...
# 24  [review, will, take, place, at, a, minimum, on...
# 25                                                 []
# 26  [monitoring, of, the, policy, the, student, d,...
# 27  [student, disability, policy, disability, serv...
# 28  [review, of, the, policy, the, policy, will, b...
# 29                                                 []

# %%
# Doing so helped me notice that there are a bunch of empty lists, so we will remove those now
# find rows with empty lists in the 'Sentence' column
rows_with_empty_lists = p1[p1['Sentence'].apply(len) == 0]

# display rows with empty lists
print(rows_with_empty_lists)
# Out:
#    Sentence
# 3        []
# 6        []
# 12       []
# 19       []
# 25       []
# 29       []

# %%
# remove rows with empty lists in the 'Sentence' column
p1 = p1[p1['Sentence'].apply(len) > 0]

# reset index
p1.reset_index(drop=True, inplace=True)

# display the modified DataFrame
print(p1)
# Out:
#                                              Sentence
# 0   [student, disability, policy, author, disabili...
# 1   [aims, and, objective, the, aim, of, this, pol...
# 2   [the, university, work, with, the, equality, a...
# 3   [guiding, principle, the, student, disability,...
# 4   [the, policy, is, based, on, the, social, mode...
# 5   [policy, statement, regents, university, londo...
# 6   [all, staff, and, student, at, regents, univer...
# 7   [student, disability, policy, disability, serv...
# 8   [implementation, of, this, policy, all, staff,...
# 9   [this, policy, will, be, available, to, all, s...
# 10  [procedure, and, process, a, student, with, a,...
# 11  [information, on, disability, disclosure, proc...
# 12  [students, are, advised, to, contact, the, stu...
# 13  [a, student, with, a, disability, is, usually,...
# 14  [if, adjustment, are, agreed, a, student, supp...
# 15  [students, are, responsible, for, s, ending, t...
# 16  [measurement, of, policy, success, feedback, f...
# 17  [any, student, complaint, that, relate, to, di...
# 18  [the, measure, of, success, for, this, policy,...
# 19  [the, student, dis, ability, and, mental, heal...
# 20  [review, will, take, place, at, a, minimum, on...
# 21  [monitoring, of, the, policy, the, student, d,...
# 22  [student, disability, policy, disability, serv...
# 23  [review, of, the, policy, the, policy, will, b...

# %%
# just to check it is still all good in this format too (can't be too careful)
p1
# Out:
#                                              Sentence
# 0   [student, disability, policy, author, disabili...
# 1   [aims, and, objective, the, aim, of, this, pol...
# 2   [the, university, work, with, the, equality, a...
# 3   [guiding, principle, the, student, disability,...
# 4   [the, policy, is, based, on, the, social, mode...
# 5   [policy, statement, regents, university, londo...
# 6   [all, staff, and, student, at, regents, univer...
# 7   [student, disability, policy, disability, serv...
# 8   [implementation, of, this, policy, all, staff,...
# 9   [this, policy, will, be, available, to, all, s...
# 10  [procedure, and, process, a, student, with, a,...
# 11  [information, on, disability, disclosure, proc...
# 12  [students, are, advised, to, contact, the, stu...
# 13  [a, student, with, a, disability, is, usually,...
# 14  [if, adjustment, are, agreed, a, student, supp...
# 15  [students, are, responsible, for, s, ending, t...
# 16  [measurement, of, policy, success, feedback, f...
# 17  [any, student, complaint, that, relate, to, di...
# 18  [the, measure, of, success, for, this, policy,...
# 19  [the, student, dis, ability, and, mental, heal...
# 20  [review, will, take, place, at, a, minimum, on...
# 21  [monitoring, of, the, policy, the, student, d,...
# 22  [student, disability, policy, disability, serv...
# 23  [review, of, the, policy, the, policy, will, b...

# %%
# save the dataset to be able to use in analysis

#export to excel file
p1.to_excel('p5.xlsx')

#export to csv file
p1.to_csv('p5.csv', index=False)
